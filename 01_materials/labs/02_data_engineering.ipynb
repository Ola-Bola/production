# %%
# %load_ext dotenv
# %dotenv
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %% [markdown]
# # What are we doing?
#
# ## Objectives
#
#
# * Build a data pipeline that downloads price data from the internet, stores it locally, transforms it into return data, and stores the feature set.
#     - Getting the data.
#     - Schemas and index in Dask.
#
# * Explore the parquet format.
#     - Reading and writing parquet files.
#     - Read datasets that are stored in distributed files.
#     - Discuss Dask vs. Pandas as a small example of big vs small data.
#
# * Discuss the use of environment variables for settings.
# * Discuss how to use Jupyter notebooks and source code concurrently.
# * Logging and using a standard logger.
#
# ## About the Data
#
# + We will download the prices for a list of stocks.
# + The source is Yahoo Finance, and the data, along with its description, is available via [Kaggle](https://www.kaggle.com/datasets/jacksoncrow/stock-market-dataset).
#
#
# ## Medallion Architecture
#
# + The architecture that we are thinking about is called Medallion by [DataBricks](https://www.databricks.com/glossary/medallion-architecture). It is an ELT type of thinking, although our data is well-structured.
#
# <div>
# <image src="./images/02_medallion_architecture.png" height=300>
# </div>
#
# + In our case, we would like to optimize the number of times that we download data from the internet.
# + Ultimately, we will build a pipeline manager class to control the process of obtaining and transforming our data.
#
# <div>
# <image src="./images/02_target_pipeline_manager.png" height=250>
# </div>

# %% [markdown]
# # Download Data
#
# Download the [Stock Market Dataset from Kaggle](https://www.kaggle.com/datasets/jacksoncrow/stock-market-dataset). Note that you may be required to register for a free account. Alternatively, download the file from [this location](https://drive.google.com/drive/folders/1AA4gapDLpI194TGce1bY25sd91Km-tU3?usp=drive_link).
#
# + Extract stock prices (not ETFs) into the directory: `./05_src/data/prices_csv/`.
# + To be clear, your folder structure should include the path `05_src/data/prices_csv/stocks`.

# %% [markdown]
# The command `%run update_path.py` runs a local script that adds the repository's `./05_src/` directory to the Notebook's kernel path. This way, we can use our modules within the notebook.

# %%
# %run update_path.py

# %% [markdown]
# To load the historical price data for stocks and ETFs, use the code below. Notice the following:
#
# + Libraries are ordered from high-level to low-level libraries from the package manager. Local modules are imported at the end.
# + The function `get_logger()` is called with `__name__` as recommended by [Python's documentation](https://docs.python.org/2/howto/logging.html#logging-advanced-tutorial).

# %%
from glob import glob
import os
import pandas as pd
import random

from utils.logger import get_logger
_logs = get_logger(__name__)

# %% [markdown]
# + The [`glob` module](https://docs.python.org/3/library/glob.html) is used for finding path names that match specified patterns using Unix shell-style rules.
#
# + Notice that the module `glob` contains a function called `glob`; therefore, we used `from glob import glob` above.
#
# + The path in which we are searching for our csv files is produced by joining two strings:
#
#
#
#     - The value of the environment variable 'SRC_DIR' that we obtain with `os.getenv('SRC_DIR')` (this variable points to ./05_src).
#
#     - Another string given by "data/prices_csv/stocks/*.csv".
#
#     - Both strings are combined into an OS-consistent path using `os.path.join(...)`.
#
# + After we know the location of all our files, we sample a subset of them.

# %%
stock_files = glob(os.path.join(os.getenv('SRC_DIR'), "data/prices_csv/stocks/*.csv"))
_logs.info(f'Found {len(stock_files)} stock price files.')

random.seed(42)
n_sample = 60
stock_files = random.sample(stock_files, n_sample)
_logs.info(f'Sampled {n_sample} stock price files for processing. The files are: {stock_files   }')
# Out:
# 2026-01-28 15:53:04,035, 3619788285.py, 2, INFO, Found 5884 stock price files.
# 2026-01-28 15:53:04,052, 3619788285.py, 7, INFO, Sampled 60 stock price files for processing. The files are: ['../../05_src/data/prices_csv/stocks\\TNC.csv', '../../05_src/data/prices_csv/stocks\\CBB.csv', '../../05_src/data/prices_csv/stocks\\ALDX.csv', '../../05_src/data/prices_csv/stocks\\GLADD.csv', '../../05_src/data/prices_csv/stocks\\FIXX.csv', '../../05_src/data/prices_csv/stocks\\ETJ.csv', '../../05_src/data/prices_csv/stocks\\CMCTP.csv', '../../05_src/data/prices_csv/stocks\\BWG.csv', '../../05_src/data/prices_csv/stocks\\VIAC.csv', '../../05_src/data/prices_csv/stocks\\REI.csv', '../../05_src/data/prices_csv/stocks\\BLPH.csv', '../../05_src/data/prices_csv/stocks\\SMG.csv', '../../05_src/data/prices_csv/stocks\\MOH.csv', '../../05_src/data/prices_csv/stocks\\AMH.csv', '../../05_src/data/prices_csv/stocks\\AMAL.csv', '../../05_src/data/prices_csv/stocks\\BPYPN.csv', '../../05_src/data/prices_csv/stocks\\ERH.csv', '../../05_src/data/prices_csv/stocks\\FAMI.csv', '../../05_src/data/prices_csv/stocks\\PFG.csv', '../../05_src/data/prices_csv/stocks\\SPXC.csv', '../../05_src/data/prices_csv/stocks\\ALL.csv', '../../05_src/data/prices_csv/stocks\\RTTR.csv', '../../05_src/data/prices_csv/stocks\\EARN.csv', '../../05_src/data/prices_csv/stocks\\ZIXI.csv', '../../05_src/data/prices_csv/stocks\\TSN.csv', '../../05_src/data/prices_csv/stocks\\WST.csv', '../../05_src/data/prices_csv/stocks\\REG.csv', '../../05_src/data/prices_csv/stocks\\MNK.csv', '../../05_src/data/prices_csv/stocks\\ESGR.csv', '../../05_src/data/prices_csv/stocks\\NGD.csv', '../../05_src/data/prices_csv/stocks\\SLRX.csv', '../../05_src/data/prices_csv/stocks\\GLW.csv', '../../05_src/data/prices_csv/stocks\\ACN.csv', '../../05_src/data/prices_csv/stocks\\CSSE.csv', '../../05_src/data/prices_csv/stocks\\WORK.csv', '../../05_src/data/prices_csv/stocks\\MOS.csv', '../../05_src/data/prices_csv/stocks\\IPWR.csv', '../../05_src/data/prices_csv/stocks\\GLUU.csv', '../../05_src/data/prices_csv/stocks\\CRMT.csv', '../../05_src/data/prices_csv/stocks\\EOLS.csv', '../../05_src/data/prices_csv/stocks\\INSU.csv', '../../05_src/data/prices_csv/stocks\\BWEN.csv', '../../05_src/data/prices_csv/stocks\\BPMX.csv', '../../05_src/data/prices_csv/stocks\\LH.csv', '../../05_src/data/prices_csv/stocks\\BRQS.csv', '../../05_src/data/prices_csv/stocks\\KALU.csv', '../../05_src/data/prices_csv/stocks\\ITCB.csv', '../../05_src/data/prices_csv/stocks\\SRE.csv', '../../05_src/data/prices_csv/stocks\\GAZ.csv', '../../05_src/data/prices_csv/stocks\\AQMS.csv', '../../05_src/data/prices_csv/stocks\\NPK.csv', '../../05_src/data/prices_csv/stocks\\QRHC.csv', '../../05_src/data/prices_csv/stocks\\CGEN.csv', '../../05_src/data/prices_csv/stocks\\LEVL.csv', '../../05_src/data/prices_csv/stocks\\BGS.csv', '../../05_src/data/prices_csv/stocks\\RIV.csv', '../../05_src/data/prices_csv/stocks\\GURE.csv', '../../05_src/data/prices_csv/stocks\\TEF.csv', '../../05_src/data/prices_csv/stocks\\SYNH.csv', '../../05_src/data/prices_csv/stocks\\KEY.csv']

# %% [markdown]
# We load the sampled files into dataframes and concatenate them:
#
# + Start with an empty list.
# + Read each file into a dataframe and [`append()` it to the list](https://docs.python.org/3/tutorial/datastructures.html#more-on-lists). Notice that `append()` is an in-place operation (it does not return a list, it modifies the list in place).
# + Finally, we concatenate all dataframes along the vertical axis (`axis=0`) using [`pd.concat()`](https://pandas.pydata.org/docs/user_guide/merging.html#concat).
# + Notice that we do not concatenate each time that we load a dataframe. According to [Panda's documentation](https://pandas.pydata.org/docs/user_guide/merging.html#concat):
#
# > "`concat()` makes a full copy of the data, and iteratively reusing `concat()` can create unnecessary copies. Collect all DataFrame or Series objects in a list before using `concat()`."

# %%
dt_list = []
for s_file in stock_files:
    _logs.info(f"Reading file: {s_file}")
    dt = pd.read_csv(s_file).assign(
        source = os.path.basename(s_file),
        ticker = os.path.basename(s_file).replace('.csv', ''),
        Date = lambda x: pd.to_datetime(x['Date'])
    )
    dt_list.append(dt)
stock_prices = pd.concat(dt_list, axis = 0, ignore_index = True)
# Out:
# 2026-01-28 15:53:07,543, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\TNC.csv
# 2026-01-28 15:53:07,753, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\CBB.csv
# 2026-01-28 15:53:07,793, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\ALDX.csv
# 2026-01-28 15:53:07,827, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\GLADD.csv
# 2026-01-28 15:53:07,859, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\FIXX.csv
# 2026-01-28 15:53:07,886, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\ETJ.csv
# 2026-01-28 15:53:07,938, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\CMCTP.csv
# 2026-01-28 15:53:07,952, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\BWG.csv
# 2026-01-28 15:53:07,993, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\VIAC.csv
# 2026-01-28 15:53:08,040, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\REI.csv
# 2026-01-28 15:53:08,082, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\BLPH.csv
# 2026-01-28 15:53:08,108, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\SMG.csv
# 2026-01-28 15:53:08,157, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\MOH.csv
# 2026-01-28 15:53:08,205, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\AMH.csv
# 2026-01-28 15:53:08,244, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\AMAL.csv
# 2026-01-28 15:53:08,272, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\BPYPN.csv
# 2026-01-28 15:53:08,313, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\ERH.csv
# 2026-01-28 15:53:08,391, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\FAMI.csv
# 2026-01-28 15:53:08,432, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\PFG.csv
# 2026-01-28 15:53:08,548, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\SPXC.csv
# 2026-01-28 15:53:08,688, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\ALL.csv
# 2026-01-28 15:53:08,770, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\RTTR.csv
# 2026-01-28 15:53:08,844, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\EARN.csv
# 2026-01-28 15:53:08,897, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\ZIXI.csv
# 2026-01-28 15:53:08,992, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\TSN.csv
# 2026-01-28 15:53:09,095, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\WST.csv
# 2026-01-28 15:53:09,195, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\REG.csv
# 2026-01-28 15:53:09,279, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\MNK.csv
# 2026-01-28 15:53:09,354, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\ESGR.csv
# 2026-01-28 15:53:09,446, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\NGD.csv
# 2026-01-28 15:53:09,534, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\SLRX.csv
# 2026-01-28 15:53:09,600, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\GLW.csv
# 2026-01-28 15:53:09,717, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\ACN.csv
# 2026-01-28 15:53:09,804, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\CSSE.csv
# 2026-01-28 15:53:09,870, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\WORK.csv
# 2026-01-28 15:53:09,935, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\MOS.csv
# 2026-01-28 15:53:10,037, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\IPWR.csv
# 2026-01-28 15:53:10,122, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\GLUU.csv
# 2026-01-28 15:53:10,235, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\CRMT.csv
# 2026-01-28 15:53:10,335, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\EOLS.csv
# 2026-01-28 15:53:10,403, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\INSU.csv
# 2026-01-28 15:53:10,469, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\BWEN.csv
# 2026-01-28 15:53:10,568, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\BPMX.csv
# 2026-01-28 15:53:10,760, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\LH.csv
# 2026-01-28 15:53:10,885, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\BRQS.csv
# 2026-01-28 15:53:10,962, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\KALU.csv
# 2026-01-28 15:53:11,086, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\ITCB.csv
# 2026-01-28 15:53:11,200, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\SRE.csv
# 2026-01-28 15:53:11,321, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\GAZ.csv
# 2026-01-28 15:53:11,435, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\AQMS.csv
# 2026-01-28 15:53:11,530, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\NPK.csv
# 2026-01-28 15:53:11,675, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\QRHC.csv
# 2026-01-28 15:53:11,785, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\CGEN.csv
# 2026-01-28 15:53:11,902, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\LEVL.csv
# 2026-01-28 15:53:11,986, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\BGS.csv
# 2026-01-28 15:53:12,085, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\RIV.csv
# 2026-01-28 15:53:12,172, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\GURE.csv
# 2026-01-28 15:53:12,260, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\TEF.csv
# 2026-01-28 15:53:12,385, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\SYNH.csv
# 2026-01-28 15:53:12,473, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\KEY.csv

# %% [markdown]
# Verify the structure of the `stock_prices` data using the [`info()` dataframe method](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.info.html):

# %%
stock_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239659 entries, 0 to 239658
# Data columns (total 9 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Date       239659 non-null  datetime64[ns]
#  1   Open       239656 non-null  float64
#  2   High       239656 non-null  float64
#  3   Low        239656 non-null  float64
#  4   Close      239656 non-null  float64
#  5   Adj Close  239656 non-null  float64
#  6   Volume     239656 non-null  float64
#  7   source     239659 non-null  object
#  8   ticker     239659 non-null  object
# dtypes: datetime64[ns](1), float64(6), object(2)
# memory usage: 16.5+ MB

# %% [markdown]
# We can subset our ticker data set using standard indexing techniques. Good references for this type of data manipulation are:
#
# + [Panda's Documentation](https://pandas.pydata.org/docs/user_guide/indexing.html#indexing-and-selecting-data).
# + [Panda's Cookbook](https://pandas.pydata.org/docs/user_guide/cookbook.html#cookbook-selection).

# %% [markdown]
# From the subset data frame, select one column and convert to list.

# %%
select_tickers = stock_prices['ticker'].unique().tolist()
select_tickers
# Out:
# ['TNC',
#  'CBB',
#  'ALDX',
#  'GLADD',
#  'FIXX',
#  'ETJ',
#  'CMCTP',
#  'BWG',
#  'VIAC',
#  'REI',
#  'BLPH',
#  'SMG',
#  'MOH',
#  'AMH',
#  'AMAL',
#  'BPYPN',
#  'ERH',
#  'FAMI',
#  'PFG',
#  'SPXC',
#  'ALL',
#  'RTTR',
#  'EARN',
#  'ZIXI',
#  'TSN',
#  'WST',
#  'REG',
#  'MNK',
#  'ESGR',
#  'NGD',
#  'SLRX',
#  'GLW',
#  'ACN',
#  'CSSE',
#  'WORK',
#  'MOS',
#  'IPWR',
#  'GLUU',
#  'CRMT',
#  'EOLS',
#  'INSU',
#  'BWEN',
#  'BPMX',
#  'LH',
#  'BRQS',
#  'KALU',
#  'ITCB',
#  'SRE',
#  'GAZ',
#  'AQMS',
#  'NPK',
#  'QRHC',
#  'CGEN',
#  'LEVL',
#  'BGS',
#  'RIV',
#  'GURE',
#  'TEF',
#  'SYNH',
#  'KEY']

# %% [markdown]
# # Storing Data in CSV
#
# + We have some data. How do we store it?
# + We can compare two options, CSV and Parquet, by measuring their performance:
#
#     - Time to save: We will measure time by using the `time` library.
#     - Space required on drive: We will use the custom function below.

# %%
def get_dir_size(path='.'):
    '''Returns the total size of files contained in path.'''
    total = 0
    with os.scandir(path) as it:
        for entry in it:
            if entry.is_file():
                total += entry.stat().st_size
            elif entry.is_dir():
                total += get_dir_size(entry.path)
    return total

# %% [markdown]
# Load the specification of a temporary directory from the environment  and create a subdirectory in it called "csv":
#
# + Use `os.getenv("TEMP_DATA")` to obtain the desired location of the temporary folder from an environment variable.
# + If the subdirectory exists, delete it using `shutil.rmtree()`; the flag `ignore_errors=True` helps us in case the subdirectory does not exist (for instance, in the first run).
# + Create a directory with path given by `csv_dir` using `os.makedirs()`; the flag `exist_ok=True` indicates that if the directory already exists, then the function will do nothing.
# + Finally, create the stock price file location, `stock_csv`, which will be used to create the csv file.

# %%
import shutil

temp = os.getenv("TEMP_DATA")
csv_dir = os.path.join(temp, "csv")

shutil.rmtree(csv_dir, ignore_errors=True)
os.makedirs(csv_dir, exist_ok=True)
stock_csv = os.path.join(csv_dir, "stock_px.csv")

# %% [markdown]
# Save the concatenated dataframe to a CSV file. We measure the time elapsed by storing the start and end times, then we calculate their difference in seconds.

# %%
import time

start = time.time()
stock_prices.to_csv(stock_csv, index = False)
end = time.time()

_logs.info(f'Writing data ({stock_prices.shape}) to csv took {end - start} seconds.')
_logs.info(f'CSV file size { os.path.getsize(stock_csv)*1e-6 } MB')
# Out:
# 2026-01-28 15:53:40,515, 807204384.py, 7, INFO, Writing data ((239659, 9)) to csv took 2.866173028945923 seconds.
# 2026-01-28 15:53:40,518, 807204384.py, 8, INFO, CSV file size 26.618403999999998 MB

# %% [markdown]
# ## Save Data to Parquet
#
# ### Notes on Dask
#
# We could use Pandas to save the data directly into Parquet files. However, we will use a different approach by applying the [Dask framework](https://www.dask.org/). Dask provides functionality for working with datasets that do not fit in memory and parallelization to speed up computation. A few notes on Dask and Pandas:
#
# - Pandas, Parquet, and Arrow:
#
#     + We can work with large datasets and Parquet files in Pandas, but we will generally be limited by the amount of data that can fit in our computer's memory.
#     + Pandas can write Parquet files using a PyArrow backend. In fact, recent versions of Pandas support PyArrow data types, and future versions will require a PyArrow backend.
#     + The PyArrow library is an interface between Python and the Apache Arrow project. In particular, the [Parquet data format](https://parquet.apache.org/) and [Arrow](https://arrow.apache.org/docs/python/parquet.html) are Apache projects.
#
# - Dask
#
#     + Dask is much more than an interface to Arrow: Dask provides parallel and distributed computing on Pandas-like dataframes.
#     + Dask is also relatively easy to use as it mimics Pandas' API.
#     + Dask allows us to work with larger datasets than Pandas. In a sense, it is an intermediate step between Pandas and big-data frameworks like Spark (or Databricks).
#     + If you are familiar with Pandas, a good introduction is [10 Minutes to Dask](https://docs.dask.org/en/stable/10-minutes-to-dask.html).

# %%
import dask.dataframe as dd

parquet_dir = os.path.join(temp, "parquet")
shutil.rmtree(parquet_dir, ignore_errors=True)
os.makedirs(parquet_dir, exist_ok=True)

# %%
px_dd = dd.from_pandas(stock_prices, npartitions = len(select_tickers))

start = time.time()
px_dd.to_parquet(parquet_dir, engine = "pyarrow")
end = time.time()

_logs.info(f'Writing dd ({stock_prices.shape}) to parquet took {end - start} seconds.')
_logs.info(f'Parquet file size { get_dir_size(parquet_dir)*1e-6 } MB')
# Out:
# 2026-01-28 15:53:50,062, 817812245.py, 7, INFO, Writing dd ((239659, 9)) to parquet took 0.39056396484375 seconds.
# 2026-01-28 15:53:50,065, 817812245.py, 8, INFO, Parquet file size 9.713384999999999 MB

# %% [markdown]
# ### Pandas, Dask, and Parquet
#
# The distinction of Pandas Dataframes, Dask Dataframes, and Parquet files is important:
#
# + Pandas dataframes combine the functionality of [NumPy](https://numpy.org/) (efficient vector operations, especially vector algebra) with a concise data manipulation framework that allows us to create columns of different data types (NumPy only allows single-type matrices), database-like operations (such as filtering rows, subsetting columns, and joining different dataframes).
# + Dask dataframes extend the functionality of Pandas dataframes beyond the confines of available memory and implement parallelized operations, among other benefits.
# + Parquet files are a file format. Parquet files can be created by Pandas and Dask, but Dask offers a superior interface. Parquet files are immutable: once written, they cannot be modified.
# + Parquet and Dask are not the same: Parquet is a file format that can be accessed by many applications and programming languages (Python, R, Power BI, etc.), while Dask is a Python package for working with large datasets using distributed computation.

# %% [markdown]
# ### Dask is Powerful, but not Infallible
#
# It is tempting to think of Dask as a super-Pandas, but each package has its advantages and disadvantages.
#
# + Dask is not good at everything (see [Dask DataFrames Best Practices](https://docs.dask.org/en/stable/dataframe-best-practices.html)).
# + A useful and somewhat idiosyncratic comparison of various data manipulation frameworks is shown below (from [DataFrames at Scale Comparison: TPC-H](https://docs.coiled.io/blog/tpch.html#when-to-use-duckdb-vs-polars-vs-dask-vs-spark))
#
# Concept              | Spark | Dask | DuckDB | Polars
# ---------------------|-------|------|--------|--------
# Fast Locally         | ❌    | 🤔  | ✅     | ✅
# Fast on Cloud (1 TB) | ✅    | ✅  | ✅     | ❌
# Fast on Cloud (10 TB)| ❌    | ✅  | ✅     | ❌
# Scales Out           | ✅    | ✅  | ❌     | ❌
# SQL                  | ✅    | 🤔  | ✅     | 🤔
# More than SQL        | ✅    | ✅  | ❌     | ✅
# Sensible Defaults    | ❌    | ✅  | ✅     | ✅
#
#
# ### Dask Best Practices
#
# Parallelism brings extra complexity and overhead. Here are a few ideas to help you decide when to use Dask (from [Dask's Best Practices](https://docs.dask.org/en/stable/best-practices.html)):
#
# #### Small is Better
#
# + Start small: if possible, use Pandas. Also, try to reduce your data using aggregation, then use Pandas.
# + More generally, NumPy, Pandas, and Scikit-Learn may have faster functions for what you need. Consult the relevant documentation, experiment, and/or consult with a colleague or expert.
#
# #### Index with Care
#
# + Use the index: it is beneficial to have a well-defined index in Dask DataFrames, as it may speed up searching (filtering) the data. A one-dimensional index is allowed.
# + Minimize full-data shuffling as much as possible: indexing is an expensive operation.
#
# ### Consider the Cost of Joins
#
# + Consider cases such as small-to-large joins, where the small dataframe fits in memory, but the large one does not. The small dataframe can be Pandas, while the larger one is a Dask dataframe.
# + Some joins are more expensive than others.
#
#     * Not expensive:
#
#         - Join a Dask DataFrame with a Pandas DataFrame.
#         - Join a Dask DataFrame with another Dask DataFrame of a single partition.
#         - Join Dask DataFrames along their indexes.
#
#     * Expensive:
#
#         - Join Dask DataFrames along columns that are not their index.

# %% [markdown]
# # How Do We Store Prices?
#
# + We can store our data as a single blob.
#
#   - This can be difficult to maintain, especially because parquet files are immutable.
#   - Using a single file, we would need to recreate the complete file any time that we update it.
#
# + An alternative strategy is to organize data files by ticker and date:
#
#   - We can create one file per ticker and month (or any other suitable frequency).
#   - Under this approach, we would only need to recreate the latest month's file at any update.

# %%
# CLean up before start
PRICE_DATA = os.getenv("PRICE_DATA")
import shutil
if os.path.exists(PRICE_DATA):
    shutil.rmtree(PRICE_DATA)

# %%
stock_prices.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'source',
#        'ticker'],
#       dtype='object')

# %%
for ticker in stock_prices['ticker'].unique():
    # Filter data for ticker
    # Notice that these are Pandas dataframes
    _logs.info(f'Processing ticker: {ticker}')
    ticker_dt = stock_prices[stock_prices['ticker'] == ticker]
    ticker_dt = ticker_dt.assign(Year = ticker_dt.Date.dt.year)
    for yr in ticker_dt['Year'].unique():
        _logs.info(f'Processing year {yr} for ticker {ticker}.')
        # Filter data for year and convert to Dask dataframe
        yr_dd = dd.from_pandas(ticker_dt[ticker_dt['Year'] == yr],2)
        
        # Define path and create directories if not exist
        yr_path = os.path.join(PRICE_DATA, ticker, f"{ticker}_{yr}")
        os.makedirs(os.path.dirname(yr_path), exist_ok=True)
        _logs.info(f'Writing data to path: {yr_path}')

        # Write to Parquet
        yr_dd.to_parquet(yr_path, engine = "pyarrow")
# Out:
# 2026-01-28 15:54:11,992, 2113979629.py, 4, INFO, Processing ticker: TNC
# 2026-01-28 15:54:12,043, 2113979629.py, 8, INFO, Processing year 1973 for ticker TNC.
# 2026-01-28 15:54:12,058, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1973
# 2026-01-28 15:54:12,085, 2113979629.py, 8, INFO, Processing year 1974 for ticker TNC.
# 2026-01-28 15:54:12,085, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1974
# 2026-01-28 15:54:12,114, 2113979629.py, 8, INFO, Processing year 1975 for ticker TNC.
# 2026-01-28 15:54:12,117, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1975
# 2026-01-28 15:54:12,138, 2113979629.py, 8, INFO, Processing year 1976 for ticker TNC.
# 2026-01-28 15:54:12,138, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1976
# 2026-01-28 15:54:12,168, 2113979629.py, 8, INFO, Processing year 1977 for ticker TNC.
# 2026-01-28 15:54:12,173, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1977
# 2026-01-28 15:54:12,190, 2113979629.py, 8, INFO, Processing year 1978 for ticker TNC.
# 2026-01-28 15:54:12,200, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1978
# 2026-01-28 15:54:12,221, 2113979629.py, 8, INFO, Processing year 1979 for ticker TNC.
# 2026-01-28 15:54:12,225, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1979
# 2026-01-28 15:54:12,250, 2113979629.py, 8, INFO, Processing year 1980 for ticker TNC.
# 2026-01-28 15:54:12,254, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1980
# 2026-01-28 15:54:12,274, 2113979629.py, 8, INFO, Processing year 1981 for ticker TNC.
# 2026-01-28 15:54:12,274, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1981
# 2026-01-28 15:54:12,301, 2113979629.py, 8, INFO, Processing year 1982 for ticker TNC.
# 2026-01-28 15:54:12,305, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1982
# 2026-01-28 15:54:12,322, 2113979629.py, 8, INFO, Processing year 1983 for ticker TNC.
# 2026-01-28 15:54:12,322, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1983
# 2026-01-28 15:54:12,340, 2113979629.py, 8, INFO, Processing year 1984 for ticker TNC.
# 2026-01-28 15:54:12,353, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1984
# 2026-01-28 15:54:12,372, 2113979629.py, 8, INFO, Processing year 1985 for ticker TNC.
# 2026-01-28 15:54:12,372, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1985
# 2026-01-28 15:54:12,414, 2113979629.py, 8, INFO, Processing year 1986 for ticker TNC.
# 2026-01-28 15:54:12,418, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1986
# 2026-01-28 15:54:12,436, 2113979629.py, 8, INFO, Processing year 1987 for ticker TNC.
# 2026-01-28 15:54:12,436, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1987
# 2026-01-28 15:54:12,456, 2113979629.py, 8, INFO, Processing year 1988 for ticker TNC.
# 2026-01-28 15:54:12,468, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1988
# 2026-01-28 15:54:12,486, 2113979629.py, 8, INFO, Processing year 1989 for ticker TNC.
# 2026-01-28 15:54:12,486, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1989
# 2026-01-28 15:54:12,513, 2113979629.py, 8, INFO, Processing year 1990 for ticker TNC.
# 2026-01-28 15:54:12,518, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1990
# 2026-01-28 15:54:12,537, 2113979629.py, 8, INFO, Processing year 1991 for ticker TNC.
# 2026-01-28 15:54:12,537, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1991
# 2026-01-28 15:54:12,558, 2113979629.py, 8, INFO, Processing year 1992 for ticker TNC.
# 2026-01-28 15:54:12,558, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1992
# 2026-01-28 15:54:12,586, 2113979629.py, 8, INFO, Processing year 1993 for ticker TNC.
# 2026-01-28 15:54:12,591, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1993
# 2026-01-28 15:54:12,611, 2113979629.py, 8, INFO, Processing year 1994 for ticker TNC.
# 2026-01-28 15:54:12,614, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1994
# 2026-01-28 15:54:12,633, 2113979629.py, 8, INFO, Processing year 1995 for ticker TNC.
# 2026-01-28 15:54:12,638, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1995
# 2026-01-28 15:54:12,658, 2113979629.py, 8, INFO, Processing year 1996 for ticker TNC.
# 2026-01-28 15:54:12,662, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1996
# 2026-01-28 15:54:12,685, 2113979629.py, 8, INFO, Processing year 1997 for ticker TNC.
# 2026-01-28 15:54:12,688, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1997
# 2026-01-28 15:54:12,709, 2113979629.py, 8, INFO, Processing year 1998 for ticker TNC.
# 2026-01-28 15:54:12,713, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1998
# 2026-01-28 15:54:12,738, 2113979629.py, 8, INFO, Processing year 1999 for ticker TNC.
# 2026-01-28 15:54:12,741, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1999
# 2026-01-28 15:54:12,764, 2113979629.py, 8, INFO, Processing year 2000 for ticker TNC.
# 2026-01-28 15:54:12,769, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2000
# 2026-01-28 15:54:12,790, 2113979629.py, 8, INFO, Processing year 2001 for ticker TNC.
# 2026-01-28 15:54:12,793, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2001
# 2026-01-28 15:54:12,817, 2113979629.py, 8, INFO, Processing year 2002 for ticker TNC.
# 2026-01-28 15:54:12,820, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2002
# 2026-01-28 15:54:12,847, 2113979629.py, 8, INFO, Processing year 2003 for ticker TNC.
# 2026-01-28 15:54:12,852, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2003
# 2026-01-28 15:54:12,872, 2113979629.py, 8, INFO, Processing year 2004 for ticker TNC.
# 2026-01-28 15:54:12,875, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2004
# 2026-01-28 15:54:12,895, 2113979629.py, 8, INFO, Processing year 2005 for ticker TNC.
# 2026-01-28 15:54:12,900, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2005
# 2026-01-28 15:54:12,929, 2113979629.py, 8, INFO, Processing year 2006 for ticker TNC.
# 2026-01-28 15:54:12,934, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2006
# 2026-01-28 15:54:12,960, 2113979629.py, 8, INFO, Processing year 2007 for ticker TNC.
# 2026-01-28 15:54:12,965, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2007
# 2026-01-28 15:54:12,992, 2113979629.py, 8, INFO, Processing year 2008 for ticker TNC.
# 2026-01-28 15:54:12,996, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2008
# 2026-01-28 15:54:13,018, 2113979629.py, 8, INFO, Processing year 2009 for ticker TNC.
# 2026-01-28 15:54:13,022, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2009
# 2026-01-28 15:54:13,042, 2113979629.py, 8, INFO, Processing year 2010 for ticker TNC.
# 2026-01-28 15:54:13,046, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2010
# 2026-01-28 15:54:13,068, 2113979629.py, 8, INFO, Processing year 2011 for ticker TNC.
# 2026-01-28 15:54:13,076, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2011
# 2026-01-28 15:54:13,141, 2113979629.py, 8, INFO, Processing year 2012 for ticker TNC.
# 2026-01-28 15:54:13,145, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2012
# 2026-01-28 15:54:13,185, 2113979629.py, 8, INFO, Processing year 2013 for ticker TNC.
# 2026-01-28 15:54:13,204, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2013
# 2026-01-28 15:54:13,236, 2113979629.py, 8, INFO, Processing year 2014 for ticker TNC.
# 2026-01-28 15:54:13,236, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2014
# 2026-01-28 15:54:13,258, 2113979629.py, 8, INFO, Processing year 2015 for ticker TNC.
# 2026-01-28 15:54:13,258, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2015
# 2026-01-28 15:54:13,285, 2113979629.py, 8, INFO, Processing year 2016 for ticker TNC.
# 2026-01-28 15:54:13,289, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2016
# 2026-01-28 15:54:13,300, 2113979629.py, 8, INFO, Processing year 2017 for ticker TNC.
# 2026-01-28 15:54:13,311, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2017
# 2026-01-28 15:54:13,320, 2113979629.py, 8, INFO, Processing year 2018 for ticker TNC.
# 2026-01-28 15:54:13,334, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2018
# 2026-01-28 15:54:13,354, 2113979629.py, 8, INFO, Processing year 2019 for ticker TNC.
# 2026-01-28 15:54:13,359, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2019
# 2026-01-28 15:54:13,372, 2113979629.py, 8, INFO, Processing year 2020 for ticker TNC.
# 2026-01-28 15:54:13,372, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2020
# 2026-01-28 15:54:13,388, 2113979629.py, 4, INFO, Processing ticker: CBB
# 2026-01-28 15:54:13,416, 2113979629.py, 8, INFO, Processing year 1980 for ticker CBB.
# 2026-01-28 15:54:13,421, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1980
# 2026-01-28 15:54:13,437, 2113979629.py, 8, INFO, Processing year 1981 for ticker CBB.
# 2026-01-28 15:54:13,437, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1981
# 2026-01-28 15:54:13,471, 2113979629.py, 8, INFO, Processing year 1982 for ticker CBB.
# 2026-01-28 15:54:13,474, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1982
# 2026-01-28 15:54:13,497, 2113979629.py, 8, INFO, Processing year 1983 for ticker CBB.
# 2026-01-28 15:54:13,503, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1983
# 2026-01-28 15:54:13,520, 2113979629.py, 8, INFO, Processing year 1984 for ticker CBB.
# 2026-01-28 15:54:13,527, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1984
# 2026-01-28 15:54:13,536, 2113979629.py, 8, INFO, Processing year 1985 for ticker CBB.
# 2026-01-28 15:54:13,551, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1985
# 2026-01-28 15:54:13,571, 2113979629.py, 8, INFO, Processing year 1986 for ticker CBB.
# 2026-01-28 15:54:13,575, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1986
# 2026-01-28 15:54:13,598, 2113979629.py, 8, INFO, Processing year 1987 for ticker CBB.
# 2026-01-28 15:54:13,601, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1987
# 2026-01-28 15:54:13,617, 2113979629.py, 8, INFO, Processing year 1988 for ticker CBB.
# 2026-01-28 15:54:13,628, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1988
# 2026-01-28 15:54:13,654, 2113979629.py, 8, INFO, Processing year 1989 for ticker CBB.
# 2026-01-28 15:54:13,657, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1989
# 2026-01-28 15:54:13,681, 2113979629.py, 8, INFO, Processing year 1990 for ticker CBB.
# 2026-01-28 15:54:13,683, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1990
# 2026-01-28 15:54:13,708, 2113979629.py, 8, INFO, Processing year 1991 for ticker CBB.
# 2026-01-28 15:54:13,712, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1991
# 2026-01-28 15:54:13,743, 2113979629.py, 8, INFO, Processing year 1992 for ticker CBB.
# 2026-01-28 15:54:13,747, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1992
# 2026-01-28 15:54:13,771, 2113979629.py, 8, INFO, Processing year 1993 for ticker CBB.
# 2026-01-28 15:54:13,771, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1993
# 2026-01-28 15:54:13,812, 2113979629.py, 8, INFO, Processing year 1994 for ticker CBB.
# 2026-01-28 15:54:13,820, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1994
# 2026-01-28 15:54:13,848, 2113979629.py, 8, INFO, Processing year 1995 for ticker CBB.
# 2026-01-28 15:54:13,848, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1995
# 2026-01-28 15:54:13,880, 2113979629.py, 8, INFO, Processing year 1996 for ticker CBB.
# 2026-01-28 15:54:13,883, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1996
# 2026-01-28 15:54:13,909, 2113979629.py, 8, INFO, Processing year 1997 for ticker CBB.
# 2026-01-28 15:54:13,914, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1997
# 2026-01-28 15:54:13,945, 2113979629.py, 8, INFO, Processing year 1998 for ticker CBB.
# 2026-01-28 15:54:13,950, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1998
# 2026-01-28 15:54:13,978, 2113979629.py, 8, INFO, Processing year 1999 for ticker CBB.
# 2026-01-28 15:54:13,982, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1999
# 2026-01-28 15:54:14,018, 2113979629.py, 8, INFO, Processing year 2000 for ticker CBB.
# 2026-01-28 15:54:14,022, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2000
# 2026-01-28 15:54:14,058, 2113979629.py, 8, INFO, Processing year 2001 for ticker CBB.
# 2026-01-28 15:54:14,062, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2001
# 2026-01-28 15:54:14,092, 2113979629.py, 8, INFO, Processing year 2002 for ticker CBB.
# 2026-01-28 15:54:14,095, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2002
# 2026-01-28 15:54:14,125, 2113979629.py, 8, INFO, Processing year 2003 for ticker CBB.
# 2026-01-28 15:54:14,130, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2003
# 2026-01-28 15:54:14,160, 2113979629.py, 8, INFO, Processing year 2004 for ticker CBB.
# 2026-01-28 15:54:14,165, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2004
# 2026-01-28 15:54:14,196, 2113979629.py, 8, INFO, Processing year 2005 for ticker CBB.
# 2026-01-28 15:54:14,200, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2005
# 2026-01-28 15:54:14,233, 2113979629.py, 8, INFO, Processing year 2006 for ticker CBB.
# 2026-01-28 15:54:14,241, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2006
# 2026-01-28 15:54:14,301, 2113979629.py, 8, INFO, Processing year 2007 for ticker CBB.
# 2026-01-28 15:54:14,308, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2007
# 2026-01-28 15:54:14,340, 2113979629.py, 8, INFO, Processing year 2008 for ticker CBB.
# 2026-01-28 15:54:14,350, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2008
# 2026-01-28 15:54:14,383, 2113979629.py, 8, INFO, Processing year 2009 for ticker CBB.
# 2026-01-28 15:54:14,387, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2009
# 2026-01-28 15:54:14,423, 2113979629.py, 8, INFO, Processing year 2010 for ticker CBB.
# 2026-01-28 15:54:14,429, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2010
# 2026-01-28 15:54:14,455, 2113979629.py, 8, INFO, Processing year 2011 for ticker CBB.
# 2026-01-28 15:54:14,466, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2011
# 2026-01-28 15:54:14,500, 2113979629.py, 8, INFO, Processing year 2012 for ticker CBB.
# 2026-01-28 15:54:14,506, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2012
# 2026-01-28 15:54:14,542, 2113979629.py, 8, INFO, Processing year 2013 for ticker CBB.
# 2026-01-28 15:54:14,549, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2013
# 2026-01-28 15:54:14,585, 2113979629.py, 8, INFO, Processing year 2014 for ticker CBB.
# 2026-01-28 15:54:14,588, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2014
# 2026-01-28 15:54:14,621, 2113979629.py, 8, INFO, Processing year 2015 for ticker CBB.
# 2026-01-28 15:54:14,621, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2015
# 2026-01-28 15:54:14,664, 2113979629.py, 8, INFO, Processing year 2016 for ticker CBB.
# 2026-01-28 15:54:14,667, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2016
# 2026-01-28 15:54:14,707, 2113979629.py, 8, INFO, Processing year 2017 for ticker CBB.
# 2026-01-28 15:54:14,711, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2017
# 2026-01-28 15:54:14,742, 2113979629.py, 8, INFO, Processing year 2018 for ticker CBB.
# 2026-01-28 15:54:14,752, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2018
# 2026-01-28 15:54:14,785, 2113979629.py, 8, INFO, Processing year 2019 for ticker CBB.
# 2026-01-28 15:54:14,790, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2019
# 2026-01-28 15:54:14,821, 2113979629.py, 8, INFO, Processing year 2020 for ticker CBB.
# 2026-01-28 15:54:14,827, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2020
# 2026-01-28 15:54:14,862, 2113979629.py, 4, INFO, Processing ticker: ALDX
# 2026-01-28 15:54:14,889, 2113979629.py, 8, INFO, Processing year 2014 for ticker ALDX.
# 2026-01-28 15:54:14,894, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX\ALDX_2014
# 2026-01-28 15:54:14,922, 2113979629.py, 8, INFO, Processing year 2015 for ticker ALDX.
# 2026-01-28 15:54:14,934, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX\ALDX_2015
# 2026-01-28 15:54:14,966, 2113979629.py, 8, INFO, Processing year 2016 for ticker ALDX.
# 2026-01-28 15:54:14,971, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX\ALDX_2016
# 2026-01-28 15:54:15,007, 2113979629.py, 8, INFO, Processing year 2017 for ticker ALDX.
# 2026-01-28 15:54:15,010, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX\ALDX_2017
# 2026-01-28 15:54:15,037, 2113979629.py, 8, INFO, Processing year 2018 for ticker ALDX.
# 2026-01-28 15:54:15,047, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX\ALDX_2018
# 2026-01-28 15:54:15,067, 2113979629.py, 8, INFO, Processing year 2019 for ticker ALDX.
# 2026-01-28 15:54:15,089, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX\ALDX_2019
# 2026-01-28 15:54:15,123, 2113979629.py, 8, INFO, Processing year 2020 for ticker ALDX.
# 2026-01-28 15:54:15,128, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX\ALDX_2020
# 2026-01-28 15:54:15,155, 2113979629.py, 4, INFO, Processing ticker: GLADD
# 2026-01-28 15:54:15,190, 2113979629.py, 8, INFO, Processing year 2018 for ticker GLADD.
# 2026-01-28 15:54:15,190, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GLADD\GLADD_2018
# 2026-01-28 15:54:15,222, 2113979629.py, 8, INFO, Processing year 2019 for ticker GLADD.
# 2026-01-28 15:54:15,222, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GLADD\GLADD_2019
# 2026-01-28 15:54:15,261, 2113979629.py, 8, INFO, Processing year 2020 for ticker GLADD.
# 2026-01-28 15:54:15,270, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GLADD\GLADD_2020
# 2026-01-28 15:54:15,300, 2113979629.py, 4, INFO, Processing ticker: FIXX
# 2026-01-28 15:54:15,322, 2113979629.py, 8, INFO, Processing year 2018 for ticker FIXX.
# 2026-01-28 15:54:15,322, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/FIXX\FIXX_2018
# 2026-01-28 15:54:15,350, 2113979629.py, 8, INFO, Processing year 2019 for ticker FIXX.
# 2026-01-28 15:54:15,350, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/FIXX\FIXX_2019
# 2026-01-28 15:54:15,394, 2113979629.py, 8, INFO, Processing year 2020 for ticker FIXX.
# 2026-01-28 15:54:15,404, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/FIXX\FIXX_2020
# 2026-01-28 15:54:15,443, 2113979629.py, 4, INFO, Processing ticker: ETJ
# 2026-01-28 15:54:15,470, 2113979629.py, 8, INFO, Processing year 2007 for ticker ETJ.
# 2026-01-28 15:54:15,470, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2007
# 2026-01-28 15:54:15,513, 2113979629.py, 8, INFO, Processing year 2008 for ticker ETJ.
# 2026-01-28 15:54:15,520, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2008
# 2026-01-28 15:54:15,553, 2113979629.py, 8, INFO, Processing year 2009 for ticker ETJ.
# 2026-01-28 15:54:15,558, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2009
# 2026-01-28 15:54:15,591, 2113979629.py, 8, INFO, Processing year 2010 for ticker ETJ.
# 2026-01-28 15:54:15,595, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2010
# 2026-01-28 15:54:15,625, 2113979629.py, 8, INFO, Processing year 2011 for ticker ETJ.
# 2026-01-28 15:54:15,636, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2011
# 2026-01-28 15:54:15,667, 2113979629.py, 8, INFO, Processing year 2012 for ticker ETJ.
# 2026-01-28 15:54:15,673, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2012
# 2026-01-28 15:54:15,711, 2113979629.py, 8, INFO, Processing year 2013 for ticker ETJ.
# 2026-01-28 15:54:15,717, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2013
# 2026-01-28 15:54:15,755, 2113979629.py, 8, INFO, Processing year 2014 for ticker ETJ.
# 2026-01-28 15:54:15,760, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2014
# 2026-01-28 15:54:15,800, 2113979629.py, 8, INFO, Processing year 2015 for ticker ETJ.
# 2026-01-28 15:54:15,805, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2015
# 2026-01-28 15:54:15,832, 2113979629.py, 8, INFO, Processing year 2016 for ticker ETJ.
# 2026-01-28 15:54:15,832, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2016
# 2026-01-28 15:54:15,868, 2113979629.py, 8, INFO, Processing year 2017 for ticker ETJ.
# 2026-01-28 15:54:15,878, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2017
# 2026-01-28 15:54:15,910, 2113979629.py, 8, INFO, Processing year 2018 for ticker ETJ.
# 2026-01-28 15:54:15,915, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2018
# 2026-01-28 15:54:15,947, 2113979629.py, 8, INFO, Processing year 2019 for ticker ETJ.
# 2026-01-28 15:54:15,953, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2019
# 2026-01-28 15:54:15,991, 2113979629.py, 8, INFO, Processing year 2020 for ticker ETJ.
# 2026-01-28 15:54:15,997, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2020
# 2026-01-28 15:54:16,034, 2113979629.py, 4, INFO, Processing ticker: CMCTP
# 2026-01-28 15:54:16,061, 2113979629.py, 8, INFO, Processing year 2018 for ticker CMCTP.
# 2026-01-28 15:54:16,067, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CMCTP\CMCTP_2018
# 2026-01-28 15:54:16,102, 2113979629.py, 8, INFO, Processing year 2019 for ticker CMCTP.
# 2026-01-28 15:54:16,106, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CMCTP\CMCTP_2019
# 2026-01-28 15:54:16,140, 2113979629.py, 8, INFO, Processing year 2020 for ticker CMCTP.
# 2026-01-28 15:54:16,145, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CMCTP\CMCTP_2020
# 2026-01-28 15:54:16,184, 2113979629.py, 4, INFO, Processing ticker: BWG
# 2026-01-28 15:54:16,214, 2113979629.py, 8, INFO, Processing year 2012 for ticker BWG.
# 2026-01-28 15:54:16,221, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BWG\BWG_2012
# 2026-01-28 15:54:16,254, 2113979629.py, 8, INFO, Processing year 2013 for ticker BWG.
# 2026-01-28 15:54:16,260, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BWG\BWG_2013
# 2026-01-28 15:54:16,303, 2113979629.py, 8, INFO, Processing year 2014 for ticker BWG.
# 2026-01-28 15:54:16,312, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BWG\BWG_2014
# 2026-01-28 15:54:16,364, 2113979629.py, 8, INFO, Processing year 2015 for ticker BWG.
# 2026-01-28 15:54:16,374, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BWG\BWG_2015
# 2026-01-28 15:54:16,407, 2113979629.py, 8, INFO, Processing year 2016 for ticker BWG.
# 2026-01-28 15:54:16,417, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BWG\BWG_2016
# 2026-01-28 15:54:16,452, 2113979629.py, 8, INFO, Processing year 2017 for ticker BWG.
# 2026-01-28 15:54:16,455, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BWG\BWG_2017
# 2026-01-28 15:54:16,492, 2113979629.py, 8, INFO, Processing year 2018 for ticker BWG.
# 2026-01-28 15:54:16,497, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BWG\BWG_2018
# 2026-01-28 15:54:16,523, 2113979629.py, 8, INFO, Processing year 2019 for ticker BWG.
# 2026-01-28 15:54:16,538, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BWG\BWG_2019
# 2026-01-28 15:54:16,571, 2113979629.py, 8, INFO, Processing year 2020 for ticker BWG.
# 2026-01-28 15:54:16,575, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BWG\BWG_2020
# 2026-01-28 15:54:16,607, 2113979629.py, 4, INFO, Processing ticker: VIAC
# 2026-01-28 15:54:16,642, 2113979629.py, 8, INFO, Processing year 2005 for ticker VIAC.
# 2026-01-28 15:54:16,647, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2005
# 2026-01-28 15:54:16,683, 2113979629.py, 8, INFO, Processing year 2006 for ticker VIAC.
# 2026-01-28 15:54:16,689, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2006
# 2026-01-28 15:54:16,724, 2113979629.py, 8, INFO, Processing year 2007 for ticker VIAC.
# 2026-01-28 15:54:16,736, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2007
# 2026-01-28 15:54:16,767, 2113979629.py, 8, INFO, Processing year 2008 for ticker VIAC.
# 2026-01-28 15:54:16,767, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2008
# 2026-01-28 15:54:16,805, 2113979629.py, 8, INFO, Processing year 2009 for ticker VIAC.
# 2026-01-28 15:54:16,809, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2009
# 2026-01-28 15:54:16,842, 2113979629.py, 8, INFO, Processing year 2010 for ticker VIAC.
# 2026-01-28 15:54:16,845, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2010
# 2026-01-28 15:54:16,886, 2113979629.py, 8, INFO, Processing year 2011 for ticker VIAC.
# 2026-01-28 15:54:16,892, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2011
# 2026-01-28 15:54:16,927, 2113979629.py, 8, INFO, Processing year 2012 for ticker VIAC.
# 2026-01-28 15:54:16,931, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2012
# 2026-01-28 15:54:16,964, 2113979629.py, 8, INFO, Processing year 2013 for ticker VIAC.
# 2026-01-28 15:54:16,971, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2013
# 2026-01-28 15:54:17,007, 2113979629.py, 8, INFO, Processing year 2014 for ticker VIAC.
# 2026-01-28 15:54:17,014, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2014
# 2026-01-28 15:54:17,050, 2113979629.py, 8, INFO, Processing year 2015 for ticker VIAC.
# 2026-01-28 15:54:17,056, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2015
# 2026-01-28 15:54:17,091, 2113979629.py, 8, INFO, Processing year 2016 for ticker VIAC.
# 2026-01-28 15:54:17,097, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2016
# 2026-01-28 15:54:17,137, 2113979629.py, 8, INFO, Processing year 2017 for ticker VIAC.
# 2026-01-28 15:54:17,141, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2017
# 2026-01-28 15:54:17,175, 2113979629.py, 8, INFO, Processing year 2018 for ticker VIAC.
# 2026-01-28 15:54:17,180, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2018
# 2026-01-28 15:54:17,212, 2113979629.py, 8, INFO, Processing year 2019 for ticker VIAC.
# 2026-01-28 15:54:17,219, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2019
# 2026-01-28 15:54:17,252, 2113979629.py, 8, INFO, Processing year 2020 for ticker VIAC.
# 2026-01-28 15:54:17,257, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2020
# 2026-01-28 15:54:17,290, 2113979629.py, 4, INFO, Processing ticker: REI
# 2026-01-28 15:54:17,322, 2113979629.py, 8, INFO, Processing year 2007 for ticker REI.
# 2026-01-28 15:54:17,326, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2007
# 2026-01-28 15:54:17,361, 2113979629.py, 8, INFO, Processing year 2008 for ticker REI.
# 2026-01-28 15:54:17,366, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2008
# 2026-01-28 15:54:17,402, 2113979629.py, 8, INFO, Processing year 2009 for ticker REI.
# 2026-01-28 15:54:17,410, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2009
# 2026-01-28 15:54:17,477, 2113979629.py, 8, INFO, Processing year 2010 for ticker REI.
# 2026-01-28 15:54:17,488, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2010
# 2026-01-28 15:54:17,558, 2113979629.py, 8, INFO, Processing year 2011 for ticker REI.
# 2026-01-28 15:54:17,566, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2011
# 2026-01-28 15:54:17,632, 2113979629.py, 8, INFO, Processing year 2012 for ticker REI.
# 2026-01-28 15:54:17,639, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2012
# 2026-01-28 15:54:17,704, 2113979629.py, 8, INFO, Processing year 2013 for ticker REI.
# 2026-01-28 15:54:17,710, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2013
# 2026-01-28 15:54:17,780, 2113979629.py, 8, INFO, Processing year 2014 for ticker REI.
# 2026-01-28 15:54:17,787, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2014
# 2026-01-28 15:54:17,836, 2113979629.py, 8, INFO, Processing year 2015 for ticker REI.
# 2026-01-28 15:54:17,856, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2015
# 2026-01-28 15:54:17,907, 2113979629.py, 8, INFO, Processing year 2016 for ticker REI.
# 2026-01-28 15:54:17,917, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2016
# 2026-01-28 15:54:17,963, 2113979629.py, 8, INFO, Processing year 2017 for ticker REI.
# 2026-01-28 15:54:17,963, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2017
# 2026-01-28 15:54:18,042, 2113979629.py, 8, INFO, Processing year 2018 for ticker REI.
# 2026-01-28 15:54:18,042, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2018
# 2026-01-28 15:54:18,105, 2113979629.py, 8, INFO, Processing year 2019 for ticker REI.
# 2026-01-28 15:54:18,112, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2019
# 2026-01-28 15:54:18,154, 2113979629.py, 8, INFO, Processing year 2020 for ticker REI.
# 2026-01-28 15:54:18,160, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2020
# 2026-01-28 15:54:18,196, 2113979629.py, 4, INFO, Processing ticker: BLPH
# 2026-01-28 15:54:18,229, 2113979629.py, 8, INFO, Processing year 2015 for ticker BLPH.
# 2026-01-28 15:54:18,236, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BLPH\BLPH_2015
# 2026-01-28 15:54:18,281, 2113979629.py, 8, INFO, Processing year 2016 for ticker BLPH.
# 2026-01-28 15:54:18,288, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BLPH\BLPH_2016
# 2026-01-28 15:54:18,326, 2113979629.py, 8, INFO, Processing year 2017 for ticker BLPH.
# 2026-01-28 15:54:18,331, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BLPH\BLPH_2017
# 2026-01-28 15:54:18,367, 2113979629.py, 8, INFO, Processing year 2018 for ticker BLPH.
# 2026-01-28 15:54:18,373, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BLPH\BLPH_2018
# 2026-01-28 15:54:18,409, 2113979629.py, 8, INFO, Processing year 2019 for ticker BLPH.
# 2026-01-28 15:54:18,414, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BLPH\BLPH_2019
# 2026-01-28 15:54:18,458, 2113979629.py, 8, INFO, Processing year 2020 for ticker BLPH.
# 2026-01-28 15:54:18,463, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BLPH\BLPH_2020
# 2026-01-28 15:54:18,504, 2113979629.py, 4, INFO, Processing ticker: SMG
# 2026-01-28 15:54:18,539, 2113979629.py, 8, INFO, Processing year 1992 for ticker SMG.
# 2026-01-28 15:54:18,544, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_1992
# 2026-01-28 15:54:18,577, 2113979629.py, 8, INFO, Processing year 1993 for ticker SMG.
# 2026-01-28 15:54:18,581, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_1993
# 2026-01-28 15:54:18,615, 2113979629.py, 8, INFO, Processing year 1994 for ticker SMG.
# 2026-01-28 15:54:18,624, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_1994
# 2026-01-28 15:54:18,677, 2113979629.py, 8, INFO, Processing year 1995 for ticker SMG.
# 2026-01-28 15:54:18,688, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_1995
# 2026-01-28 15:54:18,759, 2113979629.py, 8, INFO, Processing year 1996 for ticker SMG.
# 2026-01-28 15:54:18,771, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_1996
# 2026-01-28 15:54:18,817, 2113979629.py, 8, INFO, Processing year 1997 for ticker SMG.
# 2026-01-28 15:54:18,822, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_1997
# 2026-01-28 15:54:18,861, 2113979629.py, 8, INFO, Processing year 1998 for ticker SMG.
# 2026-01-28 15:54:18,868, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_1998
# 2026-01-28 15:54:18,902, 2113979629.py, 8, INFO, Processing year 1999 for ticker SMG.
# 2026-01-28 15:54:18,909, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_1999
# 2026-01-28 15:54:18,959, 2113979629.py, 8, INFO, Processing year 2000 for ticker SMG.
# 2026-01-28 15:54:18,968, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2000
# 2026-01-28 15:54:19,027, 2113979629.py, 8, INFO, Processing year 2001 for ticker SMG.
# 2026-01-28 15:54:19,035, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2001
# 2026-01-28 15:54:19,096, 2113979629.py, 8, INFO, Processing year 2002 for ticker SMG.
# 2026-01-28 15:54:19,108, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2002
# 2026-01-28 15:54:19,169, 2113979629.py, 8, INFO, Processing year 2003 for ticker SMG.
# 2026-01-28 15:54:19,184, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2003
# 2026-01-28 15:54:19,252, 2113979629.py, 8, INFO, Processing year 2004 for ticker SMG.
# 2026-01-28 15:54:19,266, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2004
# 2026-01-28 15:54:19,330, 2113979629.py, 8, INFO, Processing year 2005 for ticker SMG.
# 2026-01-28 15:54:19,339, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2005
# 2026-01-28 15:54:19,400, 2113979629.py, 8, INFO, Processing year 2006 for ticker SMG.
# 2026-01-28 15:54:19,407, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2006
# 2026-01-28 15:54:19,470, 2113979629.py, 8, INFO, Processing year 2007 for ticker SMG.
# 2026-01-28 15:54:19,478, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2007
# 2026-01-28 15:54:19,536, 2113979629.py, 8, INFO, Processing year 2008 for ticker SMG.
# 2026-01-28 15:54:19,543, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2008
# 2026-01-28 15:54:19,607, 2113979629.py, 8, INFO, Processing year 2009 for ticker SMG.
# 2026-01-28 15:54:19,616, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2009
# 2026-01-28 15:54:19,677, 2113979629.py, 8, INFO, Processing year 2010 for ticker SMG.
# 2026-01-28 15:54:19,685, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2010
# 2026-01-28 15:54:19,743, 2113979629.py, 8, INFO, Processing year 2011 for ticker SMG.
# 2026-01-28 15:54:19,752, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2011
# 2026-01-28 15:54:19,805, 2113979629.py, 8, INFO, Processing year 2012 for ticker SMG.
# 2026-01-28 15:54:19,813, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2012
# 2026-01-28 15:54:19,889, 2113979629.py, 8, INFO, Processing year 2013 for ticker SMG.
# 2026-01-28 15:54:19,898, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2013
# 2026-01-28 15:54:19,966, 2113979629.py, 8, INFO, Processing year 2014 for ticker SMG.
# 2026-01-28 15:54:19,977, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2014
# 2026-01-28 15:54:20,047, 2113979629.py, 8, INFO, Processing year 2015 for ticker SMG.
# 2026-01-28 15:54:20,054, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2015
# 2026-01-28 15:54:20,114, 2113979629.py, 8, INFO, Processing year 2016 for ticker SMG.
# 2026-01-28 15:54:20,123, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2016
# 2026-01-28 15:54:20,284, 2113979629.py, 8, INFO, Processing year 2017 for ticker SMG.
# 2026-01-28 15:54:20,291, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2017
# 2026-01-28 15:54:20,433, 2113979629.py, 8, INFO, Processing year 2018 for ticker SMG.
# 2026-01-28 15:54:20,501, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2018
# 2026-01-28 15:54:20,665, 2113979629.py, 8, INFO, Processing year 2019 for ticker SMG.
# 2026-01-28 15:54:20,681, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2019
# 2026-01-28 15:54:20,802, 2113979629.py, 8, INFO, Processing year 2020 for ticker SMG.
# 2026-01-28 15:54:20,806, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2020
# 2026-01-28 15:54:20,834, 2113979629.py, 4, INFO, Processing ticker: MOH
# 2026-01-28 15:54:20,855, 2113979629.py, 8, INFO, Processing year 2003 for ticker MOH.
# 2026-01-28 15:54:20,855, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2003
# 2026-01-28 15:54:20,884, 2113979629.py, 8, INFO, Processing year 2004 for ticker MOH.
# 2026-01-28 15:54:20,884, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2004
# 2026-01-28 15:54:20,917, 2113979629.py, 8, INFO, Processing year 2005 for ticker MOH.
# 2026-01-28 15:54:20,921, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2005
# 2026-01-28 15:54:20,953, 2113979629.py, 8, INFO, Processing year 2006 for ticker MOH.
# 2026-01-28 15:54:20,961, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2006
# 2026-01-28 15:54:21,001, 2113979629.py, 8, INFO, Processing year 2007 for ticker MOH.
# 2026-01-28 15:54:21,007, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2007
# 2026-01-28 15:54:21,045, 2113979629.py, 8, INFO, Processing year 2008 for ticker MOH.
# 2026-01-28 15:54:21,051, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2008
# 2026-01-28 15:54:21,090, 2113979629.py, 8, INFO, Processing year 2009 for ticker MOH.
# 2026-01-28 15:54:21,103, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2009
# 2026-01-28 15:54:21,142, 2113979629.py, 8, INFO, Processing year 2010 for ticker MOH.
# 2026-01-28 15:54:21,142, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2010
# 2026-01-28 15:54:21,173, 2113979629.py, 8, INFO, Processing year 2011 for ticker MOH.
# 2026-01-28 15:54:21,188, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2011
# 2026-01-28 15:54:21,223, 2113979629.py, 8, INFO, Processing year 2012 for ticker MOH.
# 2026-01-28 15:54:21,223, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2012
# 2026-01-28 15:54:21,266, 2113979629.py, 8, INFO, Processing year 2013 for ticker MOH.
# 2026-01-28 15:54:21,272, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2013
# 2026-01-28 15:54:21,305, 2113979629.py, 8, INFO, Processing year 2014 for ticker MOH.
# 2026-01-28 15:54:21,305, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2014
# 2026-01-28 15:54:21,346, 2113979629.py, 8, INFO, Processing year 2015 for ticker MOH.
# 2026-01-28 15:54:21,352, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2015
# 2026-01-28 15:54:21,405, 2113979629.py, 8, INFO, Processing year 2016 for ticker MOH.
# 2026-01-28 15:54:21,405, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2016
# 2026-01-28 15:54:21,446, 2113979629.py, 8, INFO, Processing year 2017 for ticker MOH.
# 2026-01-28 15:54:21,453, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2017
# 2026-01-28 15:54:21,497, 2113979629.py, 8, INFO, Processing year 2018 for ticker MOH.
# 2026-01-28 15:54:21,506, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2018
# 2026-01-28 15:54:21,539, 2113979629.py, 8, INFO, Processing year 2019 for ticker MOH.
# 2026-01-28 15:54:21,542, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2019
# 2026-01-28 15:54:21,595, 2113979629.py, 8, INFO, Processing year 2020 for ticker MOH.
# 2026-01-28 15:54:21,601, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2020
# 2026-01-28 15:54:21,634, 2113979629.py, 4, INFO, Processing ticker: AMH
# 2026-01-28 15:54:21,665, 2113979629.py, 8, INFO, Processing year 2013 for ticker AMH.
# 2026-01-28 15:54:21,667, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMH\AMH_2013
# 2026-01-28 15:54:21,708, 2113979629.py, 8, INFO, Processing year 2014 for ticker AMH.
# 2026-01-28 15:54:21,712, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMH\AMH_2014
# 2026-01-28 15:54:21,747, 2113979629.py, 8, INFO, Processing year 2015 for ticker AMH.
# 2026-01-28 15:54:21,755, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMH\AMH_2015
# 2026-01-28 15:54:21,787, 2113979629.py, 8, INFO, Processing year 2016 for ticker AMH.
# 2026-01-28 15:54:21,807, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMH\AMH_2016
# 2026-01-28 15:54:21,847, 2113979629.py, 8, INFO, Processing year 2017 for ticker AMH.
# 2026-01-28 15:54:21,854, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMH\AMH_2017
# 2026-01-28 15:54:21,887, 2113979629.py, 8, INFO, Processing year 2018 for ticker AMH.
# 2026-01-28 15:54:21,892, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMH\AMH_2018
# 2026-01-28 15:54:21,926, 2113979629.py, 8, INFO, Processing year 2019 for ticker AMH.
# 2026-01-28 15:54:21,931, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMH\AMH_2019
# 2026-01-28 15:54:21,967, 2113979629.py, 8, INFO, Processing year 2020 for ticker AMH.
# 2026-01-28 15:54:21,972, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMH\AMH_2020
# 2026-01-28 15:54:22,011, 2113979629.py, 4, INFO, Processing ticker: AMAL
# 2026-01-28 15:54:22,055, 2113979629.py, 8, INFO, Processing year 2018 for ticker AMAL.
# 2026-01-28 15:54:22,062, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAL\AMAL_2018
# 2026-01-28 15:54:22,109, 2113979629.py, 8, INFO, Processing year 2019 for ticker AMAL.
# 2026-01-28 15:54:22,119, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAL\AMAL_2019
# 2026-01-28 15:54:22,160, 2113979629.py, 8, INFO, Processing year 2020 for ticker AMAL.
# 2026-01-28 15:54:22,167, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAL\AMAL_2020
# 2026-01-28 15:54:22,207, 2113979629.py, 4, INFO, Processing ticker: BPYPN
# 2026-01-28 15:54:22,237, 2113979629.py, 8, INFO, Processing year 2020 for ticker BPYPN.
# 2026-01-28 15:54:22,241, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BPYPN\BPYPN_2020
# 2026-01-28 15:54:22,281, 2113979629.py, 4, INFO, Processing ticker: ERH
# 2026-01-28 15:54:22,311, 2113979629.py, 8, INFO, Processing year 2004 for ticker ERH.
# 2026-01-28 15:54:22,318, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2004
# 2026-01-28 15:54:22,354, 2113979629.py, 8, INFO, Processing year 2005 for ticker ERH.
# 2026-01-28 15:54:22,354, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2005
# 2026-01-28 15:54:22,460, 2113979629.py, 8, INFO, Processing year 2006 for ticker ERH.
# 2026-01-28 15:54:22,466, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2006
# 2026-01-28 15:54:22,519, 2113979629.py, 8, INFO, Processing year 2007 for ticker ERH.
# 2026-01-28 15:54:22,524, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2007
# 2026-01-28 15:54:22,564, 2113979629.py, 8, INFO, Processing year 2008 for ticker ERH.
# 2026-01-28 15:54:22,572, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2008
# 2026-01-28 15:54:22,612, 2113979629.py, 8, INFO, Processing year 2009 for ticker ERH.
# 2026-01-28 15:54:22,620, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2009
# 2026-01-28 15:54:22,660, 2113979629.py, 8, INFO, Processing year 2010 for ticker ERH.
# 2026-01-28 15:54:22,665, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2010
# 2026-01-28 15:54:22,704, 2113979629.py, 8, INFO, Processing year 2011 for ticker ERH.
# 2026-01-28 15:54:22,711, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2011
# 2026-01-28 15:54:22,749, 2113979629.py, 8, INFO, Processing year 2012 for ticker ERH.
# 2026-01-28 15:54:22,756, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2012
# 2026-01-28 15:54:22,800, 2113979629.py, 8, INFO, Processing year 2013 for ticker ERH.
# 2026-01-28 15:54:22,806, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2013
# 2026-01-28 15:54:22,847, 2113979629.py, 8, INFO, Processing year 2014 for ticker ERH.
# 2026-01-28 15:54:22,853, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2014
# 2026-01-28 15:54:22,888, 2113979629.py, 8, INFO, Processing year 2015 for ticker ERH.
# 2026-01-28 15:54:22,893, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2015
# 2026-01-28 15:54:22,928, 2113979629.py, 8, INFO, Processing year 2016 for ticker ERH.
# 2026-01-28 15:54:22,934, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2016
# 2026-01-28 15:54:22,969, 2113979629.py, 8, INFO, Processing year 2017 for ticker ERH.
# 2026-01-28 15:54:22,974, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2017
# 2026-01-28 15:54:23,011, 2113979629.py, 8, INFO, Processing year 2018 for ticker ERH.
# ...
# 2026-01-28 15:54:51,700, 2113979629.py, 8, INFO, Processing year 2016 for ticker GURE.
# 2026-01-28 15:54:51,700, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GURE\GURE_2016
# 2026-01-28 15:54:51,739, 2113979629.py, 8, INFO, Processing year 2017 for ticker GURE.
# 2026-01-28 15:54:51,739, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GURE\GURE_2017
# 2026-01-28 15:54:51,778, 2113979629.py, 8, INFO, Processing year 2018 for ticker GURE.
# 2026-01-28 15:54:51,785, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GURE\GURE_2018
# 2026-01-28 15:54:51,816, 2113979629.py, 8, INFO, Processing year 2019 for ticker GURE.
# 2026-01-28 15:54:51,833, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GURE\GURE_2019
# 2026-01-28 15:54:51,852, 2113979629.py, 8, INFO, Processing year 2020 for ticker GURE.
# 2026-01-28 15:54:51,866, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GURE\GURE_2020
# 2026-01-28 15:54:51,894, 2113979629.py, 4, INFO, Processing ticker: TEF
# 2026-01-28 15:54:51,919, 2113979629.py, 8, INFO, Processing year 1987 for ticker TEF.
# 2026-01-28 15:54:51,919, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1987
# 2026-01-28 15:54:51,957, 2113979629.py, 8, INFO, Processing year 1988 for ticker TEF.
# 2026-01-28 15:54:51,962, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1988
# 2026-01-28 15:54:51,988, 2113979629.py, 8, INFO, Processing year 1989 for ticker TEF.
# 2026-01-28 15:54:51,995, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1989
# 2026-01-28 15:54:52,025, 2113979629.py, 8, INFO, Processing year 1990 for ticker TEF.
# 2026-01-28 15:54:52,029, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1990
# 2026-01-28 15:54:52,049, 2113979629.py, 8, INFO, Processing year 1991 for ticker TEF.
# 2026-01-28 15:54:52,065, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1991
# 2026-01-28 15:54:52,117, 2113979629.py, 8, INFO, Processing year 1992 for ticker TEF.
# 2026-01-28 15:54:52,117, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1992
# 2026-01-28 15:54:52,149, 2113979629.py, 8, INFO, Processing year 1993 for ticker TEF.
# 2026-01-28 15:54:52,153, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1993
# 2026-01-28 15:54:52,164, 2113979629.py, 8, INFO, Processing year 1994 for ticker TEF.
# 2026-01-28 15:54:52,184, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1994
# 2026-01-28 15:54:52,210, 2113979629.py, 8, INFO, Processing year 1995 for ticker TEF.
# 2026-01-28 15:54:52,215, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1995
# 2026-01-28 15:54:52,243, 2113979629.py, 8, INFO, Processing year 1996 for ticker TEF.
# 2026-01-28 15:54:52,247, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1996
# 2026-01-28 15:54:52,279, 2113979629.py, 8, INFO, Processing year 1997 for ticker TEF.
# 2026-01-28 15:54:52,285, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1997
# 2026-01-28 15:54:52,318, 2113979629.py, 8, INFO, Processing year 1998 for ticker TEF.
# 2026-01-28 15:54:52,322, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1998
# 2026-01-28 15:54:52,354, 2113979629.py, 8, INFO, Processing year 1999 for ticker TEF.
# 2026-01-28 15:54:52,358, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1999
# 2026-01-28 15:54:52,390, 2113979629.py, 8, INFO, Processing year 2000 for ticker TEF.
# 2026-01-28 15:54:52,395, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2000
# 2026-01-28 15:54:52,422, 2113979629.py, 8, INFO, Processing year 2001 for ticker TEF.
# 2026-01-28 15:54:52,425, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2001
# 2026-01-28 15:54:52,452, 2113979629.py, 8, INFO, Processing year 2002 for ticker TEF.
# 2026-01-28 15:54:52,456, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2002
# 2026-01-28 15:54:52,483, 2113979629.py, 8, INFO, Processing year 2003 for ticker TEF.
# 2026-01-28 15:54:52,487, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2003
# 2026-01-28 15:54:52,525, 2113979629.py, 8, INFO, Processing year 2004 for ticker TEF.
# 2026-01-28 15:54:52,531, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2004
# 2026-01-28 15:54:52,570, 2113979629.py, 8, INFO, Processing year 2005 for ticker TEF.
# 2026-01-28 15:54:52,570, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2005
# 2026-01-28 15:54:52,618, 2113979629.py, 8, INFO, Processing year 2006 for ticker TEF.
# 2026-01-28 15:54:52,623, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2006
# 2026-01-28 15:54:52,652, 2113979629.py, 8, INFO, Processing year 2007 for ticker TEF.
# 2026-01-28 15:54:52,666, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2007
# 2026-01-28 15:54:52,694, 2113979629.py, 8, INFO, Processing year 2008 for ticker TEF.
# 2026-01-28 15:54:52,700, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2008
# 2026-01-28 15:54:52,736, 2113979629.py, 8, INFO, Processing year 2009 for ticker TEF.
# 2026-01-28 15:54:52,742, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2009
# 2026-01-28 15:54:52,770, 2113979629.py, 8, INFO, Processing year 2010 for ticker TEF.
# 2026-01-28 15:54:52,778, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2010
# 2026-01-28 15:54:52,804, 2113979629.py, 8, INFO, Processing year 2011 for ticker TEF.
# 2026-01-28 15:54:52,804, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2011
# 2026-01-28 15:54:52,840, 2113979629.py, 8, INFO, Processing year 2012 for ticker TEF.
# 2026-01-28 15:54:52,844, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2012
# 2026-01-28 15:54:52,870, 2113979629.py, 8, INFO, Processing year 2013 for ticker TEF.
# 2026-01-28 15:54:52,870, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2013
# 2026-01-28 15:54:52,918, 2113979629.py, 8, INFO, Processing year 2014 for ticker TEF.
# 2026-01-28 15:54:52,923, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2014
# 2026-01-28 15:54:52,951, 2113979629.py, 8, INFO, Processing year 2015 for ticker TEF.
# 2026-01-28 15:54:52,954, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2015
# 2026-01-28 15:54:52,984, 2113979629.py, 8, INFO, Processing year 2016 for ticker TEF.
# 2026-01-28 15:54:52,987, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2016
# 2026-01-28 15:54:53,018, 2113979629.py, 8, INFO, Processing year 2017 for ticker TEF.
# 2026-01-28 15:54:53,023, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2017
# 2026-01-28 15:54:53,051, 2113979629.py, 8, INFO, Processing year 2018 for ticker TEF.
# 2026-01-28 15:54:53,051, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2018
# 2026-01-28 15:54:53,082, 2113979629.py, 8, INFO, Processing year 2019 for ticker TEF.
# 2026-01-28 15:54:53,091, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2019
# 2026-01-28 15:54:53,121, 2113979629.py, 8, INFO, Processing year 2020 for ticker TEF.
# 2026-01-28 15:54:53,121, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2020
# 2026-01-28 15:54:53,151, 2113979629.py, 4, INFO, Processing ticker: SYNH
# 2026-01-28 15:54:53,190, 2113979629.py, 8, INFO, Processing year 2014 for ticker SYNH.
# 2026-01-28 15:54:53,195, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SYNH\SYNH_2014
# 2026-01-28 15:54:53,216, 2113979629.py, 8, INFO, Processing year 2015 for ticker SYNH.
# 2026-01-28 15:54:53,216, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SYNH\SYNH_2015
# 2026-01-28 15:54:53,268, 2113979629.py, 8, INFO, Processing year 2016 for ticker SYNH.
# 2026-01-28 15:54:53,271, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SYNH\SYNH_2016
# 2026-01-28 15:54:53,302, 2113979629.py, 8, INFO, Processing year 2017 for ticker SYNH.
# 2026-01-28 15:54:53,306, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SYNH\SYNH_2017
# 2026-01-28 15:54:53,333, 2113979629.py, 8, INFO, Processing year 2018 for ticker SYNH.
# 2026-01-28 15:54:53,338, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SYNH\SYNH_2018
# 2026-01-28 15:54:53,361, 2113979629.py, 8, INFO, Processing year 2019 for ticker SYNH.
# 2026-01-28 15:54:53,369, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SYNH\SYNH_2019
# 2026-01-28 15:54:53,387, 2113979629.py, 8, INFO, Processing year 2020 for ticker SYNH.
# 2026-01-28 15:54:53,399, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SYNH\SYNH_2020
# 2026-01-28 15:54:53,424, 2113979629.py, 4, INFO, Processing ticker: KEY
# 2026-01-28 15:54:53,452, 2113979629.py, 8, INFO, Processing year 1987 for ticker KEY.
# 2026-01-28 15:54:53,452, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1987
# 2026-01-28 15:54:53,502, 2113979629.py, 8, INFO, Processing year 1988 for ticker KEY.
# 2026-01-28 15:54:53,507, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1988
# 2026-01-28 15:54:53,534, 2113979629.py, 8, INFO, Processing year 1989 for ticker KEY.
# 2026-01-28 15:54:53,539, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1989
# 2026-01-28 15:54:53,570, 2113979629.py, 8, INFO, Processing year 1990 for ticker KEY.
# 2026-01-28 15:54:53,571, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1990
# 2026-01-28 15:54:53,602, 2113979629.py, 8, INFO, Processing year 1991 for ticker KEY.
# 2026-01-28 15:54:53,606, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1991
# 2026-01-28 15:54:53,632, 2113979629.py, 8, INFO, Processing year 1992 for ticker KEY.
# 2026-01-28 15:54:53,637, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1992
# 2026-01-28 15:54:53,665, 2113979629.py, 8, INFO, Processing year 1993 for ticker KEY.
# 2026-01-28 15:54:53,671, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1993
# 2026-01-28 15:54:53,689, 2113979629.py, 8, INFO, Processing year 1994 for ticker KEY.
# 2026-01-28 15:54:53,700, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1994
# 2026-01-28 15:54:53,743, 2113979629.py, 8, INFO, Processing year 1995 for ticker KEY.
# 2026-01-28 15:54:53,746, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1995
# 2026-01-28 15:54:53,771, 2113979629.py, 8, INFO, Processing year 1996 for ticker KEY.
# 2026-01-28 15:54:53,771, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1996
# 2026-01-28 15:54:53,802, 2113979629.py, 8, INFO, Processing year 1997 for ticker KEY.
# 2026-01-28 15:54:53,802, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1997
# 2026-01-28 15:54:53,832, 2113979629.py, 8, INFO, Processing year 1998 for ticker KEY.
# 2026-01-28 15:54:53,832, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1998
# 2026-01-28 15:54:53,870, 2113979629.py, 8, INFO, Processing year 1999 for ticker KEY.
# 2026-01-28 15:54:53,871, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1999
# 2026-01-28 15:54:53,903, 2113979629.py, 8, INFO, Processing year 2000 for ticker KEY.
# 2026-01-28 15:54:53,909, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2000
# 2026-01-28 15:54:53,936, 2113979629.py, 8, INFO, Processing year 2001 for ticker KEY.
# 2026-01-28 15:54:53,940, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2001
# 2026-01-28 15:54:54,011, 2113979629.py, 8, INFO, Processing year 2002 for ticker KEY.
# 2026-01-28 15:54:54,020, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2002
# 2026-01-28 15:54:54,091, 2113979629.py, 8, INFO, Processing year 2003 for ticker KEY.
# 2026-01-28 15:54:54,099, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2003
# 2026-01-28 15:54:54,130, 2113979629.py, 8, INFO, Processing year 2004 for ticker KEY.
# 2026-01-28 15:54:54,135, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2004
# 2026-01-28 15:54:54,177, 2113979629.py, 8, INFO, Processing year 2005 for ticker KEY.
# 2026-01-28 15:54:54,187, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2005
# 2026-01-28 15:54:54,220, 2113979629.py, 8, INFO, Processing year 2006 for ticker KEY.
# 2026-01-28 15:54:54,220, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2006
# 2026-01-28 15:54:54,256, 2113979629.py, 8, INFO, Processing year 2007 for ticker KEY.
# 2026-01-28 15:54:54,270, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2007
# 2026-01-28 15:54:54,283, 2113979629.py, 8, INFO, Processing year 2008 for ticker KEY.
# 2026-01-28 15:54:54,299, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2008
# 2026-01-28 15:54:54,332, 2113979629.py, 8, INFO, Processing year 2009 for ticker KEY.
# 2026-01-28 15:54:54,336, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2009
# 2026-01-28 15:54:54,363, 2113979629.py, 8, INFO, Processing year 2010 for ticker KEY.
# 2026-01-28 15:54:54,367, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2010
# 2026-01-28 15:54:54,393, 2113979629.py, 8, INFO, Processing year 2011 for ticker KEY.
# 2026-01-28 15:54:54,399, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2011
# 2026-01-28 15:54:54,432, 2113979629.py, 8, INFO, Processing year 2012 for ticker KEY.
# 2026-01-28 15:54:54,438, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2012
# 2026-01-28 15:54:54,477, 2113979629.py, 8, INFO, Processing year 2013 for ticker KEY.
# 2026-01-28 15:54:54,485, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2013
# 2026-01-28 15:54:54,514, 2113979629.py, 8, INFO, Processing year 2014 for ticker KEY.
# 2026-01-28 15:54:54,521, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2014
# 2026-01-28 15:54:54,553, 2113979629.py, 8, INFO, Processing year 2015 for ticker KEY.
# 2026-01-28 15:54:54,556, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2015
# 2026-01-28 15:54:54,589, 2113979629.py, 8, INFO, Processing year 2016 for ticker KEY.
# 2026-01-28 15:54:54,592, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2016
# 2026-01-28 15:54:54,622, 2113979629.py, 8, INFO, Processing year 2017 for ticker KEY.
# 2026-01-28 15:54:54,625, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2017
# 2026-01-28 15:54:54,657, 2113979629.py, 8, INFO, Processing year 2018 for ticker KEY.
# 2026-01-28 15:54:54,661, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2018
# 2026-01-28 15:54:54,691, 2113979629.py, 8, INFO, Processing year 2019 for ticker KEY.
# 2026-01-28 15:54:54,710, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2019
# 2026-01-28 15:54:54,741, 2113979629.py, 8, INFO, Processing year 2020 for ticker KEY.
# 2026-01-28 15:54:54,745, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2020

# %% [markdown]
# Why would we want to store data this way?
#
# + Data files are easier to maintain. We do not update old data, only recent data or the most recent "delta".
# + Parquet files, as long as they maintain a consistent schema, can all be read jointly.

# %% [markdown]
# # Load, Transform, and Save
#
# In this section, we will load the Parquet files we generated, transform the data, and save the resulting dataset.

# %% [markdown]
# ## Load
#
# + Parquet files can be read individually or as a collection.
# + `dd.read_parquet()` can take a list (collection) of files as input.
# + Use `glob` to obtain the collection of files.

# %%
from glob import glob

parquet_files = glob(os.path.join(PRICE_DATA, "**/*.parquet"), recursive = True)
_logs.info(f'Found {len(parquet_files)} parquet files for reading back into Dask.')

dd_px = dd.read_parquet(parquet_files).set_index("ticker")
# Out:
# 2026-01-28 15:55:03,016, 174194153.py, 4, INFO, Found 2045 parquet files for reading back into Dask.

# %% [markdown]
# ## Transform
#
# + This transformation step will create a *Features* data set. In our case, features will be stock returns (we obtained prices).
# + Dask dataframes work similarly to Pandas dataframes: in particular, we can perform groupby and apply operations.
# + Notice the use of [an anonymous (lambda) function](https://realpython.com/python-lambda/) in the apply statement.
#
# In the code below, the following operation occurs:
#
# + Start with a Dask dataframe, `dd_px`.
# + Group the rows of this dataframe by the variable `ticker`, i.e., each group will contain the observations that pertain only to one ticker at a time. The `group_key` parameter controls whether an index entry is added with the value of the grouping variable (`ticker` in this case); if we made `group_keys=True`, we would have a duplicate `ticker` column.
# + For each group defined by a `ticker`, `apply()` the following calculation:
#
#     - Sort the values by `Date` in ascending order.
#     - Assign a new variable called `Close_lag_1` by shifting the position of the closing price (`Close`) by one position.
#     - Define the schema of the resulting dataframe. If we omit this specification, we would get a warning; however, the simplicity of the calculation ensures that Dask can determine the resulting schema.

# %%
dd_px
# Out:
# Dask DataFrame Structure:
#                           Date     Open     High      Low    Close Adj Close   Volume  source   Year
# npartitions=60
# ACN             datetime64[ns]  float64  float64  float64  float64   float64  float64  object  int32
# ALDX                       ...      ...      ...      ...      ...       ...      ...     ...    ...
# ...                        ...      ...      ...      ...      ...       ...      ...     ...    ...
# ZIXI                       ...      ...      ...      ...      ...       ...      ...     ...    ...
# ZIXI                       ...      ...      ...      ...      ...       ...      ...     ...    ...
# Dask Name: sort_index, 8 graph layers

# %%
dd_shift = (
    dd_px
        .groupby('ticker', group_keys=False)
        .apply(
            lambda x: x.sort_values('Date', ascending = True)
                       .assign(Close_lag_1 = x['Close'].shift(1)), 
            meta = pd.DataFrame(data ={'Date': 'datetime64[ns]',
                    'Open': 'f8',
                    'High': 'f8',
                    'Low': 'f8',
                    'Close': 'f8',
                    'Adj Close': 'f8',
                    'Volume': 'i8',
                    'source': 'object',
                    'Year': 'int32',
                    'Close_lag_1': 'f8'},
                    index = pd.Index([], dtype=pd.StringDtype(), name='ticker'))
    ))

# %% [markdown]
# Finally, using the dataframe that we created above, we can now `assign` the `Returns` variable to the entire dataset.

# %%
dd_shift[["Close", "Close_lag_1"]].dtypes
# Out:
# Close          object
# Close_lag_1    object
# dtype: object

# %%
import dask.dataframe as dd

dd_shift["Close"] = dd.to_numeric(dd_shift["Close"], errors="coerce")
dd_shift["Close_lag_1"] = dd.to_numeric(dd_shift["Close_lag_1"], errors="coerce")

# optional but recommended: remove rows where conversion failed or lag is missing
dd_shift = dd_shift.dropna(subset=["Close", "Close_lag_1"])
dd_shift = dd_shift[dd_shift["Close_lag_1"] != 0]

# %%
dd_rets = dd_shift.assign(
    Returns = lambda x: x['Close']/x['Close_lag_1'] - 1
)

# %% [markdown]
# Question: How do we know that we are not (erroneously) combining the last price of a ticker with the first price of the next ticker?

# %% [markdown]
# ## Lazy Exection
#
# What does `dd_rets` contain?

# %%
dd_rets
# Out:
# Dask DataFrame Structure:
#                   Date    Open    High     Low  Close Adj Close  Volume  source    Year Close_lag_1  Returns
# npartitions=60
# ACN             object  object  object  object  int64    object  object  object  object       int64  float64
# ALDX               ...     ...     ...     ...    ...       ...     ...     ...     ...         ...      ...
# ...                ...     ...     ...     ...    ...       ...     ...     ...     ...         ...      ...
# ZIXI               ...     ...     ...     ...    ...       ...     ...     ...     ...         ...      ...
# ZIXI               ...     ...     ...     ...    ...       ...     ...     ...     ...         ...      ...
# Dask Name: assign, 24 graph layers

# %% [markdown]
# + Dask is a lazy execution framework: commands will not execute until the computation is required.
# + To trigger an execution in dask use `.compute()` or execute a command that requires the actual values (for example, write to Parquet or SQL).

# %%
dd_rets.compute()
# Out:
#              Date   Open   High    Low  Close  Adj Close     Volume    source  \
# ticker
# ACN    2001-07-20  15.05  15.05  14.80  15.01  11.284108  9238500.0   ACN.csv
# ACN    2001-07-23  15.00  15.01  14.55  15.00  11.276587  7501000.0   ACN.csv
# ACN    2001-07-24  14.95  14.97  14.70  14.86  11.171341  3537300.0   ACN.csv
# ACN    2001-07-25  14.70  14.95  14.65  14.95  11.238999  4208100.0   ACN.csv
# ACN    2001-07-26  14.95  14.99  14.50  14.50  10.900705  6335300.0   ACN.csv
# ...           ...    ...    ...    ...    ...        ...        ...       ...
# ZIXI   2020-03-26   4.06   4.53   3.88   4.51   4.510000  1668500.0  ZIXI.csv
# ZIXI   2020-03-27   4.49   4.71   4.10   4.60   4.600000  1146800.0  ZIXI.csv
# ZIXI   2020-03-30   4.83   4.87   4.44   4.64   4.640000  1212000.0  ZIXI.csv
# ZIXI   2020-03-31   4.60   4.69   4.10   4.31   4.310000  1057200.0  ZIXI.csv
# ZIXI   2020-04-01   4.11   4.16   3.80   3.82   3.820000   539500.0  ZIXI.csv
#
#         Year  Close_lag_1   Returns
# ticker
# ACN     2001        15.17 -0.010547
# ACN     2001        15.01 -0.000666
# ACN     2001        15.00 -0.009333
# ACN     2001        14.86  0.006057
# ACN     2001        14.95 -0.030100
# ...      ...          ...       ...
# ZIXI    2020         4.04  0.116337
# ZIXI    2020         4.00  0.150000
# ZIXI    2020         3.85  0.205195
# ZIXI    2020         3.77  0.143236
# ZIXI    2020         3.78  0.010582
#
# [239593 rows x 11 columns]

# %% [markdown]
# ## Save
#
# With our transformed data, we can now save the new feature to a Parquet file. We will need to answer the following questions depending on our context, setup, and available resources:
#
# + Should we keep the same namespace?
# + Should we save all columns?

# %%
dd_rets
# Out:
# Dask DataFrame Structure:
#                   Date    Open    High     Low  Close Adj Close  Volume  source    Year Close_lag_1  Returns
# npartitions=60
# ACN             object  object  object  object  int64    object  object  object  object       int64  float64
# ALDX               ...     ...     ...     ...    ...       ...     ...     ...     ...         ...      ...
# ...                ...     ...     ...     ...    ...       ...     ...     ...     ...         ...      ...
# ZIXI               ...     ...     ...     ...    ...       ...     ...     ...     ...         ...      ...
# ZIXI               ...     ...     ...     ...    ...       ...     ...     ...     ...         ...      ...
# Dask Name: assign, 24 graph layers

# %%
# CLean up before save
FEATURES_DATA = os.getenv("FEATURES_DATA")
if os.path.exists(FEATURES_DATA):
    shutil.rmtree(FEATURES_DATA)
dd_rets.to_parquet(FEATURES_DATA, 
                   overwrite = True, 
                   schema={
                       'Date': 'timestamp[ns]',
                       'Open': 'float64',
                       'High': 'float64',
                       'Low': 'float64',
                       'Close': 'float64',
                       'Adj Close': 'float64',
                       'Volume': 'int64',
                       'source': 'string',
                       'Year': 'int32',
                       'Close_lag_1': 'float64',
                       'Returns': 'float64',
                       'ticker': 'large_string'
                   })

# %% [markdown]
# # Optional: from Jupyter to Command Line
#
# + We have drafted our code in a Jupyter Notebook.
# + Finalized code should be written in Python modules.
#
# ## Object Oriented vs Functional Programming
#
# + We can use classes to keep parameters and functions together.
# + We *could* use Object Oriented Programming, but parallelization of data manipulation and modelling tasks benefit from *Functional Programming*.
# + An Idea:
#
#     - [Data Oriented Programming](https://blog.klipse.tech/dop/2022/06/22/principles-of-dop.html).
#     - Use the class to bundle together parameters and functions.
#     - Use stateless operations and treat all data objects as immutable (we do not modify them, we overwrite them).
#     - Take advantage of [`@staticmethod`](https://realpython.com/instance-class-and-static-methods-demystified/).
#
# The code is in `./05_src/stock_prices/data_manager.py`.

# %% [markdown]
# Our original design was:
#
# ![](./images/02_target_pipeline_manager.png)

# %%
from stock_prices.data_manager import DataManager
dm = DataManager()

# %% [markdown]
# Download all prices.

# %%
dm.process_sample_files()
# Out:
# 2026-01-28 15:56:45,415, data_manager.py, 53, INFO, Processing sample of tickers
# 2026-01-28 15:56:45,418, data_manager.py, 64, INFO, Getting file list from ../../05_src/data/prices_csv/
# 2026-01-28 15:56:45,621, data_manager.py, 66, INFO, Found 5884 files in ../../05_src/data/prices/
# 2026-01-28 15:56:45,623, data_manager.py, 74, INFO, Selecting sample of files
# 2026-01-28 15:56:45,631, data_manager.py, 80, INFO, Selected 30 files
# 2026-01-28 15:56:45,633, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\BCS.csv
# 2026-01-28 15:56:45,633, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\BCS.csv
# 2026-01-28 15:56:45,833, data_manager.py, 101, INFO, Saving data by year
# 2026-01-28 15:56:45,839, data_manager.py, 103, INFO, Processing ticker: BCS
# 2026-01-28 15:56:45,860, data_manager.py, 107, INFO, Processing year 1986 for ticker BCS.
# 2026-01-28 15:56:45,880, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BCS\BCS_1986
# 2026-01-28 15:56:46,115, data_manager.py, 107, INFO, Processing year 1987 for ticker BCS.
# 2026-01-28 15:56:46,125, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BCS\BCS_1987
# 2026-01-28 15:56:46,288, data_manager.py, 107, INFO, Processing year 1988 for ticker BCS.
# 2026-01-28 15:56:46,326, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BCS\BCS_1988
# 2026-01-28 15:56:46,747, data_manager.py, 107, INFO, Processing year 1989 for ticker BCS.
# 2026-01-28 15:56:46,775, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BCS\BCS_1989
# 2026-01-28 15:56:47,087, data_manager.py, 107, INFO, Processing year 1990 for ticker BCS.
# 2026-01-28 15:56:47,109, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BCS\BCS_1990
# 2026-01-28 15:56:47,498, data_manager.py, 107, INFO, Processing year 1991 for ticker BCS.
# 2026-01-28 15:56:47,539, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BCS\BCS_1991
# 2026-01-28 15:56:47,735, data_manager.py, 107, INFO, Processing year 1992 for ticker BCS.
# 2026-01-28 15:56:47,755, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BCS\BCS_1992
# 2026-01-28 15:56:47,934, data_manager.py, 107, INFO, Processing year 1993 for ticker BCS.
# 2026-01-28 15:56:47,954, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BCS\BCS_1993
# 2026-01-28 15:56:48,092, data_manager.py, 107, INFO, Processing year 1994 for ticker BCS.
# 2026-01-28 15:56:48,119, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BCS\BCS_1994
# 2026-01-28 15:56:48,397, data_manager.py, 107, INFO, Processing year 1995 for ticker BCS.
# 2026-01-28 15:56:48,422, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BCS\BCS_1995
# 2026-01-28 15:56:48,774, data_manager.py, 107, INFO, Processing year 1996 for ticker BCS.
# 2026-01-28 15:56:48,796, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BCS\BCS_1996
# 2026-01-28 15:56:49,257, data_manager.py, 107, INFO, Processing year 1997 for ticker BCS.
# 2026-01-28 15:56:49,278, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BCS\BCS_1997
# 2026-01-28 15:56:49,555, data_manager.py, 107, INFO, Processing year 1998 for ticker BCS.
# 2026-01-28 15:56:49,577, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BCS\BCS_1998
# 2026-01-28 15:56:49,932, data_manager.py, 107, INFO, Processing year 1999 for ticker BCS.
# 2026-01-28 15:56:49,964, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BCS\BCS_1999
# 2026-01-28 15:56:50,377, data_manager.py, 107, INFO, Processing year 2000 for ticker BCS.
# 2026-01-28 15:56:50,400, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BCS\BCS_2000
# 2026-01-28 15:56:50,700, data_manager.py, 107, INFO, Processing year 2001 for ticker BCS.
# 2026-01-28 15:56:50,709, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BCS\BCS_2001
# 2026-01-28 15:56:51,299, data_manager.py, 107, INFO, Processing year 2002 for ticker BCS.
# 2026-01-28 15:56:51,333, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BCS\BCS_2002
# 2026-01-28 15:56:51,702, data_manager.py, 107, INFO, Processing year 2003 for ticker BCS.
# 2026-01-28 15:56:51,732, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BCS\BCS_2003
# 2026-01-28 15:56:51,936, data_manager.py, 107, INFO, Processing year 2004 for ticker BCS.
# 2026-01-28 15:56:51,946, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BCS\BCS_2004
# 2026-01-28 15:56:52,212, data_manager.py, 107, INFO, Processing year 2005 for ticker BCS.
# 2026-01-28 15:56:52,236, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BCS\BCS_2005
# 2026-01-28 15:56:52,454, data_manager.py, 107, INFO, Processing year 2006 for ticker BCS.
# 2026-01-28 15:56:52,480, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BCS\BCS_2006
# 2026-01-28 15:56:52,678, data_manager.py, 107, INFO, Processing year 2007 for ticker BCS.
# 2026-01-28 15:56:52,700, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BCS\BCS_2007
# 2026-01-28 15:56:52,876, data_manager.py, 107, INFO, Processing year 2008 for ticker BCS.
# 2026-01-28 15:56:52,898, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BCS\BCS_2008
# 2026-01-28 15:56:53,060, data_manager.py, 107, INFO, Processing year 2009 for ticker BCS.
# 2026-01-28 15:56:53,079, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BCS\BCS_2009
# 2026-01-28 15:56:53,240, data_manager.py, 107, INFO, Processing year 2010 for ticker BCS.
# 2026-01-28 15:56:53,264, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BCS\BCS_2010
# 2026-01-28 15:56:53,414, data_manager.py, 107, INFO, Processing year 2011 for ticker BCS.
# 2026-01-28 15:56:53,437, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BCS\BCS_2011
# 2026-01-28 15:56:53,565, data_manager.py, 107, INFO, Processing year 2012 for ticker BCS.
# 2026-01-28 15:56:53,600, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BCS\BCS_2012
# 2026-01-28 15:56:53,741, data_manager.py, 107, INFO, Processing year 2013 for ticker BCS.
# 2026-01-28 15:56:53,760, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BCS\BCS_2013
# 2026-01-28 15:56:53,982, data_manager.py, 107, INFO, Processing year 2014 for ticker BCS.
# 2026-01-28 15:56:54,000, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BCS\BCS_2014
# 2026-01-28 15:56:54,216, data_manager.py, 107, INFO, Processing year 2015 for ticker BCS.
# 2026-01-28 15:56:54,238, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BCS\BCS_2015
# 2026-01-28 15:56:54,398, data_manager.py, 107, INFO, Processing year 2016 for ticker BCS.
# 2026-01-28 15:56:54,415, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BCS\BCS_2016
# 2026-01-28 15:56:54,557, data_manager.py, 107, INFO, Processing year 2017 for ticker BCS.
# 2026-01-28 15:56:54,578, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BCS\BCS_2017
# 2026-01-28 15:56:54,709, data_manager.py, 107, INFO, Processing year 2018 for ticker BCS.
# 2026-01-28 15:56:54,730, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BCS\BCS_2018
# 2026-01-28 15:56:54,906, data_manager.py, 107, INFO, Processing year 2019 for ticker BCS.
# 2026-01-28 15:56:54,929, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BCS\BCS_2019
# 2026-01-28 15:56:55,118, data_manager.py, 107, INFO, Processing year 2020 for ticker BCS.
# 2026-01-28 15:56:55,136, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BCS\BCS_2020
# 2026-01-28 15:56:55,257, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\AFGC.csv
# 2026-01-28 15:56:55,264, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\AFGC.csv
# 2026-01-28 15:56:55,363, data_manager.py, 101, INFO, Saving data by year
# 2026-01-28 15:56:55,370, data_manager.py, 103, INFO, Processing ticker: AFGC
# 2026-01-28 15:56:55,384, data_manager.py, 107, INFO, Processing year 2020 for ticker AFGC.
# 2026-01-28 15:56:55,423, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/AFGC\AFGC_2020
# 2026-01-28 15:56:55,642, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\RILYH.csv
# 2026-01-28 15:56:55,647, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\RILYH.csv
# 2026-01-28 15:56:55,789, data_manager.py, 101, INFO, Saving data by year
# 2026-01-28 15:56:55,799, data_manager.py, 103, INFO, Processing ticker: RILYH
# 2026-01-28 15:56:55,818, data_manager.py, 107, INFO, Processing year 2018 for ticker RILYH.
# 2026-01-28 15:56:55,840, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/RILYH\RILYH_2018
# 2026-01-28 15:56:56,091, data_manager.py, 107, INFO, Processing year 2019 for ticker RILYH.
# 2026-01-28 15:56:56,117, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/RILYH\RILYH_2019
# 2026-01-28 15:56:56,290, data_manager.py, 107, INFO, Processing year 2020 for ticker RILYH.
# 2026-01-28 15:56:56,305, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/RILYH\RILYH_2020
# 2026-01-28 15:56:56,440, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\QRTEA.csv
# 2026-01-28 15:56:56,444, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\QRTEA.csv
# 2026-01-28 15:56:56,635, data_manager.py, 101, INFO, Saving data by year
# 2026-01-28 15:56:56,640, data_manager.py, 103, INFO, Processing ticker: QRTEA
# 2026-01-28 15:56:56,655, data_manager.py, 107, INFO, Processing year 2006 for ticker QRTEA.
# 2026-01-28 15:56:56,667, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/QRTEA\QRTEA_2006
# 2026-01-28 15:56:56,772, data_manager.py, 107, INFO, Processing year 2007 for ticker QRTEA.
# 2026-01-28 15:56:56,788, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/QRTEA\QRTEA_2007
# 2026-01-28 15:56:56,880, data_manager.py, 107, INFO, Processing year 2008 for ticker QRTEA.
# 2026-01-28 15:56:56,892, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/QRTEA\QRTEA_2008
# 2026-01-28 15:56:56,985, data_manager.py, 107, INFO, Processing year 2009 for ticker QRTEA.
# 2026-01-28 15:56:57,001, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/QRTEA\QRTEA_2009
# 2026-01-28 15:56:57,112, data_manager.py, 107, INFO, Processing year 2010 for ticker QRTEA.
# 2026-01-28 15:56:57,134, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/QRTEA\QRTEA_2010
# 2026-01-28 15:56:57,290, data_manager.py, 107, INFO, Processing year 2011 for ticker QRTEA.
# 2026-01-28 15:56:57,310, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/QRTEA\QRTEA_2011
# 2026-01-28 15:56:57,449, data_manager.py, 107, INFO, Processing year 2012 for ticker QRTEA.
# 2026-01-28 15:56:57,464, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/QRTEA\QRTEA_2012
# 2026-01-28 15:56:57,567, data_manager.py, 107, INFO, Processing year 2013 for ticker QRTEA.
# 2026-01-28 15:56:57,583, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/QRTEA\QRTEA_2013
# 2026-01-28 15:56:57,695, data_manager.py, 107, INFO, Processing year 2014 for ticker QRTEA.
# 2026-01-28 15:56:57,712, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/QRTEA\QRTEA_2014
# 2026-01-28 15:56:57,810, data_manager.py, 107, INFO, Processing year 2015 for ticker QRTEA.
# 2026-01-28 15:56:57,823, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/QRTEA\QRTEA_2015
# 2026-01-28 15:56:57,921, data_manager.py, 107, INFO, Processing year 2016 for ticker QRTEA.
# 2026-01-28 15:56:57,941, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/QRTEA\QRTEA_2016
# 2026-01-28 15:56:58,282, data_manager.py, 107, INFO, Processing year 2017 for ticker QRTEA.
# 2026-01-28 15:56:58,323, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/QRTEA\QRTEA_2017
# 2026-01-28 15:56:58,823, data_manager.py, 107, INFO, Processing year 2018 for ticker QRTEA.
# 2026-01-28 15:56:58,868, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/QRTEA\QRTEA_2018
# 2026-01-28 15:56:59,397, data_manager.py, 107, INFO, Processing year 2019 for ticker QRTEA.
# 2026-01-28 15:56:59,483, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/QRTEA\QRTEA_2019
# 2026-01-28 15:56:59,866, data_manager.py, 107, INFO, Processing year 2020 for ticker QRTEA.
# 2026-01-28 15:56:59,888, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/QRTEA\QRTEA_2020
# 2026-01-28 15:57:00,192, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\PRAH.csv
# 2026-01-28 15:57:00,200, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\PRAH.csv
# 2026-01-28 15:57:00,556, data_manager.py, 101, INFO, Saving data by year
# 2026-01-28 15:57:00,580, data_manager.py, 103, INFO, Processing ticker: PRAH
# 2026-01-28 15:57:00,609, data_manager.py, 107, INFO, Processing year 2014 for ticker PRAH.
# 2026-01-28 15:57:00,874, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PRAH\PRAH_2014
# 2026-01-28 15:57:01,080, data_manager.py, 107, INFO, Processing year 2015 for ticker PRAH.
# 2026-01-28 15:57:01,102, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PRAH\PRAH_2015
# 2026-01-28 15:57:01,424, data_manager.py, 107, INFO, Processing year 2016 for ticker PRAH.
# 2026-01-28 15:57:01,446, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PRAH\PRAH_2016
# 2026-01-28 15:57:01,670, data_manager.py, 107, INFO, Processing year 2017 for ticker PRAH.
# 2026-01-28 15:57:01,694, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PRAH\PRAH_2017
# 2026-01-28 15:57:01,906, data_manager.py, 107, INFO, Processing year 2018 for ticker PRAH.
# 2026-01-28 15:57:01,934, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PRAH\PRAH_2018
# 2026-01-28 15:57:02,154, data_manager.py, 107, INFO, Processing year 2019 for ticker PRAH.
# 2026-01-28 15:57:02,175, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PRAH\PRAH_2019
# 2026-01-28 15:57:02,504, data_manager.py, 107, INFO, Processing year 2020 for ticker PRAH.
# 2026-01-28 15:57:02,528, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PRAH\PRAH_2020
# 2026-01-28 15:57:02,752, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\GNMK.csv
# 2026-01-28 15:57:02,755, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\GNMK.csv
# 2026-01-28 15:57:02,946, data_manager.py, 101, INFO, Saving data by year
# 2026-01-28 15:57:02,953, data_manager.py, 103, INFO, Processing ticker: GNMK
# 2026-01-28 15:57:02,974, data_manager.py, 107, INFO, Processing year 2010 for ticker GNMK.
# 2026-01-28 15:57:03,000, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/GNMK\GNMK_2010
# 2026-01-28 15:57:03,551, data_manager.py, 107, INFO, Processing year 2011 for ticker GNMK.
# 2026-01-28 15:57:03,568, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/GNMK\GNMK_2011
# 2026-01-28 15:57:03,651, data_manager.py, 107, INFO, Processing year 2012 for ticker GNMK.
# 2026-01-28 15:57:03,666, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/GNMK\GNMK_2012
# 2026-01-28 15:57:03,769, data_manager.py, 107, INFO, Processing year 2013 for ticker GNMK.
# 2026-01-28 15:57:03,780, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/GNMK\GNMK_2013
# 2026-01-28 15:57:03,848, data_manager.py, 107, INFO, Processing year 2014 for ticker GNMK.
# 2026-01-28 15:57:03,859, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/GNMK\GNMK_2014
# 2026-01-28 15:57:03,926, data_manager.py, 107, INFO, Processing year 2015 for ticker GNMK.
# 2026-01-28 15:57:03,936, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/GNMK\GNMK_2015
# 2026-01-28 15:57:04,013, data_manager.py, 107, INFO, Processing year 2016 for ticker GNMK.
# 2026-01-28 15:57:04,021, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/GNMK\GNMK_2016
# 2026-01-28 15:57:04,089, data_manager.py, 107, INFO, Processing year 2017 for ticker GNMK.
# 2026-01-28 15:57:04,100, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/GNMK\GNMK_2017
# 2026-01-28 15:57:04,163, data_manager.py, 107, INFO, Processing year 2018 for ticker GNMK.
# 2026-01-28 15:57:04,172, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/GNMK\GNMK_2018
# 2026-01-28 15:57:04,234, data_manager.py, 107, INFO, Processing year 2019 for ticker GNMK.
# 2026-01-28 15:57:04,241, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/GNMK\GNMK_2019
# 2026-01-28 15:57:04,295, data_manager.py, 107, INFO, Processing year 2020 for ticker GNMK.
# 2026-01-28 15:57:04,303, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/GNMK\GNMK_2020
# 2026-01-28 15:57:04,359, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\NUV.csv
# 2026-01-28 15:57:04,363, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\NUV.csv
# 2026-01-28 15:57:04,452, data_manager.py, 101, INFO, Saving data by year
# 2026-01-28 15:57:04,454, data_manager.py, 103, INFO, Processing ticker: NUV
# 2026-01-28 15:57:04,466, data_manager.py, 107, INFO, Processing year 1987 for ticker NUV.
# 2026-01-28 15:57:04,482, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NUV\NUV_1987
# 2026-01-28 15:57:04,568, data_manager.py, 107, INFO, Processing year 1988 for ticker NUV.
# 2026-01-28 15:57:04,583, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NUV\NUV_1988
# 2026-01-28 15:57:04,654, data_manager.py, 107, INFO, Processing year 1989 for ticker NUV.
# 2026-01-28 15:57:04,664, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NUV\NUV_1989
# 2026-01-28 15:57:04,729, data_manager.py, 107, INFO, Processing year 1990 for ticker NUV.
# 2026-01-28 15:57:04,739, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NUV\NUV_1990
# 2026-01-28 15:57:04,835, data_manager.py, 107, INFO, Processing year 1991 for ticker NUV.
# 2026-01-28 15:57:04,846, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NUV\NUV_1991
# 2026-01-28 15:57:04,956, data_manager.py, 107, INFO, Processing year 1992 for ticker NUV.
# 2026-01-28 15:57:04,970, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NUV\NUV_1992
# 2026-01-28 15:57:05,081, data_manager.py, 107, INFO, Processing year 1993 for ticker NUV.
# 2026-01-28 15:57:05,092, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NUV\NUV_1993
# 2026-01-28 15:57:05,159, data_manager.py, 107, INFO, Processing year 1994 for ticker NUV.
# 2026-01-28 15:57:05,167, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NUV\NUV_1994
# 2026-01-28 15:57:05,224, data_manager.py, 107, INFO, Processing year 1995 for ticker NUV.
# 2026-01-28 15:57:05,237, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NUV\NUV_1995
# 2026-01-28 15:57:05,283, data_manager.py, 107, INFO, Processing year 1996 for ticker NUV.
# 2026-01-28 15:57:05,289, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NUV\NUV_1996
# 2026-01-28 15:57:05,327, data_manager.py, 107, INFO, Processing year 1997 for ticker NUV.
# 2026-01-28 15:57:05,336, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NUV\NUV_1997
# 2026-01-28 15:57:05,375, data_manager.py, 107, INFO, Processing year 1998 for ticker NUV.
# 2026-01-28 15:57:05,381, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NUV\NUV_1998
# 2026-01-28 15:57:05,417, data_manager.py, 107, INFO, Processing year 1999 for ticker NUV.
# 2026-01-28 15:57:05,424, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NUV\NUV_1999
# 2026-01-28 15:57:05,459, data_manager.py, 107, INFO, Processing year 2000 for ticker NUV.
# 2026-01-28 15:57:05,465, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NUV\NUV_2000
# 2026-01-28 15:57:05,508, data_manager.py, 107, INFO, Processing year 2001 for ticker NUV.
# 2026-01-28 15:57:05,515, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NUV\NUV_2001
# 2026-01-28 15:57:05,557, data_manager.py, 107, INFO, Processing year 2002 for ticker NUV.
# 2026-01-28 15:57:05,568, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NUV\NUV_2002
# 2026-01-28 15:57:05,628, data_manager.py, 107, INFO, Processing year 2003 for ticker NUV.
# 2026-01-28 15:57:05,634, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NUV\NUV_2003
# 2026-01-28 15:57:05,710, data_manager.py, 107, INFO, Processing year 2004 for ticker NUV.
# 2026-01-28 15:57:05,717, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NUV\NUV_2004
# 2026-01-28 15:57:05,755, data_manager.py, 107, INFO, Processing year 2005 for ticker NUV.
# 2026-01-28 15:57:05,760, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NUV\NUV_2005
# 2026-01-28 15:57:05,801, data_manager.py, 107, INFO, Processing year 2006 for ticker NUV.
# 2026-01-28 15:57:05,807, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NUV\NUV_2006
# 2026-01-28 15:57:05,845, data_manager.py, 107, INFO, Processing year 2007 for ticker NUV.
# 2026-01-28 15:57:05,853, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NUV\NUV_2007
# 2026-01-28 15:57:05,904, data_manager.py, 107, INFO, Processing year 2008 for ticker NUV.
# 2026-01-28 15:57:05,912, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NUV\NUV_2008
# 2026-01-28 15:57:05,970, data_manager.py, 107, INFO, Processing year 2009 for ticker NUV.
# 2026-01-28 15:57:05,983, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NUV\NUV_2009
# 2026-01-28 15:57:06,054, data_manager.py, 107, INFO, Processing year 2010 for ticker NUV.
# 2026-01-28 15:57:06,063, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NUV\NUV_2010
# 2026-01-28 15:57:06,134, data_manager.py, 107, INFO, Processing year 2011 for ticker NUV.
# 2026-01-28 15:57:06,143, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NUV\NUV_2011
# 2026-01-28 15:57:06,212, data_manager.py, 107, INFO, Processing year 2012 for ticker NUV.
# 2026-01-28 15:57:06,221, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NUV\NUV_2012
# 2026-01-28 15:57:06,283, data_manager.py, 107, INFO, Processing year 2013 for ticker NUV.
# 2026-01-28 15:57:06,294, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NUV\NUV_2013
# 2026-01-28 15:57:06,359, data_manager.py, 107, INFO, Processing year 2014 for ticker NUV.
# 2026-01-28 15:57:06,367, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NUV\NUV_2014
# 2026-01-28 15:57:06,425, data_manager.py, 107, INFO, Processing year 2015 for ticker NUV.
# 2026-01-28 15:57:06,434, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NUV\NUV_2015
# 2026-01-28 15:57:06,567, data_manager.py, 107, INFO, Processing year 2016 for ticker NUV.
# 2026-01-28 15:57:06,585, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NUV\NUV_2016
# 2026-01-28 15:57:06,739, data_manager.py, 107, INFO, Processing year 2017 for ticker NUV.
# 2026-01-28 15:57:06,770, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NUV\NUV_2017
# 2026-01-28 15:57:06,867, data_manager.py, 107, INFO, Processing year 2018 for ticker NUV.
# 2026-01-28 15:57:06,875, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NUV\NUV_2018
# 2026-01-28 15:57:06,987, data_manager.py, 107, INFO, Processing year 2019 for ticker NUV.
# 2026-01-28 15:57:07,002, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NUV\NUV_2019
# 2026-01-28 15:57:07,068, data_manager.py, 107, INFO, Processing year 2020 for ticker NUV.
# 2026-01-28 15:57:07,076, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NUV\NUV_2020
# 2026-01-28 15:57:07,141, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\NEX.csv
# 2026-01-28 15:57:07,143, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\NEX.csv
# 2026-01-28 15:57:07,215, data_manager.py, 101, INFO, Saving data by year
# 2026-01-28 15:57:07,215, data_manager.py, 103, INFO, Processing ticker: NEX
# 2026-01-28 15:57:07,215, data_manager.py, 107, INFO, Processing year 2007 for ticker NEX.
# 2026-01-28 15:57:07,234, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NEX\NEX_2007
# 2026-01-28 15:57:07,303, data_manager.py, 107, INFO, Processing year 2008 for ticker NEX.
# 2026-01-28 15:57:07,310, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NEX\NEX_2008
# 2026-01-28 15:57:07,369, data_manager.py, 107, INFO, Processing year 2010 for ticker NEX.
# 2026-01-28 15:57:07,376, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NEX\NEX_2010
# 2026-01-28 15:57:07,428, data_manager.py, 107, INFO, Processing year 2011 for ticker NEX.
# 2026-01-28 15:57:07,436, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NEX\NEX_2011
# 2026-01-28 15:57:07,486, data_manager.py, 107, INFO, Processing year 2012 for ticker NEX.
# 2026-01-28 15:57:07,492, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NEX\NEX_2012
# 2026-01-28 15:57:07,540, data_manager.py, 107, INFO, Processing year 2015 for ticker NEX.
# 2026-01-28 15:57:07,551, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NEX\NEX_2015
# 2026-01-28 15:57:07,600, data_manager.py, 107, INFO, Processing year 2016 for ticker NEX.
# 2026-01-28 15:57:07,605, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NEX\NEX_2016
# 2026-01-28 15:57:07,656, data_manager.py, 107, INFO, Processing year 2017 for ticker NEX.
# 2026-01-28 15:57:07,665, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NEX\NEX_2017
# 2026-01-28 15:57:07,717, data_manager.py, 107, INFO, Processing year 2018 for ticker NEX.
# 2026-01-28 15:57:07,728, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NEX\NEX_2018
# 2026-01-28 15:57:07,796, data_manager.py, 107, INFO, Processing year 2019 for ticker NEX.
# 2026-01-28 15:57:07,806, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NEX\NEX_2019
# 2026-01-28 15:57:07,882, data_manager.py, 107, INFO, Processing year 2020 for ticker NEX.
# 2026-01-28 15:57:07,888, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NEX\NEX_2020
# 2026-01-28 15:57:07,968, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\TCBI.csv
# 2026-01-28 15:57:07,970, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\TCBI.csv
# 2026-01-28 15:57:08,055, data_manager.py, 101, INFO, Saving data by year
# 2026-01-28 15:57:08,055, data_manager.py, 103, INFO, Processing ticker: TCBI
# 2026-01-28 15:57:08,068, data_manager.py, 107, INFO, Processing year 2003 for ticker TCBI.
# 2026-01-28 15:57:08,079, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/TCBI\TCBI_2003
# 2026-01-28 15:57:08,144, data_manager.py, 107, INFO, Processing year 2004 for ticker TCBI.
# 2026-01-28 15:57:08,154, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/TCBI\TCBI_2004
# 2026-01-28 15:57:08,233, data_manager.py, 107, INFO, Processing year 2005 for ticker TCBI.
# 2026-01-28 15:57:08,240, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/TCBI\TCBI_2005
# 2026-01-28 15:57:08,290, data_manager.py, 107, INFO, Processing year 2006 for ticker TCBI.
# 2026-01-28 15:57:08,296, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/TCBI\TCBI_2006
# 2026-01-28 15:57:08,346, data_manager.py, 107, INFO, Processing year 2007 for ticker TCBI.
# 2026-01-28 15:57:08,354, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/TCBI\TCBI_2007
# 2026-01-28 15:57:08,418, data_manager.py, 107, INFO, Processing year 2008 for ticker TCBI.
# 2026-01-28 15:57:08,420, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/TCBI\TCBI_2008
# 2026-01-28 15:57:08,491, data_manager.py, 107, INFO, Processing year 2009 for ticker TCBI.
# 2026-01-28 15:57:08,504, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/TCBI\TCBI_2009
# 2026-01-28 15:57:08,576, data_manager.py, 107, INFO, Processing year 2010 for ticker TCBI.
# 2026-01-28 15:57:08,589, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/TCBI\TCBI_2010
# 2026-01-28 15:57:08,669, data_manager.py, 107, INFO, Processing year 2011 for ticker TCBI.
# 2026-01-28 15:57:08,683, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/TCBI\TCBI_2011
# 2026-01-28 15:57:08,765, data_manager.py, 107, INFO, Processing year 2012 for ticker TCBI.
# 2026-01-28 15:57:08,776, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/TCBI\TCBI_2012
# 2026-01-28 15:57:08,842, data_manager.py, 107, INFO, Processing year 2013 for ticker TCBI.
# 2026-01-28 15:57:08,854, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/TCBI\TCBI_2013
# 2026-01-28 15:57:08,937, data_manager.py, 107, INFO, Processing year 2014 for ticker TCBI.
# 2026-01-28 15:57:08,950, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/TCBI\TCBI_2014
# 2026-01-28 15:57:09,023, data_manager.py, 107, INFO, Processing year 2015 for ticker TCBI.
# 2026-01-28 15:57:09,034, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/TCBI\TCBI_2015
# 2026-01-28 15:57:09,091, data_manager.py, 107, INFO, Processing year 2016 for ticker TCBI.
# 2026-01-28 15:57:09,100, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/TCBI\TCBI_2016
# 2026-01-28 15:57:09,173, data_manager.py, 107, INFO, Processing year 2017 for ticker TCBI.
# 2026-01-28 15:57:09,184, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/TCBI\TCBI_2017
# 2026-01-28 15:57:09,248, data_manager.py, 107, INFO, Processing year 2018 for ticker TCBI.
# 2026-01-28 15:57:09,260, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/TCBI\TCBI_2018
# 2026-01-28 15:57:09,347, data_manager.py, 107, INFO, Processing year 2019 for ticker TCBI.
# 2026-01-28 15:57:09,360, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/TCBI\TCBI_2019
# 2026-01-28 15:57:09,424, data_manager.py, 107, INFO, Processing year 2020 for ticker TCBI.
# 2026-01-28 15:57:09,433, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/TCBI\TCBI_2020
# 2026-01-28 15:57:09,490, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\FOX.csv
# 2026-01-28 15:57:09,492, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\FOX.csv
# 2026-01-28 15:57:09,551, data_manager.py, 101, INFO, Saving data by year
# 2026-01-28 15:57:09,554, data_manager.py, 103, INFO, Processing ticker: FOX
# 2026-01-28 15:57:09,563, data_manager.py, 107, INFO, Processing year 2019 for ticker FOX.
# 2026-01-28 15:57:09,576, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/FOX\FOX_2019
# 2026-01-28 15:57:09,668, data_manager.py, 107, INFO, Processing year 2020 for ticker FOX.
# 2026-01-28 15:57:09,680, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/FOX\FOX_2020
# 2026-01-28 15:57:09,754, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\VLGEA.csv
# 2026-01-28 15:57:09,755, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\VLGEA.csv
# 2026-01-28 15:57:09,838, data_manager.py, 101, INFO, Saving data by year
# 2026-01-28 15:57:09,841, data_manager.py, 103, INFO, Processing ticker: VLGEA
# 2026-01-28 15:57:09,850, data_manager.py, 107, INFO, Processing year 1973 for ticker VLGEA.
# 2026-01-28 15:57:09,866, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/VLGEA\VLGEA_1973
# 2026-01-28 15:57:09,931, data_manager.py, 107, INFO, Processing year 1974 for ticker VLGEA.
# 2026-01-28 15:57:09,938, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/VLGEA\VLGEA_1974
# 2026-01-28 15:57:09,991, data_manager.py, 107, INFO, Processing year 1975 for ticker VLGEA.
# 2026-01-28 15:57:10,000, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/VLGEA\VLGEA_1975
# 2026-01-28 15:57:10,059, data_manager.py, 107, INFO, Processing year 1976 for ticker VLGEA.
# 2026-01-28 15:57:10,068, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/VLGEA\VLGEA_1976
# 2026-01-28 15:57:10,131, data_manager.py, 107, INFO, Processing year 1977 for ticker VLGEA.
# 2026-01-28 15:57:10,140, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/VLGEA\VLGEA_1977
# 2026-01-28 15:57:10,228, data_manager.py, 107, INFO, Processing year 1978 for ticker VLGEA.
# 2026-01-28 15:57:10,238, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/VLGEA\VLGEA_1978
# 2026-01-28 15:57:10,321, data_manager.py, 107, INFO, Processing year 1979 for ticker VLGEA.
# 2026-01-28 15:57:10,331, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/VLGEA\VLGEA_1979
# 2026-01-28 15:57:10,400, data_manager.py, 107, INFO, Processing year 1980 for ticker VLGEA.
# 2026-01-28 15:57:10,409, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/VLGEA\VLGEA_1980
# 2026-01-28 15:57:10,470, data_manager.py, 107, INFO, Processing year 1981 for ticker VLGEA.
# 2026-01-28 15:57:10,479, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/VLGEA\VLGEA_1981
# 2026-01-28 15:57:10,533, data_manager.py, 107, INFO, Processing year 1982 for ticker VLGEA.
# 2026-01-28 15:57:10,541, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/VLGEA\VLGEA_1982
# 2026-01-28 15:57:10,606, data_manager.py, 107, INFO, Processing year 1983 for ticker VLGEA.
# 2026-01-28 15:57:10,615, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/VLGEA\VLGEA_1983
# 2026-01-28 15:57:10,666, data_manager.py, 107, INFO, Processing year 1984 for ticker VLGEA.
# 2026-01-28 15:57:10,675, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/VLGEA\VLGEA_1984
# 2026-01-28 15:57:10,723, data_manager.py, 107, INFO, Processing year 1985 for ticker VLGEA.
# 2026-01-28 15:57:10,731, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/VLGEA\VLGEA_1985
# 2026-01-28 15:57:10,790, data_manager.py, 107, INFO, Processing year 1986 for ticker VLGEA.
# 2026-01-28 15:57:10,801, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/VLGEA\VLGEA_1986
# 2026-01-28 15:57:10,856, data_manager.py, 107, INFO, Processing year 1987 for ticker VLGEA.
# 2026-01-28 15:57:10,865, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/VLGEA\VLGEA_1987
# 2026-01-28 15:57:10,916, data_manager.py, 107, INFO, Processing year 1988 for ticker VLGEA.
# 2026-01-28 15:57:10,923, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/VLGEA\VLGEA_1988
# 2026-01-28 15:57:10,985, data_manager.py, 107, INFO, Processing year 1989 for ticker VLGEA.
# 2026-01-28 15:57:10,996, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/VLGEA\VLGEA_1989
# 2026-01-28 15:57:11,102, data_manager.py, 107, INFO, Processing year 1990 for ticker VLGEA.
# 2026-01-28 15:57:11,138, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/VLGEA\VLGEA_1990
# 2026-01-28 15:57:11,219, data_manager.py, 107, INFO, Processing year 1991 for ticker VLGEA.
# 2026-01-28 15:57:11,231, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/VLGEA\VLGEA_1991
# 2026-01-28 15:57:11,299, data_manager.py, 107, INFO, Processing year 1992 for ticker VLGEA.
# 2026-01-28 15:57:11,308, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/VLGEA\VLGEA_1992
# 2026-01-28 15:57:11,363, data_manager.py, 107, INFO, Processing year 1993 for ticker VLGEA.
# 2026-01-28 15:57:11,369, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/VLGEA\VLGEA_1993
# 2026-01-28 15:57:11,412, data_manager.py, 107, INFO, Processing year 1994 for ticker VLGEA.
# 2026-01-28 15:57:11,433, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/VLGEA\VLGEA_1994
# 2026-01-28 15:57:11,489, data_manager.py, 107, INFO, Processing year 1995 for ticker VLGEA.
# 2026-01-28 15:57:11,499, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/VLGEA\VLGEA_1995
# 2026-01-28 15:57:11,553, data_manager.py, 107, INFO, Processing year 1996 for ticker VLGEA.
# 2026-01-28 15:57:11,558, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/VLGEA\VLGEA_1996
# 2026-01-28 15:57:11,619, data_manager.py, 107, INFO, Processing year 1997 for ticker VLGEA.
# 2026-01-28 15:57:11,634, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/VLGEA\VLGEA_1997
# 2026-01-28 15:57:11,710, data_manager.py, 107, INFO, Processing year 1998 for ticker VLGEA.
# 2026-01-28 15:57:11,722, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/VLGEA\VLGEA_1998
# 2026-01-28 15:57:11,793, data_manager.py, 107, INFO, Processing year 1999 for ticker VLGEA.
# 2026-01-28 15:57:11,804, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/VLGEA\VLGEA_1999
# 2026-01-28 15:57:11,881, data_manager.py, 107, INFO, Processing year 2000 for ticker VLGEA.
# 2026-01-28 15:57:11,893, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/VLGEA\VLGEA_2000
# 2026-01-28 15:57:11,970, data_manager.py, 107, INFO, Processing year 2001 for ticker VLGEA.
# 2026-01-28 15:57:11,981, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/VLGEA\VLGEA_2001
# 2026-01-28 15:57:12,057, data_manager.py, 107, INFO, Processing year 2002 for ticker VLGEA.
# 2026-01-28 15:57:12,066, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/VLGEA\VLGEA_2002
# 2026-01-28 15:57:12,130, data_manager.py, 107, INFO, Processing year 2003 for ticker VLGEA.
# 2026-01-28 15:57:12,136, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/VLGEA\VLGEA_2003
# 2026-01-28 15:57:12,192, data_manager.py, 107, INFO, Processing year 2004 for ticker VLGEA.
# 2026-01-28 15:57:12,200, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/VLGEA\VLGEA_2004
# 2026-01-28 15:57:12,254, data_manager.py, 107, INFO, Processing year 2005 for ticker VLGEA.
# 2026-01-28 15:57:12,263, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/VLGEA\VLGEA_2005
# 2026-01-28 15:57:12,314, data_manager.py, 107, INFO, Processing year 2006 for ticker VLGEA.
# 2026-01-28 15:57:12,321, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/VLGEA\VLGEA_2006
# 2026-01-28 15:57:12,379, data_manager.py, 107, INFO, Processing year 2007 for ticker VLGEA.
# 2026-01-28 15:57:12,388, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/VLGEA\VLGEA_2007
# 2026-01-28 15:57:12,440, data_manager.py, 107, INFO, Processing year 2008 for ticker VLGEA.
# 2026-01-28 15:57:12,447, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/VLGEA\VLGEA_2008
# 2026-01-28 15:57:12,493, data_manager.py, 107, INFO, Processing year 2009 for ticker VLGEA.
# 2026-01-28 15:57:12,503, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/VLGEA\VLGEA_2009
# 2026-01-28 15:57:12,580, data_manager.py, 107, INFO, Processing year 2010 for ticker VLGEA.
# 2026-01-28 15:57:12,589, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/VLGEA\VLGEA_2010
# 2026-01-28 15:57:12,663, data_manager.py, 107, INFO, Processing year 2011 for ticker VLGEA.
# 2026-01-28 15:57:12,675, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/VLGEA\VLGEA_2011
# 2026-01-28 15:57:12,782, data_manager.py, 107, INFO, Processing year 2012 for ticker VLGEA.
# 2026-01-28 15:57:12,792, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/VLGEA\VLGEA_2012
# 2026-01-28 15:57:12,867, data_manager.py, 107, INFO, Processing year 2013 for ticker VLGEA.
# 2026-01-28 15:57:12,871, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/VLGEA\VLGEA_2013
# 2026-01-28 15:57:12,960, data_manager.py, 107, INFO, Processing year 2014 for ticker VLGEA.
# 2026-01-28 15:57:12,969, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/VLGEA\VLGEA_2014
# 2026-01-28 15:57:13,025, data_manager.py, 107, INFO, Processing year 2015 for ticker VLGEA.
# 2026-01-28 15:57:13,035, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/VLGEA\VLGEA_2015
# 2026-01-28 15:57:13,098, data_manager.py, 107, INFO, Processing year 2016 for ticker VLGEA.
# 2026-01-28 15:57:13,106, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/VLGEA\VLGEA_2016
# 2026-01-28 15:57:13,163, data_manager.py, 107, INFO, Processing year 2017 for ticker VLGEA.
# 2026-01-28 15:57:13,168, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/VLGEA\VLGEA_2017
# 2026-01-28 15:57:13,247, data_manager.py, 107, INFO, Processing year 2018 for ticker VLGEA.
# 2026-01-28 15:57:13,260, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/VLGEA\VLGEA_2018
# 2026-01-28 15:57:13,326, data_manager.py, 107, INFO, Processing year 2019 for ticker VLGEA.
# 2026-01-28 15:57:13,336, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/VLGEA\VLGEA_2019
# 2026-01-28 15:57:13,409, data_manager.py, 107, INFO, Processing year 2020 for ticker VLGEA.
# 2026-01-28 15:57:13,422, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/VLGEA\VLGEA_2020
# 2026-01-28 15:57:13,494, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\STPP.csv
# 2026-01-28 15:57:13,496, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\STPP.csv
# 2026-01-28 15:57:13,568, data_manager.py, 101, INFO, Saving data by year
# 2026-01-28 15:57:13,570, data_manager.py, 103, INFO, Processing ticker: STPP
# 2026-01-28 15:57:13,577, data_manager.py, 107, INFO, Processing year 2010 for ticker STPP.
# 2026-01-28 15:57:13,615, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/STPP\STPP_2010
# 2026-01-28 15:57:13,703, data_manager.py, 107, INFO, Processing year 2011 for ticker STPP.
# 2026-01-28 15:57:13,711, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/STPP\STPP_2011
# 2026-01-28 15:57:13,906, data_manager.py, 107, INFO, Processing year 2012 for ticker STPP.
# 2026-01-28 15:57:13,912, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/STPP\STPP_2012
# 2026-01-28 15:57:14,029, data_manager.py, 107, INFO, Processing year 2013 for ticker STPP.
# 2026-01-28 15:57:14,034, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/STPP\STPP_2013
# 2026-01-28 15:57:14,121, data_manager.py, 107, INFO, Processing year 2014 for ticker STPP.
# 2026-01-28 15:57:14,127, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/STPP\STPP_2014
# 2026-01-28 15:57:14,262, data_manager.py, 107, INFO, Processing year 2015 for ticker STPP.
# 2026-01-28 15:57:14,273, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/STPP\STPP_2015
# 2026-01-28 15:57:14,390, data_manager.py, 107, INFO, Processing year 2016 for ticker STPP.
# 2026-01-28 15:57:14,399, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/STPP\STPP_2016
# 2026-01-28 15:57:14,509, data_manager.py, 107, INFO, Processing year 2017 for ticker STPP.
# 2026-01-28 15:57:14,518, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/STPP\STPP_2017
# 2026-01-28 15:57:14,645, data_manager.py, 107, INFO, Processing year 2018 for ticker STPP.
# 2026-01-28 15:57:14,654, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/STPP\STPP_2018
# 2026-01-28 15:57:14,792, data_manager.py, 107, INFO, Processing year 2019 for ticker STPP.
# 2026-01-28 15:57:14,800, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/STPP\STPP_2019
# 2026-01-28 15:57:14,913, data_manager.py, 107, INFO, Processing year 2020 for ticker STPP.
# 2026-01-28 15:57:14,913, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/STPP\STPP_2020
# 2026-01-28 15:57:15,038, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\ASR.csv
# 2026-01-28 15:57:15,038, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\ASR.csv
# 2026-01-28 15:57:15,254, data_manager.py, 101, INFO, Saving data by year
# 2026-01-28 15:57:15,254, data_manager.py, 103, INFO, Processing ticker: ASR
# 2026-01-28 15:57:15,263, data_manager.py, 107, INFO, Processing year 2000 for ticker ASR.
# 2026-01-28 15:57:15,266, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/ASR\ASR_2000
# 2026-01-28 15:57:15,462, data_manager.py, 107, INFO, Processing year 2001 for ticker ASR.
# 2026-01-28 15:57:15,478, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/ASR\ASR_2001
# 2026-01-28 15:57:15,545, data_manager.py, 107, INFO, Processing year 2002 for ticker ASR.
# 2026-01-28 15:57:15,545, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/ASR\ASR_2002
# 2026-01-28 15:57:15,649, data_manager.py, 107, INFO, Processing year 2003 for ticker ASR.
# 2026-01-28 15:57:15,655, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/ASR\ASR_2003
# 2026-01-28 15:57:15,830, data_manager.py, 107, INFO, Processing year 2004 for ticker ASR.
# 2026-01-28 15:57:15,847, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/ASR\ASR_2004
# 2026-01-28 15:57:15,942, data_manager.py, 107, INFO, Processing year 2005 for ticker ASR.
# 2026-01-28 15:57:15,947, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/ASR\ASR_2005
# 2026-01-28 15:57:16,122, data_manager.py, 107, INFO, Processing year 2006 for ticker ASR.
# 2026-01-28 15:57:16,128, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/ASR\ASR_2006
# 2026-01-28 15:57:16,303, data_manager.py, 107, INFO, Processing year 2007 for ticker ASR.
# 2026-01-28 15:57:16,311, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/ASR\ASR_2007
# 2026-01-28 15:57:16,389, data_manager.py, 107, INFO, Processing year 2008 for ticker ASR.
# 2026-01-28 15:57:16,393, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/ASR\ASR_2008
# 2026-01-28 15:57:16,563, data_manager.py, 107, INFO, Processing year 2009 for ticker ASR.
# 2026-01-28 15:57:16,565, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/ASR\ASR_2009
# 2026-01-28 15:57:16,645, data_manager.py, 107, INFO, Processing year 2010 for ticker ASR.
# 2026-01-28 15:57:16,661, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/ASR\ASR_2010
# 2026-01-28 15:57:16,740, data_manager.py, 107, INFO, Processing year 2011 for ticker ASR.
# ...
# 2026-01-28 15:57:52,689, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SFL\SFL_2004
# 2026-01-28 15:57:52,869, data_manager.py, 107, INFO, Processing year 2005 for ticker SFL.
# 2026-01-28 15:57:52,884, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SFL\SFL_2005
# 2026-01-28 15:57:53,152, data_manager.py, 107, INFO, Processing year 2006 for ticker SFL.
# 2026-01-28 15:57:53,167, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SFL\SFL_2006
# 2026-01-28 15:57:54,198, data_manager.py, 107, INFO, Processing year 2007 for ticker SFL.
# 2026-01-28 15:57:54,205, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SFL\SFL_2007
# 2026-01-28 15:57:55,695, data_manager.py, 107, INFO, Processing year 2008 for ticker SFL.
# 2026-01-28 15:57:55,919, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SFL\SFL_2008
# 2026-01-28 15:57:56,598, data_manager.py, 107, INFO, Processing year 2009 for ticker SFL.
# 2026-01-28 15:57:56,614, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SFL\SFL_2009
# 2026-01-28 15:57:57,302, data_manager.py, 107, INFO, Processing year 2010 for ticker SFL.
# 2026-01-28 15:57:57,312, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SFL\SFL_2010
# 2026-01-28 15:57:57,567, data_manager.py, 107, INFO, Processing year 2011 for ticker SFL.
# 2026-01-28 15:57:57,582, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SFL\SFL_2011
# 2026-01-28 15:57:58,369, data_manager.py, 107, INFO, Processing year 2012 for ticker SFL.
# 2026-01-28 15:57:58,387, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SFL\SFL_2012
# 2026-01-28 15:57:58,679, data_manager.py, 107, INFO, Processing year 2013 for ticker SFL.
# 2026-01-28 15:57:58,687, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SFL\SFL_2013
# 2026-01-28 15:57:59,758, data_manager.py, 107, INFO, Processing year 2014 for ticker SFL.
# 2026-01-28 15:57:59,766, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SFL\SFL_2014
# 2026-01-28 15:58:00,490, data_manager.py, 107, INFO, Processing year 2015 for ticker SFL.
# 2026-01-28 15:58:00,499, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SFL\SFL_2015
# 2026-01-28 15:58:00,640, data_manager.py, 107, INFO, Processing year 2016 for ticker SFL.
# 2026-01-28 15:58:00,654, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SFL\SFL_2016
# 2026-01-28 15:58:00,860, data_manager.py, 107, INFO, Processing year 2017 for ticker SFL.
# 2026-01-28 15:58:00,871, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SFL\SFL_2017
# 2026-01-28 15:58:00,986, data_manager.py, 107, INFO, Processing year 2018 for ticker SFL.
# 2026-01-28 15:58:00,996, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SFL\SFL_2018
# 2026-01-28 15:58:01,104, data_manager.py, 107, INFO, Processing year 2019 for ticker SFL.
# 2026-01-28 15:58:01,114, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SFL\SFL_2019
# 2026-01-28 15:58:01,223, data_manager.py, 107, INFO, Processing year 2020 for ticker SFL.
# 2026-01-28 15:58:01,233, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SFL\SFL_2020
# 2026-01-28 15:58:01,387, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\IRIX.csv
# 2026-01-28 15:58:01,389, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\IRIX.csv
# 2026-01-28 15:58:01,507, data_manager.py, 101, INFO, Saving data by year
# 2026-01-28 15:58:01,513, data_manager.py, 103, INFO, Processing ticker: IRIX
# 2026-01-28 15:58:01,521, data_manager.py, 107, INFO, Processing year 1996 for ticker IRIX.
# 2026-01-28 15:58:01,532, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/IRIX\IRIX_1996
# 2026-01-28 15:58:01,666, data_manager.py, 107, INFO, Processing year 1997 for ticker IRIX.
# 2026-01-28 15:58:01,674, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/IRIX\IRIX_1997
# 2026-01-28 15:58:01,837, data_manager.py, 107, INFO, Processing year 1998 for ticker IRIX.
# 2026-01-28 15:58:01,848, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/IRIX\IRIX_1998
# 2026-01-28 15:58:01,930, data_manager.py, 107, INFO, Processing year 1999 for ticker IRIX.
# 2026-01-28 15:58:01,938, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/IRIX\IRIX_1999
# 2026-01-28 15:58:02,011, data_manager.py, 107, INFO, Processing year 2000 for ticker IRIX.
# 2026-01-28 15:58:02,019, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/IRIX\IRIX_2000
# 2026-01-28 15:58:02,374, data_manager.py, 107, INFO, Processing year 2001 for ticker IRIX.
# 2026-01-28 15:58:02,389, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/IRIX\IRIX_2001
# 2026-01-28 15:58:02,465, data_manager.py, 107, INFO, Processing year 2002 for ticker IRIX.
# 2026-01-28 15:58:02,473, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/IRIX\IRIX_2002
# 2026-01-28 15:58:02,619, data_manager.py, 107, INFO, Processing year 2003 for ticker IRIX.
# 2026-01-28 15:58:02,628, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/IRIX\IRIX_2003
# 2026-01-28 15:58:02,774, data_manager.py, 107, INFO, Processing year 2004 for ticker IRIX.
# 2026-01-28 15:58:02,786, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/IRIX\IRIX_2004
# 2026-01-28 15:58:02,922, data_manager.py, 107, INFO, Processing year 2005 for ticker IRIX.
# 2026-01-28 15:58:02,934, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/IRIX\IRIX_2005
# 2026-01-28 15:58:03,128, data_manager.py, 107, INFO, Processing year 2006 for ticker IRIX.
# 2026-01-28 15:58:03,140, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/IRIX\IRIX_2006
# 2026-01-28 15:58:03,348, data_manager.py, 107, INFO, Processing year 2007 for ticker IRIX.
# 2026-01-28 15:58:03,356, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/IRIX\IRIX_2007
# 2026-01-28 15:58:03,479, data_manager.py, 107, INFO, Processing year 2008 for ticker IRIX.
# 2026-01-28 15:58:03,489, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/IRIX\IRIX_2008
# 2026-01-28 15:58:03,596, data_manager.py, 107, INFO, Processing year 2009 for ticker IRIX.
# 2026-01-28 15:58:03,603, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/IRIX\IRIX_2009
# 2026-01-28 15:58:03,752, data_manager.py, 107, INFO, Processing year 2010 for ticker IRIX.
# 2026-01-28 15:58:03,765, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/IRIX\IRIX_2010
# 2026-01-28 15:58:03,858, data_manager.py, 107, INFO, Processing year 2011 for ticker IRIX.
# 2026-01-28 15:58:03,883, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/IRIX\IRIX_2011
# 2026-01-28 15:58:03,981, data_manager.py, 107, INFO, Processing year 2012 for ticker IRIX.
# 2026-01-28 15:58:03,995, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/IRIX\IRIX_2012
# 2026-01-28 15:58:04,129, data_manager.py, 107, INFO, Processing year 2013 for ticker IRIX.
# 2026-01-28 15:58:04,138, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/IRIX\IRIX_2013
# 2026-01-28 15:58:04,266, data_manager.py, 107, INFO, Processing year 2014 for ticker IRIX.
# 2026-01-28 15:58:04,273, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/IRIX\IRIX_2014
# 2026-01-28 15:58:04,347, data_manager.py, 107, INFO, Processing year 2015 for ticker IRIX.
# 2026-01-28 15:58:04,358, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/IRIX\IRIX_2015
# 2026-01-28 15:58:04,465, data_manager.py, 107, INFO, Processing year 2016 for ticker IRIX.
# 2026-01-28 15:58:04,473, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/IRIX\IRIX_2016
# 2026-01-28 15:58:04,595, data_manager.py, 107, INFO, Processing year 2017 for ticker IRIX.
# 2026-01-28 15:58:04,603, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/IRIX\IRIX_2017
# 2026-01-28 15:58:04,781, data_manager.py, 107, INFO, Processing year 2018 for ticker IRIX.
# 2026-01-28 15:58:04,789, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/IRIX\IRIX_2018
# 2026-01-28 15:58:05,008, data_manager.py, 107, INFO, Processing year 2019 for ticker IRIX.
# 2026-01-28 15:58:05,018, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/IRIX\IRIX_2019
# 2026-01-28 15:58:05,775, data_manager.py, 107, INFO, Processing year 2020 for ticker IRIX.
# 2026-01-28 15:58:05,787, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/IRIX\IRIX_2020
# 2026-01-28 15:58:06,117, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\AVXL.csv
# 2026-01-28 15:58:06,121, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\AVXL.csv
# 2026-01-28 15:58:06,390, data_manager.py, 101, INFO, Saving data by year
# 2026-01-28 15:58:06,394, data_manager.py, 103, INFO, Processing ticker: AVXL
# 2026-01-28 15:58:06,402, data_manager.py, 107, INFO, Processing year 2006 for ticker AVXL.
# 2026-01-28 15:58:06,414, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/AVXL\AVXL_2006
# 2026-01-28 15:58:06,965, data_manager.py, 107, INFO, Processing year 2007 for ticker AVXL.
# 2026-01-28 15:58:06,976, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/AVXL\AVXL_2007
# 2026-01-28 15:58:07,135, data_manager.py, 107, INFO, Processing year 2008 for ticker AVXL.
# 2026-01-28 15:58:07,211, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/AVXL\AVXL_2008
# 2026-01-28 15:58:09,553, data_manager.py, 107, INFO, Processing year 2009 for ticker AVXL.
# 2026-01-28 15:58:09,562, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/AVXL\AVXL_2009
# 2026-01-28 15:58:09,941, data_manager.py, 107, INFO, Processing year 2010 for ticker AVXL.
# 2026-01-28 15:58:09,952, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/AVXL\AVXL_2010
# 2026-01-28 15:58:10,078, data_manager.py, 107, INFO, Processing year 2011 for ticker AVXL.
# 2026-01-28 15:58:10,087, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/AVXL\AVXL_2011
# 2026-01-28 15:58:10,214, data_manager.py, 107, INFO, Processing year 2012 for ticker AVXL.
# 2026-01-28 15:58:10,224, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/AVXL\AVXL_2012
# 2026-01-28 15:58:10,302, data_manager.py, 107, INFO, Processing year 2013 for ticker AVXL.
# 2026-01-28 15:58:10,311, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/AVXL\AVXL_2013
# 2026-01-28 15:58:10,380, data_manager.py, 107, INFO, Processing year 2014 for ticker AVXL.
# 2026-01-28 15:58:10,402, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/AVXL\AVXL_2014
# 2026-01-28 15:58:10,530, data_manager.py, 107, INFO, Processing year 2015 for ticker AVXL.
# 2026-01-28 15:58:10,538, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/AVXL\AVXL_2015
# 2026-01-28 15:58:10,609, data_manager.py, 107, INFO, Processing year 2016 for ticker AVXL.
# 2026-01-28 15:58:10,622, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/AVXL\AVXL_2016
# 2026-01-28 15:58:10,724, data_manager.py, 107, INFO, Processing year 2017 for ticker AVXL.
# 2026-01-28 15:58:10,734, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/AVXL\AVXL_2017
# 2026-01-28 15:58:10,852, data_manager.py, 107, INFO, Processing year 2018 for ticker AVXL.
# 2026-01-28 15:58:11,021, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/AVXL\AVXL_2018
# 2026-01-28 15:58:11,165, data_manager.py, 107, INFO, Processing year 2019 for ticker AVXL.
# 2026-01-28 15:58:11,173, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/AVXL\AVXL_2019
# 2026-01-28 15:58:11,241, data_manager.py, 107, INFO, Processing year 2020 for ticker AVXL.
# 2026-01-28 15:58:11,250, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/AVXL\AVXL_2020
# 2026-01-28 15:58:11,333, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\DCP.csv
# 2026-01-28 15:58:11,337, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\DCP.csv
# 2026-01-28 15:58:11,418, data_manager.py, 101, INFO, Saving data by year
# 2026-01-28 15:58:11,423, data_manager.py, 103, INFO, Processing ticker: DCP
# 2026-01-28 15:58:11,432, data_manager.py, 107, INFO, Processing year 2005 for ticker DCP.
# 2026-01-28 15:58:11,441, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DCP\DCP_2005
# 2026-01-28 15:58:11,560, data_manager.py, 107, INFO, Processing year 2006 for ticker DCP.
# 2026-01-28 15:58:11,570, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DCP\DCP_2006
# 2026-01-28 15:58:11,637, data_manager.py, 107, INFO, Processing year 2007 for ticker DCP.
# 2026-01-28 15:58:11,646, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DCP\DCP_2007
# 2026-01-28 15:58:11,741, data_manager.py, 107, INFO, Processing year 2008 for ticker DCP.
# 2026-01-28 15:58:11,749, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DCP\DCP_2008
# 2026-01-28 15:58:11,813, data_manager.py, 107, INFO, Processing year 2009 for ticker DCP.
# 2026-01-28 15:58:11,822, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DCP\DCP_2009
# 2026-01-28 15:58:11,894, data_manager.py, 107, INFO, Processing year 2010 for ticker DCP.
# 2026-01-28 15:58:11,902, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DCP\DCP_2010
# 2026-01-28 15:58:11,970, data_manager.py, 107, INFO, Processing year 2011 for ticker DCP.
# 2026-01-28 15:58:11,980, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DCP\DCP_2011
# 2026-01-28 15:58:12,046, data_manager.py, 107, INFO, Processing year 2012 for ticker DCP.
# 2026-01-28 15:58:12,054, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DCP\DCP_2012
# 2026-01-28 15:58:12,122, data_manager.py, 107, INFO, Processing year 2013 for ticker DCP.
# 2026-01-28 15:58:12,132, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DCP\DCP_2013
# 2026-01-28 15:58:12,196, data_manager.py, 107, INFO, Processing year 2014 for ticker DCP.
# 2026-01-28 15:58:12,205, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DCP\DCP_2014
# 2026-01-28 15:58:12,268, data_manager.py, 107, INFO, Processing year 2015 for ticker DCP.
# 2026-01-28 15:58:12,278, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DCP\DCP_2015
# 2026-01-28 15:58:12,343, data_manager.py, 107, INFO, Processing year 2016 for ticker DCP.
# 2026-01-28 15:58:12,352, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DCP\DCP_2016
# 2026-01-28 15:58:12,423, data_manager.py, 107, INFO, Processing year 2017 for ticker DCP.
# 2026-01-28 15:58:12,433, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DCP\DCP_2017
# 2026-01-28 15:58:12,498, data_manager.py, 107, INFO, Processing year 2018 for ticker DCP.
# 2026-01-28 15:58:12,505, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DCP\DCP_2018
# 2026-01-28 15:58:12,566, data_manager.py, 107, INFO, Processing year 2019 for ticker DCP.
# 2026-01-28 15:58:12,575, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DCP\DCP_2019
# 2026-01-28 15:58:12,635, data_manager.py, 107, INFO, Processing year 2020 for ticker DCP.
# 2026-01-28 15:58:12,642, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DCP\DCP_2020

# %% [markdown]
# Finally, add features to the data set and save to a *feature store*.

# %%
dm.featurize()
# Out:
# 2026-01-28 15:59:45,411, data_manager.py, 134, INFO, Creating features data.
# 2026-01-28 15:59:45,415, data_manager.py, 144, INFO, Loading price data from ../../05_src/data/prices/
# 2026-01-28 16:01:05,125, data_manager.py, 153, INFO, Creating features
# 2026-01-28 16:01:05,139, data_manager.py, 174, INFO, DTYPES right before returns:
# Date           object
# Open           object
# High           object
# Low            object
# Close          object
# Adj Close      object
# Volume         object
# source         object
# Year           object
# Close_lag_1    object
# dtype: object
# 2026-01-28 16:01:05,242, data_manager.py, 190, INFO, Saving features to ../../05_src/data/features/stock_features
