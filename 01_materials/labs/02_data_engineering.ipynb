# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
# %load_ext dotenv
# %dotenv

# %% [markdown]
# # What are we doing?
#
# ## Objectives
#
#
# * Build a data pipeline that downloads price data from the internet, stores it locally, transforms it into return data, and stores the feature set.
#     - Getting the data.
#     - Schemas and index in Dask.
#
# * Explore the parquet format.
#     - Reading and writing parquet files.
#     - Read datasets that are stored in distributed files.
#     - Discuss Dask vs. Pandas as a small example of big vs small data.
#
# * Discuss the use of environment variables for settings.
# * Discuss how to use Jupyter notebooks and source code concurrently.
# * Logging and using a standard logger.
#
# ## About the Data
#
# + We will download the prices for a list of stocks.
# + The source is Yahoo Finance, and the data, along with its description, is available via [Kaggle](https://www.kaggle.com/datasets/jacksoncrow/stock-market-dataset).
#
#
# ## Medallion Architecture
#
# + The architecture that we are thinking about is called Medallion by [DataBricks](https://www.databricks.com/glossary/medallion-architecture). It is an ELT type of thinking, although our data is well-structured.
#
# <div>
# <image src="./images/02_medallion_architecture.png" height=300>
# </div>
#
# + In our case, we would like to optimize the number of times that we download data from the internet.
# + Ultimately, we will build a pipeline manager class to control the process of obtaining and transforming our data.
#
# <div>
# <image src="./images/02_target_pipeline_manager.png" height=250>
# </div>

# %% [markdown]
# # Download Data
#
# Download the [Stock Market Dataset from Kaggle](https://www.kaggle.com/datasets/jacksoncrow/stock-market-dataset). Note that you may be required to register for a free account. Alternatively, download the file from [this location](https://drive.google.com/drive/folders/1AA4gapDLpI194TGce1bY25sd91Km-tU3?usp=drive_link).
#
# + Extract stock prices (not ETFs) into the directory: `./05_src/data/prices_csv/`.
# + To be clear, your folder structure should include the path `05_src/data/prices_csv/stocks`.

# %% [markdown]
# The command `%run update_path.py` runs a local script that adds the repository's `./05_src/` directory to the Notebook's kernel path. This way, we can use our modules within the notebook.

# %%
# %run update_path.py

# %% [markdown]
# To load the historical price data for stocks and ETFs, use the code below. Notice the following:
#
# + Libraries are ordered from high-level to low-level libraries from the package manager. Local modules are imported at the end.
# + The function `get_logger()` is called with `__name__` as recommended by [Python's documentation](https://docs.python.org/2/howto/logging.html#logging-advanced-tutorial).

# %%
from glob import glob
import os
import pandas as pd
import random

from utils.logger import get_logger
_logs = get_logger(__name__)

# %% [markdown]
# + The [`glob` module](https://docs.python.org/3/library/glob.html) is used for finding path names that match specified patterns using Unix shell-style rules.
#
# + Notice that the module `glob` contains a function called `glob`; therefore, we used `from glob import glob` above.
#
# + The path in which we are searching for our csv files is produced by joining two strings:
#
#
#
#     - The value of the environment variable 'SRC_DIR' that we obtain with `os.getenv('SRC_DIR')` (this variable points to ./05_src).
#
#     - Another string given by "data/prices_csv/stocks/*.csv".
#
#     - Both strings are combined into an OS-consistent path using `os.path.join(...)`.
#
# + After we know the location of all our files, we sample a subset of them.

# %%
stock_files = glob(os.path.join(os.getenv('SRC_DIR'), "data/prices_csv/stocks/*.csv"))
_logs.info(f'Found {len(stock_files)} stock price files.')

random.seed(42)
n_sample = 60
stock_files = random.sample(stock_files, n_sample)
_logs.info(f'Sampled {n_sample} stock price files for processing. The files are: {stock_files   }')
# Out:
# 2026-01-21 17:38:57,330, 3619788285.py, 2, INFO, Found 5884 stock price files.
# 2026-01-21 17:38:57,330, 3619788285.py, 7, INFO, Sampled 60 stock price files for processing. The files are: ['../../05_src/data/prices_csv/stocks\\TNC.csv', '../../05_src/data/prices_csv/stocks\\CBB.csv', '../../05_src/data/prices_csv/stocks\\ALDX.csv', '../../05_src/data/prices_csv/stocks\\GLADD.csv', '../../05_src/data/prices_csv/stocks\\FIXX.csv', '../../05_src/data/prices_csv/stocks\\ETJ.csv', '../../05_src/data/prices_csv/stocks\\CMCTP.csv', '../../05_src/data/prices_csv/stocks\\BWG.csv', '../../05_src/data/prices_csv/stocks\\VIAC.csv', '../../05_src/data/prices_csv/stocks\\REI.csv', '../../05_src/data/prices_csv/stocks\\BLPH.csv', '../../05_src/data/prices_csv/stocks\\SMG.csv', '../../05_src/data/prices_csv/stocks\\MOH.csv', '../../05_src/data/prices_csv/stocks\\AMH.csv', '../../05_src/data/prices_csv/stocks\\AMAL.csv', '../../05_src/data/prices_csv/stocks\\BPYPN.csv', '../../05_src/data/prices_csv/stocks\\ERH.csv', '../../05_src/data/prices_csv/stocks\\FAMI.csv', '../../05_src/data/prices_csv/stocks\\PFG.csv', '../../05_src/data/prices_csv/stocks\\SPXC.csv', '../../05_src/data/prices_csv/stocks\\ALL.csv', '../../05_src/data/prices_csv/stocks\\RTTR.csv', '../../05_src/data/prices_csv/stocks\\EARN.csv', '../../05_src/data/prices_csv/stocks\\ZIXI.csv', '../../05_src/data/prices_csv/stocks\\TSN.csv', '../../05_src/data/prices_csv/stocks\\WST.csv', '../../05_src/data/prices_csv/stocks\\REG.csv', '../../05_src/data/prices_csv/stocks\\MNK.csv', '../../05_src/data/prices_csv/stocks\\ESGR.csv', '../../05_src/data/prices_csv/stocks\\NGD.csv', '../../05_src/data/prices_csv/stocks\\SLRX.csv', '../../05_src/data/prices_csv/stocks\\GLW.csv', '../../05_src/data/prices_csv/stocks\\ACN.csv', '../../05_src/data/prices_csv/stocks\\CSSE.csv', '../../05_src/data/prices_csv/stocks\\WORK.csv', '../../05_src/data/prices_csv/stocks\\MOS.csv', '../../05_src/data/prices_csv/stocks\\IPWR.csv', '../../05_src/data/prices_csv/stocks\\GLUU.csv', '../../05_src/data/prices_csv/stocks\\CRMT.csv', '../../05_src/data/prices_csv/stocks\\EOLS.csv', '../../05_src/data/prices_csv/stocks\\INSU.csv', '../../05_src/data/prices_csv/stocks\\BWEN.csv', '../../05_src/data/prices_csv/stocks\\BPMX.csv', '../../05_src/data/prices_csv/stocks\\LH.csv', '../../05_src/data/prices_csv/stocks\\BRQS.csv', '../../05_src/data/prices_csv/stocks\\KALU.csv', '../../05_src/data/prices_csv/stocks\\ITCB.csv', '../../05_src/data/prices_csv/stocks\\SRE.csv', '../../05_src/data/prices_csv/stocks\\GAZ.csv', '../../05_src/data/prices_csv/stocks\\AQMS.csv', '../../05_src/data/prices_csv/stocks\\NPK.csv', '../../05_src/data/prices_csv/stocks\\QRHC.csv', '../../05_src/data/prices_csv/stocks\\CGEN.csv', '../../05_src/data/prices_csv/stocks\\LEVL.csv', '../../05_src/data/prices_csv/stocks\\BGS.csv', '../../05_src/data/prices_csv/stocks\\RIV.csv', '../../05_src/data/prices_csv/stocks\\GURE.csv', '../../05_src/data/prices_csv/stocks\\TEF.csv', '../../05_src/data/prices_csv/stocks\\SYNH.csv', '../../05_src/data/prices_csv/stocks\\KEY.csv']

# %% [markdown]
# We load the sampled files into dataframes and concatenate them:
#
# + Start with an empty list.
# + Read each file into a dataframe and [`append()` it to the list](https://docs.python.org/3/tutorial/datastructures.html#more-on-lists). Notice that `append()` is an in-place operation (it does not return a list, it modifies the list in place).
# + Finally, we concatenate all dataframes along the vertical axis (`axis=0`) using [`pd.concat()`](https://pandas.pydata.org/docs/user_guide/merging.html#concat).
# + Notice that we do not concatenate each time that we load a dataframe. According to [Panda's documentation](https://pandas.pydata.org/docs/user_guide/merging.html#concat):
#
# > "`concat()` makes a full copy of the data, and iteratively reusing `concat()` can create unnecessary copies. Collect all DataFrame or Series objects in a list before using `concat()`."

# %%
dt_list = []
for s_file in stock_files:
    _logs.info(f"Reading file: {s_file}")
    dt = pd.read_csv(s_file).assign(
        source = os.path.basename(s_file),
        ticker = os.path.basename(s_file).replace('.csv', ''),
        Date = lambda x: pd.to_datetime(x['Date'])
    )
    dt_list.append(dt)
stock_prices = pd.concat(dt_list, axis = 0, ignore_index = True)
# Out:
# 2026-01-21 17:39:03,350, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\TNC.csv
# 2026-01-21 17:39:03,464, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\CBB.csv
# 2026-01-21 17:39:03,496, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\ALDX.csv
# 2026-01-21 17:39:03,545, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\GLADD.csv
# 2026-01-21 17:39:03,575, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\FIXX.csv
# 2026-01-21 17:39:03,598, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\ETJ.csv
# 2026-01-21 17:39:03,630, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\CMCTP.csv
# 2026-01-21 17:39:03,661, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\BWG.csv
# 2026-01-21 17:39:03,681, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\VIAC.csv
# 2026-01-21 17:39:03,714, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\REI.csv
# 2026-01-21 17:39:03,740, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\BLPH.csv
# 2026-01-21 17:39:03,759, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\SMG.csv
# 2026-01-21 17:39:03,798, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\MOH.csv
# 2026-01-21 17:39:03,829, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\AMH.csv
# 2026-01-21 17:39:03,854, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\AMAL.csv
# 2026-01-21 17:39:03,866, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\BPYPN.csv
# 2026-01-21 17:39:03,891, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\ERH.csv
# 2026-01-21 17:39:03,928, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\FAMI.csv
# 2026-01-21 17:39:03,942, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\PFG.csv
# 2026-01-21 17:39:03,977, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\SPXC.csv
# 2026-01-21 17:39:04,010, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\ALL.csv
# 2026-01-21 17:39:04,043, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\RTTR.csv
# 2026-01-21 17:39:04,078, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\EARN.csv
# 2026-01-21 17:39:04,099, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\ZIXI.csv
# 2026-01-21 17:39:04,134, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\TSN.csv
# 2026-01-21 17:39:04,162, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\WST.csv
# 2026-01-21 17:39:04,191, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\REG.csv
# 2026-01-21 17:39:04,228, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\MNK.csv
# 2026-01-21 17:39:04,261, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\ESGR.csv
# 2026-01-21 17:39:04,292, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\NGD.csv
# 2026-01-21 17:39:04,318, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\SLRX.csv
# 2026-01-21 17:39:04,344, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\GLW.csv
# 2026-01-21 17:39:04,379, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\ACN.csv
# 2026-01-21 17:39:04,403, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\CSSE.csv
# 2026-01-21 17:39:04,428, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\WORK.csv
# 2026-01-21 17:39:04,450, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\MOS.csv
# 2026-01-21 17:39:04,474, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\IPWR.csv
# 2026-01-21 17:39:04,492, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\GLUU.csv
# 2026-01-21 17:39:04,542, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\CRMT.csv
# 2026-01-21 17:39:04,561, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\EOLS.csv
# 2026-01-21 17:39:04,596, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\INSU.csv
# 2026-01-21 17:39:04,616, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\BWEN.csv
# 2026-01-21 17:39:04,641, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\BPMX.csv
# 2026-01-21 17:39:04,675, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\LH.csv
# 2026-01-21 17:39:04,696, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\BRQS.csv
# 2026-01-21 17:39:04,722, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\KALU.csv
# 2026-01-21 17:39:04,745, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\ITCB.csv
# 2026-01-21 17:39:04,774, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\SRE.csv
# 2026-01-21 17:39:04,793, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\GAZ.csv
# 2026-01-21 17:39:04,828, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\AQMS.csv
# 2026-01-21 17:39:04,851, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\NPK.csv
# 2026-01-21 17:39:04,874, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\QRHC.csv
# 2026-01-21 17:39:04,914, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\CGEN.csv
# 2026-01-21 17:39:04,950, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\LEVL.csv
# 2026-01-21 17:39:04,968, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\BGS.csv
# 2026-01-21 17:39:04,992, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\RIV.csv
# 2026-01-21 17:39:05,021, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\GURE.csv
# 2026-01-21 17:39:05,045, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\TEF.csv
# 2026-01-21 17:39:05,074, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\SYNH.csv
# 2026-01-21 17:39:05,105, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\KEY.csv

# %% [markdown]
# Verify the structure of the `stock_prices` data using the [`info()` dataframe method](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.info.html):

# %%
stock_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239659 entries, 0 to 239658
# Data columns (total 9 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Date       239659 non-null  datetime64[ns]
#  1   Open       239656 non-null  float64
#  2   High       239656 non-null  float64
#  3   Low        239656 non-null  float64
#  4   Close      239656 non-null  float64
#  5   Adj Close  239656 non-null  float64
#  6   Volume     239656 non-null  float64
#  7   source     239659 non-null  object
#  8   ticker     239659 non-null  object
# dtypes: datetime64[ns](1), float64(6), object(2)
# memory usage: 16.5+ MB

# %% [markdown]
# We can subset our ticker data set using standard indexing techniques. Good references for this type of data manipulation are:
#
# + [Panda's Documentation](https://pandas.pydata.org/docs/user_guide/indexing.html#indexing-and-selecting-data).
# + [Panda's Cookbook](https://pandas.pydata.org/docs/user_guide/cookbook.html#cookbook-selection).

# %% [markdown]
# From the subset data frame, select one column and convert to list.

# %%
select_tickers = stock_prices['ticker'].unique().tolist()
select_tickers
# Out:
# ['TNC',
#  'CBB',
#  'ALDX',
#  'GLADD',
#  'FIXX',
#  'ETJ',
#  'CMCTP',
#  'BWG',
#  'VIAC',
#  'REI',
#  'BLPH',
#  'SMG',
#  'MOH',
#  'AMH',
#  'AMAL',
#  'BPYPN',
#  'ERH',
#  'FAMI',
#  'PFG',
#  'SPXC',
#  'ALL',
#  'RTTR',
#  'EARN',
#  'ZIXI',
#  'TSN',
#  'WST',
#  'REG',
#  'MNK',
#  'ESGR',
#  'NGD',
#  'SLRX',
#  'GLW',
#  'ACN',
#  'CSSE',
#  'WORK',
#  'MOS',
#  'IPWR',
#  'GLUU',
#  'CRMT',
#  'EOLS',
#  'INSU',
#  'BWEN',
#  'BPMX',
#  'LH',
#  'BRQS',
#  'KALU',
#  'ITCB',
#  'SRE',
#  'GAZ',
#  'AQMS',
#  'NPK',
#  'QRHC',
#  'CGEN',
#  'LEVL',
#  'BGS',
#  'RIV',
#  'GURE',
#  'TEF',
#  'SYNH',
#  'KEY']

# %% [markdown]
# # Storing Data in CSV
#
# + We have some data. How do we store it?
# + We can compare two options, CSV and Parquet, by measuring their performance:
#
#     - Time to save: We will measure time by using the `time` library.
#     - Space required on drive: We will use the custom function below.

# %%
def get_dir_size(path='.'):
    '''Returns the total size of files contained in path.'''
    total = 0
    with os.scandir(path) as it:
        for entry in it:
            if entry.is_file():
                total += entry.stat().st_size
            elif entry.is_dir():
                total += get_dir_size(entry.path)
    return total

# %% [markdown]
# Load the specification of a temporary directory from the environment  and create a subdirectory in it called "csv":
#
# + Use `os.getenv("TEMP_DATA")` to obtain the desired location of the temporary folder from an environment variable.
# + If the subdirectory exists, delete it using `shutil.rmtree()`; the flag `ignore_errors=True` helps us in case the subdirectory does not exist (for instance, in the first run).
# + Create a directory with path given by `csv_dir` using `os.makedirs()`; the flag `exist_ok=True` indicates that if the directory already exists, then the function will do nothing.
# + Finally, create the stock price file location, `stock_csv`, which will be used to create the csv file.

# %%
import shutil

temp = os.getenv("TEMP_DATA")
csv_dir = os.path.join(temp, "csv")

shutil.rmtree(csv_dir, ignore_errors=True)
os.makedirs(csv_dir, exist_ok=True)
stock_csv = os.path.join(csv_dir, "stock_px.csv")

# %% [markdown]
# Save the concatenated dataframe to a CSV file. We measure the time elapsed by storing the start and end times, then we calculate their difference in seconds.

# %%
import time

start = time.time()
stock_prices.to_csv(stock_csv, index = False)
end = time.time()

_logs.info(f'Writing data ({stock_prices.shape}) to csv took {end - start} seconds.')
_logs.info(f'CSV file size { os.path.getsize(stock_csv)*1e-6 } MB')
# Out:
# 2026-01-21 17:39:32,809, 807204384.py, 7, INFO, Writing data ((239659, 9)) to csv took 1.8374855518341064 seconds.
# 2026-01-21 17:39:32,809, 807204384.py, 8, INFO, CSV file size 26.618403999999998 MB

# %% [markdown]
# ## Save Data to Parquet
#
# ### Notes on Dask
#
# We could use Pandas to save the data directly into Parquet files. However, we will use a different approach by applying the [Dask framework](https://www.dask.org/). Dask provides functionality for working with datasets that do not fit in memory and parallelization to speed up computation. A few notes on Dask and Pandas:
#
# - Pandas, Parquet, and Arrow:
#
#     + We can work with large datasets and Parquet files in Pandas, but we will generally be limited by the amount of data that can fit in our computer's memory.
#     + Pandas can write Parquet files using a PyArrow backend. In fact, recent versions of Pandas support PyArrow data types, and future versions will require a PyArrow backend.
#     + The PyArrow library is an interface between Python and the Apache Arrow project. In particular, the [Parquet data format](https://parquet.apache.org/) and [Arrow](https://arrow.apache.org/docs/python/parquet.html) are Apache projects.
#
# - Dask
#
#     + Dask is much more than an interface to Arrow: Dask provides parallel and distributed computing on Pandas-like dataframes.
#     + Dask is also relatively easy to use as it mimics Pandas' API.
#     + Dask allows us to work with larger datasets than Pandas. In a sense, it is an intermediate step between Pandas and big-data frameworks like Spark (or Databricks).
#     + If you are familiar with Pandas, a good introduction is [10 Minutes to Dask](https://docs.dask.org/en/stable/10-minutes-to-dask.html).

# %%
import dask.dataframe as dd

parquet_dir = os.path.join(temp, "parquet")
shutil.rmtree(parquet_dir, ignore_errors=True)
os.makedirs(parquet_dir, exist_ok=True)

# %%
px_dd = dd.from_pandas(stock_prices, npartitions = len(select_tickers))

start = time.time()
px_dd.to_parquet(parquet_dir, engine = "pyarrow")
end = time.time()

_logs.info(f'Writing dd ({stock_prices.shape}) to parquet took {end - start} seconds.')
_logs.info(f'Parquet file size { get_dir_size(parquet_dir)*1e-6 } MB')
# Out:
# 2026-01-21 17:39:42,440, 817812245.py, 7, INFO, Writing dd ((239659, 9)) to parquet took 0.8355216979980469 seconds.
# 2026-01-21 17:39:42,440, 817812245.py, 8, INFO, Parquet file size 9.713384999999999 MB

# %% [markdown]
# ### Pandas, Dask, and Parquet
#
# The distinction of Pandas Dataframes, Dask Dataframes, and Parquet files is important:
#
# + Pandas dataframes combine the functionality of [NumPy](https://numpy.org/) (efficient vector operations, especially vector algebra) with a concise data manipulation framework that allows us to create columns of different data types (NumPy only allows single-type matrices), database-like operations (such as filtering rows, subsetting columns, and joining different dataframes).
# + Dask dataframes extend the functionality of Pandas dataframes beyond the confines of available memory and implement parallelized operations, among other benefits.
# + Parquet files are a file format. Parquet files can be created by Pandas and Dask, but Dask offers a superior interface. Parquet files are immutable: once written, they cannot be modified.
# + Parquet and Dask are not the same: Parquet is a file format that can be accessed by many applications and programming languages (Python, R, Power BI, etc.), while Dask is a Python package for working with large datasets using distributed computation.

# %% [markdown]
# ### Dask is Powerful, but not Infallible
#
# It is tempting to think of Dask as a super-Pandas, but each package has its advantages and disadvantages.
#
# + Dask is not good at everything (see [Dask DataFrames Best Practices](https://docs.dask.org/en/stable/dataframe-best-practices.html)).
# + A useful and somewhat idiosyncratic comparison of various data manipulation frameworks is shown below (from [DataFrames at Scale Comparison: TPC-H](https://docs.coiled.io/blog/tpch.html#when-to-use-duckdb-vs-polars-vs-dask-vs-spark))
#
# Concept              | Spark | Dask | DuckDB | Polars
# ---------------------|-------|------|--------|--------
# Fast Locally         | ❌    | 🤔  | ✅     | ✅
# Fast on Cloud (1 TB) | ✅    | ✅  | ✅     | ❌
# Fast on Cloud (10 TB)| ❌    | ✅  | ✅     | ❌
# Scales Out           | ✅    | ✅  | ❌     | ❌
# SQL                  | ✅    | 🤔  | ✅     | 🤔
# More than SQL        | ✅    | ✅  | ❌     | ✅
# Sensible Defaults    | ❌    | ✅  | ✅     | ✅
#
#
# ### Dask Best Practices
#
# Parallelism brings extra complexity and overhead. Here are a few ideas to help you decide when to use Dask (from [Dask's Best Practices](https://docs.dask.org/en/stable/best-practices.html)):
#
# #### Small is Better
#
# + Start small: if possible, use Pandas. Also, try to reduce your data using aggregation, then use Pandas.
# + More generally, NumPy, Pandas, and Scikit-Learn may have faster functions for what you need. Consult the relevant documentation, experiment, and/or consult with a colleague or expert.
#
# #### Index with Care
#
# + Use the index: it is beneficial to have a well-defined index in Dask DataFrames, as it may speed up searching (filtering) the data. A one-dimensional index is allowed.
# + Minimize full-data shuffling as much as possible: indexing is an expensive operation.
#
# ### Consider the Cost of Joins
#
# + Consider cases such as small-to-large joins, where the small dataframe fits in memory, but the large one does not. The small dataframe can be Pandas, while the larger one is a Dask dataframe.
# + Some joins are more expensive than others.
#
#     * Not expensive:
#
#         - Join a Dask DataFrame with a Pandas DataFrame.
#         - Join a Dask DataFrame with another Dask DataFrame of a single partition.
#         - Join Dask DataFrames along their indexes.
#
#     * Expensive:
#
#         - Join Dask DataFrames along columns that are not their index.

# %% [markdown]
# # How Do We Store Prices?
#
# + We can store our data as a single blob.
#
#   - This can be difficult to maintain, especially because parquet files are immutable.
#   - Using a single file, we would need to recreate the complete file any time that we update it.
#
# + An alternative strategy is to organize data files by ticker and date:
#
#   - We can create one file per ticker and month (or any other suitable frequency).
#   - Under this approach, we would only need to recreate the latest month's file at any update.

# %%
# CLean up before start
PRICE_DATA = os.getenv("PRICE_DATA")
import shutil
if os.path.exists(PRICE_DATA):
    shutil.rmtree(PRICE_DATA)

# %%
stock_prices.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'source',
#        'ticker'],
#       dtype='object')

# %%
for ticker in stock_prices['ticker'].unique():
    # Filter data for ticker
    # Notice that these are Pandas dataframes
    _logs.info(f'Processing ticker: {ticker}')
    ticker_dt = stock_prices[stock_prices['ticker'] == ticker]
    ticker_dt = ticker_dt.assign(Year = ticker_dt.Date.dt.year)
    for yr in ticker_dt['Year'].unique():
        _logs.info(f'Processing year {yr} for ticker {ticker}.')
        # Filter data for year and convert to Dask dataframe
        yr_dd = dd.from_pandas(ticker_dt[ticker_dt['Year'] == yr],2)
        
        # Define path and create directories if not exist
        yr_path = os.path.join(PRICE_DATA, ticker, f"{ticker}_{yr}")
        os.makedirs(os.path.dirname(yr_path), exist_ok=True)
        _logs.info(f'Writing data to path: {yr_path}')

        # Write to Parquet
        yr_dd.to_parquet(yr_path, engine = "pyarrow")
# Out:
# 2026-01-21 17:40:04,827, 2113979629.py, 4, INFO, Processing ticker: TNC
# 2026-01-21 17:40:04,871, 2113979629.py, 8, INFO, Processing year 1973 for ticker TNC.
# 2026-01-21 17:40:04,879, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1973
# 2026-01-21 17:40:04,896, 2113979629.py, 8, INFO, Processing year 1974 for ticker TNC.
# 2026-01-21 17:40:04,907, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1974
# 2026-01-21 17:40:04,932, 2113979629.py, 8, INFO, Processing year 1975 for ticker TNC.
# 2026-01-21 17:40:04,932, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1975
# 2026-01-21 17:40:04,959, 2113979629.py, 8, INFO, Processing year 1976 for ticker TNC.
# 2026-01-21 17:40:04,965, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1976
# 2026-01-21 17:40:04,988, 2113979629.py, 8, INFO, Processing year 1977 for ticker TNC.
# 2026-01-21 17:40:04,991, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1977
# 2026-01-21 17:40:05,010, 2113979629.py, 8, INFO, Processing year 1978 for ticker TNC.
# 2026-01-21 17:40:05,017, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1978
# 2026-01-21 17:40:05,044, 2113979629.py, 8, INFO, Processing year 1979 for ticker TNC.
# 2026-01-21 17:40:05,048, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1979
# 2026-01-21 17:40:05,071, 2113979629.py, 8, INFO, Processing year 1980 for ticker TNC.
# 2026-01-21 17:40:05,077, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1980
# 2026-01-21 17:40:05,095, 2113979629.py, 8, INFO, Processing year 1981 for ticker TNC.
# 2026-01-21 17:40:05,095, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1981
# 2026-01-21 17:40:05,124, 2113979629.py, 8, INFO, Processing year 1982 for ticker TNC.
# 2026-01-21 17:40:05,130, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1982
# 2026-01-21 17:40:05,145, 2113979629.py, 8, INFO, Processing year 1983 for ticker TNC.
# 2026-01-21 17:40:05,145, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1983
# 2026-01-21 17:40:05,175, 2113979629.py, 8, INFO, Processing year 1984 for ticker TNC.
# 2026-01-21 17:40:05,180, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1984
# 2026-01-21 17:40:05,199, 2113979629.py, 8, INFO, Processing year 1985 for ticker TNC.
# 2026-01-21 17:40:05,208, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1985
# 2026-01-21 17:40:05,231, 2113979629.py, 8, INFO, Processing year 1986 for ticker TNC.
# 2026-01-21 17:40:05,242, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1986
# 2026-01-21 17:40:05,260, 2113979629.py, 8, INFO, Processing year 1987 for ticker TNC.
# 2026-01-21 17:40:05,260, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1987
# 2026-01-21 17:40:05,292, 2113979629.py, 8, INFO, Processing year 1988 for ticker TNC.
# 2026-01-21 17:40:05,298, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1988
# 2026-01-21 17:40:05,327, 2113979629.py, 8, INFO, Processing year 1989 for ticker TNC.
# 2026-01-21 17:40:05,330, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1989
# 2026-01-21 17:40:05,428, 2113979629.py, 8, INFO, Processing year 1990 for ticker TNC.
# 2026-01-21 17:40:05,430, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1990
# 2026-01-21 17:40:05,476, 2113979629.py, 8, INFO, Processing year 1991 for ticker TNC.
# 2026-01-21 17:40:05,479, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1991
# 2026-01-21 17:40:05,583, 2113979629.py, 8, INFO, Processing year 1992 for ticker TNC.
# 2026-01-21 17:40:05,586, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1992
# 2026-01-21 17:40:05,652, 2113979629.py, 8, INFO, Processing year 1993 for ticker TNC.
# 2026-01-21 17:40:05,655, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1993
# 2026-01-21 17:40:05,694, 2113979629.py, 8, INFO, Processing year 1994 for ticker TNC.
# 2026-01-21 17:40:05,698, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1994
# 2026-01-21 17:40:05,780, 2113979629.py, 8, INFO, Processing year 1995 for ticker TNC.
# 2026-01-21 17:40:05,783, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1995
# 2026-01-21 17:40:05,838, 2113979629.py, 8, INFO, Processing year 1996 for ticker TNC.
# 2026-01-21 17:40:05,844, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1996
# 2026-01-21 17:40:05,917, 2113979629.py, 8, INFO, Processing year 1997 for ticker TNC.
# 2026-01-21 17:40:05,919, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1997
# 2026-01-21 17:40:05,958, 2113979629.py, 8, INFO, Processing year 1998 for ticker TNC.
# 2026-01-21 17:40:05,961, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1998
# 2026-01-21 17:40:06,026, 2113979629.py, 8, INFO, Processing year 1999 for ticker TNC.
# 2026-01-21 17:40:06,029, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1999
# 2026-01-21 17:40:06,070, 2113979629.py, 8, INFO, Processing year 2000 for ticker TNC.
# 2026-01-21 17:40:06,074, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2000
# 2026-01-21 17:40:06,149, 2113979629.py, 8, INFO, Processing year 2001 for ticker TNC.
# 2026-01-21 17:40:06,154, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2001
# 2026-01-21 17:40:06,223, 2113979629.py, 8, INFO, Processing year 2002 for ticker TNC.
# 2026-01-21 17:40:06,229, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2002
# 2026-01-21 17:40:06,276, 2113979629.py, 8, INFO, Processing year 2003 for ticker TNC.
# 2026-01-21 17:40:06,279, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2003
# 2026-01-21 17:40:06,322, 2113979629.py, 8, INFO, Processing year 2004 for ticker TNC.
# 2026-01-21 17:40:06,326, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2004
# 2026-01-21 17:40:06,415, 2113979629.py, 8, INFO, Processing year 2005 for ticker TNC.
# 2026-01-21 17:40:06,419, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2005
# 2026-01-21 17:40:06,483, 2113979629.py, 8, INFO, Processing year 2006 for ticker TNC.
# 2026-01-21 17:40:06,483, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2006
# 2026-01-21 17:40:06,545, 2113979629.py, 8, INFO, Processing year 2007 for ticker TNC.
# 2026-01-21 17:40:06,547, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2007
# 2026-01-21 17:40:06,615, 2113979629.py, 8, INFO, Processing year 2008 for ticker TNC.
# 2026-01-21 17:40:06,618, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2008
# 2026-01-21 17:40:06,719, 2113979629.py, 8, INFO, Processing year 2009 for ticker TNC.
# 2026-01-21 17:40:06,726, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2009
# 2026-01-21 17:40:06,794, 2113979629.py, 8, INFO, Processing year 2010 for ticker TNC.
# 2026-01-21 17:40:06,797, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2010
# 2026-01-21 17:40:06,832, 2113979629.py, 8, INFO, Processing year 2011 for ticker TNC.
# 2026-01-21 17:40:06,840, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2011
# 2026-01-21 17:40:06,871, 2113979629.py, 8, INFO, Processing year 2012 for ticker TNC.
# 2026-01-21 17:40:06,877, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2012
# 2026-01-21 17:40:06,900, 2113979629.py, 8, INFO, Processing year 2013 for ticker TNC.
# 2026-01-21 17:40:06,903, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2013
# 2026-01-21 17:40:06,929, 2113979629.py, 8, INFO, Processing year 2014 for ticker TNC.
# 2026-01-21 17:40:06,933, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2014
# 2026-01-21 17:40:06,960, 2113979629.py, 8, INFO, Processing year 2015 for ticker TNC.
# 2026-01-21 17:40:06,968, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2015
# 2026-01-21 17:40:06,995, 2113979629.py, 8, INFO, Processing year 2016 for ticker TNC.
# 2026-01-21 17:40:06,998, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2016
# 2026-01-21 17:40:07,035, 2113979629.py, 8, INFO, Processing year 2017 for ticker TNC.
# 2026-01-21 17:40:07,048, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2017
# 2026-01-21 17:40:07,100, 2113979629.py, 8, INFO, Processing year 2018 for ticker TNC.
# 2026-01-21 17:40:07,109, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2018
# 2026-01-21 17:40:07,153, 2113979629.py, 8, INFO, Processing year 2019 for ticker TNC.
# 2026-01-21 17:40:07,161, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2019
# 2026-01-21 17:40:07,215, 2113979629.py, 8, INFO, Processing year 2020 for ticker TNC.
# 2026-01-21 17:40:07,223, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2020
# 2026-01-21 17:40:07,238, 2113979629.py, 4, INFO, Processing ticker: CBB
# 2026-01-21 17:40:07,259, 2113979629.py, 8, INFO, Processing year 1980 for ticker CBB.
# 2026-01-21 17:40:07,259, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1980
# 2026-01-21 17:40:07,288, 2113979629.py, 8, INFO, Processing year 1981 for ticker CBB.
# 2026-01-21 17:40:07,294, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1981
# 2026-01-21 17:40:07,312, 2113979629.py, 8, INFO, Processing year 1982 for ticker CBB.
# 2026-01-21 17:40:07,312, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1982
# 2026-01-21 17:40:07,329, 2113979629.py, 8, INFO, Processing year 1983 for ticker CBB.
# 2026-01-21 17:40:07,329, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1983
# 2026-01-21 17:40:07,358, 2113979629.py, 8, INFO, Processing year 1984 for ticker CBB.
# 2026-01-21 17:40:07,361, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1984
# 2026-01-21 17:40:07,374, 2113979629.py, 8, INFO, Processing year 1985 for ticker CBB.
# 2026-01-21 17:40:07,374, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1985
# 2026-01-21 17:40:07,393, 2113979629.py, 8, INFO, Processing year 1986 for ticker CBB.
# 2026-01-21 17:40:07,407, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1986
# 2026-01-21 17:40:07,426, 2113979629.py, 8, INFO, Processing year 1987 for ticker CBB.
# 2026-01-21 17:40:07,426, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1987
# 2026-01-21 17:40:07,443, 2113979629.py, 8, INFO, Processing year 1988 for ticker CBB.
# 2026-01-21 17:40:07,460, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1988
# 2026-01-21 17:40:07,477, 2113979629.py, 8, INFO, Processing year 1989 for ticker CBB.
# 2026-01-21 17:40:07,477, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1989
# 2026-01-21 17:40:07,521, 2113979629.py, 8, INFO, Processing year 1990 for ticker CBB.
# 2026-01-21 17:40:07,530, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1990
# 2026-01-21 17:40:07,545, 2113979629.py, 8, INFO, Processing year 1991 for ticker CBB.
# 2026-01-21 17:40:07,559, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1991
# 2026-01-21 17:40:07,575, 2113979629.py, 8, INFO, Processing year 1992 for ticker CBB.
# 2026-01-21 17:40:07,575, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1992
# 2026-01-21 17:40:07,605, 2113979629.py, 8, INFO, Processing year 1993 for ticker CBB.
# 2026-01-21 17:40:07,609, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1993
# 2026-01-21 17:40:07,628, 2113979629.py, 8, INFO, Processing year 1994 for ticker CBB.
# 2026-01-21 17:40:07,631, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1994
# 2026-01-21 17:40:07,648, 2113979629.py, 8, INFO, Processing year 1995 for ticker CBB.
# 2026-01-21 17:40:07,656, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1995
# 2026-01-21 17:40:07,675, 2113979629.py, 8, INFO, Processing year 1996 for ticker CBB.
# 2026-01-21 17:40:07,675, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1996
# 2026-01-21 17:40:07,697, 2113979629.py, 8, INFO, Processing year 1997 for ticker CBB.
# 2026-01-21 17:40:07,700, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1997
# 2026-01-21 17:40:07,720, 2113979629.py, 8, INFO, Processing year 1998 for ticker CBB.
# 2026-01-21 17:40:07,721, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1998
# 2026-01-21 17:40:07,814, 2113979629.py, 8, INFO, Processing year 1999 for ticker CBB.
# 2026-01-21 17:40:07,818, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1999
# 2026-01-21 17:40:07,839, 2113979629.py, 8, INFO, Processing year 2000 for ticker CBB.
# 2026-01-21 17:40:07,846, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2000
# 2026-01-21 17:40:07,874, 2113979629.py, 8, INFO, Processing year 2001 for ticker CBB.
# 2026-01-21 17:40:07,880, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2001
# 2026-01-21 17:40:07,912, 2113979629.py, 8, INFO, Processing year 2002 for ticker CBB.
# 2026-01-21 17:40:07,917, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2002
# 2026-01-21 17:40:07,945, 2113979629.py, 8, INFO, Processing year 2003 for ticker CBB.
# 2026-01-21 17:40:07,948, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2003
# 2026-01-21 17:40:07,971, 2113979629.py, 8, INFO, Processing year 2004 for ticker CBB.
# 2026-01-21 17:40:07,976, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2004
# 2026-01-21 17:40:07,995, 2113979629.py, 8, INFO, Processing year 2005 for ticker CBB.
# 2026-01-21 17:40:07,998, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2005
# 2026-01-21 17:40:08,017, 2113979629.py, 8, INFO, Processing year 2006 for ticker CBB.
# 2026-01-21 17:40:08,020, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2006
# 2026-01-21 17:40:08,039, 2113979629.py, 8, INFO, Processing year 2007 for ticker CBB.
# 2026-01-21 17:40:08,044, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2007
# 2026-01-21 17:40:08,064, 2113979629.py, 8, INFO, Processing year 2008 for ticker CBB.
# 2026-01-21 17:40:08,069, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2008
# 2026-01-21 17:40:08,092, 2113979629.py, 8, INFO, Processing year 2009 for ticker CBB.
# 2026-01-21 17:40:08,096, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2009
# 2026-01-21 17:40:08,127, 2113979629.py, 8, INFO, Processing year 2010 for ticker CBB.
# 2026-01-21 17:40:08,127, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2010
# 2026-01-21 17:40:08,166, 2113979629.py, 8, INFO, Processing year 2011 for ticker CBB.
# 2026-01-21 17:40:08,166, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2011
# 2026-01-21 17:40:08,195, 2113979629.py, 8, INFO, Processing year 2012 for ticker CBB.
# 2026-01-21 17:40:08,198, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2012
# 2026-01-21 17:40:08,210, 2113979629.py, 8, INFO, Processing year 2013 for ticker CBB.
# 2026-01-21 17:40:08,222, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2013
# 2026-01-21 17:40:08,243, 2113979629.py, 8, INFO, Processing year 2014 for ticker CBB.
# 2026-01-21 17:40:08,243, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2014
# 2026-01-21 17:40:08,273, 2113979629.py, 8, INFO, Processing year 2015 for ticker CBB.
# 2026-01-21 17:40:08,277, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2015
# 2026-01-21 17:40:08,296, 2113979629.py, 8, INFO, Processing year 2016 for ticker CBB.
# 2026-01-21 17:40:08,305, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2016
# 2026-01-21 17:40:08,326, 2113979629.py, 8, INFO, Processing year 2017 for ticker CBB.
# 2026-01-21 17:40:08,326, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2017
# 2026-01-21 17:40:08,346, 2113979629.py, 8, INFO, Processing year 2018 for ticker CBB.
# 2026-01-21 17:40:08,358, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2018
# 2026-01-21 17:40:08,376, 2113979629.py, 8, INFO, Processing year 2019 for ticker CBB.
# 2026-01-21 17:40:08,376, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2019
# 2026-01-21 17:40:08,398, 2113979629.py, 8, INFO, Processing year 2020 for ticker CBB.
# 2026-01-21 17:40:08,406, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2020
# 2026-01-21 17:40:08,425, 2113979629.py, 4, INFO, Processing ticker: ALDX
# 2026-01-21 17:40:08,438, 2113979629.py, 8, INFO, Processing year 2014 for ticker ALDX.
# 2026-01-21 17:40:08,438, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX\ALDX_2014
# 2026-01-21 17:40:08,461, 2113979629.py, 8, INFO, Processing year 2015 for ticker ALDX.
# 2026-01-21 17:40:08,461, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX\ALDX_2015
# 2026-01-21 17:40:08,485, 2113979629.py, 8, INFO, Processing year 2016 for ticker ALDX.
# 2026-01-21 17:40:08,487, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX\ALDX_2016
# 2026-01-21 17:40:08,508, 2113979629.py, 8, INFO, Processing year 2017 for ticker ALDX.
# 2026-01-21 17:40:08,513, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX\ALDX_2017
# 2026-01-21 17:40:08,526, 2113979629.py, 8, INFO, Processing year 2018 for ticker ALDX.
# 2026-01-21 17:40:08,538, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX\ALDX_2018
# 2026-01-21 17:40:08,557, 2113979629.py, 8, INFO, Processing year 2019 for ticker ALDX.
# 2026-01-21 17:40:08,561, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX\ALDX_2019
# 2026-01-21 17:40:08,580, 2113979629.py, 8, INFO, Processing year 2020 for ticker ALDX.
# 2026-01-21 17:40:08,583, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX\ALDX_2020
# 2026-01-21 17:40:08,604, 2113979629.py, 4, INFO, Processing ticker: GLADD
# 2026-01-21 17:40:08,605, 2113979629.py, 8, INFO, Processing year 2018 for ticker GLADD.
# 2026-01-21 17:40:08,620, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GLADD\GLADD_2018
# 2026-01-21 17:40:08,645, 2113979629.py, 8, INFO, Processing year 2019 for ticker GLADD.
# 2026-01-21 17:40:08,649, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GLADD\GLADD_2019
# 2026-01-21 17:40:08,670, 2113979629.py, 8, INFO, Processing year 2020 for ticker GLADD.
# 2026-01-21 17:40:08,677, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GLADD\GLADD_2020
# 2026-01-21 17:40:08,709, 2113979629.py, 4, INFO, Processing ticker: FIXX
# 2026-01-21 17:40:08,725, 2113979629.py, 8, INFO, Processing year 2018 for ticker FIXX.
# 2026-01-21 17:40:08,728, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/FIXX\FIXX_2018
# 2026-01-21 17:40:08,745, 2113979629.py, 8, INFO, Processing year 2019 for ticker FIXX.
# 2026-01-21 17:40:08,745, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/FIXX\FIXX_2019
# 2026-01-21 17:40:08,757, 2113979629.py, 8, INFO, Processing year 2020 for ticker FIXX.
# 2026-01-21 17:40:08,772, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/FIXX\FIXX_2020
# 2026-01-21 17:40:08,793, 2113979629.py, 4, INFO, Processing ticker: ETJ
# 2026-01-21 17:40:08,810, 2113979629.py, 8, INFO, Processing year 2007 for ticker ETJ.
# 2026-01-21 17:40:08,813, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2007
# 2026-01-21 17:40:08,834, 2113979629.py, 8, INFO, Processing year 2008 for ticker ETJ.
# 2026-01-21 17:40:08,838, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2008
# 2026-01-21 17:40:08,859, 2113979629.py, 8, INFO, Processing year 2009 for ticker ETJ.
# 2026-01-21 17:40:08,863, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2009
# 2026-01-21 17:40:08,876, 2113979629.py, 8, INFO, Processing year 2010 for ticker ETJ.
# 2026-01-21 17:40:08,888, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2010
# 2026-01-21 17:40:08,910, 2113979629.py, 8, INFO, Processing year 2011 for ticker ETJ.
# 2026-01-21 17:40:08,910, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2011
# 2026-01-21 17:40:08,931, 2113979629.py, 8, INFO, Processing year 2012 for ticker ETJ.
# 2026-01-21 17:40:08,941, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2012
# 2026-01-21 17:40:08,963, 2113979629.py, 8, INFO, Processing year 2013 for ticker ETJ.
# 2026-01-21 17:40:08,963, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2013
# 2026-01-21 17:40:08,991, 2113979629.py, 8, INFO, Processing year 2014 for ticker ETJ.
# 2026-01-21 17:40:08,995, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2014
# 2026-01-21 17:40:09,009, 2113979629.py, 8, INFO, Processing year 2015 for ticker ETJ.
# 2026-01-21 17:40:09,009, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2015
# 2026-01-21 17:40:09,038, 2113979629.py, 8, INFO, Processing year 2016 for ticker ETJ.
# 2026-01-21 17:40:09,045, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2016
# 2026-01-21 17:40:09,065, 2113979629.py, 8, INFO, Processing year 2017 for ticker ETJ.
# 2026-01-21 17:40:09,065, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2017
# 2026-01-21 17:40:09,088, 2113979629.py, 8, INFO, Processing year 2018 for ticker ETJ.
# 2026-01-21 17:40:09,093, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2018
# 2026-01-21 17:40:09,107, 2113979629.py, 8, INFO, Processing year 2019 for ticker ETJ.
# 2026-01-21 17:40:09,107, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2019
# 2026-01-21 17:40:09,126, 2113979629.py, 8, INFO, Processing year 2020 for ticker ETJ.
# 2026-01-21 17:40:09,143, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2020
# 2026-01-21 17:40:09,162, 2113979629.py, 4, INFO, Processing ticker: CMCTP
# 2026-01-21 17:40:09,176, 2113979629.py, 8, INFO, Processing year 2018 for ticker CMCTP.
# 2026-01-21 17:40:09,176, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CMCTP\CMCTP_2018
# 2026-01-21 17:40:09,209, 2113979629.py, 8, INFO, Processing year 2019 for ticker CMCTP.
# 2026-01-21 17:40:09,209, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CMCTP\CMCTP_2019
# 2026-01-21 17:40:09,229, 2113979629.py, 8, INFO, Processing year 2020 for ticker CMCTP.
# 2026-01-21 17:40:09,229, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CMCTP\CMCTP_2020
# 2026-01-21 17:40:09,258, 2113979629.py, 4, INFO, Processing ticker: BWG
# 2026-01-21 17:40:09,272, 2113979629.py, 8, INFO, Processing year 2012 for ticker BWG.
# 2026-01-21 17:40:09,272, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BWG\BWG_2012
# 2026-01-21 17:40:09,295, 2113979629.py, 8, INFO, Processing year 2013 for ticker BWG.
# 2026-01-21 17:40:09,295, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BWG\BWG_2013
# 2026-01-21 17:40:09,321, 2113979629.py, 8, INFO, Processing year 2014 for ticker BWG.
# 2026-01-21 17:40:09,326, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BWG\BWG_2014
# 2026-01-21 17:40:09,344, 2113979629.py, 8, INFO, Processing year 2015 for ticker BWG.
# 2026-01-21 17:40:09,344, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BWG\BWG_2015
# 2026-01-21 17:40:09,355, 2113979629.py, 8, INFO, Processing year 2016 for ticker BWG.
# 2026-01-21 17:40:09,355, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BWG\BWG_2016
# 2026-01-21 17:40:09,393, 2113979629.py, 8, INFO, Processing year 2017 for ticker BWG.
# 2026-01-21 17:40:09,398, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BWG\BWG_2017
# 2026-01-21 17:40:09,424, 2113979629.py, 8, INFO, Processing year 2018 for ticker BWG.
# 2026-01-21 17:40:09,427, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BWG\BWG_2018
# 2026-01-21 17:40:09,447, 2113979629.py, 8, INFO, Processing year 2019 for ticker BWG.
# 2026-01-21 17:40:09,458, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BWG\BWG_2019
# 2026-01-21 17:40:09,477, 2113979629.py, 8, INFO, Processing year 2020 for ticker BWG.
# 2026-01-21 17:40:09,481, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BWG\BWG_2020
# 2026-01-21 17:40:09,502, 2113979629.py, 4, INFO, Processing ticker: VIAC
# 2026-01-21 17:40:09,519, 2113979629.py, 8, INFO, Processing year 2005 for ticker VIAC.
# 2026-01-21 17:40:09,523, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2005
# 2026-01-21 17:40:09,543, 2113979629.py, 8, INFO, Processing year 2006 for ticker VIAC.
# 2026-01-21 17:40:09,546, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2006
# 2026-01-21 17:40:09,567, 2113979629.py, 8, INFO, Processing year 2007 for ticker VIAC.
# 2026-01-21 17:40:09,577, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2007
# 2026-01-21 17:40:09,596, 2113979629.py, 8, INFO, Processing year 2008 for ticker VIAC.
# 2026-01-21 17:40:09,599, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2008
# 2026-01-21 17:40:09,617, 2113979629.py, 8, INFO, Processing year 2009 for ticker VIAC.
# 2026-01-21 17:40:09,619, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2009
# 2026-01-21 17:40:09,644, 2113979629.py, 8, INFO, Processing year 2010 for ticker VIAC.
# 2026-01-21 17:40:09,647, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2010
# 2026-01-21 17:40:09,668, 2113979629.py, 8, INFO, Processing year 2011 for ticker VIAC.
# 2026-01-21 17:40:09,674, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2011
# 2026-01-21 17:40:09,698, 2113979629.py, 8, INFO, Processing year 2012 for ticker VIAC.
# 2026-01-21 17:40:09,705, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2012
# 2026-01-21 17:40:09,726, 2113979629.py, 8, INFO, Processing year 2013 for ticker VIAC.
# 2026-01-21 17:40:09,729, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2013
# 2026-01-21 17:40:09,750, 2113979629.py, 8, INFO, Processing year 2014 for ticker VIAC.
# 2026-01-21 17:40:09,753, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2014
# 2026-01-21 17:40:09,777, 2113979629.py, 8, INFO, Processing year 2015 for ticker VIAC.
# 2026-01-21 17:40:09,777, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2015
# 2026-01-21 17:40:09,814, 2113979629.py, 8, INFO, Processing year 2016 for ticker VIAC.
# 2026-01-21 17:40:09,814, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2016
# 2026-01-21 17:40:09,844, 2113979629.py, 8, INFO, Processing year 2017 for ticker VIAC.
# 2026-01-21 17:40:09,844, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2017
# 2026-01-21 17:40:09,875, 2113979629.py, 8, INFO, Processing year 2018 for ticker VIAC.
# 2026-01-21 17:40:09,878, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2018
# 2026-01-21 17:40:09,898, 2113979629.py, 8, INFO, Processing year 2019 for ticker VIAC.
# 2026-01-21 17:40:09,898, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2019
# 2026-01-21 17:40:09,927, 2113979629.py, 8, INFO, Processing year 2020 for ticker VIAC.
# 2026-01-21 17:40:09,927, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2020
# 2026-01-21 17:40:09,950, 2113979629.py, 4, INFO, Processing ticker: REI
# 2026-01-21 17:40:09,957, 2113979629.py, 8, INFO, Processing year 2007 for ticker REI.
# 2026-01-21 17:40:09,957, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2007
# 2026-01-21 17:40:09,998, 2113979629.py, 8, INFO, Processing year 2008 for ticker REI.
# 2026-01-21 17:40:10,004, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2008
# 2026-01-21 17:40:10,028, 2113979629.py, 8, INFO, Processing year 2009 for ticker REI.
# 2026-01-21 17:40:10,028, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2009
# 2026-01-21 17:40:10,057, 2113979629.py, 8, INFO, Processing year 2010 for ticker REI.
# 2026-01-21 17:40:10,060, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2010
# 2026-01-21 17:40:10,074, 2113979629.py, 8, INFO, Processing year 2011 for ticker REI.
# 2026-01-21 17:40:10,074, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2011
# 2026-01-21 17:40:10,094, 2113979629.py, 8, INFO, Processing year 2012 for ticker REI.
# 2026-01-21 17:40:10,109, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2012
# 2026-01-21 17:40:10,126, 2113979629.py, 8, INFO, Processing year 2013 for ticker REI.
# 2026-01-21 17:40:10,126, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2013
# 2026-01-21 17:40:10,149, 2113979629.py, 8, INFO, Processing year 2014 for ticker REI.
# 2026-01-21 17:40:10,158, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2014
# 2026-01-21 17:40:10,176, 2113979629.py, 8, INFO, Processing year 2015 for ticker REI.
# 2026-01-21 17:40:10,176, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2015
# 2026-01-21 17:40:10,210, 2113979629.py, 8, INFO, Processing year 2016 for ticker REI.
# 2026-01-21 17:40:10,213, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2016
# 2026-01-21 17:40:10,221, 2113979629.py, 8, INFO, Processing year 2017 for ticker REI.
# 2026-01-21 17:40:10,221, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2017
# 2026-01-21 17:40:10,243, 2113979629.py, 8, INFO, Processing year 2018 for ticker REI.
# 2026-01-21 17:40:10,257, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2018
# 2026-01-21 17:40:10,280, 2113979629.py, 8, INFO, Processing year 2019 for ticker REI.
# 2026-01-21 17:40:10,280, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2019
# 2026-01-21 17:40:10,313, 2113979629.py, 8, INFO, Processing year 2020 for ticker REI.
# 2026-01-21 17:40:10,315, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2020
# 2026-01-21 17:40:10,321, 2113979629.py, 4, INFO, Processing ticker: BLPH
# 2026-01-21 17:40:10,342, 2113979629.py, 8, INFO, Processing year 2015 for ticker BLPH.
# 2026-01-21 17:40:10,357, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BLPH\BLPH_2015
# 2026-01-21 17:40:10,376, 2113979629.py, 8, INFO, Processing year 2016 for ticker BLPH.
# 2026-01-21 17:40:10,376, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BLPH\BLPH_2016
# 2026-01-21 17:40:10,405, 2113979629.py, 8, INFO, Processing year 2017 for ticker BLPH.
# 2026-01-21 17:40:10,405, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BLPH\BLPH_2017
# 2026-01-21 17:40:10,436, 2113979629.py, 8, INFO, Processing year 2018 for ticker BLPH.
# 2026-01-21 17:40:10,441, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BLPH\BLPH_2018
# 2026-01-21 17:40:10,466, 2113979629.py, 8, INFO, Processing year 2019 for ticker BLPH.
# 2026-01-21 17:40:10,469, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BLPH\BLPH_2019
# 2026-01-21 17:40:10,487, 2113979629.py, 8, INFO, Processing year 2020 for ticker BLPH.
# 2026-01-21 17:40:10,487, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BLPH\BLPH_2020
# 2026-01-21 17:40:10,506, 2113979629.py, 4, INFO, Processing ticker: SMG
# 2026-01-21 17:40:10,532, 2113979629.py, 8, INFO, Processing year 1992 for ticker SMG.
# 2026-01-21 17:40:10,535, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_1992
# 2026-01-21 17:40:10,558, 2113979629.py, 8, INFO, Processing year 1993 for ticker SMG.
# 2026-01-21 17:40:10,561, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_1993
# 2026-01-21 17:40:10,584, 2113979629.py, 8, INFO, Processing year 1994 for ticker SMG.
# 2026-01-21 17:40:10,591, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_1994
# 2026-01-21 17:40:10,610, 2113979629.py, 8, INFO, Processing year 1995 for ticker SMG.
# 2026-01-21 17:40:10,613, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_1995
# 2026-01-21 17:40:10,631, 2113979629.py, 8, INFO, Processing year 1996 for ticker SMG.
# 2026-01-21 17:40:10,634, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_1996
# 2026-01-21 17:40:10,660, 2113979629.py, 8, INFO, Processing year 1997 for ticker SMG.
# 2026-01-21 17:40:10,663, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_1997
# 2026-01-21 17:40:10,685, 2113979629.py, 8, INFO, Processing year 1998 for ticker SMG.
# 2026-01-21 17:40:10,697, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_1998
# 2026-01-21 17:40:10,717, 2113979629.py, 8, INFO, Processing year 1999 for ticker SMG.
# 2026-01-21 17:40:10,720, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_1999
# 2026-01-21 17:40:10,746, 2113979629.py, 8, INFO, Processing year 2000 for ticker SMG.
# 2026-01-21 17:40:10,749, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2000
# 2026-01-21 17:40:10,767, 2113979629.py, 8, INFO, Processing year 2001 for ticker SMG.
# 2026-01-21 17:40:10,771, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2001
# 2026-01-21 17:40:10,801, 2113979629.py, 8, INFO, Processing year 2002 for ticker SMG.
# 2026-01-21 17:40:10,810, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2002
# 2026-01-21 17:40:10,831, 2113979629.py, 8, INFO, Processing year 2003 for ticker SMG.
# 2026-01-21 17:40:10,835, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2003
# 2026-01-21 17:40:10,859, 2113979629.py, 8, INFO, Processing year 2004 for ticker SMG.
# 2026-01-21 17:40:10,861, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2004
# 2026-01-21 17:40:10,873, 2113979629.py, 8, INFO, Processing year 2005 for ticker SMG.
# 2026-01-21 17:40:10,873, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2005
# 2026-01-21 17:40:10,907, 2113979629.py, 8, INFO, Processing year 2006 for ticker SMG.
# 2026-01-21 17:40:10,909, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2006
# 2026-01-21 17:40:10,927, 2113979629.py, 8, INFO, Processing year 2007 for ticker SMG.
# 2026-01-21 17:40:10,927, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2007
# 2026-01-21 17:40:10,957, 2113979629.py, 8, INFO, Processing year 2008 for ticker SMG.
# 2026-01-21 17:40:10,959, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2008
# 2026-01-21 17:40:10,978, 2113979629.py, 8, INFO, Processing year 2009 for ticker SMG.
# 2026-01-21 17:40:10,978, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2009
# 2026-01-21 17:40:10,998, 2113979629.py, 8, INFO, Processing year 2010 for ticker SMG.
# 2026-01-21 17:40:11,005, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2010
# 2026-01-21 17:40:11,027, 2113979629.py, 8, INFO, Processing year 2011 for ticker SMG.
# 2026-01-21 17:40:11,030, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2011
# 2026-01-21 17:40:11,045, 2113979629.py, 8, INFO, Processing year 2012 for ticker SMG.
# 2026-01-21 17:40:11,045, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2012
# 2026-01-21 17:40:11,058, 2113979629.py, 8, INFO, Processing year 2013 for ticker SMG.
# 2026-01-21 17:40:11,058, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2013
# 2026-01-21 17:40:11,090, 2113979629.py, 8, INFO, Processing year 2014 for ticker SMG.
# 2026-01-21 17:40:11,096, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2014
# 2026-01-21 17:40:11,116, 2113979629.py, 8, INFO, Processing year 2015 for ticker SMG.
# 2026-01-21 17:40:11,119, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2015
# 2026-01-21 17:40:11,142, 2113979629.py, 8, INFO, Processing year 2016 for ticker SMG.
# 2026-01-21 17:40:11,146, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2016
# 2026-01-21 17:40:11,166, 2113979629.py, 8, INFO, Processing year 2017 for ticker SMG.
# 2026-01-21 17:40:11,171, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2017
# 2026-01-21 17:40:11,194, 2113979629.py, 8, INFO, Processing year 2018 for ticker SMG.
# 2026-01-21 17:40:11,198, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2018
# 2026-01-21 17:40:11,221, 2113979629.py, 8, INFO, Processing year 2019 for ticker SMG.
# 2026-01-21 17:40:11,226, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2019
# 2026-01-21 17:40:11,238, 2113979629.py, 8, INFO, Processing year 2020 for ticker SMG.
# 2026-01-21 17:40:11,238, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2020
# 2026-01-21 17:40:11,259, 2113979629.py, 4, INFO, Processing ticker: MOH
# 2026-01-21 17:40:11,276, 2113979629.py, 8, INFO, Processing year 2003 for ticker MOH.
# 2026-01-21 17:40:11,276, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2003
# 2026-01-21 17:40:11,288, 2113979629.py, 8, INFO, Processing year 2004 for ticker MOH.
# 2026-01-21 17:40:11,306, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2004
# 2026-01-21 17:40:11,326, 2113979629.py, 8, INFO, Processing year 2005 for ticker MOH.
# 2026-01-21 17:40:11,326, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2005
# 2026-01-21 17:40:11,360, 2113979629.py, 8, INFO, Processing year 2006 for ticker MOH.
# 2026-01-21 17:40:11,360, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2006
# 2026-01-21 17:40:11,382, 2113979629.py, 8, INFO, Processing year 2007 for ticker MOH.
# 2026-01-21 17:40:11,382, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2007
# 2026-01-21 17:40:11,407, 2113979629.py, 8, INFO, Processing year 2008 for ticker MOH.
# 2026-01-21 17:40:11,411, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2008
# 2026-01-21 17:40:11,443, 2113979629.py, 8, INFO, Processing year 2009 for ticker MOH.
# 2026-01-21 17:40:11,448, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2009
# 2026-01-21 17:40:11,471, 2113979629.py, 8, INFO, Processing year 2010 for ticker MOH.
# 2026-01-21 17:40:11,474, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2010
# 2026-01-21 17:40:11,489, 2113979629.py, 8, INFO, Processing year 2011 for ticker MOH.
# 2026-01-21 17:40:11,489, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2011
# 2026-01-21 17:40:11,519, 2113979629.py, 8, INFO, Processing year 2012 for ticker MOH.
# 2026-01-21 17:40:11,524, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2012
# 2026-01-21 17:40:11,544, 2113979629.py, 8, INFO, Processing year 2013 for ticker MOH.
# 2026-01-21 17:40:11,547, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2013
# 2026-01-21 17:40:11,572, 2113979629.py, 8, INFO, Processing year 2014 for ticker MOH.
# 2026-01-21 17:40:11,576, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2014
# 2026-01-21 17:40:11,596, 2113979629.py, 8, INFO, Processing year 2015 for ticker MOH.
# 2026-01-21 17:40:11,599, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2015
# 2026-01-21 17:40:11,617, 2113979629.py, 8, INFO, Processing year 2016 for ticker MOH.
# 2026-01-21 17:40:11,619, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2016
# 2026-01-21 17:40:11,639, 2113979629.py, 8, INFO, Processing year 2017 for ticker MOH.
# 2026-01-21 17:40:11,644, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2017
# 2026-01-21 17:40:11,664, 2113979629.py, 8, INFO, Processing year 2018 for ticker MOH.
# 2026-01-21 17:40:11,666, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2018
# 2026-01-21 17:40:11,687, 2113979629.py, 8, INFO, Processing year 2019 for ticker MOH.
# 2026-01-21 17:40:11,693, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2019
# 2026-01-21 17:40:11,723, 2113979629.py, 8, INFO, Processing year 2020 for ticker MOH.
# 2026-01-21 17:40:11,727, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2020
# 2026-01-21 17:40:11,746, 2113979629.py, 4, INFO, Processing ticker: AMH
# 2026-01-21 17:40:11,760, 2113979629.py, 8, INFO, Processing year 2013 for ticker AMH.
# 2026-01-21 17:40:11,766, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMH\AMH_2013
# 2026-01-21 17:40:11,796, 2113979629.py, 8, INFO, Processing year 2014 for ticker AMH.
# 2026-01-21 17:40:11,796, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMH\AMH_2014
# 2026-01-21 17:40:11,825, 2113979629.py, 8, INFO, Processing year 2015 for ticker AMH.
# 2026-01-21 17:40:11,829, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMH\AMH_2015
# 2026-01-21 17:40:11,850, 2113979629.py, 8, INFO, Processing year 2016 for ticker AMH.
# 2026-01-21 17:40:11,857, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMH\AMH_2016
# 2026-01-21 17:40:11,877, 2113979629.py, 8, INFO, Processing year 2017 for ticker AMH.
# 2026-01-21 17:40:11,877, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMH\AMH_2017
# 2026-01-21 17:40:11,901, 2113979629.py, 8, INFO, Processing year 2018 for ticker AMH.
# 2026-01-21 17:40:11,905, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMH\AMH_2018
# 2026-01-21 17:40:11,926, 2113979629.py, 8, INFO, Processing year 2019 for ticker AMH.
# 2026-01-21 17:40:11,926, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMH\AMH_2019
# 2026-01-21 17:40:11,957, 2113979629.py, 8, INFO, Processing year 2020 for ticker AMH.
# 2026-01-21 17:40:11,959, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMH\AMH_2020
# 2026-01-21 17:40:11,971, 2113979629.py, 4, INFO, Processing ticker: AMAL
# 2026-01-21 17:40:11,994, 2113979629.py, 8, INFO, Processing year 2018 for ticker AMAL.
# 2026-01-21 17:40:11,998, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAL\AMAL_2018
# 2026-01-21 17:40:12,012, 2113979629.py, 8, INFO, Processing year 2019 for ticker AMAL.
# 2026-01-21 17:40:12,027, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAL\AMAL_2019
# 2026-01-21 17:40:12,046, 2113979629.py, 8, INFO, Processing year 2020 for ticker AMAL.
# 2026-01-21 17:40:12,046, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAL\AMAL_2020
# 2026-01-21 17:40:12,068, 2113979629.py, 4, INFO, Processing ticker: BPYPN
# 2026-01-21 17:40:12,076, 2113979629.py, 8, INFO, Processing year 2020 for ticker BPYPN.
# 2026-01-21 17:40:12,076, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BPYPN\BPYPN_2020
# 2026-01-21 17:40:12,112, 2113979629.py, 4, INFO, Processing ticker: ERH
# 2026-01-21 17:40:12,129, 2113979629.py, 8, INFO, Processing year 2004 for ticker ERH.
# 2026-01-21 17:40:12,132, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2004
# 2026-01-21 17:40:12,148, 2113979629.py, 8, INFO, Processing year 2005 for ticker ERH.
# 2026-01-21 17:40:12,148, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2005
# 2026-01-21 17:40:12,180, 2113979629.py, 8, INFO, Processing year 2006 for ticker ERH.
# 2026-01-21 17:40:12,182, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2006
# 2026-01-21 17:40:12,210, 2113979629.py, 8, INFO, Processing year 2007 for ticker ERH.
# 2026-01-21 17:40:12,210, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2007
# 2026-01-21 17:40:12,232, 2113979629.py, 8, INFO, Processing year 2008 for ticker ERH.
# 2026-01-21 17:40:12,240, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2008
# 2026-01-21 17:40:12,261, 2113979629.py, 8, INFO, Processing year 2009 for ticker ERH.
# 2026-01-21 17:40:12,264, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2009
# 2026-01-21 17:40:12,287, 2113979629.py, 8, INFO, Processing year 2010 for ticker ERH.
# 2026-01-21 17:40:12,293, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2010
# 2026-01-21 17:40:12,310, 2113979629.py, 8, INFO, Processing year 2011 for ticker ERH.
# 2026-01-21 17:40:12,323, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2011
# 2026-01-21 17:40:12,350, 2113979629.py, 8, INFO, Processing year 2012 for ticker ERH.
# 2026-01-21 17:40:12,353, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2012
# 2026-01-21 17:40:12,376, 2113979629.py, 8, INFO, Processing year 2013 for ticker ERH.
# 2026-01-21 17:40:12,380, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2013
# 2026-01-21 17:40:12,405, 2113979629.py, 8, INFO, Processing year 2014 for ticker ERH.
# 2026-01-21 17:40:12,405, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2014
# 2026-01-21 17:40:12,423, 2113979629.py, 8, INFO, Processing year 2015 for ticker ERH.
# 2026-01-21 17:40:12,437, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2015
# 2026-01-21 17:40:12,485, 2113979629.py, 8, INFO, Processing year 2016 for ticker ERH.
# 2026-01-21 17:40:12,493, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2016
# 2026-01-21 17:40:12,516, 2113979629.py, 8, INFO, Processing year 2017 for ticker ERH.
# 2026-01-21 17:40:12,521, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2017
# 2026-01-21 17:40:12,550, 2113979629.py, 8, INFO, Processing year 2018 for ticker ERH.
# ...
# 2026-01-21 17:40:36,411, 2113979629.py, 8, INFO, Processing year 2016 for ticker GURE.
# 2026-01-21 17:40:36,411, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GURE\GURE_2016
# 2026-01-21 17:40:36,441, 2113979629.py, 8, INFO, Processing year 2017 for ticker GURE.
# 2026-01-21 17:40:36,444, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GURE\GURE_2017
# 2026-01-21 17:40:36,464, 2113979629.py, 8, INFO, Processing year 2018 for ticker GURE.
# 2026-01-21 17:40:36,469, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GURE\GURE_2018
# 2026-01-21 17:40:36,496, 2113979629.py, 8, INFO, Processing year 2019 for ticker GURE.
# 2026-01-21 17:40:36,496, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GURE\GURE_2019
# 2026-01-21 17:40:36,521, 2113979629.py, 8, INFO, Processing year 2020 for ticker GURE.
# 2026-01-21 17:40:36,526, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GURE\GURE_2020
# 2026-01-21 17:40:36,558, 2113979629.py, 4, INFO, Processing ticker: TEF
# 2026-01-21 17:40:36,571, 2113979629.py, 8, INFO, Processing year 1987 for ticker TEF.
# 2026-01-21 17:40:36,571, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1987
# 2026-01-21 17:40:36,595, 2113979629.py, 8, INFO, Processing year 1988 for ticker TEF.
# 2026-01-21 17:40:36,609, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1988
# 2026-01-21 17:40:36,627, 2113979629.py, 8, INFO, Processing year 1989 for ticker TEF.
# 2026-01-21 17:40:36,627, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1989
# 2026-01-21 17:40:36,657, 2113979629.py, 8, INFO, Processing year 1990 for ticker TEF.
# 2026-01-21 17:40:36,659, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1990
# 2026-01-21 17:40:36,678, 2113979629.py, 8, INFO, Processing year 1991 for ticker TEF.
# 2026-01-21 17:40:36,678, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1991
# 2026-01-21 17:40:36,710, 2113979629.py, 8, INFO, Processing year 1992 for ticker TEF.
# 2026-01-21 17:40:36,715, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1992
# 2026-01-21 17:40:36,732, 2113979629.py, 8, INFO, Processing year 1993 for ticker TEF.
# 2026-01-21 17:40:36,742, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1993
# 2026-01-21 17:40:36,756, 2113979629.py, 8, INFO, Processing year 1994 for ticker TEF.
# 2026-01-21 17:40:36,756, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1994
# 2026-01-21 17:40:36,776, 2113979629.py, 8, INFO, Processing year 1995 for ticker TEF.
# 2026-01-21 17:40:36,792, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1995
# 2026-01-21 17:40:36,805, 2113979629.py, 8, INFO, Processing year 1996 for ticker TEF.
# 2026-01-21 17:40:36,805, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1996
# 2026-01-21 17:40:36,859, 2113979629.py, 8, INFO, Processing year 1997 for ticker TEF.
# 2026-01-21 17:40:36,861, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1997
# 2026-01-21 17:40:36,884, 2113979629.py, 8, INFO, Processing year 1998 for ticker TEF.
# 2026-01-21 17:40:36,888, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1998
# 2026-01-21 17:40:36,906, 2113979629.py, 8, INFO, Processing year 1999 for ticker TEF.
# 2026-01-21 17:40:36,921, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1999
# 2026-01-21 17:40:36,942, 2113979629.py, 8, INFO, Processing year 2000 for ticker TEF.
# 2026-01-21 17:40:36,945, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2000
# 2026-01-21 17:40:36,965, 2113979629.py, 8, INFO, Processing year 2001 for ticker TEF.
# 2026-01-21 17:40:36,969, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2001
# 2026-01-21 17:40:36,995, 2113979629.py, 8, INFO, Processing year 2002 for ticker TEF.
# 2026-01-21 17:40:36,998, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2002
# 2026-01-21 17:40:37,018, 2113979629.py, 8, INFO, Processing year 2003 for ticker TEF.
# 2026-01-21 17:40:37,023, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2003
# 2026-01-21 17:40:37,045, 2113979629.py, 8, INFO, Processing year 2004 for ticker TEF.
# 2026-01-21 17:40:37,048, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2004
# 2026-01-21 17:40:37,068, 2113979629.py, 8, INFO, Processing year 2005 for ticker TEF.
# 2026-01-21 17:40:37,074, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2005
# 2026-01-21 17:40:37,100, 2113979629.py, 8, INFO, Processing year 2006 for ticker TEF.
# 2026-01-21 17:40:37,104, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2006
# 2026-01-21 17:40:37,125, 2113979629.py, 8, INFO, Processing year 2007 for ticker TEF.
# 2026-01-21 17:40:37,129, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2007
# 2026-01-21 17:40:37,151, 2113979629.py, 8, INFO, Processing year 2008 for ticker TEF.
# 2026-01-21 17:40:37,156, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2008
# 2026-01-21 17:40:37,180, 2113979629.py, 8, INFO, Processing year 2009 for ticker TEF.
# 2026-01-21 17:40:37,196, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2009
# 2026-01-21 17:40:37,231, 2113979629.py, 8, INFO, Processing year 2010 for ticker TEF.
# 2026-01-21 17:40:37,231, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2010
# 2026-01-21 17:40:37,259, 2113979629.py, 8, INFO, Processing year 2011 for ticker TEF.
# 2026-01-21 17:40:37,259, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2011
# 2026-01-21 17:40:37,287, 2113979629.py, 8, INFO, Processing year 2012 for ticker TEF.
# 2026-01-21 17:40:37,293, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2012
# 2026-01-21 17:40:37,304, 2113979629.py, 8, INFO, Processing year 2013 for ticker TEF.
# 2026-01-21 17:40:37,304, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2013
# 2026-01-21 17:40:37,342, 2113979629.py, 8, INFO, Processing year 2014 for ticker TEF.
# 2026-01-21 17:40:37,345, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2014
# 2026-01-21 17:40:37,367, 2113979629.py, 8, INFO, Processing year 2015 for ticker TEF.
# 2026-01-21 17:40:37,373, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2015
# 2026-01-21 17:40:37,394, 2113979629.py, 8, INFO, Processing year 2016 for ticker TEF.
# 2026-01-21 17:40:37,394, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2016
# 2026-01-21 17:40:37,407, 2113979629.py, 8, INFO, Processing year 2017 for ticker TEF.
# 2026-01-21 17:40:37,424, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2017
# 2026-01-21 17:40:37,449, 2113979629.py, 8, INFO, Processing year 2018 for ticker TEF.
# 2026-01-21 17:40:37,452, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2018
# 2026-01-21 17:40:37,476, 2113979629.py, 8, INFO, Processing year 2019 for ticker TEF.
# 2026-01-21 17:40:37,476, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2019
# 2026-01-21 17:40:37,509, 2113979629.py, 8, INFO, Processing year 2020 for ticker TEF.
# 2026-01-21 17:40:37,509, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2020
# 2026-01-21 17:40:37,536, 2113979629.py, 4, INFO, Processing ticker: SYNH
# 2026-01-21 17:40:37,554, 2113979629.py, 8, INFO, Processing year 2014 for ticker SYNH.
# 2026-01-21 17:40:37,558, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SYNH\SYNH_2014
# 2026-01-21 17:40:37,578, 2113979629.py, 8, INFO, Processing year 2015 for ticker SYNH.
# 2026-01-21 17:40:37,578, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SYNH\SYNH_2015
# 2026-01-21 17:40:37,609, 2113979629.py, 8, INFO, Processing year 2016 for ticker SYNH.
# 2026-01-21 17:40:37,612, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SYNH\SYNH_2016
# 2026-01-21 17:40:37,634, 2113979629.py, 8, INFO, Processing year 2017 for ticker SYNH.
# 2026-01-21 17:40:37,637, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SYNH\SYNH_2017
# 2026-01-21 17:40:37,660, 2113979629.py, 8, INFO, Processing year 2018 for ticker SYNH.
# 2026-01-21 17:40:37,663, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SYNH\SYNH_2018
# 2026-01-21 17:40:37,682, 2113979629.py, 8, INFO, Processing year 2019 for ticker SYNH.
# 2026-01-21 17:40:37,685, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SYNH\SYNH_2019
# 2026-01-21 17:40:37,715, 2113979629.py, 8, INFO, Processing year 2020 for ticker SYNH.
# 2026-01-21 17:40:37,715, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SYNH\SYNH_2020
# 2026-01-21 17:40:37,737, 2113979629.py, 4, INFO, Processing ticker: KEY
# 2026-01-21 17:40:37,754, 2113979629.py, 8, INFO, Processing year 1987 for ticker KEY.
# 2026-01-21 17:40:37,754, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1987
# 2026-01-21 17:40:37,787, 2113979629.py, 8, INFO, Processing year 1988 for ticker KEY.
# 2026-01-21 17:40:37,791, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1988
# 2026-01-21 17:40:37,811, 2113979629.py, 8, INFO, Processing year 1989 for ticker KEY.
# 2026-01-21 17:40:37,814, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1989
# 2026-01-21 17:40:37,834, 2113979629.py, 8, INFO, Processing year 1990 for ticker KEY.
# 2026-01-21 17:40:37,837, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1990
# 2026-01-21 17:40:37,867, 2113979629.py, 8, INFO, Processing year 1991 for ticker KEY.
# 2026-01-21 17:40:37,872, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1991
# 2026-01-21 17:40:37,894, 2113979629.py, 8, INFO, Processing year 1992 for ticker KEY.
# 2026-01-21 17:40:37,897, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1992
# 2026-01-21 17:40:37,924, 2113979629.py, 8, INFO, Processing year 1993 for ticker KEY.
# 2026-01-21 17:40:37,927, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1993
# 2026-01-21 17:40:37,949, 2113979629.py, 8, INFO, Processing year 1994 for ticker KEY.
# 2026-01-21 17:40:37,954, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1994
# 2026-01-21 17:40:37,976, 2113979629.py, 8, INFO, Processing year 1995 for ticker KEY.
# 2026-01-21 17:40:37,980, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1995
# 2026-01-21 17:40:38,008, 2113979629.py, 8, INFO, Processing year 1996 for ticker KEY.
# 2026-01-21 17:40:38,013, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1996
# 2026-01-21 17:40:38,034, 2113979629.py, 8, INFO, Processing year 1997 for ticker KEY.
# 2026-01-21 17:40:38,040, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1997
# 2026-01-21 17:40:38,063, 2113979629.py, 8, INFO, Processing year 1998 for ticker KEY.
# 2026-01-21 17:40:38,064, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1998
# 2026-01-21 17:40:38,110, 2113979629.py, 8, INFO, Processing year 1999 for ticker KEY.
# 2026-01-21 17:40:38,116, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1999
# 2026-01-21 17:40:38,148, 2113979629.py, 8, INFO, Processing year 2000 for ticker KEY.
# 2026-01-21 17:40:38,155, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2000
# 2026-01-21 17:40:38,197, 2113979629.py, 8, INFO, Processing year 2001 for ticker KEY.
# 2026-01-21 17:40:38,202, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2001
# 2026-01-21 17:40:38,277, 2113979629.py, 8, INFO, Processing year 2002 for ticker KEY.
# 2026-01-21 17:40:38,280, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2002
# 2026-01-21 17:40:38,309, 2113979629.py, 8, INFO, Processing year 2003 for ticker KEY.
# 2026-01-21 17:40:38,313, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2003
# 2026-01-21 17:40:38,363, 2113979629.py, 8, INFO, Processing year 2004 for ticker KEY.
# 2026-01-21 17:40:38,363, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2004
# 2026-01-21 17:40:38,396, 2113979629.py, 8, INFO, Processing year 2005 for ticker KEY.
# 2026-01-21 17:40:38,407, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2005
# 2026-01-21 17:40:38,441, 2113979629.py, 8, INFO, Processing year 2006 for ticker KEY.
# 2026-01-21 17:40:38,445, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2006
# 2026-01-21 17:40:38,466, 2113979629.py, 8, INFO, Processing year 2007 for ticker KEY.
# 2026-01-21 17:40:38,477, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2007
# 2026-01-21 17:40:38,506, 2113979629.py, 8, INFO, Processing year 2008 for ticker KEY.
# 2026-01-21 17:40:38,511, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2008
# 2026-01-21 17:40:38,538, 2113979629.py, 8, INFO, Processing year 2009 for ticker KEY.
# 2026-01-21 17:40:38,544, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2009
# 2026-01-21 17:40:38,573, 2113979629.py, 8, INFO, Processing year 2010 for ticker KEY.
# 2026-01-21 17:40:38,579, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2010
# 2026-01-21 17:40:38,608, 2113979629.py, 8, INFO, Processing year 2011 for ticker KEY.
# 2026-01-21 17:40:38,614, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2011
# 2026-01-21 17:40:38,638, 2113979629.py, 8, INFO, Processing year 2012 for ticker KEY.
# 2026-01-21 17:40:38,641, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2012
# 2026-01-21 17:40:38,664, 2113979629.py, 8, INFO, Processing year 2013 for ticker KEY.
# 2026-01-21 17:40:38,677, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2013
# 2026-01-21 17:40:38,716, 2113979629.py, 8, INFO, Processing year 2014 for ticker KEY.
# 2026-01-21 17:40:38,722, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2014
# 2026-01-21 17:40:38,749, 2113979629.py, 8, INFO, Processing year 2015 for ticker KEY.
# 2026-01-21 17:40:38,751, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2015
# 2026-01-21 17:40:38,776, 2113979629.py, 8, INFO, Processing year 2016 for ticker KEY.
# 2026-01-21 17:40:38,780, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2016
# 2026-01-21 17:40:38,804, 2113979629.py, 8, INFO, Processing year 2017 for ticker KEY.
# 2026-01-21 17:40:38,809, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2017
# 2026-01-21 17:40:38,832, 2113979629.py, 8, INFO, Processing year 2018 for ticker KEY.
# 2026-01-21 17:40:38,835, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2018
# 2026-01-21 17:40:38,857, 2113979629.py, 8, INFO, Processing year 2019 for ticker KEY.
# 2026-01-21 17:40:38,860, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2019
# 2026-01-21 17:40:38,881, 2113979629.py, 8, INFO, Processing year 2020 for ticker KEY.
# 2026-01-21 17:40:38,884, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2020

# %% [markdown]
# Why would we want to store data this way?
#
# + Data files are easier to maintain. We do not update old data, only recent data or the most recent "delta".
# + Parquet files, as long as they maintain a consistent schema, can all be read jointly.

# %% [markdown]
# # Load, Transform, and Save
#
# In this section, we will load the Parquet files we generated, transform the data, and save the resulting dataset.

# %% [markdown]
# ## Load
#
# + Parquet files can be read individually or as a collection.
# + `dd.read_parquet()` can take a list (collection) of files as input.
# + Use `glob` to obtain the collection of files.

# %%
from glob import glob

parquet_files = glob(os.path.join(PRICE_DATA, "**/*.parquet"), recursive = True)
_logs.info(f'Found {len(parquet_files)} parquet files for reading back into Dask.')

dd_px = dd.read_parquet(parquet_files).set_index("ticker")
# Out:
# 2026-01-21 17:40:47,422, 174194153.py, 4, INFO, Found 2045 parquet files for reading back into Dask.

# %% [markdown]
# ## Transform
#
# + This transformation step will create a *Features* data set. In our case, features will be stock returns (we obtained prices).
# + Dask dataframes work similarly to Pandas dataframes: in particular, we can perform groupby and apply operations.
# + Notice the use of [an anonymous (lambda) function](https://realpython.com/python-lambda/) in the apply statement.
#
# In the code below, the following operation occurs:
#
# + Start with a Dask dataframe, `dd_px`.
# + Group the rows of this dataframe by the variable `ticker`, i.e., each group will contain the observations that pertain only to one ticker at a time. The `group_key` parameter controls whether an index entry is added with the value of the grouping variable (`ticker` in this case); if we made `group_keys=True`, we would have a duplicate `ticker` column.
# + For each group defined by a `ticker`, `apply()` the following calculation:
#
#     - Sort the values by `Date` in ascending order.
#     - Assign a new variable called `Close_lag_1` by shifting the position of the closing price (`Close`) by one position.
#     - Define the schema of the resulting dataframe. If we omit this specification, we would get a warning; however, the simplicity of the calculation ensures that Dask can determine the resulting schema.

# %%
dd_px
# Out:
# Dask DataFrame Structure:
#                           Date     Open     High      Low    Close Adj Close   Volume  source   Year
# npartitions=60
# ACN             datetime64[ns]  float64  float64  float64  float64   float64  float64  object  int32
# ALDX                       ...      ...      ...      ...      ...       ...      ...     ...    ...
# ...                        ...      ...      ...      ...      ...       ...      ...     ...    ...
# ZIXI                       ...      ...      ...      ...      ...       ...      ...     ...    ...
# ZIXI                       ...      ...      ...      ...      ...       ...      ...     ...    ...
# Dask Name: sort_index, 8 graph layers

# %%
dd_shift = (
    dd_px
        .groupby('ticker', group_keys=False)
        .apply(
            lambda x: x.sort_values('Date', ascending = True)
                       .assign(Close_lag_1 = x['Close'].shift(1)), 
            meta = pd.DataFrame(data ={'Date': 'datetime64[ns]',
                    'Open': 'f8',
                    'High': 'f8',
                    'Low': 'f8',
                    'Close': 'f8',
                    'Adj Close': 'f8',
                    'Volume': 'i8',
                    'source': 'object',
                    'Year': 'int32',
                    'Close_lag_1': 'f8'},
                    index = pd.Index([], dtype=pd.StringDtype(), name='ticker'))
    ))

# %% [markdown]
# Finally, using the dataframe that we created above, we can now `assign` the `Returns` variable to the entire dataset.

# %%
dd_shift[["Close", "Close_lag_1"]].dtypes
# Out:
# Close          object
# Close_lag_1    object
# dtype: object

# %%
import dask.dataframe as dd

dd_shift["Close"] = dd.to_numeric(dd_shift["Close"], errors="coerce")
dd_shift["Close_lag_1"] = dd.to_numeric(dd_shift["Close_lag_1"], errors="coerce")

# optional but recommended: remove rows where conversion failed or lag is missing
dd_shift = dd_shift.dropna(subset=["Close", "Close_lag_1"])
dd_shift = dd_shift[dd_shift["Close_lag_1"] != 0]

# %%
dd_rets = dd_shift.assign(
    Returns = lambda x: x['Close']/x['Close_lag_1'] - 1
)

# %% [markdown]
# Question: How do we know that we are not (erroneously) combining the last price of a ticker with the first price of the next ticker?

# %% [markdown]
# ## Lazy Exection
#
# What does `dd_rets` contain?

# %%
dd_rets
# Out:
# Dask DataFrame Structure:
#                   Date    Open    High     Low  Close Adj Close  Volume  source    Year Close_lag_1  Returns
# npartitions=60
# ACN             object  object  object  object  int64    object  object  object  object       int64  float64
# ALDX               ...     ...     ...     ...    ...       ...     ...     ...     ...         ...      ...
# ...                ...     ...     ...     ...    ...       ...     ...     ...     ...         ...      ...
# ZIXI               ...     ...     ...     ...    ...       ...     ...     ...     ...         ...      ...
# ZIXI               ...     ...     ...     ...    ...       ...     ...     ...     ...         ...      ...
# Dask Name: assign, 24 graph layers

# %% [markdown]
# + Dask is a lazy execution framework: commands will not execute until the computation is required.
# + To trigger an execution in dask use `.compute()` or execute a command that requires the actual values (for example, write to Parquet or SQL).

# %%
dd_rets.compute()
# Out:
#              Date   Open   High    Low  Close  Adj Close     Volume    source  \
# ticker
# ACN    2001-07-20  15.05  15.05  14.80  15.01  11.284108  9238500.0   ACN.csv
# ACN    2001-07-23  15.00  15.01  14.55  15.00  11.276587  7501000.0   ACN.csv
# ACN    2001-07-24  14.95  14.97  14.70  14.86  11.171341  3537300.0   ACN.csv
# ACN    2001-07-25  14.70  14.95  14.65  14.95  11.238999  4208100.0   ACN.csv
# ACN    2001-07-26  14.95  14.99  14.50  14.50  10.900705  6335300.0   ACN.csv
# ...           ...    ...    ...    ...    ...        ...        ...       ...
# ZIXI   2020-03-26   4.06   4.53   3.88   4.51   4.510000  1668500.0  ZIXI.csv
# ZIXI   2020-03-27   4.49   4.71   4.10   4.60   4.600000  1146800.0  ZIXI.csv
# ZIXI   2020-03-30   4.83   4.87   4.44   4.64   4.640000  1212000.0  ZIXI.csv
# ZIXI   2020-03-31   4.60   4.69   4.10   4.31   4.310000  1057200.0  ZIXI.csv
# ZIXI   2020-04-01   4.11   4.16   3.80   3.82   3.820000   539500.0  ZIXI.csv
#
#         Year  Close_lag_1   Returns
# ticker
# ACN     2001        15.17 -0.010547
# ACN     2001        15.01 -0.000666
# ACN     2001        15.00 -0.009333
# ACN     2001        14.86  0.006057
# ACN     2001        14.95 -0.030100
# ...      ...          ...       ...
# ZIXI    2020         4.04  0.116337
# ZIXI    2020         4.00  0.150000
# ZIXI    2020         3.85  0.205195
# ZIXI    2020         3.77  0.143236
# ZIXI    2020         3.78  0.010582
#
# [239593 rows x 11 columns]

# %% [markdown]
# ## Save
#
# With our transformed data, we can now save the new feature to a Parquet file. We will need to answer the following questions depending on our context, setup, and available resources:
#
# + Should we keep the same namespace?
# + Should we save all columns?

# %%
dd_rets
# Out:
# Dask DataFrame Structure:
#                   Date    Open    High     Low  Close Adj Close  Volume  source    Year Close_lag_1  Returns
# npartitions=60
# ACN             object  object  object  object  int64    object  object  object  object       int64  float64
# ALDX               ...     ...     ...     ...    ...       ...     ...     ...     ...         ...      ...
# ...                ...     ...     ...     ...    ...       ...     ...     ...     ...         ...      ...
# ZIXI               ...     ...     ...     ...    ...       ...     ...     ...     ...         ...      ...
# ZIXI               ...     ...     ...     ...    ...       ...     ...     ...     ...         ...      ...
# Dask Name: assign, 24 graph layers

# %%
# CLean up before save
FEATURES_DATA = os.getenv("FEATURES_DATA")
if os.path.exists(FEATURES_DATA):
    shutil.rmtree(FEATURES_DATA)
dd_rets.to_parquet(FEATURES_DATA, 
                   overwrite = True, 
                   schema={
                       'Date': 'timestamp[ns]',
                       'Open': 'float64',
                       'High': 'float64',
                       'Low': 'float64',
                       'Close': 'float64',
                       'Adj Close': 'float64',
                       'Volume': 'int64',
                       'source': 'string',
                       'Year': 'int32',
                       'Close_lag_1': 'float64',
                       'Returns': 'float64',
                       'ticker': 'large_string'
                   })

# %% [markdown]
# # Optional: from Jupyter to Command Line
#
# + We have drafted our code in a Jupyter Notebook.
# + Finalized code should be written in Python modules.
#
# ## Object Oriented vs Functional Programming
#
# + We can use classes to keep parameters and functions together.
# + We *could* use Object Oriented Programming, but parallelization of data manipulation and modelling tasks benefit from *Functional Programming*.
# + An Idea:
#
#     - [Data Oriented Programming](https://blog.klipse.tech/dop/2022/06/22/principles-of-dop.html).
#     - Use the class to bundle together parameters and functions.
#     - Use stateless operations and treat all data objects as immutable (we do not modify them, we overwrite them).
#     - Take advantage of [`@staticmethod`](https://realpython.com/instance-class-and-static-methods-demystified/).
#
# The code is in `./05_src/stock_prices/data_manager.py`.

# %% [markdown]
# Our original design was:
#
# ![](./images/02_target_pipeline_manager.png)

# %%
from stock_prices.data_manager import DataManager
dm = DataManager()

# %% [markdown]
# Download all prices.

# %%
dm.process_sample_files()
# Out:
# 2026-01-21 17:42:15,967, data_manager.py, 53, INFO, Processing sample of tickers
# 2026-01-21 17:42:15,968, data_manager.py, 64, INFO, Getting file list from ../../05_src/data/prices_csv/
# 2026-01-21 17:42:16,008, data_manager.py, 66, INFO, Found 5884 files in ../../05_src/data/prices/
# 2026-01-21 17:42:16,008, data_manager.py, 74, INFO, Selecting sample of files
# 2026-01-21 17:42:16,008, data_manager.py, 80, INFO, Selected 30 files
# 2026-01-21 17:42:16,008, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\CASS.csv
# 2026-01-21 17:42:16,008, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\CASS.csv
# 2026-01-21 17:42:16,086, data_manager.py, 101, INFO, Saving data by year
# 2026-01-21 17:42:16,089, data_manager.py, 103, INFO, Processing ticker: CASS
# 2026-01-21 17:42:16,094, data_manager.py, 107, INFO, Processing year 1996 for ticker CASS.
# 2026-01-21 17:42:16,099, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CASS\CASS_1996
# 2026-01-21 17:42:16,125, data_manager.py, 107, INFO, Processing year 1997 for ticker CASS.
# 2026-01-21 17:42:16,125, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CASS\CASS_1997
# 2026-01-21 17:42:16,159, data_manager.py, 107, INFO, Processing year 1998 for ticker CASS.
# 2026-01-21 17:42:16,171, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CASS\CASS_1998
# 2026-01-21 17:42:16,208, data_manager.py, 107, INFO, Processing year 1999 for ticker CASS.
# 2026-01-21 17:42:16,210, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CASS\CASS_1999
# 2026-01-21 17:42:16,220, data_manager.py, 107, INFO, Processing year 2000 for ticker CASS.
# 2026-01-21 17:42:16,237, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CASS\CASS_2000
# 2026-01-21 17:42:16,253, data_manager.py, 107, INFO, Processing year 2001 for ticker CASS.
# 2026-01-21 17:42:16,253, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CASS\CASS_2001
# 2026-01-21 17:42:16,270, data_manager.py, 107, INFO, Processing year 2002 for ticker CASS.
# 2026-01-21 17:42:16,270, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CASS\CASS_2002
# 2026-01-21 17:42:16,287, data_manager.py, 107, INFO, Processing year 2003 for ticker CASS.
# 2026-01-21 17:42:16,303, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CASS\CASS_2003
# 2026-01-21 17:42:16,322, data_manager.py, 107, INFO, Processing year 2004 for ticker CASS.
# 2026-01-21 17:42:16,322, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CASS\CASS_2004
# 2026-01-21 17:42:16,337, data_manager.py, 107, INFO, Processing year 2005 for ticker CASS.
# 2026-01-21 17:42:16,353, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CASS\CASS_2005
# 2026-01-21 17:42:16,372, data_manager.py, 107, INFO, Processing year 2006 for ticker CASS.
# 2026-01-21 17:42:16,372, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CASS\CASS_2006
# 2026-01-21 17:42:16,387, data_manager.py, 107, INFO, Processing year 2007 for ticker CASS.
# 2026-01-21 17:42:16,403, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CASS\CASS_2007
# 2026-01-21 17:42:16,424, data_manager.py, 107, INFO, Processing year 2008 for ticker CASS.
# 2026-01-21 17:42:16,424, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CASS\CASS_2008
# 2026-01-21 17:42:16,454, data_manager.py, 107, INFO, Processing year 2009 for ticker CASS.
# 2026-01-21 17:42:16,454, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CASS\CASS_2009
# 2026-01-21 17:42:16,474, data_manager.py, 107, INFO, Processing year 2010 for ticker CASS.
# 2026-01-21 17:42:16,474, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CASS\CASS_2010
# 2026-01-21 17:42:16,496, data_manager.py, 107, INFO, Processing year 2011 for ticker CASS.
# 2026-01-21 17:42:16,499, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CASS\CASS_2011
# 2026-01-21 17:42:16,522, data_manager.py, 107, INFO, Processing year 2012 for ticker CASS.
# 2026-01-21 17:42:16,527, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CASS\CASS_2012
# 2026-01-21 17:42:16,546, data_manager.py, 107, INFO, Processing year 2013 for ticker CASS.
# 2026-01-21 17:42:16,548, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CASS\CASS_2013
# 2026-01-21 17:42:16,568, data_manager.py, 107, INFO, Processing year 2014 for ticker CASS.
# 2026-01-21 17:42:16,571, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CASS\CASS_2014
# 2026-01-21 17:42:16,590, data_manager.py, 107, INFO, Processing year 2015 for ticker CASS.
# 2026-01-21 17:42:16,590, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CASS\CASS_2015
# 2026-01-21 17:42:16,620, data_manager.py, 107, INFO, Processing year 2016 for ticker CASS.
# 2026-01-21 17:42:16,626, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CASS\CASS_2016
# 2026-01-21 17:42:16,645, data_manager.py, 107, INFO, Processing year 2017 for ticker CASS.
# 2026-01-21 17:42:16,645, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CASS\CASS_2017
# 2026-01-21 17:42:16,668, data_manager.py, 107, INFO, Processing year 2018 for ticker CASS.
# 2026-01-21 17:42:16,668, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CASS\CASS_2018
# 2026-01-21 17:42:16,695, data_manager.py, 107, INFO, Processing year 2019 for ticker CASS.
# 2026-01-21 17:42:16,701, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CASS\CASS_2019
# 2026-01-21 17:42:16,723, data_manager.py, 107, INFO, Processing year 2020 for ticker CASS.
# 2026-01-21 17:42:16,728, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CASS\CASS_2020
# 2026-01-21 17:42:16,753, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\CHEF.csv
# 2026-01-21 17:42:16,753, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\CHEF.csv
# 2026-01-21 17:42:16,796, data_manager.py, 101, INFO, Saving data by year
# 2026-01-21 17:42:16,797, data_manager.py, 103, INFO, Processing ticker: CHEF
# 2026-01-21 17:42:16,801, data_manager.py, 107, INFO, Processing year 2011 for ticker CHEF.
# 2026-01-21 17:42:16,805, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CHEF\CHEF_2011
# 2026-01-21 17:42:16,825, data_manager.py, 107, INFO, Processing year 2012 for ticker CHEF.
# 2026-01-21 17:42:16,827, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CHEF\CHEF_2012
# 2026-01-21 17:42:16,851, data_manager.py, 107, INFO, Processing year 2013 for ticker CHEF.
# 2026-01-21 17:42:16,855, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CHEF\CHEF_2013
# 2026-01-21 17:42:16,875, data_manager.py, 107, INFO, Processing year 2014 for ticker CHEF.
# 2026-01-21 17:42:16,877, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CHEF\CHEF_2014
# 2026-01-21 17:42:16,900, data_manager.py, 107, INFO, Processing year 2015 for ticker CHEF.
# 2026-01-21 17:42:16,904, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CHEF\CHEF_2015
# 2026-01-21 17:42:16,927, data_manager.py, 107, INFO, Processing year 2016 for ticker CHEF.
# 2026-01-21 17:42:16,929, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CHEF\CHEF_2016
# 2026-01-21 17:42:16,948, data_manager.py, 107, INFO, Processing year 2017 for ticker CHEF.
# 2026-01-21 17:42:16,953, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CHEF\CHEF_2017
# 2026-01-21 17:42:16,974, data_manager.py, 107, INFO, Processing year 2018 for ticker CHEF.
# 2026-01-21 17:42:16,979, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CHEF\CHEF_2018
# 2026-01-21 17:42:17,010, data_manager.py, 107, INFO, Processing year 2019 for ticker CHEF.
# 2026-01-21 17:42:17,014, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CHEF\CHEF_2019
# 2026-01-21 17:42:17,037, data_manager.py, 107, INFO, Processing year 2020 for ticker CHEF.
# 2026-01-21 17:42:17,042, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CHEF\CHEF_2020
# 2026-01-21 17:42:17,061, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\COFS.csv
# 2026-01-21 17:42:17,062, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\COFS.csv
# 2026-01-21 17:42:17,109, data_manager.py, 101, INFO, Saving data by year
# 2026-01-21 17:42:17,110, data_manager.py, 103, INFO, Processing ticker: COFS
# 2026-01-21 17:42:17,110, data_manager.py, 107, INFO, Processing year 2001 for ticker COFS.
# 2026-01-21 17:42:17,140, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/COFS\COFS_2001
# 2026-01-21 17:42:17,220, data_manager.py, 107, INFO, Processing year 2002 for ticker COFS.
# 2026-01-21 17:42:17,225, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/COFS\COFS_2002
# 2026-01-21 17:42:17,261, data_manager.py, 107, INFO, Processing year 2003 for ticker COFS.
# 2026-01-21 17:42:17,271, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/COFS\COFS_2003
# 2026-01-21 17:42:17,285, data_manager.py, 107, INFO, Processing year 2004 for ticker COFS.
# 2026-01-21 17:42:17,285, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/COFS\COFS_2004
# 2026-01-21 17:42:17,309, data_manager.py, 107, INFO, Processing year 2005 for ticker COFS.
# 2026-01-21 17:42:17,321, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/COFS\COFS_2005
# 2026-01-21 17:42:17,342, data_manager.py, 107, INFO, Processing year 2006 for ticker COFS.
# 2026-01-21 17:42:17,345, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/COFS\COFS_2006
# 2026-01-21 17:42:17,371, data_manager.py, 107, INFO, Processing year 2007 for ticker COFS.
# 2026-01-21 17:42:17,375, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/COFS\COFS_2007
# 2026-01-21 17:42:17,388, data_manager.py, 107, INFO, Processing year 2008 for ticker COFS.
# 2026-01-21 17:42:17,388, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/COFS\COFS_2008
# 2026-01-21 17:42:17,418, data_manager.py, 107, INFO, Processing year 2009 for ticker COFS.
# 2026-01-21 17:42:17,421, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/COFS\COFS_2009
# 2026-01-21 17:42:17,442, data_manager.py, 107, INFO, Processing year 2010 for ticker COFS.
# 2026-01-21 17:42:17,442, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/COFS\COFS_2010
# 2026-01-21 17:42:17,462, data_manager.py, 107, INFO, Processing year 2011 for ticker COFS.
# 2026-01-21 17:42:17,471, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/COFS\COFS_2011
# 2026-01-21 17:42:17,490, data_manager.py, 107, INFO, Processing year 2012 for ticker COFS.
# 2026-01-21 17:42:17,490, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/COFS\COFS_2012
# 2026-01-21 17:42:17,510, data_manager.py, 107, INFO, Processing year 2013 for ticker COFS.
# 2026-01-21 17:42:17,513, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/COFS\COFS_2013
# 2026-01-21 17:42:17,532, data_manager.py, 107, INFO, Processing year 2014 for ticker COFS.
# 2026-01-21 17:42:17,539, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/COFS\COFS_2014
# 2026-01-21 17:42:17,558, data_manager.py, 107, INFO, Processing year 2015 for ticker COFS.
# 2026-01-21 17:42:17,562, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/COFS\COFS_2015
# 2026-01-21 17:42:17,573, data_manager.py, 107, INFO, Processing year 2016 for ticker COFS.
# 2026-01-21 17:42:17,590, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/COFS\COFS_2016
# 2026-01-21 17:42:17,609, data_manager.py, 107, INFO, Processing year 2017 for ticker COFS.
# 2026-01-21 17:42:17,612, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/COFS\COFS_2017
# 2026-01-21 17:42:17,633, data_manager.py, 107, INFO, Processing year 2018 for ticker COFS.
# 2026-01-21 17:42:17,635, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/COFS\COFS_2018
# 2026-01-21 17:42:17,657, data_manager.py, 107, INFO, Processing year 2019 for ticker COFS.
# 2026-01-21 17:42:17,658, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/COFS\COFS_2019
# 2026-01-21 17:42:17,675, data_manager.py, 107, INFO, Processing year 2020 for ticker COFS.
# 2026-01-21 17:42:17,685, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/COFS\COFS_2020
# 2026-01-21 17:42:17,709, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\IZEA.csv
# 2026-01-21 17:42:17,709, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\IZEA.csv
# 2026-01-21 17:42:17,728, data_manager.py, 101, INFO, Saving data by year
# 2026-01-21 17:42:17,728, data_manager.py, 103, INFO, Processing ticker: IZEA
# 2026-01-21 17:42:17,735, data_manager.py, 107, INFO, Processing year 2012 for ticker IZEA.
# 2026-01-21 17:42:17,740, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/IZEA\IZEA_2012
# 2026-01-21 17:42:17,762, data_manager.py, 107, INFO, Processing year 2013 for ticker IZEA.
# 2026-01-21 17:42:17,764, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/IZEA\IZEA_2013
# 2026-01-21 17:42:17,785, data_manager.py, 107, INFO, Processing year 2014 for ticker IZEA.
# 2026-01-21 17:42:17,785, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/IZEA\IZEA_2014
# 2026-01-21 17:42:17,816, data_manager.py, 107, INFO, Processing year 2015 for ticker IZEA.
# 2026-01-21 17:42:17,821, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/IZEA\IZEA_2015
# 2026-01-21 17:42:17,850, data_manager.py, 107, INFO, Processing year 2016 for ticker IZEA.
# 2026-01-21 17:42:17,851, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/IZEA\IZEA_2016
# 2026-01-21 17:42:17,879, data_manager.py, 107, INFO, Processing year 2017 for ticker IZEA.
# 2026-01-21 17:42:17,884, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/IZEA\IZEA_2017
# 2026-01-21 17:42:17,907, data_manager.py, 107, INFO, Processing year 2018 for ticker IZEA.
# 2026-01-21 17:42:17,909, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/IZEA\IZEA_2018
# 2026-01-21 17:42:17,927, data_manager.py, 107, INFO, Processing year 2019 for ticker IZEA.
# 2026-01-21 17:42:17,932, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/IZEA\IZEA_2019
# 2026-01-21 17:42:17,955, data_manager.py, 107, INFO, Processing year 2020 for ticker IZEA.
# 2026-01-21 17:42:17,958, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/IZEA\IZEA_2020
# 2026-01-21 17:42:17,977, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\WBAI.csv
# 2026-01-21 17:42:17,978, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\WBAI.csv
# 2026-01-21 17:42:18,000, data_manager.py, 101, INFO, Saving data by year
# 2026-01-21 17:42:18,000, data_manager.py, 103, INFO, Processing ticker: WBAI
# 2026-01-21 17:42:18,003, data_manager.py, 107, INFO, Processing year 2013 for ticker WBAI.
# 2026-01-21 17:42:18,006, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/WBAI\WBAI_2013
# 2026-01-21 17:42:18,030, data_manager.py, 107, INFO, Processing year 2014 for ticker WBAI.
# 2026-01-21 17:42:18,032, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/WBAI\WBAI_2014
# 2026-01-21 17:42:18,055, data_manager.py, 107, INFO, Processing year 2015 for ticker WBAI.
# 2026-01-21 17:42:18,059, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/WBAI\WBAI_2015
# 2026-01-21 17:42:18,083, data_manager.py, 107, INFO, Processing year 2016 for ticker WBAI.
# 2026-01-21 17:42:18,090, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/WBAI\WBAI_2016
# 2026-01-21 17:42:18,116, data_manager.py, 107, INFO, Processing year 2017 for ticker WBAI.
# 2026-01-21 17:42:18,121, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/WBAI\WBAI_2017
# 2026-01-21 17:42:18,142, data_manager.py, 107, INFO, Processing year 2018 for ticker WBAI.
# 2026-01-21 17:42:18,145, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/WBAI\WBAI_2018
# 2026-01-21 17:42:18,167, data_manager.py, 107, INFO, Processing year 2019 for ticker WBAI.
# 2026-01-21 17:42:18,175, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/WBAI\WBAI_2019
# 2026-01-21 17:42:18,210, data_manager.py, 107, INFO, Processing year 2020 for ticker WBAI.
# 2026-01-21 17:42:18,219, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/WBAI\WBAI_2020
# 2026-01-21 17:42:18,239, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\DMAC.csv
# 2026-01-21 17:42:18,239, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\DMAC.csv
# 2026-01-21 17:42:18,274, data_manager.py, 101, INFO, Saving data by year
# 2026-01-21 17:42:18,276, data_manager.py, 103, INFO, Processing ticker: DMAC
# 2026-01-21 17:42:18,277, data_manager.py, 107, INFO, Processing year 2012 for ticker DMAC.
# 2026-01-21 17:42:18,277, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DMAC\DMAC_2012
# 2026-01-21 17:42:18,312, data_manager.py, 107, INFO, Processing year 2013 for ticker DMAC.
# 2026-01-21 17:42:18,316, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DMAC\DMAC_2013
# 2026-01-21 17:42:18,338, data_manager.py, 107, INFO, Processing year 2014 for ticker DMAC.
# 2026-01-21 17:42:18,338, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DMAC\DMAC_2014
# 2026-01-21 17:42:18,376, data_manager.py, 107, INFO, Processing year 2015 for ticker DMAC.
# 2026-01-21 17:42:18,379, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DMAC\DMAC_2015
# 2026-01-21 17:42:18,408, data_manager.py, 107, INFO, Processing year 2016 for ticker DMAC.
# 2026-01-21 17:42:18,412, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DMAC\DMAC_2016
# 2026-01-21 17:42:18,431, data_manager.py, 107, INFO, Processing year 2017 for ticker DMAC.
# 2026-01-21 17:42:18,435, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DMAC\DMAC_2017
# 2026-01-21 17:42:18,454, data_manager.py, 107, INFO, Processing year 2018 for ticker DMAC.
# 2026-01-21 17:42:18,459, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DMAC\DMAC_2018
# 2026-01-21 17:42:18,477, data_manager.py, 107, INFO, Processing year 2019 for ticker DMAC.
# 2026-01-21 17:42:18,480, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DMAC\DMAC_2019
# 2026-01-21 17:42:18,499, data_manager.py, 107, INFO, Processing year 2020 for ticker DMAC.
# 2026-01-21 17:42:18,502, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DMAC\DMAC_2020
# 2026-01-21 17:42:18,522, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\LITE.csv
# 2026-01-21 17:42:18,523, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\LITE.csv
# 2026-01-21 17:42:18,548, data_manager.py, 101, INFO, Saving data by year
# 2026-01-21 17:42:18,549, data_manager.py, 103, INFO, Processing ticker: LITE
# 2026-01-21 17:42:18,552, data_manager.py, 107, INFO, Processing year 2015 for ticker LITE.
# 2026-01-21 17:42:18,557, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LITE\LITE_2015
# 2026-01-21 17:42:18,579, data_manager.py, 107, INFO, Processing year 2016 for ticker LITE.
# 2026-01-21 17:42:18,584, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LITE\LITE_2016
# 2026-01-21 17:42:18,604, data_manager.py, 107, INFO, Processing year 2017 for ticker LITE.
# 2026-01-21 17:42:18,608, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LITE\LITE_2017
# 2026-01-21 17:42:18,628, data_manager.py, 107, INFO, Processing year 2018 for ticker LITE.
# 2026-01-21 17:42:18,630, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LITE\LITE_2018
# 2026-01-21 17:42:18,649, data_manager.py, 107, INFO, Processing year 2019 for ticker LITE.
# 2026-01-21 17:42:18,654, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LITE\LITE_2019
# 2026-01-21 17:42:18,678, data_manager.py, 107, INFO, Processing year 2020 for ticker LITE.
# 2026-01-21 17:42:18,682, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LITE\LITE_2020
# 2026-01-21 17:42:18,719, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\EOI.csv
# 2026-01-21 17:42:18,723, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\EOI.csv
# 2026-01-21 17:42:18,760, data_manager.py, 101, INFO, Saving data by year
# 2026-01-21 17:42:18,770, data_manager.py, 103, INFO, Processing ticker: EOI
# 2026-01-21 17:42:18,771, data_manager.py, 107, INFO, Processing year 2004 for ticker EOI.
# 2026-01-21 17:42:18,771, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/EOI\EOI_2004
# 2026-01-21 17:42:18,797, data_manager.py, 107, INFO, Processing year 2005 for ticker EOI.
# 2026-01-21 17:42:18,805, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/EOI\EOI_2005
# 2026-01-21 17:42:18,818, data_manager.py, 107, INFO, Processing year 2006 for ticker EOI.
# 2026-01-21 17:42:18,818, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/EOI\EOI_2006
# 2026-01-21 17:42:18,841, data_manager.py, 107, INFO, Processing year 2007 for ticker EOI.
# 2026-01-21 17:42:18,841, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/EOI\EOI_2007
# 2026-01-21 17:42:18,869, data_manager.py, 107, INFO, Processing year 2008 for ticker EOI.
# 2026-01-21 17:42:18,874, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/EOI\EOI_2008
# 2026-01-21 17:42:18,896, data_manager.py, 107, INFO, Processing year 2009 for ticker EOI.
# 2026-01-21 17:42:18,896, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/EOI\EOI_2009
# 2026-01-21 17:42:18,921, data_manager.py, 107, INFO, Processing year 2010 for ticker EOI.
# 2026-01-21 17:42:18,923, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/EOI\EOI_2010
# 2026-01-21 17:42:18,940, data_manager.py, 107, INFO, Processing year 2011 for ticker EOI.
# 2026-01-21 17:42:18,940, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/EOI\EOI_2011
# 2026-01-21 17:42:18,970, data_manager.py, 107, INFO, Processing year 2012 for ticker EOI.
# 2026-01-21 17:42:18,973, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/EOI\EOI_2012
# 2026-01-21 17:42:18,991, data_manager.py, 107, INFO, Processing year 2013 for ticker EOI.
# 2026-01-21 17:42:18,991, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/EOI\EOI_2013
# 2026-01-21 17:42:19,020, data_manager.py, 107, INFO, Processing year 2014 for ticker EOI.
# 2026-01-21 17:42:19,024, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/EOI\EOI_2014
# 2026-01-21 17:42:19,035, data_manager.py, 107, INFO, Processing year 2015 for ticker EOI.
# 2026-01-21 17:42:19,035, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/EOI\EOI_2015
# 2026-01-21 17:42:19,056, data_manager.py, 107, INFO, Processing year 2016 for ticker EOI.
# 2026-01-21 17:42:19,072, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/EOI\EOI_2016
# 2026-01-21 17:42:19,106, data_manager.py, 107, INFO, Processing year 2017 for ticker EOI.
# 2026-01-21 17:42:19,109, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/EOI\EOI_2017
# 2026-01-21 17:42:19,118, data_manager.py, 107, INFO, Processing year 2018 for ticker EOI.
# 2026-01-21 17:42:19,139, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/EOI\EOI_2018
# 2026-01-21 17:42:19,159, data_manager.py, 107, INFO, Processing year 2019 for ticker EOI.
# 2026-01-21 17:42:19,163, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/EOI\EOI_2019
# 2026-01-21 17:42:19,189, data_manager.py, 107, INFO, Processing year 2020 for ticker EOI.
# 2026-01-21 17:42:19,193, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/EOI\EOI_2020
# 2026-01-21 17:42:19,211, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\LSI.csv
# 2026-01-21 17:42:19,211, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\LSI.csv
# 2026-01-21 17:42:19,244, data_manager.py, 101, INFO, Saving data by year
# 2026-01-21 17:42:19,244, data_manager.py, 103, INFO, Processing ticker: LSI
# 2026-01-21 17:42:19,244, data_manager.py, 107, INFO, Processing year 1995 for ticker LSI.
# 2026-01-21 17:42:19,253, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LSI\LSI_1995
# 2026-01-21 17:42:19,275, data_manager.py, 107, INFO, Processing year 1996 for ticker LSI.
# 2026-01-21 17:42:19,277, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LSI\LSI_1996
# 2026-01-21 17:42:19,297, data_manager.py, 107, INFO, Processing year 1997 for ticker LSI.
# 2026-01-21 17:42:19,302, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LSI\LSI_1997
# 2026-01-21 17:42:19,325, data_manager.py, 107, INFO, Processing year 1998 for ticker LSI.
# 2026-01-21 17:42:19,328, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LSI\LSI_1998
# 2026-01-21 17:42:19,357, data_manager.py, 107, INFO, Processing year 1999 for ticker LSI.
# 2026-01-21 17:42:19,357, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LSI\LSI_1999
# 2026-01-21 17:42:19,395, data_manager.py, 107, INFO, Processing year 2000 for ticker LSI.
# 2026-01-21 17:42:19,397, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LSI\LSI_2000
# 2026-01-21 17:42:19,418, data_manager.py, 107, INFO, Processing year 2001 for ticker LSI.
# 2026-01-21 17:42:19,425, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LSI\LSI_2001
# 2026-01-21 17:42:19,450, data_manager.py, 107, INFO, Processing year 2002 for ticker LSI.
# 2026-01-21 17:42:19,454, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LSI\LSI_2002
# 2026-01-21 17:42:19,475, data_manager.py, 107, INFO, Processing year 2003 for ticker LSI.
# 2026-01-21 17:42:19,478, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LSI\LSI_2003
# 2026-01-21 17:42:19,497, data_manager.py, 107, INFO, Processing year 2004 for ticker LSI.
# 2026-01-21 17:42:19,501, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LSI\LSI_2004
# 2026-01-21 17:42:19,520, data_manager.py, 107, INFO, Processing year 2005 for ticker LSI.
# 2026-01-21 17:42:19,523, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LSI\LSI_2005
# 2026-01-21 17:42:19,546, data_manager.py, 107, INFO, Processing year 2006 for ticker LSI.
# 2026-01-21 17:42:19,550, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LSI\LSI_2006
# 2026-01-21 17:42:19,571, data_manager.py, 107, INFO, Processing year 2007 for ticker LSI.
# 2026-01-21 17:42:19,573, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LSI\LSI_2007
# 2026-01-21 17:42:19,594, data_manager.py, 107, INFO, Processing year 2008 for ticker LSI.
# 2026-01-21 17:42:19,598, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LSI\LSI_2008
# 2026-01-21 17:42:19,624, data_manager.py, 107, INFO, Processing year 2009 for ticker LSI.
# 2026-01-21 17:42:19,628, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LSI\LSI_2009
# 2026-01-21 17:42:19,651, data_manager.py, 107, INFO, Processing year 2010 for ticker LSI.
# 2026-01-21 17:42:19,654, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LSI\LSI_2010
# 2026-01-21 17:42:19,674, data_manager.py, 107, INFO, Processing year 2011 for ticker LSI.
# 2026-01-21 17:42:19,678, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LSI\LSI_2011
# 2026-01-21 17:42:19,740, data_manager.py, 107, INFO, Processing year 2012 for ticker LSI.
# 2026-01-21 17:42:19,744, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LSI\LSI_2012
# 2026-01-21 17:42:19,806, data_manager.py, 107, INFO, Processing year 2013 for ticker LSI.
# 2026-01-21 17:42:19,810, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LSI\LSI_2013
# 2026-01-21 17:42:19,833, data_manager.py, 107, INFO, Processing year 2014 for ticker LSI.
# 2026-01-21 17:42:19,851, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LSI\LSI_2014
# 2026-01-21 17:42:19,874, data_manager.py, 107, INFO, Processing year 2015 for ticker LSI.
# 2026-01-21 17:42:19,877, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LSI\LSI_2015
# 2026-01-21 17:42:19,914, data_manager.py, 107, INFO, Processing year 2016 for ticker LSI.
# 2026-01-21 17:42:19,927, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LSI\LSI_2016
# 2026-01-21 17:42:19,951, data_manager.py, 107, INFO, Processing year 2017 for ticker LSI.
# 2026-01-21 17:42:19,959, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LSI\LSI_2017
# 2026-01-21 17:42:19,982, data_manager.py, 107, INFO, Processing year 2018 for ticker LSI.
# 2026-01-21 17:42:19,982, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LSI\LSI_2018
# 2026-01-21 17:42:20,012, data_manager.py, 107, INFO, Processing year 2019 for ticker LSI.
# 2026-01-21 17:42:20,016, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LSI\LSI_2019
# 2026-01-21 17:42:20,039, data_manager.py, 107, INFO, Processing year 2020 for ticker LSI.
# 2026-01-21 17:42:20,043, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LSI\LSI_2020
# 2026-01-21 17:42:20,065, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\LAC.csv
# 2026-01-21 17:42:20,066, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\LAC.csv
# 2026-01-21 17:42:20,101, data_manager.py, 101, INFO, Saving data by year
# 2026-01-21 17:42:20,103, data_manager.py, 103, INFO, Processing ticker: LAC
# 2026-01-21 17:42:20,106, data_manager.py, 107, INFO, Processing year 2008 for ticker LAC.
# 2026-01-21 17:42:20,108, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LAC\LAC_2008
# 2026-01-21 17:42:20,134, data_manager.py, 107, INFO, Processing year 2009 for ticker LAC.
# 2026-01-21 17:42:20,141, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LAC\LAC_2009
# 2026-01-21 17:42:20,171, data_manager.py, 107, INFO, Processing year 2010 for ticker LAC.
# 2026-01-21 17:42:20,175, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LAC\LAC_2010
# 2026-01-21 17:42:20,194, data_manager.py, 107, INFO, Processing year 2011 for ticker LAC.
# 2026-01-21 17:42:20,200, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LAC\LAC_2011
# 2026-01-21 17:42:20,219, data_manager.py, 107, INFO, Processing year 2012 for ticker LAC.
# 2026-01-21 17:42:20,223, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LAC\LAC_2012
# 2026-01-21 17:42:20,240, data_manager.py, 107, INFO, Processing year 2013 for ticker LAC.
# 2026-01-21 17:42:20,244, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LAC\LAC_2013
# 2026-01-21 17:42:20,262, data_manager.py, 107, INFO, Processing year 2014 for ticker LAC.
# 2026-01-21 17:42:20,265, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LAC\LAC_2014
# 2026-01-21 17:42:20,293, data_manager.py, 107, INFO, Processing year 2015 for ticker LAC.
# 2026-01-21 17:42:20,297, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LAC\LAC_2015
# 2026-01-21 17:42:20,331, data_manager.py, 107, INFO, Processing year 2016 for ticker LAC.
# 2026-01-21 17:42:20,340, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LAC\LAC_2016
# 2026-01-21 17:42:20,355, data_manager.py, 107, INFO, Processing year 2017 for ticker LAC.
# 2026-01-21 17:42:20,371, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LAC\LAC_2017
# 2026-01-21 17:42:20,396, data_manager.py, 107, INFO, Processing year 2018 for ticker LAC.
# 2026-01-21 17:42:20,399, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LAC\LAC_2018
# 2026-01-21 17:42:20,428, data_manager.py, 107, INFO, Processing year 2019 for ticker LAC.
# 2026-01-21 17:42:20,433, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LAC\LAC_2019
# 2026-01-21 17:42:20,462, data_manager.py, 107, INFO, Processing year 2020 for ticker LAC.
# 2026-01-21 17:42:20,471, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LAC\LAC_2020
# 2026-01-21 17:42:20,492, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\NIB.csv
# 2026-01-21 17:42:20,492, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\NIB.csv
# 2026-01-21 17:42:20,521, data_manager.py, 101, INFO, Saving data by year
# 2026-01-21 17:42:20,522, data_manager.py, 103, INFO, Processing ticker: NIB
# 2026-01-21 17:42:20,524, data_manager.py, 107, INFO, Processing year 2008 for ticker NIB.
# 2026-01-21 17:42:20,527, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NIB\NIB_2008
# 2026-01-21 17:42:20,546, data_manager.py, 107, INFO, Processing year 2009 for ticker NIB.
# 2026-01-21 17:42:20,549, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NIB\NIB_2009
# 2026-01-21 17:42:20,573, data_manager.py, 107, INFO, Processing year 2010 for ticker NIB.
# 2026-01-21 17:42:20,576, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NIB\NIB_2010
# 2026-01-21 17:42:20,595, data_manager.py, 107, INFO, Processing year 2011 for ticker NIB.
# 2026-01-21 17:42:20,599, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NIB\NIB_2011
# 2026-01-21 17:42:20,618, data_manager.py, 107, INFO, Processing year 2012 for ticker NIB.
# 2026-01-21 17:42:20,622, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NIB\NIB_2012
# 2026-01-21 17:42:20,644, data_manager.py, 107, INFO, Processing year 2013 for ticker NIB.
# 2026-01-21 17:42:20,647, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NIB\NIB_2013
# 2026-01-21 17:42:20,671, data_manager.py, 107, INFO, Processing year 2014 for ticker NIB.
# 2026-01-21 17:42:20,673, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NIB\NIB_2014
# 2026-01-21 17:42:20,695, data_manager.py, 107, INFO, Processing year 2015 for ticker NIB.
# 2026-01-21 17:42:20,698, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NIB\NIB_2015
# 2026-01-21 17:42:20,717, data_manager.py, 107, INFO, Processing year 2016 for ticker NIB.
# 2026-01-21 17:42:20,722, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NIB\NIB_2016
# 2026-01-21 17:42:20,743, data_manager.py, 107, INFO, Processing year 2017 for ticker NIB.
# 2026-01-21 17:42:20,747, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NIB\NIB_2017
# 2026-01-21 17:42:20,773, data_manager.py, 107, INFO, Processing year 2018 for ticker NIB.
# 2026-01-21 17:42:20,785, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NIB\NIB_2018
# 2026-01-21 17:42:20,812, data_manager.py, 107, INFO, Processing year 2019 for ticker NIB.
# 2026-01-21 17:42:20,812, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NIB\NIB_2019
# 2026-01-21 17:42:20,836, data_manager.py, 107, INFO, Processing year 2020 for ticker NIB.
# 2026-01-21 17:42:20,839, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NIB\NIB_2020
# 2026-01-21 17:42:20,860, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\UAA.csv
# 2026-01-21 17:42:20,865, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\UAA.csv
# 2026-01-21 17:42:20,897, data_manager.py, 101, INFO, Saving data by year
# 2026-01-21 17:42:20,897, data_manager.py, 103, INFO, Processing ticker: UAA
# 2026-01-21 17:42:20,902, data_manager.py, 107, INFO, Processing year 2005 for ticker UAA.
# 2026-01-21 17:42:20,908, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/UAA\UAA_2005
# 2026-01-21 17:42:20,920, data_manager.py, 107, INFO, Processing year 2006 for ticker UAA.
# 2026-01-21 17:42:20,920, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/UAA\UAA_2006
# 2026-01-21 17:42:20,941, data_manager.py, 107, INFO, Processing year 2007 for ticker UAA.
# 2026-01-21 17:42:20,954, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/UAA\UAA_2007
# 2026-01-21 17:42:20,975, data_manager.py, 107, INFO, Processing year 2008 for ticker UAA.
# 2026-01-21 17:42:20,975, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/UAA\UAA_2008
# 2026-01-21 17:42:20,998, data_manager.py, 107, INFO, Processing year 2009 for ticker UAA.
# 2026-01-21 17:42:21,001, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/UAA\UAA_2009
# 2026-01-21 17:42:21,022, data_manager.py, 107, INFO, Processing year 2010 for ticker UAA.
# 2026-01-21 17:42:21,022, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/UAA\UAA_2010
# 2026-01-21 17:42:21,041, data_manager.py, 107, INFO, Processing year 2011 for ticker UAA.
# 2026-01-21 17:42:21,041, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/UAA\UAA_2011
# 2026-01-21 17:42:21,068, data_manager.py, 107, INFO, Processing year 2012 for ticker UAA.
# 2026-01-21 17:42:21,073, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/UAA\UAA_2012
# 2026-01-21 17:42:21,096, data_manager.py, 107, INFO, Processing year 2013 for ticker UAA.
# 2026-01-21 17:42:21,097, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/UAA\UAA_2013
# 2026-01-21 17:42:21,123, data_manager.py, 107, INFO, Processing year 2014 for ticker UAA.
# 2026-01-21 17:42:21,127, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/UAA\UAA_2014
# 2026-01-21 17:42:21,134, data_manager.py, 107, INFO, Processing year 2015 for ticker UAA.
# 2026-01-21 17:42:21,150, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/UAA\UAA_2015
# 2026-01-21 17:42:21,173, data_manager.py, 107, INFO, Processing year 2016 for ticker UAA.
# 2026-01-21 17:42:21,176, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/UAA\UAA_2016
# 2026-01-21 17:42:21,203, data_manager.py, 107, INFO, Processing year 2017 for ticker UAA.
# 2026-01-21 17:42:21,207, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/UAA\UAA_2017
# 2026-01-21 17:42:21,234, data_manager.py, 107, INFO, Processing year 2018 for ticker UAA.
# 2026-01-21 17:42:21,240, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/UAA\UAA_2018
# 2026-01-21 17:42:21,258, data_manager.py, 107, INFO, Processing year 2019 for ticker UAA.
# 2026-01-21 17:42:21,258, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/UAA\UAA_2019
# 2026-01-21 17:42:21,285, data_manager.py, 107, INFO, Processing year 2020 for ticker UAA.
# 2026-01-21 17:42:21,292, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/UAA\UAA_2020
# 2026-01-21 17:42:21,301, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\DTY.csv
# 2026-01-21 17:42:21,301, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\DTY.csv
# 2026-01-21 17:42:21,323, data_manager.py, 101, INFO, Saving data by year
# 2026-01-21 17:42:21,323, data_manager.py, 103, INFO, Processing ticker: DTY
# 2026-01-21 17:42:21,323, data_manager.py, 107, INFO, Processing year 2014 for ticker DTY.
# 2026-01-21 17:42:21,334, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DTY\DTY_2014
# 2026-01-21 17:42:21,355, data_manager.py, 107, INFO, Processing year 2016 for ticker DTY.
# 2026-01-21 17:42:21,355, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DTY\DTY_2016
# 2026-01-21 17:42:21,368, data_manager.py, 107, INFO, Processing year 2017 for ticker DTY.
# 2026-01-21 17:42:21,368, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DTY\DTY_2017
# 2026-01-21 17:42:21,409, data_manager.py, 107, INFO, Processing year 2018 for ticker DTY.
# 2026-01-21 17:42:21,413, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DTY\DTY_2018
# 2026-01-21 17:42:21,433, data_manager.py, 107, INFO, Processing year 2019 for ticker DTY.
# 2026-01-21 17:42:21,437, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DTY\DTY_2019
# 2026-01-21 17:42:21,475, data_manager.py, 107, INFO, Processing year 2020 for ticker DTY.
# 2026-01-21 17:42:21,478, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DTY\DTY_2020
# 2026-01-21 17:42:21,497, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\PYN.csv
# 2026-01-21 17:42:21,498, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\PYN.csv
# 2026-01-21 17:42:21,528, data_manager.py, 101, INFO, Saving data by year
# 2026-01-21 17:42:21,529, data_manager.py, 103, INFO, Processing ticker: PYN
# 2026-01-21 17:42:21,532, data_manager.py, 107, INFO, Processing year 2002 for ticker PYN.
# 2026-01-21 17:42:21,542, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PYN\PYN_2002
# 2026-01-21 17:42:21,561, data_manager.py, 107, INFO, Processing year 2003 for ticker PYN.
# 2026-01-21 17:42:21,564, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PYN\PYN_2003
# 2026-01-21 17:42:21,582, data_manager.py, 107, INFO, Processing year 2004 for ticker PYN.
# 2026-01-21 17:42:21,587, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PYN\PYN_2004
# 2026-01-21 17:42:21,605, data_manager.py, 107, INFO, Processing year 2005 for ticker PYN.
# 2026-01-21 17:42:21,609, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PYN\PYN_2005
# 2026-01-21 17:42:21,630, data_manager.py, 107, INFO, Processing year 2006 for ticker PYN.
# 2026-01-21 17:42:21,633, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PYN\PYN_2006
# 2026-01-21 17:42:21,662, data_manager.py, 107, INFO, Processing year 2007 for ticker PYN.
# 2026-01-21 17:42:21,666, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PYN\PYN_2007
# 2026-01-21 17:42:21,688, data_manager.py, 107, INFO, Processing year 2008 for ticker PYN.
# 2026-01-21 17:42:21,692, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PYN\PYN_2008
# 2026-01-21 17:42:21,711, data_manager.py, 107, INFO, Processing year 2009 for ticker PYN.
# 2026-01-21 17:42:21,719, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PYN\PYN_2009
# 2026-01-21 17:42:21,769, data_manager.py, 107, INFO, Processing year 2010 for ticker PYN.
# 2026-01-21 17:42:21,777, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PYN\PYN_2010
# 2026-01-21 17:42:21,841, data_manager.py, 107, INFO, Processing year 2011 for ticker PYN.
# 2026-01-21 17:42:21,842, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PYN\PYN_2011
# 2026-01-21 17:42:21,876, data_manager.py, 107, INFO, Processing year 2012 for ticker PYN.
# 2026-01-21 17:42:21,889, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PYN\PYN_2012
# 2026-01-21 17:42:21,913, data_manager.py, 107, INFO, Processing year 2013 for ticker PYN.
# 2026-01-21 17:42:21,913, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PYN\PYN_2013
# 2026-01-21 17:42:21,960, data_manager.py, 107, INFO, Processing year 2014 for ticker PYN.
# 2026-01-21 17:42:21,965, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PYN\PYN_2014
# 2026-01-21 17:42:21,990, data_manager.py, 107, INFO, Processing year 2015 for ticker PYN.
# 2026-01-21 17:42:21,990, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PYN\PYN_2015
# 2026-01-21 17:42:22,013, data_manager.py, 107, INFO, Processing year 2016 for ticker PYN.
# 2026-01-21 17:42:22,023, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PYN\PYN_2016
# 2026-01-21 17:42:22,040, data_manager.py, 107, INFO, Processing year 2017 for ticker PYN.
# 2026-01-21 17:42:22,049, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PYN\PYN_2017
# 2026-01-21 17:42:22,069, data_manager.py, 107, INFO, Processing year 2018 for ticker PYN.
# 2026-01-21 17:42:22,073, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PYN\PYN_2018
# 2026-01-21 17:42:22,094, data_manager.py, 107, INFO, Processing year 2019 for ticker PYN.
# 2026-01-21 17:42:22,094, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PYN\PYN_2019
# 2026-01-21 17:42:22,113, data_manager.py, 107, INFO, Processing year 2020 for ticker PYN.
# 2026-01-21 17:42:22,122, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PYN\PYN_2020
# 2026-01-21 17:42:22,142, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\EFX.csv
# 2026-01-21 17:42:22,142, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\EFX.csv
# 2026-01-21 17:42:22,182, data_manager.py, 101, INFO, Saving data by year
# 2026-01-21 17:42:22,183, data_manager.py, 103, INFO, Processing ticker: EFX
# 2026-01-21 17:42:22,185, data_manager.py, 107, INFO, Processing year 1980 for ticker EFX.
# 2026-01-21 17:42:22,185, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/EFX\EFX_1980
# 2026-01-21 17:42:22,213, data_manager.py, 107, INFO, Processing year 1981 for ticker EFX.
# 2026-01-21 17:42:22,219, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/EFX\EFX_1981
# 2026-01-21 17:42:22,240, data_manager.py, 107, INFO, Processing year 1982 for ticker EFX.
# 2026-01-21 17:42:22,240, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/EFX\EFX_1982
# 2026-01-21 17:42:22,258, data_manager.py, 107, INFO, Processing year 1983 for ticker EFX.
# 2026-01-21 17:42:22,258, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/EFX\EFX_1983
# 2026-01-21 17:42:22,288, data_manager.py, 107, INFO, Processing year 1984 for ticker EFX.
# 2026-01-21 17:42:22,291, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/EFX\EFX_1984
# 2026-01-21 17:42:22,304, data_manager.py, 107, INFO, Processing year 1985 for ticker EFX.
# 2026-01-21 17:42:22,314, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/EFX\EFX_1985
# 2026-01-21 17:42:22,335, data_manager.py, 107, INFO, Processing year 1986 for ticker EFX.
# 2026-01-21 17:42:22,340, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/EFX\EFX_1986
# 2026-01-21 17:42:22,356, data_manager.py, 107, INFO, Processing year 1987 for ticker EFX.
# 2026-01-21 17:42:22,356, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/EFX\EFX_1987
# 2026-01-21 17:42:22,392, data_manager.py, 107, INFO, Processing year 1988 for ticker EFX.
# ...
# 2026-01-21 17:42:30,365, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DWSN\DWSN_2007
# 2026-01-21 17:42:30,396, data_manager.py, 107, INFO, Processing year 2008 for ticker DWSN.
# 2026-01-21 17:42:30,402, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DWSN\DWSN_2008
# 2026-01-21 17:42:30,443, data_manager.py, 107, INFO, Processing year 2009 for ticker DWSN.
# 2026-01-21 17:42:30,453, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DWSN\DWSN_2009
# 2026-01-21 17:42:30,509, data_manager.py, 107, INFO, Processing year 2010 for ticker DWSN.
# 2026-01-21 17:42:30,524, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DWSN\DWSN_2010
# 2026-01-21 17:42:30,556, data_manager.py, 107, INFO, Processing year 2011 for ticker DWSN.
# 2026-01-21 17:42:30,572, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DWSN\DWSN_2011
# 2026-01-21 17:42:30,605, data_manager.py, 107, INFO, Processing year 2012 for ticker DWSN.
# 2026-01-21 17:42:30,609, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DWSN\DWSN_2012
# 2026-01-21 17:42:30,641, data_manager.py, 107, INFO, Processing year 2013 for ticker DWSN.
# 2026-01-21 17:42:30,641, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DWSN\DWSN_2013
# 2026-01-21 17:42:30,676, data_manager.py, 107, INFO, Processing year 2014 for ticker DWSN.
# 2026-01-21 17:42:30,676, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DWSN\DWSN_2014
# 2026-01-21 17:42:30,704, data_manager.py, 107, INFO, Processing year 2015 for ticker DWSN.
# 2026-01-21 17:42:30,704, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DWSN\DWSN_2015
# 2026-01-21 17:42:30,745, data_manager.py, 107, INFO, Processing year 2016 for ticker DWSN.
# 2026-01-21 17:42:30,749, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DWSN\DWSN_2016
# 2026-01-21 17:42:30,775, data_manager.py, 107, INFO, Processing year 2017 for ticker DWSN.
# 2026-01-21 17:42:30,782, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DWSN\DWSN_2017
# 2026-01-21 17:42:30,809, data_manager.py, 107, INFO, Processing year 2018 for ticker DWSN.
# 2026-01-21 17:42:30,814, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DWSN\DWSN_2018
# 2026-01-21 17:42:30,844, data_manager.py, 107, INFO, Processing year 2019 for ticker DWSN.
# 2026-01-21 17:42:30,847, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DWSN\DWSN_2019
# 2026-01-21 17:42:30,873, data_manager.py, 107, INFO, Processing year 2020 for ticker DWSN.
# 2026-01-21 17:42:30,876, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DWSN\DWSN_2020
# 2026-01-21 17:42:30,900, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\HPI.csv
# 2026-01-21 17:42:30,901, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\HPI.csv
# 2026-01-21 17:42:30,938, data_manager.py, 101, INFO, Saving data by year
# 2026-01-21 17:42:30,938, data_manager.py, 103, INFO, Processing ticker: HPI
# 2026-01-21 17:42:30,938, data_manager.py, 107, INFO, Processing year 2003 for ticker HPI.
# 2026-01-21 17:42:30,938, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HPI\HPI_2003
# 2026-01-21 17:42:30,978, data_manager.py, 107, INFO, Processing year 2004 for ticker HPI.
# 2026-01-21 17:42:30,981, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HPI\HPI_2004
# 2026-01-21 17:42:31,006, data_manager.py, 107, INFO, Processing year 2005 for ticker HPI.
# 2026-01-21 17:42:31,006, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HPI\HPI_2005
# 2026-01-21 17:42:31,037, data_manager.py, 107, INFO, Processing year 2006 for ticker HPI.
# 2026-01-21 17:42:31,041, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HPI\HPI_2006
# 2026-01-21 17:42:31,061, data_manager.py, 107, INFO, Processing year 2007 for ticker HPI.
# 2026-01-21 17:42:31,071, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HPI\HPI_2007
# 2026-01-21 17:42:31,094, data_manager.py, 107, INFO, Processing year 2008 for ticker HPI.
# 2026-01-21 17:42:31,106, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HPI\HPI_2008
# 2026-01-21 17:42:31,132, data_manager.py, 107, INFO, Processing year 2009 for ticker HPI.
# 2026-01-21 17:42:31,139, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HPI\HPI_2009
# 2026-01-21 17:42:31,171, data_manager.py, 107, INFO, Processing year 2010 for ticker HPI.
# 2026-01-21 17:42:31,173, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HPI\HPI_2010
# 2026-01-21 17:42:31,206, data_manager.py, 107, INFO, Processing year 2011 for ticker HPI.
# 2026-01-21 17:42:31,206, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HPI\HPI_2011
# 2026-01-21 17:42:31,239, data_manager.py, 107, INFO, Processing year 2012 for ticker HPI.
# 2026-01-21 17:42:31,244, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HPI\HPI_2012
# 2026-01-21 17:42:31,275, data_manager.py, 107, INFO, Processing year 2013 for ticker HPI.
# 2026-01-21 17:42:31,279, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HPI\HPI_2013
# 2026-01-21 17:42:31,307, data_manager.py, 107, INFO, Processing year 2014 for ticker HPI.
# 2026-01-21 17:42:31,323, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HPI\HPI_2014
# 2026-01-21 17:42:31,355, data_manager.py, 107, INFO, Processing year 2015 for ticker HPI.
# 2026-01-21 17:42:31,367, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HPI\HPI_2015
# 2026-01-21 17:42:31,423, data_manager.py, 107, INFO, Processing year 2016 for ticker HPI.
# 2026-01-21 17:42:31,423, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HPI\HPI_2016
# 2026-01-21 17:42:31,460, data_manager.py, 107, INFO, Processing year 2017 for ticker HPI.
# 2026-01-21 17:42:31,471, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HPI\HPI_2017
# 2026-01-21 17:42:31,504, data_manager.py, 107, INFO, Processing year 2018 for ticker HPI.
# 2026-01-21 17:42:31,510, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HPI\HPI_2018
# 2026-01-21 17:42:31,540, data_manager.py, 107, INFO, Processing year 2019 for ticker HPI.
# 2026-01-21 17:42:31,540, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HPI\HPI_2019
# 2026-01-21 17:42:31,573, data_manager.py, 107, INFO, Processing year 2020 for ticker HPI.
# 2026-01-21 17:42:31,586, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HPI\HPI_2020
# 2026-01-21 17:42:31,606, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\NCSM.csv
# 2026-01-21 17:42:31,606, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\NCSM.csv
# 2026-01-21 17:42:31,638, data_manager.py, 101, INFO, Saving data by year
# 2026-01-21 17:42:31,638, data_manager.py, 103, INFO, Processing ticker: NCSM
# 2026-01-21 17:42:31,638, data_manager.py, 107, INFO, Processing year 2017 for ticker NCSM.
# 2026-01-21 17:42:31,657, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NCSM\NCSM_2017
# 2026-01-21 17:42:31,685, data_manager.py, 107, INFO, Processing year 2018 for ticker NCSM.
# 2026-01-21 17:42:31,691, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NCSM\NCSM_2018
# 2026-01-21 17:42:31,715, data_manager.py, 107, INFO, Processing year 2019 for ticker NCSM.
# 2026-01-21 17:42:31,722, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NCSM\NCSM_2019
# 2026-01-21 17:42:31,744, data_manager.py, 107, INFO, Processing year 2020 for ticker NCSM.
# 2026-01-21 17:42:31,747, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NCSM\NCSM_2020
# 2026-01-21 17:42:31,771, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\CGIX.csv
# 2026-01-21 17:42:31,772, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\CGIX.csv
# 2026-01-21 17:42:31,806, data_manager.py, 101, INFO, Saving data by year
# 2026-01-21 17:42:31,807, data_manager.py, 103, INFO, Processing ticker: CGIX
# 2026-01-21 17:42:31,810, data_manager.py, 107, INFO, Processing year 2013 for ticker CGIX.
# 2026-01-21 17:42:31,813, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CGIX\CGIX_2013
# 2026-01-21 17:42:31,839, data_manager.py, 107, INFO, Processing year 2014 for ticker CGIX.
# 2026-01-21 17:42:31,843, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CGIX\CGIX_2014
# 2026-01-21 17:42:31,874, data_manager.py, 107, INFO, Processing year 2015 for ticker CGIX.
# 2026-01-21 17:42:31,877, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CGIX\CGIX_2015
# 2026-01-21 17:42:31,904, data_manager.py, 107, INFO, Processing year 2016 for ticker CGIX.
# 2026-01-21 17:42:31,908, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CGIX\CGIX_2016
# 2026-01-21 17:42:31,932, data_manager.py, 107, INFO, Processing year 2017 for ticker CGIX.
# 2026-01-21 17:42:31,937, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CGIX\CGIX_2017
# 2026-01-21 17:42:31,960, data_manager.py, 107, INFO, Processing year 2018 for ticker CGIX.
# 2026-01-21 17:42:31,963, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CGIX\CGIX_2018
# 2026-01-21 17:42:31,992, data_manager.py, 107, INFO, Processing year 2019 for ticker CGIX.
# 2026-01-21 17:42:31,994, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CGIX\CGIX_2019
# 2026-01-21 17:42:32,021, data_manager.py, 107, INFO, Processing year 2020 for ticker CGIX.
# 2026-01-21 17:42:32,024, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CGIX\CGIX_2020
# 2026-01-21 17:42:32,051, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\HAIN.csv
# 2026-01-21 17:42:32,053, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\HAIN.csv
# 2026-01-21 17:42:32,111, data_manager.py, 101, INFO, Saving data by year
# 2026-01-21 17:42:32,111, data_manager.py, 103, INFO, Processing ticker: HAIN
# 2026-01-21 17:42:32,124, data_manager.py, 107, INFO, Processing year 1994 for ticker HAIN.
# 2026-01-21 17:42:32,126, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HAIN\HAIN_1994
# 2026-01-21 17:42:32,156, data_manager.py, 107, INFO, Processing year 1995 for ticker HAIN.
# 2026-01-21 17:42:32,160, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HAIN\HAIN_1995
# 2026-01-21 17:42:32,188, data_manager.py, 107, INFO, Processing year 1996 for ticker HAIN.
# 2026-01-21 17:42:32,191, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HAIN\HAIN_1996
# 2026-01-21 17:42:32,210, data_manager.py, 107, INFO, Processing year 1997 for ticker HAIN.
# 2026-01-21 17:42:32,220, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HAIN\HAIN_1997
# 2026-01-21 17:42:32,242, data_manager.py, 107, INFO, Processing year 1998 for ticker HAIN.
# 2026-01-21 17:42:32,242, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HAIN\HAIN_1998
# 2026-01-21 17:42:32,274, data_manager.py, 107, INFO, Processing year 1999 for ticker HAIN.
# 2026-01-21 17:42:32,274, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HAIN\HAIN_1999
# 2026-01-21 17:42:32,301, data_manager.py, 107, INFO, Processing year 2000 for ticker HAIN.
# 2026-01-21 17:42:32,301, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HAIN\HAIN_2000
# 2026-01-21 17:42:32,328, data_manager.py, 107, INFO, Processing year 2001 for ticker HAIN.
# 2026-01-21 17:42:32,336, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HAIN\HAIN_2001
# 2026-01-21 17:42:32,360, data_manager.py, 107, INFO, Processing year 2002 for ticker HAIN.
# 2026-01-21 17:42:32,360, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HAIN\HAIN_2002
# 2026-01-21 17:42:32,389, data_manager.py, 107, INFO, Processing year 2003 for ticker HAIN.
# 2026-01-21 17:42:32,389, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HAIN\HAIN_2003
# 2026-01-21 17:42:32,420, data_manager.py, 107, INFO, Processing year 2004 for ticker HAIN.
# 2026-01-21 17:42:32,423, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HAIN\HAIN_2004
# 2026-01-21 17:42:32,443, data_manager.py, 107, INFO, Processing year 2005 for ticker HAIN.
# 2026-01-21 17:42:32,456, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HAIN\HAIN_2005
# 2026-01-21 17:42:32,493, data_manager.py, 107, INFO, Processing year 2006 for ticker HAIN.
# 2026-01-21 17:42:32,496, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HAIN\HAIN_2006
# 2026-01-21 17:42:32,536, data_manager.py, 107, INFO, Processing year 2007 for ticker HAIN.
# 2026-01-21 17:42:32,541, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HAIN\HAIN_2007
# 2026-01-21 17:42:32,580, data_manager.py, 107, INFO, Processing year 2008 for ticker HAIN.
# 2026-01-21 17:42:32,584, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HAIN\HAIN_2008
# 2026-01-21 17:42:32,608, data_manager.py, 107, INFO, Processing year 2009 for ticker HAIN.
# 2026-01-21 17:42:32,620, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HAIN\HAIN_2009
# 2026-01-21 17:42:32,647, data_manager.py, 107, INFO, Processing year 2010 for ticker HAIN.
# 2026-01-21 17:42:32,653, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HAIN\HAIN_2010
# 2026-01-21 17:42:32,677, data_manager.py, 107, INFO, Processing year 2011 for ticker HAIN.
# 2026-01-21 17:42:32,680, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HAIN\HAIN_2011
# 2026-01-21 17:42:32,707, data_manager.py, 107, INFO, Processing year 2012 for ticker HAIN.
# 2026-01-21 17:42:32,710, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HAIN\HAIN_2012
# 2026-01-21 17:42:32,734, data_manager.py, 107, INFO, Processing year 2013 for ticker HAIN.
# 2026-01-21 17:42:32,737, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HAIN\HAIN_2013
# 2026-01-21 17:42:32,759, data_manager.py, 107, INFO, Processing year 2014 for ticker HAIN.
# 2026-01-21 17:42:32,762, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HAIN\HAIN_2014
# 2026-01-21 17:42:32,789, data_manager.py, 107, INFO, Processing year 2015 for ticker HAIN.
# 2026-01-21 17:42:32,794, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HAIN\HAIN_2015
# 2026-01-21 17:42:32,815, data_manager.py, 107, INFO, Processing year 2016 for ticker HAIN.
# 2026-01-21 17:42:32,820, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HAIN\HAIN_2016
# 2026-01-21 17:42:32,842, data_manager.py, 107, INFO, Processing year 2017 for ticker HAIN.
# 2026-01-21 17:42:32,848, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HAIN\HAIN_2017
# 2026-01-21 17:42:32,873, data_manager.py, 107, INFO, Processing year 2018 for ticker HAIN.
# 2026-01-21 17:42:32,876, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HAIN\HAIN_2018
# 2026-01-21 17:42:32,897, data_manager.py, 107, INFO, Processing year 2019 for ticker HAIN.
# 2026-01-21 17:42:32,901, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HAIN\HAIN_2019
# 2026-01-21 17:42:32,924, data_manager.py, 107, INFO, Processing year 2020 for ticker HAIN.
# 2026-01-21 17:42:32,928, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HAIN\HAIN_2020

# %% [markdown]
# Finally, add features to the data set and save to a *feature store*.

# %%
dm.featurize()
# Out:
# 2026-01-21 17:42:37,729, data_manager.py, 134, INFO, Creating features data.
# 2026-01-21 17:42:37,730, data_manager.py, 144, INFO, Loading price data from ../../05_src/data/prices/
# 2026-01-21 17:43:05,174, data_manager.py, 153, INFO, Creating features
# 2026-01-21 17:43:05,178, data_manager.py, 174, INFO, DTYPES right before returns:
# Date           object
# Open           object
# High           object
# Low            object
# Close          object
# Adj Close      object
# Volume         object
# source         object
# Year           object
# Close_lag_1    object
# dtype: object
# 2026-01-21 17:43:05,199, data_manager.py, 190, INFO, Saving features to ../../05_src/data/features/stock_features
