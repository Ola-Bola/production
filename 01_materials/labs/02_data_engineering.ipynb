# %%
# %load_ext dotenv
# %dotenv

# %% [markdown]
# # What are we doing?
#
# ## Objectives
#
#
# * Build a data pipeline that downloads price data from the internet, stores it locally, transforms it into return data, and stores the feature set.
#     - Getting the data.
#     - Schemas and index in Dask.
#
# * Explore the parquet format.
#     - Reading and writing parquet files.
#     - Read datasets that are stored in distributed files.
#     - Discuss Dask vs. Pandas as a small example of big vs small data.
#
# * Discuss the use of environment variables for settings.
# * Discuss how to use Jupyter notebooks and source code concurrently.
# * Logging and using a standard logger.
#
# ## About the Data
#
# + We will download the prices for a list of stocks.
# + The source is Yahoo Finance, and the data, along with its description, is available via [Kaggle](https://www.kaggle.com/datasets/jacksoncrow/stock-market-dataset).
#
#
# ## Medallion Architecture
#
# + The architecture that we are thinking about is called Medallion by [DataBricks](https://www.databricks.com/glossary/medallion-architecture). It is an ELT type of thinking, although our data is well-structured.
#
# <div>
# <image src="./images/02_medallion_architecture.png" height=300>
# </div>
#
# + In our case, we would like to optimize the number of times that we download data from the internet.
# + Ultimately, we will build a pipeline manager class to control the process of obtaining and transforming our data.
#
# <div>
# <image src="./images/02_target_pipeline_manager.png" height=250>
# </div>

# %% [markdown]
# # Download Data
#
# Download the [Stock Market Dataset from Kaggle](https://www.kaggle.com/datasets/jacksoncrow/stock-market-dataset). Note that you may be required to register for a free account. Alternatively, download the file from [this location](https://drive.google.com/drive/folders/1AA4gapDLpI194TGce1bY25sd91Km-tU3?usp=drive_link).
#
# + Extract stock prices (not ETFs) into the directory: `./05_src/data/prices_csv/`.
# + To be clear, your folder structure should include the path `05_src/data/prices_csv/stocks`.

# %% [markdown]
# The command `%run update_path.py` runs a local script that adds the repository's `./05_src/` directory to the Notebook's kernel path. This way, we can use our modules within the notebook.

# %%
# %run update_path.py

# %% [markdown]
# To load the historical price data for stocks and ETFs, use the code below. Notice the following:
#
# + Libraries are ordered from high-level to low-level libraries from the package manager. Local modules are imported at the end.
# + The function `get_logger()` is called with `__name__` as recommended by [Python's documentation](https://docs.python.org/2/howto/logging.html#logging-advanced-tutorial).

# %%
from glob import glob
import os
import pandas as pd
import random

from utils.logger import get_logger
_logs = get_logger(__name__)

# %% [markdown]
# + The [`glob` module](https://docs.python.org/3/library/glob.html) is used for finding path names that match specified patterns using Unix shell-style rules.
#
# + Notice that the module `glob` contains a function called `glob`; therefore, we used `from glob import glob` above.
#
# + The path in which we are searching for our csv files is produced by joining two strings:
#
#
#
#     - The value of the environment variable 'SRC_DIR' that we obtain with `os.getenv('SRC_DIR')` (this variable points to ./05_src).
#
#     - Another string given by "data/prices_csv/stocks/*.csv".
#
#     - Both strings are combined into an OS-consistent path using `os.path.join(...)`.
#
# + After we know the location of all our files, we sample a subset of them.

# %%
stock_files = glob(os.path.join(os.getenv('SRC_DIR'), "data/prices_csv/stocks/*.csv"))
_logs.info(f'Found {len(stock_files)} stock price files.')

random.seed(42)
n_sample = 60
stock_files = random.sample(stock_files, n_sample)
_logs.info(f'Sampled {n_sample} stock price files for processing. The files are: {stock_files   }')
# Out:
# 2026-01-21 10:39:13,584, 3619788285.py, 2, INFO, Found 5884 stock price files.
# 2026-01-21 10:39:13,586, 3619788285.py, 7, INFO, Sampled 60 stock price files for processing. The files are: ['../../05_src/data/prices_csv/stocks\\TNC.csv', '../../05_src/data/prices_csv/stocks\\CBB.csv', '../../05_src/data/prices_csv/stocks\\ALDX.csv', '../../05_src/data/prices_csv/stocks\\GLADD.csv', '../../05_src/data/prices_csv/stocks\\FIXX.csv', '../../05_src/data/prices_csv/stocks\\ETJ.csv', '../../05_src/data/prices_csv/stocks\\CMCTP.csv', '../../05_src/data/prices_csv/stocks\\BWG.csv', '../../05_src/data/prices_csv/stocks\\VIAC.csv', '../../05_src/data/prices_csv/stocks\\REI.csv', '../../05_src/data/prices_csv/stocks\\BLPH.csv', '../../05_src/data/prices_csv/stocks\\SMG.csv', '../../05_src/data/prices_csv/stocks\\MOH.csv', '../../05_src/data/prices_csv/stocks\\AMH.csv', '../../05_src/data/prices_csv/stocks\\AMAL.csv', '../../05_src/data/prices_csv/stocks\\BPYPN.csv', '../../05_src/data/prices_csv/stocks\\ERH.csv', '../../05_src/data/prices_csv/stocks\\FAMI.csv', '../../05_src/data/prices_csv/stocks\\PFG.csv', '../../05_src/data/prices_csv/stocks\\SPXC.csv', '../../05_src/data/prices_csv/stocks\\ALL.csv', '../../05_src/data/prices_csv/stocks\\RTTR.csv', '../../05_src/data/prices_csv/stocks\\EARN.csv', '../../05_src/data/prices_csv/stocks\\ZIXI.csv', '../../05_src/data/prices_csv/stocks\\TSN.csv', '../../05_src/data/prices_csv/stocks\\WST.csv', '../../05_src/data/prices_csv/stocks\\REG.csv', '../../05_src/data/prices_csv/stocks\\MNK.csv', '../../05_src/data/prices_csv/stocks\\ESGR.csv', '../../05_src/data/prices_csv/stocks\\NGD.csv', '../../05_src/data/prices_csv/stocks\\SLRX.csv', '../../05_src/data/prices_csv/stocks\\GLW.csv', '../../05_src/data/prices_csv/stocks\\ACN.csv', '../../05_src/data/prices_csv/stocks\\CSSE.csv', '../../05_src/data/prices_csv/stocks\\WORK.csv', '../../05_src/data/prices_csv/stocks\\MOS.csv', '../../05_src/data/prices_csv/stocks\\IPWR.csv', '../../05_src/data/prices_csv/stocks\\GLUU.csv', '../../05_src/data/prices_csv/stocks\\CRMT.csv', '../../05_src/data/prices_csv/stocks\\EOLS.csv', '../../05_src/data/prices_csv/stocks\\INSU.csv', '../../05_src/data/prices_csv/stocks\\BWEN.csv', '../../05_src/data/prices_csv/stocks\\BPMX.csv', '../../05_src/data/prices_csv/stocks\\LH.csv', '../../05_src/data/prices_csv/stocks\\BRQS.csv', '../../05_src/data/prices_csv/stocks\\KALU.csv', '../../05_src/data/prices_csv/stocks\\ITCB.csv', '../../05_src/data/prices_csv/stocks\\SRE.csv', '../../05_src/data/prices_csv/stocks\\GAZ.csv', '../../05_src/data/prices_csv/stocks\\AQMS.csv', '../../05_src/data/prices_csv/stocks\\NPK.csv', '../../05_src/data/prices_csv/stocks\\QRHC.csv', '../../05_src/data/prices_csv/stocks\\CGEN.csv', '../../05_src/data/prices_csv/stocks\\LEVL.csv', '../../05_src/data/prices_csv/stocks\\BGS.csv', '../../05_src/data/prices_csv/stocks\\RIV.csv', '../../05_src/data/prices_csv/stocks\\GURE.csv', '../../05_src/data/prices_csv/stocks\\TEF.csv', '../../05_src/data/prices_csv/stocks\\SYNH.csv', '../../05_src/data/prices_csv/stocks\\KEY.csv']

# %% [markdown]
# We load the sampled files into dataframes and concatenate them:
#
# + Start with an empty list.
# + Read each file into a dataframe and [`append()` it to the list](https://docs.python.org/3/tutorial/datastructures.html#more-on-lists). Notice that `append()` is an in-place operation (it does not return a list, it modifies the list in place).
# + Finally, we concatenate all dataframes along the vertical axis (`axis=0`) using [`pd.concat()`](https://pandas.pydata.org/docs/user_guide/merging.html#concat).
# + Notice that we do not concatenate each time that we load a dataframe. According to [Panda's documentation](https://pandas.pydata.org/docs/user_guide/merging.html#concat):
#
# > "`concat()` makes a full copy of the data, and iteratively reusing `concat()` can create unnecessary copies. Collect all DataFrame or Series objects in a list before using `concat()`."

# %%
dt_list = []
for s_file in stock_files:
    _logs.info(f"Reading file: {s_file}")
    dt = pd.read_csv(s_file).assign(
        source = os.path.basename(s_file),
        ticker = os.path.basename(s_file).replace('.csv', ''),
        Date = lambda x: pd.to_datetime(x['Date'])
    )
    dt_list.append(dt)
stock_prices = pd.concat(dt_list, axis = 0, ignore_index = True)
# Out:
# 2026-01-21 10:39:17,975, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\TNC.csv
# 2026-01-21 10:39:18,078, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\CBB.csv
# 2026-01-21 10:39:18,122, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\ALDX.csv
# 2026-01-21 10:39:18,146, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\GLADD.csv
# 2026-01-21 10:39:18,164, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\FIXX.csv
# 2026-01-21 10:39:18,188, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\ETJ.csv
# 2026-01-21 10:39:18,219, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\CMCTP.csv
# 2026-01-21 10:39:18,242, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\BWG.csv
# 2026-01-21 10:39:18,268, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\VIAC.csv
# 2026-01-21 10:39:18,304, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\REI.csv
# 2026-01-21 10:39:18,337, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\BLPH.csv
# 2026-01-21 10:39:18,373, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\SMG.csv
# 2026-01-21 10:39:18,411, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\MOH.csv
# 2026-01-21 10:39:18,443, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\AMH.csv
# 2026-01-21 10:39:18,471, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\AMAL.csv
# 2026-01-21 10:39:18,487, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\BPYPN.csv
# 2026-01-21 10:39:18,505, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\ERH.csv
# 2026-01-21 10:39:18,553, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\FAMI.csv
# 2026-01-21 10:39:18,574, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\PFG.csv
# 2026-01-21 10:39:18,607, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\SPXC.csv
# 2026-01-21 10:39:18,650, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\ALL.csv
# 2026-01-21 10:39:18,685, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\RTTR.csv
# 2026-01-21 10:39:18,706, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\EARN.csv
# 2026-01-21 10:39:18,720, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\ZIXI.csv
# 2026-01-21 10:39:18,769, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\TSN.csv
# 2026-01-21 10:39:18,805, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\WST.csv
# 2026-01-21 10:39:18,853, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\REG.csv
# 2026-01-21 10:39:18,885, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\MNK.csv
# 2026-01-21 10:39:18,920, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\ESGR.csv
# 2026-01-21 10:39:18,949, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\NGD.csv
# 2026-01-21 10:39:18,982, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\SLRX.csv
# 2026-01-21 10:39:19,006, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\GLW.csv
# 2026-01-21 10:39:19,044, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\ACN.csv
# 2026-01-21 10:39:19,092, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\CSSE.csv
# 2026-01-21 10:39:19,106, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\WORK.csv
# 2026-01-21 10:39:19,132, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\MOS.csv
# 2026-01-21 10:39:19,190, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\IPWR.csv
# 2026-01-21 10:39:19,221, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\GLUU.csv
# 2026-01-21 10:39:19,267, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\CRMT.csv
# 2026-01-21 10:39:19,301, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\EOLS.csv
# 2026-01-21 10:39:19,325, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\INSU.csv
# 2026-01-21 10:39:19,349, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\BWEN.csv
# 2026-01-21 10:39:19,368, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\BPMX.csv
# 2026-01-21 10:39:19,413, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\LH.csv
# 2026-01-21 10:39:19,437, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\BRQS.csv
# 2026-01-21 10:39:19,462, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\KALU.csv
# 2026-01-21 10:39:19,486, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\ITCB.csv
# 2026-01-21 10:39:19,521, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\SRE.csv
# 2026-01-21 10:39:19,550, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\GAZ.csv
# 2026-01-21 10:39:19,581, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\AQMS.csv
# 2026-01-21 10:39:19,608, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\NPK.csv
# 2026-01-21 10:39:19,657, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\QRHC.csv
# 2026-01-21 10:39:19,686, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\CGEN.csv
# 2026-01-21 10:39:19,731, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\LEVL.csv
# 2026-01-21 10:39:19,748, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\BGS.csv
# 2026-01-21 10:39:19,780, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\RIV.csv
# 2026-01-21 10:39:19,806, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\GURE.csv
# 2026-01-21 10:39:19,839, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\TEF.csv
# 2026-01-21 10:39:19,888, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\SYNH.csv
# 2026-01-21 10:39:19,914, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\KEY.csv

# %% [markdown]
# Verify the structure of the `stock_prices` data using the [`info()` dataframe method](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.info.html):

# %%
stock_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239659 entries, 0 to 239658
# Data columns (total 9 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Date       239659 non-null  datetime64[ns]
#  1   Open       239656 non-null  float64
#  2   High       239656 non-null  float64
#  3   Low        239656 non-null  float64
#  4   Close      239656 non-null  float64
#  5   Adj Close  239656 non-null  float64
#  6   Volume     239656 non-null  float64
#  7   source     239659 non-null  object
#  8   ticker     239659 non-null  object
# dtypes: datetime64[ns](1), float64(6), object(2)
# memory usage: 16.5+ MB

# %% [markdown]
# We can subset our ticker data set using standard indexing techniques. Good references for this type of data manipulation are:
#
# + [Panda's Documentation](https://pandas.pydata.org/docs/user_guide/indexing.html#indexing-and-selecting-data).
# + [Panda's Cookbook](https://pandas.pydata.org/docs/user_guide/cookbook.html#cookbook-selection).

# %% [markdown]
# From the subset data frame, select one column and convert to list.

# %%
select_tickers = stock_prices['ticker'].unique().tolist()
select_tickers
# Out:
# ['TNC',
#  'CBB',
#  'ALDX',
#  'GLADD',
#  'FIXX',
#  'ETJ',
#  'CMCTP',
#  'BWG',
#  'VIAC',
#  'REI',
#  'BLPH',
#  'SMG',
#  'MOH',
#  'AMH',
#  'AMAL',
#  'BPYPN',
#  'ERH',
#  'FAMI',
#  'PFG',
#  'SPXC',
#  'ALL',
#  'RTTR',
#  'EARN',
#  'ZIXI',
#  'TSN',
#  'WST',
#  'REG',
#  'MNK',
#  'ESGR',
#  'NGD',
#  'SLRX',
#  'GLW',
#  'ACN',
#  'CSSE',
#  'WORK',
#  'MOS',
#  'IPWR',
#  'GLUU',
#  'CRMT',
#  'EOLS',
#  'INSU',
#  'BWEN',
#  'BPMX',
#  'LH',
#  'BRQS',
#  'KALU',
#  'ITCB',
#  'SRE',
#  'GAZ',
#  'AQMS',
#  'NPK',
#  'QRHC',
#  'CGEN',
#  'LEVL',
#  'BGS',
#  'RIV',
#  'GURE',
#  'TEF',
#  'SYNH',
#  'KEY']

# %% [markdown]
# # Storing Data in CSV
#
# + We have some data. How do we store it?
# + We can compare two options, CSV and Parquet, by measuring their performance:
#
#     - Time to save: We will measure time by using the `time` library.
#     - Space required on drive: We will use the custom function below.

# %%
def get_dir_size(path='.'):
    '''Returns the total size of files contained in path.'''
    total = 0
    with os.scandir(path) as it:
        for entry in it:
            if entry.is_file():
                total += entry.stat().st_size
            elif entry.is_dir():
                total += get_dir_size(entry.path)
    return total

# %% [markdown]
# Load the specification of a temporary directory from the environment  and create a subdirectory in it called "csv":
#
# + Use `os.getenv("TEMP_DATA")` to obtain the desired location of the temporary folder from an environment variable.
# + If the subdirectory exists, delete it using `shutil.rmtree()`; the flag `ignore_errors=True` helps us in case the subdirectory does not exist (for instance, in the first run).
# + Create a directory with path given by `csv_dir` using `os.makedirs()`; the flag `exist_ok=True` indicates that if the directory already exists, then the function will do nothing.
# + Finally, create the stock price file location, `stock_csv`, which will be used to create the csv file.

# %%
import shutil

temp = os.getenv("TEMP_DATA")
csv_dir = os.path.join(temp, "csv")

shutil.rmtree(csv_dir, ignore_errors=True)
os.makedirs(csv_dir, exist_ok=True)
stock_csv = os.path.join(csv_dir, "stock_px.csv")

# %% [markdown]
# Save the concatenated dataframe to a CSV file. We measure the time elapsed by storing the start and end times, then we calculate their difference in seconds.

# %%
import time

start = time.time()
stock_prices.to_csv(stock_csv, index = False)
end = time.time()

_logs.info(f'Writing data ({stock_prices.shape}) to csv took {end - start} seconds.')
_logs.info(f'CSV file size { os.path.getsize(stock_csv)*1e-6 } MB')
# Out:
# 2026-01-21 10:39:50,963, 807204384.py, 7, INFO, Writing data ((239659, 9)) to csv took 2.0008137226104736 seconds.
# 2026-01-21 10:39:50,964, 807204384.py, 8, INFO, CSV file size 26.618403999999998 MB

# %% [markdown]
# ## Save Data to Parquet
#
# ### Notes on Dask
#
# We could use Pandas to save the data directly into Parquet files. However, we will use a different approach by applying the [Dask framework](https://www.dask.org/). Dask provides functionality for working with datasets that do not fit in memory and parallelization to speed up computation. A few notes on Dask and Pandas:
#
# - Pandas, Parquet, and Arrow:
#
#     + We can work with large datasets and Parquet files in Pandas, but we will generally be limited by the amount of data that can fit in our computer's memory.
#     + Pandas can write Parquet files using a PyArrow backend. In fact, recent versions of Pandas support PyArrow data types, and future versions will require a PyArrow backend.
#     + The PyArrow library is an interface between Python and the Apache Arrow project. In particular, the [Parquet data format](https://parquet.apache.org/) and [Arrow](https://arrow.apache.org/docs/python/parquet.html) are Apache projects.
#
# - Dask
#
#     + Dask is much more than an interface to Arrow: Dask provides parallel and distributed computing on Pandas-like dataframes.
#     + Dask is also relatively easy to use as it mimics Pandas' API.
#     + Dask allows us to work with larger datasets than Pandas. In a sense, it is an intermediate step between Pandas and big-data frameworks like Spark (or Databricks).
#     + If you are familiar with Pandas, a good introduction is [10 Minutes to Dask](https://docs.dask.org/en/stable/10-minutes-to-dask.html).

# %%
import dask.dataframe as dd

parquet_dir = os.path.join(temp, "parquet")
shutil.rmtree(parquet_dir, ignore_errors=True)
os.makedirs(parquet_dir, exist_ok=True)

# %%
px_dd = dd.from_pandas(stock_prices, npartitions = len(select_tickers))

start = time.time()
px_dd.to_parquet(parquet_dir, engine = "pyarrow")
end = time.time()

_logs.info(f'Writing dd ({stock_prices.shape}) to parquet took {end - start} seconds.')
_logs.info(f'Parquet file size { get_dir_size(parquet_dir)*1e-6 } MB')
# Out:
# 2026-01-21 10:40:02,020, 817812245.py, 7, INFO, Writing dd ((239659, 9)) to parquet took 1.0348546504974365 seconds.
# 2026-01-21 10:40:02,031, 817812245.py, 8, INFO, Parquet file size 9.713384999999999 MB

# %% [markdown]
# ### Pandas, Dask, and Parquet
#
# The distinction of Pandas Dataframes, Dask Dataframes, and Parquet files is important:
#
# + Pandas dataframes combine the functionality of [NumPy](https://numpy.org/) (efficient vector operations, especially vector algebra) with a concise data manipulation framework that allows us to create columns of different data types (NumPy only allows single-type matrices), database-like operations (such as filtering rows, subsetting columns, and joining different dataframes).
# + Dask dataframes extend the functionality of Pandas dataframes beyond the confines of available memory and implement parallelized operations, among other benefits.
# + Parquet files are a file format. Parquet files can be created by Pandas and Dask, but Dask offers a superior interface. Parquet files are immutable: once written, they cannot be modified.
# + Parquet and Dask are not the same: Parquet is a file format that can be accessed by many applications and programming languages (Python, R, Power BI, etc.), while Dask is a Python package for working with large datasets using distributed computation.

# %% [markdown]
# ### Dask is Powerful, but not Infallible
#
# It is tempting to think of Dask as a super-Pandas, but each package has its advantages and disadvantages.
#
# + Dask is not good at everything (see [Dask DataFrames Best Practices](https://docs.dask.org/en/stable/dataframe-best-practices.html)).
# + A useful and somewhat idiosyncratic comparison of various data manipulation frameworks is shown below (from [DataFrames at Scale Comparison: TPC-H](https://docs.coiled.io/blog/tpch.html#when-to-use-duckdb-vs-polars-vs-dask-vs-spark))
#
# Concept              | Spark | Dask | DuckDB | Polars
# ---------------------|-------|------|--------|--------
# Fast Locally         | ❌    | 🤔  | ✅     | ✅
# Fast on Cloud (1 TB) | ✅    | ✅  | ✅     | ❌
# Fast on Cloud (10 TB)| ❌    | ✅  | ✅     | ❌
# Scales Out           | ✅    | ✅  | ❌     | ❌
# SQL                  | ✅    | 🤔  | ✅     | 🤔
# More than SQL        | ✅    | ✅  | ❌     | ✅
# Sensible Defaults    | ❌    | ✅  | ✅     | ✅
#
#
# ### Dask Best Practices
#
# Parallelism brings extra complexity and overhead. Here are a few ideas to help you decide when to use Dask (from [Dask's Best Practices](https://docs.dask.org/en/stable/best-practices.html)):
#
# #### Small is Better
#
# + Start small: if possible, use Pandas. Also, try to reduce your data using aggregation, then use Pandas.
# + More generally, NumPy, Pandas, and Scikit-Learn may have faster functions for what you need. Consult the relevant documentation, experiment, and/or consult with a colleague or expert.
#
# #### Index with Care
#
# + Use the index: it is beneficial to have a well-defined index in Dask DataFrames, as it may speed up searching (filtering) the data. A one-dimensional index is allowed.
# + Minimize full-data shuffling as much as possible: indexing is an expensive operation.
#
# ### Consider the Cost of Joins
#
# + Consider cases such as small-to-large joins, where the small dataframe fits in memory, but the large one does not. The small dataframe can be Pandas, while the larger one is a Dask dataframe.
# + Some joins are more expensive than others.
#
#     * Not expensive:
#
#         - Join a Dask DataFrame with a Pandas DataFrame.
#         - Join a Dask DataFrame with another Dask DataFrame of a single partition.
#         - Join Dask DataFrames along their indexes.
#
#     * Expensive:
#
#         - Join Dask DataFrames along columns that are not their index.

# %% [markdown]
# # How Do We Store Prices?
#
# + We can store our data as a single blob.
#
#   - This can be difficult to maintain, especially because parquet files are immutable.
#   - Using a single file, we would need to recreate the complete file any time that we update it.
#
# + An alternative strategy is to organize data files by ticker and date:
#
#   - We can create one file per ticker and month (or any other suitable frequency).
#   - Under this approach, we would only need to recreate the latest month's file at any update.

# %%
# CLean up before start
PRICE_DATA = os.getenv("PRICE_DATA")
import shutil
if os.path.exists(PRICE_DATA):
    shutil.rmtree(PRICE_DATA)

# %%
stock_prices.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'source',
#        'ticker'],
#       dtype='object')

# %%
for ticker in stock_prices['ticker'].unique():
    # Filter data for ticker
    # Notice that these are Pandas dataframes
    _logs.info(f'Processing ticker: {ticker}')
    ticker_dt = stock_prices[stock_prices['ticker'] == ticker]
    ticker_dt = ticker_dt.assign(Year = ticker_dt.Date.dt.year)
    for yr in ticker_dt['Year'].unique():
        _logs.info(f'Processing year {yr} for ticker {ticker}.')
        # Filter data for year and convert to Dask dataframe
        yr_dd = dd.from_pandas(ticker_dt[ticker_dt['Year'] == yr],2)
        
        # Define path and create directories if not exist
        yr_path = os.path.join(PRICE_DATA, ticker, f"{ticker}_{yr}")
        os.makedirs(os.path.dirname(yr_path), exist_ok=True)
        _logs.info(f'Writing data to path: {yr_path}')

        # Write to Parquet
        yr_dd.to_parquet(yr_path, engine = "pyarrow")
# Out:
# 2026-01-21 10:41:04,810, 2113979629.py, 4, INFO, Processing ticker: TNC
# 2026-01-21 10:41:04,845, 2113979629.py, 8, INFO, Processing year 1973 for ticker TNC.
# 2026-01-21 10:41:04,854, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1973
# 2026-01-21 10:41:04,886, 2113979629.py, 8, INFO, Processing year 1974 for ticker TNC.
# 2026-01-21 10:41:04,887, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1974
# 2026-01-21 10:41:04,920, 2113979629.py, 8, INFO, Processing year 1975 for ticker TNC.
# 2026-01-21 10:41:04,920, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1975
# 2026-01-21 10:41:04,963, 2113979629.py, 8, INFO, Processing year 1976 for ticker TNC.
# 2026-01-21 10:41:04,969, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1976
# 2026-01-21 10:41:04,996, 2113979629.py, 8, INFO, Processing year 1977 for ticker TNC.
# 2026-01-21 10:41:05,004, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1977
# 2026-01-21 10:41:05,036, 2113979629.py, 8, INFO, Processing year 1978 for ticker TNC.
# 2026-01-21 10:41:05,040, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1978
# 2026-01-21 10:41:05,158, 2113979629.py, 8, INFO, Processing year 1979 for ticker TNC.
# 2026-01-21 10:41:05,166, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1979
# 2026-01-21 10:41:05,233, 2113979629.py, 8, INFO, Processing year 1980 for ticker TNC.
# 2026-01-21 10:41:05,239, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1980
# 2026-01-21 10:41:05,291, 2113979629.py, 8, INFO, Processing year 1981 for ticker TNC.
# 2026-01-21 10:41:05,297, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1981
# 2026-01-21 10:41:05,343, 2113979629.py, 8, INFO, Processing year 1982 for ticker TNC.
# 2026-01-21 10:41:05,349, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1982
# 2026-01-21 10:41:05,386, 2113979629.py, 8, INFO, Processing year 1983 for ticker TNC.
# 2026-01-21 10:41:05,391, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1983
# 2026-01-21 10:41:05,448, 2113979629.py, 8, INFO, Processing year 1984 for ticker TNC.
# 2026-01-21 10:41:05,455, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1984
# 2026-01-21 10:41:05,509, 2113979629.py, 8, INFO, Processing year 1985 for ticker TNC.
# 2026-01-21 10:41:05,518, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1985
# 2026-01-21 10:41:05,582, 2113979629.py, 8, INFO, Processing year 1986 for ticker TNC.
# 2026-01-21 10:41:05,591, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1986
# 2026-01-21 10:41:05,679, 2113979629.py, 8, INFO, Processing year 1987 for ticker TNC.
# 2026-01-21 10:41:05,690, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1987
# 2026-01-21 10:41:05,729, 2113979629.py, 8, INFO, Processing year 1988 for ticker TNC.
# 2026-01-21 10:41:05,736, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1988
# 2026-01-21 10:41:05,777, 2113979629.py, 8, INFO, Processing year 1989 for ticker TNC.
# 2026-01-21 10:41:05,783, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1989
# 2026-01-21 10:41:05,824, 2113979629.py, 8, INFO, Processing year 1990 for ticker TNC.
# 2026-01-21 10:41:05,829, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1990
# 2026-01-21 10:41:05,863, 2113979629.py, 8, INFO, Processing year 1991 for ticker TNC.
# 2026-01-21 10:41:05,869, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1991
# 2026-01-21 10:41:05,928, 2113979629.py, 8, INFO, Processing year 1992 for ticker TNC.
# 2026-01-21 10:41:05,936, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1992
# 2026-01-21 10:41:06,012, 2113979629.py, 8, INFO, Processing year 1993 for ticker TNC.
# 2026-01-21 10:41:06,018, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1993
# 2026-01-21 10:41:06,063, 2113979629.py, 8, INFO, Processing year 1994 for ticker TNC.
# 2026-01-21 10:41:06,072, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1994
# 2026-01-21 10:41:06,123, 2113979629.py, 8, INFO, Processing year 1995 for ticker TNC.
# 2026-01-21 10:41:06,141, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1995
# 2026-01-21 10:41:06,190, 2113979629.py, 8, INFO, Processing year 1996 for ticker TNC.
# 2026-01-21 10:41:06,196, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1996
# 2026-01-21 10:41:06,245, 2113979629.py, 8, INFO, Processing year 1997 for ticker TNC.
# 2026-01-21 10:41:06,255, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1997
# 2026-01-21 10:41:06,318, 2113979629.py, 8, INFO, Processing year 1998 for ticker TNC.
# 2026-01-21 10:41:06,326, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1998
# 2026-01-21 10:41:06,403, 2113979629.py, 8, INFO, Processing year 1999 for ticker TNC.
# 2026-01-21 10:41:06,414, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1999
# 2026-01-21 10:41:06,488, 2113979629.py, 8, INFO, Processing year 2000 for ticker TNC.
# 2026-01-21 10:41:06,501, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2000
# 2026-01-21 10:41:06,609, 2113979629.py, 8, INFO, Processing year 2001 for ticker TNC.
# 2026-01-21 10:41:06,640, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2001
# 2026-01-21 10:41:06,767, 2113979629.py, 8, INFO, Processing year 2002 for ticker TNC.
# 2026-01-21 10:41:06,777, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2002
# 2026-01-21 10:41:06,913, 2113979629.py, 8, INFO, Processing year 2003 for ticker TNC.
# 2026-01-21 10:41:06,924, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2003
# 2026-01-21 10:41:07,059, 2113979629.py, 8, INFO, Processing year 2004 for ticker TNC.
# 2026-01-21 10:41:07,070, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2004
# 2026-01-21 10:41:07,175, 2113979629.py, 8, INFO, Processing year 2005 for ticker TNC.
# 2026-01-21 10:41:07,183, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2005
# 2026-01-21 10:41:07,236, 2113979629.py, 8, INFO, Processing year 2006 for ticker TNC.
# 2026-01-21 10:41:07,245, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2006
# 2026-01-21 10:41:07,286, 2113979629.py, 8, INFO, Processing year 2007 for ticker TNC.
# 2026-01-21 10:41:07,291, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2007
# 2026-01-21 10:41:07,335, 2113979629.py, 8, INFO, Processing year 2008 for ticker TNC.
# 2026-01-21 10:41:07,339, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2008
# 2026-01-21 10:41:07,397, 2113979629.py, 8, INFO, Processing year 2009 for ticker TNC.
# 2026-01-21 10:41:07,402, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2009
# 2026-01-21 10:41:07,475, 2113979629.py, 8, INFO, Processing year 2010 for ticker TNC.
# 2026-01-21 10:41:07,480, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2010
# 2026-01-21 10:41:07,545, 2113979629.py, 8, INFO, Processing year 2011 for ticker TNC.
# 2026-01-21 10:41:07,549, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2011
# 2026-01-21 10:41:07,627, 2113979629.py, 8, INFO, Processing year 2012 for ticker TNC.
# 2026-01-21 10:41:07,638, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2012
# 2026-01-21 10:41:07,686, 2113979629.py, 8, INFO, Processing year 2013 for ticker TNC.
# 2026-01-21 10:41:07,690, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2013
# 2026-01-21 10:41:07,745, 2113979629.py, 8, INFO, Processing year 2014 for ticker TNC.
# 2026-01-21 10:41:07,756, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2014
# 2026-01-21 10:41:07,821, 2113979629.py, 8, INFO, Processing year 2015 for ticker TNC.
# 2026-01-21 10:41:07,826, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2015
# 2026-01-21 10:41:07,877, 2113979629.py, 8, INFO, Processing year 2016 for ticker TNC.
# 2026-01-21 10:41:07,886, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2016
# 2026-01-21 10:41:07,929, 2113979629.py, 8, INFO, Processing year 2017 for ticker TNC.
# 2026-01-21 10:41:07,929, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2017
# 2026-01-21 10:41:07,983, 2113979629.py, 8, INFO, Processing year 2018 for ticker TNC.
# 2026-01-21 10:41:07,983, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2018
# 2026-01-21 10:41:08,031, 2113979629.py, 8, INFO, Processing year 2019 for ticker TNC.
# 2026-01-21 10:41:08,036, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2019
# 2026-01-21 10:41:08,066, 2113979629.py, 8, INFO, Processing year 2020 for ticker TNC.
# 2026-01-21 10:41:08,084, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2020
# 2026-01-21 10:41:08,119, 2113979629.py, 4, INFO, Processing ticker: CBB
# 2026-01-21 10:41:08,146, 2113979629.py, 8, INFO, Processing year 1980 for ticker CBB.
# 2026-01-21 10:41:08,146, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1980
# 2026-01-21 10:41:08,198, 2113979629.py, 8, INFO, Processing year 1981 for ticker CBB.
# 2026-01-21 10:41:08,203, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1981
# 2026-01-21 10:41:08,238, 2113979629.py, 8, INFO, Processing year 1982 for ticker CBB.
# 2026-01-21 10:41:08,242, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1982
# 2026-01-21 10:41:08,279, 2113979629.py, 8, INFO, Processing year 1983 for ticker CBB.
# 2026-01-21 10:41:08,279, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1983
# 2026-01-21 10:41:08,323, 2113979629.py, 8, INFO, Processing year 1984 for ticker CBB.
# 2026-01-21 10:41:08,330, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1984
# 2026-01-21 10:41:08,364, 2113979629.py, 8, INFO, Processing year 1985 for ticker CBB.
# 2026-01-21 10:41:08,371, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1985
# 2026-01-21 10:41:08,402, 2113979629.py, 8, INFO, Processing year 1986 for ticker CBB.
# 2026-01-21 10:41:08,414, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1986
# 2026-01-21 10:41:08,447, 2113979629.py, 8, INFO, Processing year 1987 for ticker CBB.
# 2026-01-21 10:41:08,453, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1987
# 2026-01-21 10:41:08,484, 2113979629.py, 8, INFO, Processing year 1988 for ticker CBB.
# 2026-01-21 10:41:08,487, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1988
# 2026-01-21 10:41:08,516, 2113979629.py, 8, INFO, Processing year 1989 for ticker CBB.
# 2026-01-21 10:41:08,529, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1989
# 2026-01-21 10:41:08,551, 2113979629.py, 8, INFO, Processing year 1990 for ticker CBB.
# 2026-01-21 10:41:08,567, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1990
# 2026-01-21 10:41:08,600, 2113979629.py, 8, INFO, Processing year 1991 for ticker CBB.
# 2026-01-21 10:41:08,605, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1991
# 2026-01-21 10:41:08,633, 2113979629.py, 8, INFO, Processing year 1992 for ticker CBB.
# 2026-01-21 10:41:08,633, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1992
# 2026-01-21 10:41:08,671, 2113979629.py, 8, INFO, Processing year 1993 for ticker CBB.
# 2026-01-21 10:41:08,683, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1993
# 2026-01-21 10:41:08,720, 2113979629.py, 8, INFO, Processing year 1994 for ticker CBB.
# 2026-01-21 10:41:08,726, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1994
# 2026-01-21 10:41:08,758, 2113979629.py, 8, INFO, Processing year 1995 for ticker CBB.
# 2026-01-21 10:41:08,764, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1995
# 2026-01-21 10:41:08,795, 2113979629.py, 8, INFO, Processing year 1996 for ticker CBB.
# 2026-01-21 10:41:08,795, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1996
# 2026-01-21 10:41:08,829, 2113979629.py, 8, INFO, Processing year 1997 for ticker CBB.
# 2026-01-21 10:41:08,835, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1997
# 2026-01-21 10:41:08,868, 2113979629.py, 8, INFO, Processing year 1998 for ticker CBB.
# 2026-01-21 10:41:08,874, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1998
# 2026-01-21 10:41:08,913, 2113979629.py, 8, INFO, Processing year 1999 for ticker CBB.
# 2026-01-21 10:41:08,920, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1999
# 2026-01-21 10:41:08,956, 2113979629.py, 8, INFO, Processing year 2000 for ticker CBB.
# 2026-01-21 10:41:08,960, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2000
# 2026-01-21 10:41:08,991, 2113979629.py, 8, INFO, Processing year 2001 for ticker CBB.
# 2026-01-21 10:41:08,997, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2001
# 2026-01-21 10:41:09,037, 2113979629.py, 8, INFO, Processing year 2002 for ticker CBB.
# 2026-01-21 10:41:09,042, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2002
# 2026-01-21 10:41:09,084, 2113979629.py, 8, INFO, Processing year 2003 for ticker CBB.
# 2026-01-21 10:41:09,089, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2003
# 2026-01-21 10:41:09,123, 2113979629.py, 8, INFO, Processing year 2004 for ticker CBB.
# 2026-01-21 10:41:09,129, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2004
# 2026-01-21 10:41:09,159, 2113979629.py, 8, INFO, Processing year 2005 for ticker CBB.
# 2026-01-21 10:41:09,165, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2005
# 2026-01-21 10:41:09,193, 2113979629.py, 8, INFO, Processing year 2006 for ticker CBB.
# 2026-01-21 10:41:09,203, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2006
# 2026-01-21 10:41:09,243, 2113979629.py, 8, INFO, Processing year 2007 for ticker CBB.
# 2026-01-21 10:41:09,253, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2007
# 2026-01-21 10:41:09,299, 2113979629.py, 8, INFO, Processing year 2008 for ticker CBB.
# 2026-01-21 10:41:09,299, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2008
# 2026-01-21 10:41:09,356, 2113979629.py, 8, INFO, Processing year 2009 for ticker CBB.
# 2026-01-21 10:41:09,359, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2009
# 2026-01-21 10:41:09,385, 2113979629.py, 8, INFO, Processing year 2010 for ticker CBB.
# 2026-01-21 10:41:09,400, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2010
# 2026-01-21 10:41:09,431, 2113979629.py, 8, INFO, Processing year 2011 for ticker CBB.
# 2026-01-21 10:41:09,436, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2011
# 2026-01-21 10:41:09,468, 2113979629.py, 8, INFO, Processing year 2012 for ticker CBB.
# 2026-01-21 10:41:09,479, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2012
# 2026-01-21 10:41:09,515, 2113979629.py, 8, INFO, Processing year 2013 for ticker CBB.
# 2026-01-21 10:41:09,519, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2013
# 2026-01-21 10:41:09,553, 2113979629.py, 8, INFO, Processing year 2014 for ticker CBB.
# 2026-01-21 10:41:09,553, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2014
# 2026-01-21 10:41:09,587, 2113979629.py, 8, INFO, Processing year 2015 for ticker CBB.
# 2026-01-21 10:41:09,587, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2015
# 2026-01-21 10:41:09,612, 2113979629.py, 8, INFO, Processing year 2016 for ticker CBB.
# 2026-01-21 10:41:09,628, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2016
# 2026-01-21 10:41:09,662, 2113979629.py, 8, INFO, Processing year 2017 for ticker CBB.
# 2026-01-21 10:41:09,669, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2017
# 2026-01-21 10:41:09,703, 2113979629.py, 8, INFO, Processing year 2018 for ticker CBB.
# 2026-01-21 10:41:09,708, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2018
# 2026-01-21 10:41:09,741, 2113979629.py, 8, INFO, Processing year 2019 for ticker CBB.
# 2026-01-21 10:41:09,745, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2019
# 2026-01-21 10:41:09,779, 2113979629.py, 8, INFO, Processing year 2020 for ticker CBB.
# 2026-01-21 10:41:09,784, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2020
# 2026-01-21 10:41:09,818, 2113979629.py, 4, INFO, Processing ticker: ALDX
# 2026-01-21 10:41:09,843, 2113979629.py, 8, INFO, Processing year 2014 for ticker ALDX.
# 2026-01-21 10:41:09,845, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX\ALDX_2014
# 2026-01-21 10:41:09,866, 2113979629.py, 8, INFO, Processing year 2015 for ticker ALDX.
# 2026-01-21 10:41:09,884, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX\ALDX_2015
# 2026-01-21 10:41:09,928, 2113979629.py, 8, INFO, Processing year 2016 for ticker ALDX.
# 2026-01-21 10:41:09,936, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX\ALDX_2016
# 2026-01-21 10:41:09,974, 2113979629.py, 8, INFO, Processing year 2017 for ticker ALDX.
# 2026-01-21 10:41:09,980, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX\ALDX_2017
# 2026-01-21 10:41:10,017, 2113979629.py, 8, INFO, Processing year 2018 for ticker ALDX.
# 2026-01-21 10:41:10,021, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX\ALDX_2018
# 2026-01-21 10:41:10,051, 2113979629.py, 8, INFO, Processing year 2019 for ticker ALDX.
# 2026-01-21 10:41:10,051, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX\ALDX_2019
# 2026-01-21 10:41:10,088, 2113979629.py, 8, INFO, Processing year 2020 for ticker ALDX.
# 2026-01-21 10:41:10,095, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX\ALDX_2020
# 2026-01-21 10:41:10,129, 2113979629.py, 4, INFO, Processing ticker: GLADD
# 2026-01-21 10:41:10,159, 2113979629.py, 8, INFO, Processing year 2018 for ticker GLADD.
# 2026-01-21 10:41:10,165, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GLADD\GLADD_2018
# 2026-01-21 10:41:10,198, 2113979629.py, 8, INFO, Processing year 2019 for ticker GLADD.
# 2026-01-21 10:41:10,206, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GLADD\GLADD_2019
# 2026-01-21 10:41:10,245, 2113979629.py, 8, INFO, Processing year 2020 for ticker GLADD.
# 2026-01-21 10:41:10,254, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GLADD\GLADD_2020
# 2026-01-21 10:41:10,290, 2113979629.py, 4, INFO, Processing ticker: FIXX
# 2026-01-21 10:41:10,321, 2113979629.py, 8, INFO, Processing year 2018 for ticker FIXX.
# 2026-01-21 10:41:10,325, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/FIXX\FIXX_2018
# 2026-01-21 10:41:10,370, 2113979629.py, 8, INFO, Processing year 2019 for ticker FIXX.
# 2026-01-21 10:41:10,375, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/FIXX\FIXX_2019
# 2026-01-21 10:41:10,414, 2113979629.py, 8, INFO, Processing year 2020 for ticker FIXX.
# 2026-01-21 10:41:10,422, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/FIXX\FIXX_2020
# 2026-01-21 10:41:10,470, 2113979629.py, 4, INFO, Processing ticker: ETJ
# 2026-01-21 10:41:10,508, 2113979629.py, 8, INFO, Processing year 2007 for ticker ETJ.
# 2026-01-21 10:41:10,513, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2007
# 2026-01-21 10:41:10,550, 2113979629.py, 8, INFO, Processing year 2008 for ticker ETJ.
# 2026-01-21 10:41:10,554, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2008
# 2026-01-21 10:41:10,590, 2113979629.py, 8, INFO, Processing year 2009 for ticker ETJ.
# 2026-01-21 10:41:10,595, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2009
# 2026-01-21 10:41:10,637, 2113979629.py, 8, INFO, Processing year 2010 for ticker ETJ.
# 2026-01-21 10:41:10,642, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2010
# 2026-01-21 10:41:10,683, 2113979629.py, 8, INFO, Processing year 2011 for ticker ETJ.
# 2026-01-21 10:41:10,688, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2011
# 2026-01-21 10:41:10,738, 2113979629.py, 8, INFO, Processing year 2012 for ticker ETJ.
# 2026-01-21 10:41:10,743, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2012
# 2026-01-21 10:41:10,792, 2113979629.py, 8, INFO, Processing year 2013 for ticker ETJ.
# 2026-01-21 10:41:10,800, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2013
# 2026-01-21 10:41:10,842, 2113979629.py, 8, INFO, Processing year 2014 for ticker ETJ.
# 2026-01-21 10:41:10,851, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2014
# 2026-01-21 10:41:10,895, 2113979629.py, 8, INFO, Processing year 2015 for ticker ETJ.
# 2026-01-21 10:41:10,902, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2015
# 2026-01-21 10:41:10,939, 2113979629.py, 8, INFO, Processing year 2016 for ticker ETJ.
# 2026-01-21 10:41:10,947, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2016
# 2026-01-21 10:41:11,002, 2113979629.py, 8, INFO, Processing year 2017 for ticker ETJ.
# 2026-01-21 10:41:11,010, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2017
# 2026-01-21 10:41:11,051, 2113979629.py, 8, INFO, Processing year 2018 for ticker ETJ.
# 2026-01-21 10:41:11,055, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2018
# 2026-01-21 10:41:11,091, 2113979629.py, 8, INFO, Processing year 2019 for ticker ETJ.
# 2026-01-21 10:41:11,099, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2019
# 2026-01-21 10:41:11,136, 2113979629.py, 8, INFO, Processing year 2020 for ticker ETJ.
# 2026-01-21 10:41:11,143, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2020
# 2026-01-21 10:41:11,182, 2113979629.py, 4, INFO, Processing ticker: CMCTP
# 2026-01-21 10:41:11,220, 2113979629.py, 8, INFO, Processing year 2018 for ticker CMCTP.
# 2026-01-21 10:41:11,225, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CMCTP\CMCTP_2018
# 2026-01-21 10:41:11,257, 2113979629.py, 8, INFO, Processing year 2019 for ticker CMCTP.
# 2026-01-21 10:41:11,263, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CMCTP\CMCTP_2019
# 2026-01-21 10:41:11,298, 2113979629.py, 8, INFO, Processing year 2020 for ticker CMCTP.
# 2026-01-21 10:41:11,303, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CMCTP\CMCTP_2020
# 2026-01-21 10:41:11,346, 2113979629.py, 4, INFO, Processing ticker: BWG
# 2026-01-21 10:41:11,383, 2113979629.py, 8, INFO, Processing year 2012 for ticker BWG.
# 2026-01-21 10:41:11,387, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BWG\BWG_2012
# 2026-01-21 10:41:11,458, 2113979629.py, 8, INFO, Processing year 2013 for ticker BWG.
# 2026-01-21 10:41:11,467, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BWG\BWG_2013
# 2026-01-21 10:41:11,535, 2113979629.py, 8, INFO, Processing year 2014 for ticker BWG.
# 2026-01-21 10:41:11,541, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BWG\BWG_2014
# 2026-01-21 10:41:11,579, 2113979629.py, 8, INFO, Processing year 2015 for ticker BWG.
# 2026-01-21 10:41:11,584, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BWG\BWG_2015
# 2026-01-21 10:41:11,624, 2113979629.py, 8, INFO, Processing year 2016 for ticker BWG.
# 2026-01-21 10:41:11,633, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BWG\BWG_2016
# 2026-01-21 10:41:11,667, 2113979629.py, 8, INFO, Processing year 2017 for ticker BWG.
# 2026-01-21 10:41:11,671, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BWG\BWG_2017
# 2026-01-21 10:41:11,705, 2113979629.py, 8, INFO, Processing year 2018 for ticker BWG.
# 2026-01-21 10:41:11,710, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BWG\BWG_2018
# 2026-01-21 10:41:11,741, 2113979629.py, 8, INFO, Processing year 2019 for ticker BWG.
# 2026-01-21 10:41:11,747, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BWG\BWG_2019
# 2026-01-21 10:41:11,782, 2113979629.py, 8, INFO, Processing year 2020 for ticker BWG.
# 2026-01-21 10:41:11,786, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BWG\BWG_2020
# 2026-01-21 10:41:11,819, 2113979629.py, 4, INFO, Processing ticker: VIAC
# 2026-01-21 10:41:11,854, 2113979629.py, 8, INFO, Processing year 2005 for ticker VIAC.
# 2026-01-21 10:41:11,859, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2005
# 2026-01-21 10:41:11,901, 2113979629.py, 8, INFO, Processing year 2006 for ticker VIAC.
# 2026-01-21 10:41:11,907, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2006
# 2026-01-21 10:41:11,943, 2113979629.py, 8, INFO, Processing year 2007 for ticker VIAC.
# 2026-01-21 10:41:11,950, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2007
# 2026-01-21 10:41:11,982, 2113979629.py, 8, INFO, Processing year 2008 for ticker VIAC.
# 2026-01-21 10:41:11,992, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2008
# 2026-01-21 10:41:12,037, 2113979629.py, 8, INFO, Processing year 2009 for ticker VIAC.
# 2026-01-21 10:41:12,045, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2009
# 2026-01-21 10:41:12,141, 2113979629.py, 8, INFO, Processing year 2010 for ticker VIAC.
# 2026-01-21 10:41:12,152, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2010
# 2026-01-21 10:41:12,224, 2113979629.py, 8, INFO, Processing year 2011 for ticker VIAC.
# 2026-01-21 10:41:12,230, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2011
# 2026-01-21 10:41:12,286, 2113979629.py, 8, INFO, Processing year 2012 for ticker VIAC.
# 2026-01-21 10:41:12,298, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2012
# 2026-01-21 10:41:12,334, 2113979629.py, 8, INFO, Processing year 2013 for ticker VIAC.
# 2026-01-21 10:41:12,334, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2013
# 2026-01-21 10:41:12,381, 2113979629.py, 8, INFO, Processing year 2014 for ticker VIAC.
# 2026-01-21 10:41:12,386, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2014
# 2026-01-21 10:41:12,419, 2113979629.py, 8, INFO, Processing year 2015 for ticker VIAC.
# 2026-01-21 10:41:12,419, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2015
# 2026-01-21 10:41:12,446, 2113979629.py, 8, INFO, Processing year 2016 for ticker VIAC.
# 2026-01-21 10:41:12,465, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2016
# 2026-01-21 10:41:12,500, 2113979629.py, 8, INFO, Processing year 2017 for ticker VIAC.
# 2026-01-21 10:41:12,505, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2017
# 2026-01-21 10:41:12,532, 2113979629.py, 8, INFO, Processing year 2018 for ticker VIAC.
# 2026-01-21 10:41:12,546, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2018
# 2026-01-21 10:41:12,586, 2113979629.py, 8, INFO, Processing year 2019 for ticker VIAC.
# 2026-01-21 10:41:12,591, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2019
# 2026-01-21 10:41:12,642, 2113979629.py, 8, INFO, Processing year 2020 for ticker VIAC.
# 2026-01-21 10:41:12,647, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2020
# 2026-01-21 10:41:12,690, 2113979629.py, 4, INFO, Processing ticker: REI
# 2026-01-21 10:41:12,731, 2113979629.py, 8, INFO, Processing year 2007 for ticker REI.
# 2026-01-21 10:41:12,735, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2007
# 2026-01-21 10:41:12,767, 2113979629.py, 8, INFO, Processing year 2008 for ticker REI.
# 2026-01-21 10:41:12,772, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2008
# 2026-01-21 10:41:12,805, 2113979629.py, 8, INFO, Processing year 2009 for ticker REI.
# 2026-01-21 10:41:12,809, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2009
# 2026-01-21 10:41:12,846, 2113979629.py, 8, INFO, Processing year 2010 for ticker REI.
# 2026-01-21 10:41:12,851, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2010
# 2026-01-21 10:41:12,883, 2113979629.py, 8, INFO, Processing year 2011 for ticker REI.
# 2026-01-21 10:41:12,887, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2011
# 2026-01-21 10:41:12,921, 2113979629.py, 8, INFO, Processing year 2012 for ticker REI.
# 2026-01-21 10:41:12,926, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2012
# 2026-01-21 10:41:12,966, 2113979629.py, 8, INFO, Processing year 2013 for ticker REI.
# 2026-01-21 10:41:12,970, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2013
# 2026-01-21 10:41:13,002, 2113979629.py, 8, INFO, Processing year 2014 for ticker REI.
# 2026-01-21 10:41:13,006, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2014
# 2026-01-21 10:41:13,037, 2113979629.py, 8, INFO, Processing year 2015 for ticker REI.
# 2026-01-21 10:41:13,042, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2015
# 2026-01-21 10:41:13,073, 2113979629.py, 8, INFO, Processing year 2016 for ticker REI.
# 2026-01-21 10:41:13,079, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2016
# 2026-01-21 10:41:13,110, 2113979629.py, 8, INFO, Processing year 2017 for ticker REI.
# 2026-01-21 10:41:13,116, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2017
# 2026-01-21 10:41:13,148, 2113979629.py, 8, INFO, Processing year 2018 for ticker REI.
# 2026-01-21 10:41:13,158, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2018
# 2026-01-21 10:41:13,203, 2113979629.py, 8, INFO, Processing year 2019 for ticker REI.
# 2026-01-21 10:41:13,203, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2019
# 2026-01-21 10:41:13,254, 2113979629.py, 8, INFO, Processing year 2020 for ticker REI.
# 2026-01-21 10:41:13,256, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2020
# 2026-01-21 10:41:13,291, 2113979629.py, 4, INFO, Processing ticker: BLPH
# 2026-01-21 10:41:13,315, 2113979629.py, 8, INFO, Processing year 2015 for ticker BLPH.
# 2026-01-21 10:41:13,315, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BLPH\BLPH_2015
# 2026-01-21 10:41:13,352, 2113979629.py, 8, INFO, Processing year 2016 for ticker BLPH.
# 2026-01-21 10:41:13,365, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BLPH\BLPH_2016
# 2026-01-21 10:41:13,388, 2113979629.py, 8, INFO, Processing year 2017 for ticker BLPH.
# 2026-01-21 10:41:13,401, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BLPH\BLPH_2017
# 2026-01-21 10:41:13,441, 2113979629.py, 8, INFO, Processing year 2018 for ticker BLPH.
# 2026-01-21 10:41:13,450, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BLPH\BLPH_2018
# 2026-01-21 10:41:13,489, 2113979629.py, 8, INFO, Processing year 2019 for ticker BLPH.
# 2026-01-21 10:41:13,494, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BLPH\BLPH_2019
# 2026-01-21 10:41:13,530, 2113979629.py, 8, INFO, Processing year 2020 for ticker BLPH.
# 2026-01-21 10:41:13,536, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BLPH\BLPH_2020
# 2026-01-21 10:41:13,572, 2113979629.py, 4, INFO, Processing ticker: SMG
# 2026-01-21 10:41:13,599, 2113979629.py, 8, INFO, Processing year 1992 for ticker SMG.
# 2026-01-21 10:41:13,604, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_1992
# 2026-01-21 10:41:13,634, 2113979629.py, 8, INFO, Processing year 1993 for ticker SMG.
# 2026-01-21 10:41:13,634, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_1993
# 2026-01-21 10:41:13,672, 2113979629.py, 8, INFO, Processing year 1994 for ticker SMG.
# 2026-01-21 10:41:13,677, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_1994
# 2026-01-21 10:41:13,703, 2113979629.py, 8, INFO, Processing year 1995 for ticker SMG.
# 2026-01-21 10:41:13,718, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_1995
# 2026-01-21 10:41:13,749, 2113979629.py, 8, INFO, Processing year 1996 for ticker SMG.
# 2026-01-21 10:41:13,763, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_1996
# 2026-01-21 10:41:13,780, 2113979629.py, 8, INFO, Processing year 1997 for ticker SMG.
# 2026-01-21 10:41:13,795, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_1997
# 2026-01-21 10:41:13,827, 2113979629.py, 8, INFO, Processing year 1998 for ticker SMG.
# 2026-01-21 10:41:13,832, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_1998
# 2026-01-21 10:41:13,861, 2113979629.py, 8, INFO, Processing year 1999 for ticker SMG.
# 2026-01-21 10:41:13,869, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_1999
# 2026-01-21 10:41:13,899, 2113979629.py, 8, INFO, Processing year 2000 for ticker SMG.
# 2026-01-21 10:41:13,904, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2000
# 2026-01-21 10:41:13,936, 2113979629.py, 8, INFO, Processing year 2001 for ticker SMG.
# 2026-01-21 10:41:13,940, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2001
# 2026-01-21 10:41:13,976, 2113979629.py, 8, INFO, Processing year 2002 for ticker SMG.
# 2026-01-21 10:41:13,982, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2002
# 2026-01-21 10:41:14,023, 2113979629.py, 8, INFO, Processing year 2003 for ticker SMG.
# 2026-01-21 10:41:14,030, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2003
# 2026-01-21 10:41:14,059, 2113979629.py, 8, INFO, Processing year 2004 for ticker SMG.
# 2026-01-21 10:41:14,065, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2004
# 2026-01-21 10:41:14,094, 2113979629.py, 8, INFO, Processing year 2005 for ticker SMG.
# 2026-01-21 10:41:14,100, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2005
# 2026-01-21 10:41:14,130, 2113979629.py, 8, INFO, Processing year 2006 for ticker SMG.
# 2026-01-21 10:41:14,134, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2006
# 2026-01-21 10:41:14,169, 2113979629.py, 8, INFO, Processing year 2007 for ticker SMG.
# 2026-01-21 10:41:14,172, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2007
# 2026-01-21 10:41:14,202, 2113979629.py, 8, INFO, Processing year 2008 for ticker SMG.
# 2026-01-21 10:41:14,211, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2008
# 2026-01-21 10:41:14,250, 2113979629.py, 8, INFO, Processing year 2009 for ticker SMG.
# 2026-01-21 10:41:14,258, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2009
# 2026-01-21 10:41:14,302, 2113979629.py, 8, INFO, Processing year 2010 for ticker SMG.
# 2026-01-21 10:41:14,309, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2010
# 2026-01-21 10:41:14,363, 2113979629.py, 8, INFO, Processing year 2011 for ticker SMG.
# 2026-01-21 10:41:14,368, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2011
# 2026-01-21 10:41:14,403, 2113979629.py, 8, INFO, Processing year 2012 for ticker SMG.
# 2026-01-21 10:41:14,407, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2012
# 2026-01-21 10:41:14,440, 2113979629.py, 8, INFO, Processing year 2013 for ticker SMG.
# 2026-01-21 10:41:14,445, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2013
# 2026-01-21 10:41:14,477, 2113979629.py, 8, INFO, Processing year 2014 for ticker SMG.
# 2026-01-21 10:41:14,484, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2014
# 2026-01-21 10:41:14,523, 2113979629.py, 8, INFO, Processing year 2015 for ticker SMG.
# 2026-01-21 10:41:14,530, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2015
# 2026-01-21 10:41:14,566, 2113979629.py, 8, INFO, Processing year 2016 for ticker SMG.
# 2026-01-21 10:41:14,571, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2016
# 2026-01-21 10:41:14,604, 2113979629.py, 8, INFO, Processing year 2017 for ticker SMG.
# 2026-01-21 10:41:14,609, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2017
# 2026-01-21 10:41:14,642, 2113979629.py, 8, INFO, Processing year 2018 for ticker SMG.
# 2026-01-21 10:41:14,649, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2018
# 2026-01-21 10:41:14,684, 2113979629.py, 8, INFO, Processing year 2019 for ticker SMG.
# 2026-01-21 10:41:14,688, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2019
# 2026-01-21 10:41:14,722, 2113979629.py, 8, INFO, Processing year 2020 for ticker SMG.
# 2026-01-21 10:41:14,728, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2020
# 2026-01-21 10:41:14,762, 2113979629.py, 4, INFO, Processing ticker: MOH
# 2026-01-21 10:41:14,791, 2113979629.py, 8, INFO, Processing year 2003 for ticker MOH.
# 2026-01-21 10:41:14,796, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2003
# 2026-01-21 10:41:14,838, 2113979629.py, 8, INFO, Processing year 2004 for ticker MOH.
# 2026-01-21 10:41:14,848, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2004
# 2026-01-21 10:41:14,956, 2113979629.py, 8, INFO, Processing year 2005 for ticker MOH.
# 2026-01-21 10:41:14,968, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2005
# 2026-01-21 10:41:15,040, 2113979629.py, 8, INFO, Processing year 2006 for ticker MOH.
# 2026-01-21 10:41:15,045, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2006
# 2026-01-21 10:41:15,092, 2113979629.py, 8, INFO, Processing year 2007 for ticker MOH.
# 2026-01-21 10:41:15,100, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2007
# 2026-01-21 10:41:15,139, 2113979629.py, 8, INFO, Processing year 2008 for ticker MOH.
# 2026-01-21 10:41:15,150, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2008
# 2026-01-21 10:41:15,186, 2113979629.py, 8, INFO, Processing year 2009 for ticker MOH.
# 2026-01-21 10:41:15,190, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2009
# 2026-01-21 10:41:15,216, 2113979629.py, 8, INFO, Processing year 2010 for ticker MOH.
# 2026-01-21 10:41:15,234, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2010
# 2026-01-21 10:41:15,271, 2113979629.py, 8, INFO, Processing year 2011 for ticker MOH.
# 2026-01-21 10:41:15,275, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2011
# 2026-01-21 10:41:15,312, 2113979629.py, 8, INFO, Processing year 2012 for ticker MOH.
# 2026-01-21 10:41:15,317, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2012
# 2026-01-21 10:41:15,346, 2113979629.py, 8, INFO, Processing year 2013 for ticker MOH.
# 2026-01-21 10:41:15,346, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2013
# 2026-01-21 10:41:15,392, 2113979629.py, 8, INFO, Processing year 2014 for ticker MOH.
# 2026-01-21 10:41:15,401, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2014
# 2026-01-21 10:41:15,437, 2113979629.py, 8, INFO, Processing year 2015 for ticker MOH.
# 2026-01-21 10:41:15,441, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2015
# 2026-01-21 10:41:15,476, 2113979629.py, 8, INFO, Processing year 2016 for ticker MOH.
# 2026-01-21 10:41:15,480, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2016
# 2026-01-21 10:41:15,512, 2113979629.py, 8, INFO, Processing year 2017 for ticker MOH.
# 2026-01-21 10:41:15,519, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2017
# 2026-01-21 10:41:15,551, 2113979629.py, 8, INFO, Processing year 2018 for ticker MOH.
# 2026-01-21 10:41:15,555, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2018
# 2026-01-21 10:41:15,591, 2113979629.py, 8, INFO, Processing year 2019 for ticker MOH.
# 2026-01-21 10:41:15,596, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2019
# 2026-01-21 10:41:15,625, 2113979629.py, 8, INFO, Processing year 2020 for ticker MOH.
# 2026-01-21 10:41:15,633, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2020
# 2026-01-21 10:41:15,667, 2113979629.py, 4, INFO, Processing ticker: AMH
# 2026-01-21 10:41:15,694, 2113979629.py, 8, INFO, Processing year 2013 for ticker AMH.
# 2026-01-21 10:41:15,705, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMH\AMH_2013
# 2026-01-21 10:41:15,737, 2113979629.py, 8, INFO, Processing year 2014 for ticker AMH.
# 2026-01-21 10:41:15,742, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMH\AMH_2014
# 2026-01-21 10:41:15,772, 2113979629.py, 8, INFO, Processing year 2015 for ticker AMH.
# 2026-01-21 10:41:15,777, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMH\AMH_2015
# 2026-01-21 10:41:15,805, 2113979629.py, 8, INFO, Processing year 2016 for ticker AMH.
# 2026-01-21 10:41:15,809, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMH\AMH_2016
# 2026-01-21 10:41:15,838, 2113979629.py, 8, INFO, Processing year 2017 for ticker AMH.
# 2026-01-21 10:41:15,843, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMH\AMH_2017
# 2026-01-21 10:41:15,875, 2113979629.py, 8, INFO, Processing year 2018 for ticker AMH.
# 2026-01-21 10:41:15,880, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMH\AMH_2018
# 2026-01-21 10:41:15,918, 2113979629.py, 8, INFO, Processing year 2019 for ticker AMH.
# 2026-01-21 10:41:15,923, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMH\AMH_2019
# 2026-01-21 10:41:15,964, 2113979629.py, 8, INFO, Processing year 2020 for ticker AMH.
# 2026-01-21 10:41:15,968, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMH\AMH_2020
# 2026-01-21 10:41:16,002, 2113979629.py, 4, INFO, Processing ticker: AMAL
# 2026-01-21 10:41:16,028, 2113979629.py, 8, INFO, Processing year 2018 for ticker AMAL.
# 2026-01-21 10:41:16,034, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAL\AMAL_2018
# 2026-01-21 10:41:16,062, 2113979629.py, 8, INFO, Processing year 2019 for ticker AMAL.
# 2026-01-21 10:41:16,071, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAL\AMAL_2019
# 2026-01-21 10:41:16,101, 2113979629.py, 8, INFO, Processing year 2020 for ticker AMAL.
# 2026-01-21 10:41:16,116, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAL\AMAL_2020
# 2026-01-21 10:41:16,154, 2113979629.py, 4, INFO, Processing ticker: BPYPN
# 2026-01-21 10:41:16,178, 2113979629.py, 8, INFO, Processing year 2020 for ticker BPYPN.
# 2026-01-21 10:41:16,178, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BPYPN\BPYPN_2020
# 2026-01-21 10:41:16,222, 2113979629.py, 4, INFO, Processing ticker: ERH
# 2026-01-21 10:41:16,250, 2113979629.py, 8, INFO, Processing year 2004 for ticker ERH.
# 2026-01-21 10:41:16,250, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2004
# 2026-01-21 10:41:16,285, 2113979629.py, 8, INFO, Processing year 2005 for ticker ERH.
# 2026-01-21 10:41:16,296, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2005
# 2026-01-21 10:41:16,329, 2113979629.py, 8, INFO, Processing year 2006 for ticker ERH.
# 2026-01-21 10:41:16,335, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2006
# 2026-01-21 10:41:16,370, 2113979629.py, 8, INFO, Processing year 2007 for ticker ERH.
# 2026-01-21 10:41:16,375, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2007
# 2026-01-21 10:41:16,409, 2113979629.py, 8, INFO, Processing year 2008 for ticker ERH.
# 2026-01-21 10:41:16,416, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2008
# 2026-01-21 10:41:16,445, 2113979629.py, 8, INFO, Processing year 2009 for ticker ERH.
# 2026-01-21 10:41:16,455, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2009
# 2026-01-21 10:41:16,499, 2113979629.py, 8, INFO, Processing year 2010 for ticker ERH.
# 2026-01-21 10:41:16,504, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2010
# 2026-01-21 10:41:16,544, 2113979629.py, 8, INFO, Processing year 2011 for ticker ERH.
# 2026-01-21 10:41:16,551, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2011
# 2026-01-21 10:41:16,583, 2113979629.py, 8, INFO, Processing year 2012 for ticker ERH.
# 2026-01-21 10:41:16,587, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2012
# 2026-01-21 10:41:16,618, 2113979629.py, 8, INFO, Processing year 2013 for ticker ERH.
# 2026-01-21 10:41:16,623, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2013
# 2026-01-21 10:41:16,655, 2113979629.py, 8, INFO, Processing year 2014 for ticker ERH.
# 2026-01-21 10:41:16,660, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2014
# 2026-01-21 10:41:16,691, 2113979629.py, 8, INFO, Processing year 2015 for ticker ERH.
# 2026-01-21 10:41:16,698, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2015
# 2026-01-21 10:41:16,729, 2113979629.py, 8, INFO, Processing year 2016 for ticker ERH.
# 2026-01-21 10:41:16,733, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2016
# 2026-01-21 10:41:16,772, 2113979629.py, 8, INFO, Processing year 2017 for ticker ERH.
# 2026-01-21 10:41:16,777, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2017
# 2026-01-21 10:41:16,815, 2113979629.py, 8, INFO, Processing year 2018 for ticker ERH.
# ...
# 2026-01-21 10:41:48,756, 2113979629.py, 8, INFO, Processing year 2016 for ticker GURE.
# 2026-01-21 10:41:48,763, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GURE\GURE_2016
# 2026-01-21 10:41:48,799, 2113979629.py, 8, INFO, Processing year 2017 for ticker GURE.
# 2026-01-21 10:41:48,804, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GURE\GURE_2017
# 2026-01-21 10:41:48,841, 2113979629.py, 8, INFO, Processing year 2018 for ticker GURE.
# 2026-01-21 10:41:48,846, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GURE\GURE_2018
# 2026-01-21 10:41:48,888, 2113979629.py, 8, INFO, Processing year 2019 for ticker GURE.
# 2026-01-21 10:41:48,892, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GURE\GURE_2019
# 2026-01-21 10:41:48,928, 2113979629.py, 8, INFO, Processing year 2020 for ticker GURE.
# 2026-01-21 10:41:48,933, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GURE\GURE_2020
# 2026-01-21 10:41:48,966, 2113979629.py, 4, INFO, Processing ticker: TEF
# 2026-01-21 10:41:48,993, 2113979629.py, 8, INFO, Processing year 1987 for ticker TEF.
# 2026-01-21 10:41:49,000, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1987
# 2026-01-21 10:41:49,045, 2113979629.py, 8, INFO, Processing year 1988 for ticker TEF.
# 2026-01-21 10:41:49,054, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1988
# 2026-01-21 10:41:49,103, 2113979629.py, 8, INFO, Processing year 1989 for ticker TEF.
# 2026-01-21 10:41:49,112, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1989
# 2026-01-21 10:41:49,166, 2113979629.py, 8, INFO, Processing year 1990 for ticker TEF.
# 2026-01-21 10:41:49,171, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1990
# 2026-01-21 10:41:49,212, 2113979629.py, 8, INFO, Processing year 1991 for ticker TEF.
# 2026-01-21 10:41:49,219, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1991
# 2026-01-21 10:41:49,246, 2113979629.py, 8, INFO, Processing year 1992 for ticker TEF.
# 2026-01-21 10:41:49,246, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1992
# 2026-01-21 10:41:49,296, 2113979629.py, 8, INFO, Processing year 1993 for ticker TEF.
# 2026-01-21 10:41:49,300, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1993
# 2026-01-21 10:41:49,335, 2113979629.py, 8, INFO, Processing year 1994 for ticker TEF.
# 2026-01-21 10:41:49,344, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1994
# 2026-01-21 10:41:49,377, 2113979629.py, 8, INFO, Processing year 1995 for ticker TEF.
# 2026-01-21 10:41:49,384, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1995
# 2026-01-21 10:41:49,424, 2113979629.py, 8, INFO, Processing year 1996 for ticker TEF.
# 2026-01-21 10:41:49,434, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1996
# 2026-01-21 10:41:49,461, 2113979629.py, 8, INFO, Processing year 1997 for ticker TEF.
# 2026-01-21 10:41:49,461, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1997
# 2026-01-21 10:41:49,515, 2113979629.py, 8, INFO, Processing year 1998 for ticker TEF.
# 2026-01-21 10:41:49,519, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1998
# 2026-01-21 10:41:49,546, 2113979629.py, 8, INFO, Processing year 1999 for ticker TEF.
# 2026-01-21 10:41:49,546, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1999
# 2026-01-21 10:41:49,597, 2113979629.py, 8, INFO, Processing year 2000 for ticker TEF.
# 2026-01-21 10:41:49,604, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2000
# 2026-01-21 10:41:49,655, 2113979629.py, 8, INFO, Processing year 2001 for ticker TEF.
# 2026-01-21 10:41:49,659, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2001
# 2026-01-21 10:41:49,679, 2113979629.py, 8, INFO, Processing year 2002 for ticker TEF.
# 2026-01-21 10:41:49,695, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2002
# 2026-01-21 10:41:49,726, 2113979629.py, 8, INFO, Processing year 2003 for ticker TEF.
# 2026-01-21 10:41:49,738, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2003
# 2026-01-21 10:41:49,772, 2113979629.py, 8, INFO, Processing year 2004 for ticker TEF.
# 2026-01-21 10:41:49,776, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2004
# 2026-01-21 10:41:49,805, 2113979629.py, 8, INFO, Processing year 2005 for ticker TEF.
# 2026-01-21 10:41:49,808, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2005
# 2026-01-21 10:41:49,842, 2113979629.py, 8, INFO, Processing year 2006 for ticker TEF.
# 2026-01-21 10:41:49,848, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2006
# 2026-01-21 10:41:49,879, 2113979629.py, 8, INFO, Processing year 2007 for ticker TEF.
# 2026-01-21 10:41:49,885, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2007
# 2026-01-21 10:41:49,914, 2113979629.py, 8, INFO, Processing year 2008 for ticker TEF.
# 2026-01-21 10:41:49,919, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2008
# 2026-01-21 10:41:49,949, 2113979629.py, 8, INFO, Processing year 2009 for ticker TEF.
# 2026-01-21 10:41:49,953, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2009
# 2026-01-21 10:41:49,989, 2113979629.py, 8, INFO, Processing year 2010 for ticker TEF.
# 2026-01-21 10:41:49,992, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2010
# 2026-01-21 10:41:50,025, 2113979629.py, 8, INFO, Processing year 2011 for ticker TEF.
# 2026-01-21 10:41:50,030, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2011
# 2026-01-21 10:41:50,058, 2113979629.py, 8, INFO, Processing year 2012 for ticker TEF.
# 2026-01-21 10:41:50,068, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2012
# 2026-01-21 10:41:50,124, 2113979629.py, 8, INFO, Processing year 2013 for ticker TEF.
# 2026-01-21 10:41:50,132, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2013
# 2026-01-21 10:41:50,168, 2113979629.py, 8, INFO, Processing year 2014 for ticker TEF.
# 2026-01-21 10:41:50,184, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2014
# 2026-01-21 10:41:50,218, 2113979629.py, 8, INFO, Processing year 2015 for ticker TEF.
# 2026-01-21 10:41:50,229, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2015
# 2026-01-21 10:41:50,266, 2113979629.py, 8, INFO, Processing year 2016 for ticker TEF.
# 2026-01-21 10:41:50,271, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2016
# 2026-01-21 10:41:50,304, 2113979629.py, 8, INFO, Processing year 2017 for ticker TEF.
# 2026-01-21 10:41:50,309, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2017
# 2026-01-21 10:41:50,366, 2113979629.py, 8, INFO, Processing year 2018 for ticker TEF.
# 2026-01-21 10:41:50,372, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2018
# 2026-01-21 10:41:50,415, 2113979629.py, 8, INFO, Processing year 2019 for ticker TEF.
# 2026-01-21 10:41:50,423, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2019
# 2026-01-21 10:41:50,479, 2113979629.py, 8, INFO, Processing year 2020 for ticker TEF.
# 2026-01-21 10:41:50,486, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2020
# 2026-01-21 10:41:50,537, 2113979629.py, 4, INFO, Processing ticker: SYNH
# 2026-01-21 10:41:50,578, 2113979629.py, 8, INFO, Processing year 2014 for ticker SYNH.
# 2026-01-21 10:41:50,582, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SYNH\SYNH_2014
# 2026-01-21 10:41:50,609, 2113979629.py, 8, INFO, Processing year 2015 for ticker SYNH.
# 2026-01-21 10:41:50,631, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SYNH\SYNH_2015
# 2026-01-21 10:41:50,668, 2113979629.py, 8, INFO, Processing year 2016 for ticker SYNH.
# 2026-01-21 10:41:50,680, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SYNH\SYNH_2016
# 2026-01-21 10:41:50,728, 2113979629.py, 8, INFO, Processing year 2017 for ticker SYNH.
# 2026-01-21 10:41:50,730, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SYNH\SYNH_2017
# 2026-01-21 10:41:50,769, 2113979629.py, 8, INFO, Processing year 2018 for ticker SYNH.
# 2026-01-21 10:41:50,781, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SYNH\SYNH_2018
# 2026-01-21 10:41:50,818, 2113979629.py, 8, INFO, Processing year 2019 for ticker SYNH.
# 2026-01-21 10:41:50,822, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SYNH\SYNH_2019
# 2026-01-21 10:41:50,855, 2113979629.py, 8, INFO, Processing year 2020 for ticker SYNH.
# 2026-01-21 10:41:50,864, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SYNH\SYNH_2020
# 2026-01-21 10:41:50,898, 2113979629.py, 4, INFO, Processing ticker: KEY
# 2026-01-21 10:41:50,928, 2113979629.py, 8, INFO, Processing year 1987 for ticker KEY.
# 2026-01-21 10:41:50,933, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1987
# 2026-01-21 10:41:50,965, 2113979629.py, 8, INFO, Processing year 1988 for ticker KEY.
# 2026-01-21 10:41:50,970, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1988
# 2026-01-21 10:41:51,016, 2113979629.py, 8, INFO, Processing year 1989 for ticker KEY.
# 2026-01-21 10:41:51,022, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1989
# 2026-01-21 10:41:51,054, 2113979629.py, 8, INFO, Processing year 1990 for ticker KEY.
# 2026-01-21 10:41:51,056, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1990
# 2026-01-21 10:41:51,079, 2113979629.py, 8, INFO, Processing year 1991 for ticker KEY.
# 2026-01-21 10:41:51,100, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1991
# 2026-01-21 10:41:51,135, 2113979629.py, 8, INFO, Processing year 1992 for ticker KEY.
# 2026-01-21 10:41:51,140, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1992
# 2026-01-21 10:41:51,168, 2113979629.py, 8, INFO, Processing year 1993 for ticker KEY.
# 2026-01-21 10:41:51,180, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1993
# 2026-01-21 10:41:51,208, 2113979629.py, 8, INFO, Processing year 1994 for ticker KEY.
# 2026-01-21 10:41:51,218, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1994
# 2026-01-21 10:41:51,249, 2113979629.py, 8, INFO, Processing year 1995 for ticker KEY.
# 2026-01-21 10:41:51,254, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1995
# 2026-01-21 10:41:51,291, 2113979629.py, 8, INFO, Processing year 1996 for ticker KEY.
# 2026-01-21 10:41:51,300, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1996
# 2026-01-21 10:41:51,335, 2113979629.py, 8, INFO, Processing year 1997 for ticker KEY.
# 2026-01-21 10:41:51,337, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1997
# 2026-01-21 10:41:51,373, 2113979629.py, 8, INFO, Processing year 1998 for ticker KEY.
# 2026-01-21 10:41:51,377, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1998
# 2026-01-21 10:41:51,413, 2113979629.py, 8, INFO, Processing year 1999 for ticker KEY.
# 2026-01-21 10:41:51,418, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1999
# 2026-01-21 10:41:51,445, 2113979629.py, 8, INFO, Processing year 2000 for ticker KEY.
# 2026-01-21 10:41:51,445, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2000
# 2026-01-21 10:41:51,491, 2113979629.py, 8, INFO, Processing year 2001 for ticker KEY.
# 2026-01-21 10:41:51,497, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2001
# 2026-01-21 10:41:51,529, 2113979629.py, 8, INFO, Processing year 2002 for ticker KEY.
# 2026-01-21 10:41:51,534, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2002
# 2026-01-21 10:41:51,562, 2113979629.py, 8, INFO, Processing year 2003 for ticker KEY.
# 2026-01-21 10:41:51,569, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2003
# 2026-01-21 10:41:51,601, 2113979629.py, 8, INFO, Processing year 2004 for ticker KEY.
# 2026-01-21 10:41:51,607, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2004
# 2026-01-21 10:41:51,650, 2113979629.py, 8, INFO, Processing year 2005 for ticker KEY.
# 2026-01-21 10:41:51,654, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2005
# 2026-01-21 10:41:51,689, 2113979629.py, 8, INFO, Processing year 2006 for ticker KEY.
# 2026-01-21 10:41:51,695, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2006
# 2026-01-21 10:41:51,731, 2113979629.py, 8, INFO, Processing year 2007 for ticker KEY.
# 2026-01-21 10:41:51,735, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2007
# 2026-01-21 10:41:51,767, 2113979629.py, 8, INFO, Processing year 2008 for ticker KEY.
# 2026-01-21 10:41:51,772, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2008
# 2026-01-21 10:41:51,802, 2113979629.py, 8, INFO, Processing year 2009 for ticker KEY.
# 2026-01-21 10:41:51,807, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2009
# 2026-01-21 10:41:51,838, 2113979629.py, 8, INFO, Processing year 2010 for ticker KEY.
# 2026-01-21 10:41:51,842, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2010
# 2026-01-21 10:41:51,880, 2113979629.py, 8, INFO, Processing year 2011 for ticker KEY.
# 2026-01-21 10:41:51,887, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2011
# 2026-01-21 10:41:52,016, 2113979629.py, 8, INFO, Processing year 2012 for ticker KEY.
# 2026-01-21 10:41:52,028, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2012
# 2026-01-21 10:41:52,053, 2113979629.py, 8, INFO, Processing year 2013 for ticker KEY.
# 2026-01-21 10:41:52,066, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2013
# 2026-01-21 10:41:52,097, 2113979629.py, 8, INFO, Processing year 2014 for ticker KEY.
# 2026-01-21 10:41:52,102, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2014
# 2026-01-21 10:41:52,133, 2113979629.py, 8, INFO, Processing year 2015 for ticker KEY.
# 2026-01-21 10:41:52,137, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2015
# 2026-01-21 10:41:52,164, 2113979629.py, 8, INFO, Processing year 2016 for ticker KEY.
# 2026-01-21 10:41:52,164, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2016
# 2026-01-21 10:41:52,201, 2113979629.py, 8, INFO, Processing year 2017 for ticker KEY.
# 2026-01-21 10:41:52,201, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2017
# 2026-01-21 10:41:52,233, 2113979629.py, 8, INFO, Processing year 2018 for ticker KEY.
# 2026-01-21 10:41:52,233, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2018
# 2026-01-21 10:41:52,274, 2113979629.py, 8, INFO, Processing year 2019 for ticker KEY.
# 2026-01-21 10:41:52,278, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2019
# 2026-01-21 10:41:52,318, 2113979629.py, 8, INFO, Processing year 2020 for ticker KEY.
# 2026-01-21 10:41:52,330, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2020

# %% [markdown]
# Why would we want to store data this way?
#
# + Data files are easier to maintain. We do not update old data, only recent data or the most recent "delta".
# + Parquet files, as long as they maintain a consistent schema, can all be read jointly.

# %% [markdown]
# # Load, Transform, and Save
#
# In this section, we will load the Parquet files we generated, transform the data, and save the resulting dataset.

# %% [markdown]
# ## Load
#
# + Parquet files can be read individually or as a collection.
# + `dd.read_parquet()` can take a list (collection) of files as input.
# + Use `glob` to obtain the collection of files.

# %%
from glob import glob

parquet_files = glob(os.path.join(PRICE_DATA, "**/*.parquet"), recursive = True)
_logs.info(f'Found {len(parquet_files)} parquet files for reading back into Dask.')

dd_px = dd.read_parquet(parquet_files).set_index("ticker")
# Out:
# 2026-01-21 10:42:01,077, 174194153.py, 4, INFO, Found 2045 parquet files for reading back into Dask.

# %% [markdown]
# ## Transform
#
# + This transformation step will create a *Features* data set. In our case, features will be stock returns (we obtained prices).
# + Dask dataframes work similarly to Pandas dataframes: in particular, we can perform groupby and apply operations.
# + Notice the use of [an anonymous (lambda) function](https://realpython.com/python-lambda/) in the apply statement.
#
# In the code below, the following operation occurs:
#
# + Start with a Dask dataframe, `dd_px`.
# + Group the rows of this dataframe by the variable `ticker`, i.e., each group will contain the observations that pertain only to one ticker at a time. The `group_key` parameter controls whether an index entry is added with the value of the grouping variable (`ticker` in this case); if we made `group_keys=True`, we would have a duplicate `ticker` column.
# + For each group defined by a `ticker`, `apply()` the following calculation:
#
#     - Sort the values by `Date` in ascending order.
#     - Assign a new variable called `Close_lag_1` by shifting the position of the closing price (`Close`) by one position.
#     - Define the schema of the resulting dataframe. If we omit this specification, we would get a warning; however, the simplicity of the calculation ensures that Dask can determine the resulting schema.

# %%
dd_px
# Out:
# Dask DataFrame Structure:
#                           Date     Open     High      Low    Close Adj Close   Volume  source   Year
# npartitions=60
# ACN             datetime64[ns]  float64  float64  float64  float64   float64  float64  object  int32
# ALDX                       ...      ...      ...      ...      ...       ...      ...     ...    ...
# ...                        ...      ...      ...      ...      ...       ...      ...     ...    ...
# ZIXI                       ...      ...      ...      ...      ...       ...      ...     ...    ...
# ZIXI                       ...      ...      ...      ...      ...       ...      ...     ...    ...
# Dask Name: sort_index, 8 graph layers

# %%
dd_shift = (
    dd_px
        .groupby('ticker', group_keys=False)
        .apply(
            lambda x: x.sort_values('Date', ascending = True)
                       .assign(Close_lag_1 = x['Close'].shift(1)), 
            meta = pd.DataFrame(data ={'Date': 'datetime64[ns]',
                    'Open': 'f8',
                    'High': 'f8',
                    'Low': 'f8',
                    'Close': 'f8',
                    'Adj Close': 'f8',
                    'Volume': 'i8',
                    'source': 'object',
                    'Year': 'int32',
                    'Close_lag_1': 'f8'},
                    index = pd.Index([], dtype=pd.StringDtype(), name='ticker'))
    ))

# %% [markdown]
# Finally, using the dataframe that we created above, we can now `assign` the `Returns` variable to the entire dataset.

# %%
dd_shift[["Close", "Close_lag_1"]].dtypes
# Out:
# Close          object
# Close_lag_1    object
# dtype: object

# %%
import dask.dataframe as dd

dd_shift["Close"] = dd.to_numeric(dd_shift["Close"], errors="coerce")
dd_shift["Close_lag_1"] = dd.to_numeric(dd_shift["Close_lag_1"], errors="coerce")

# optional but recommended: remove rows where conversion failed or lag is missing
dd_shift = dd_shift.dropna(subset=["Close", "Close_lag_1"])
dd_shift = dd_shift[dd_shift["Close_lag_1"] != 0]

# %%
dd_rets = dd_shift.assign(
    Returns = lambda x: x['Close']/x['Close_lag_1'] - 1
)

# %% [markdown]
# Question: How do we know that we are not (erroneously) combining the last price of a ticker with the first price of the next ticker?

# %% [markdown]
# ## Lazy Exection
#
# What does `dd_rets` contain?

# %%
dd_rets
# Out:
# Dask DataFrame Structure:
#                   Date    Open    High     Low  Close Adj Close  Volume  source    Year Close_lag_1  Returns
# npartitions=60
# ACN             object  object  object  object  int64    object  object  object  object       int64  float64
# ALDX               ...     ...     ...     ...    ...       ...     ...     ...     ...         ...      ...
# ...                ...     ...     ...     ...    ...       ...     ...     ...     ...         ...      ...
# ZIXI               ...     ...     ...     ...    ...       ...     ...     ...     ...         ...      ...
# ZIXI               ...     ...     ...     ...    ...       ...     ...     ...     ...         ...      ...
# Dask Name: assign, 24 graph layers

# %% [markdown]
# + Dask is a lazy execution framework: commands will not execute until the computation is required.
# + To trigger an execution in dask use `.compute()` or execute a command that requires the actual values (for example, write to Parquet or SQL).

# %%
dd_rets.compute()
# Out:
#              Date   Open   High    Low  Close  Adj Close     Volume    source  \
# ticker
# ACN    2001-07-20  15.05  15.05  14.80  15.01  11.284108  9238500.0   ACN.csv
# ACN    2001-07-23  15.00  15.01  14.55  15.00  11.276587  7501000.0   ACN.csv
# ACN    2001-07-24  14.95  14.97  14.70  14.86  11.171341  3537300.0   ACN.csv
# ACN    2001-07-25  14.70  14.95  14.65  14.95  11.238999  4208100.0   ACN.csv
# ACN    2001-07-26  14.95  14.99  14.50  14.50  10.900705  6335300.0   ACN.csv
# ...           ...    ...    ...    ...    ...        ...        ...       ...
# ZIXI   2020-03-26   4.06   4.53   3.88   4.51   4.510000  1668500.0  ZIXI.csv
# ZIXI   2020-03-27   4.49   4.71   4.10   4.60   4.600000  1146800.0  ZIXI.csv
# ZIXI   2020-03-30   4.83   4.87   4.44   4.64   4.640000  1212000.0  ZIXI.csv
# ZIXI   2020-03-31   4.60   4.69   4.10   4.31   4.310000  1057200.0  ZIXI.csv
# ZIXI   2020-04-01   4.11   4.16   3.80   3.82   3.820000   539500.0  ZIXI.csv
#
#         Year  Close_lag_1   Returns
# ticker
# ACN     2001        15.17 -0.010547
# ACN     2001        15.01 -0.000666
# ACN     2001        15.00 -0.009333
# ACN     2001        14.86  0.006057
# ACN     2001        14.95 -0.030100
# ...      ...          ...       ...
# ZIXI    2020         4.04  0.116337
# ZIXI    2020         4.00  0.150000
# ZIXI    2020         3.85  0.205195
# ZIXI    2020         3.77  0.143236
# ZIXI    2020         3.78  0.010582
#
# [239593 rows x 11 columns]

# %% [markdown]
# ## Save
#
# With our transformed data, we can now save the new feature to a Parquet file. We will need to answer the following questions depending on our context, setup, and available resources:
#
# + Should we keep the same namespace?
# + Should we save all columns?

# %%
dd_rets
# Out:
# Dask DataFrame Structure:
#                   Date    Open    High     Low  Close Adj Close  Volume  source    Year Close_lag_1  Returns
# npartitions=60
# ACN             object  object  object  object  int64    object  object  object  object       int64  float64
# ALDX               ...     ...     ...     ...    ...       ...     ...     ...     ...         ...      ...
# ...                ...     ...     ...     ...    ...       ...     ...     ...     ...         ...      ...
# ZIXI               ...     ...     ...     ...    ...       ...     ...     ...     ...         ...      ...
# ZIXI               ...     ...     ...     ...    ...       ...     ...     ...     ...         ...      ...
# Dask Name: assign, 24 graph layers

# %%
# CLean up before save
FEATURES_DATA = os.getenv("FEATURES_DATA")
if os.path.exists(FEATURES_DATA):
    shutil.rmtree(FEATURES_DATA)
dd_rets.to_parquet(FEATURES_DATA, 
                   overwrite = True, 
                   schema={
                       'Date': 'timestamp[ns]',
                       'Open': 'float64',
                       'High': 'float64',
                       'Low': 'float64',
                       'Close': 'float64',
                       'Adj Close': 'float64',
                       'Volume': 'int64',
                       'source': 'string',
                       'Year': 'int32',
                       'Close_lag_1': 'float64',
                       'Returns': 'float64',
                       'ticker': 'large_string'
                   })

# %% [markdown]
# # Optional: from Jupyter to Command Line
#
# + We have drafted our code in a Jupyter Notebook.
# + Finalized code should be written in Python modules.
#
# ## Object Oriented vs Functional Programming
#
# + We can use classes to keep parameters and functions together.
# + We *could* use Object Oriented Programming, but parallelization of data manipulation and modelling tasks benefit from *Functional Programming*.
# + An Idea:
#
#     - [Data Oriented Programming](https://blog.klipse.tech/dop/2022/06/22/principles-of-dop.html).
#     - Use the class to bundle together parameters and functions.
#     - Use stateless operations and treat all data objects as immutable (we do not modify them, we overwrite them).
#     - Take advantage of [`@staticmethod`](https://realpython.com/instance-class-and-static-methods-demystified/).
#
# The code is in `./05_src/stock_prices/data_manager.py`.

# %% [markdown]
# Our original design was:
#
# ![](./images/02_target_pipeline_manager.png)

# %%
from stock_prices.data_manager import DataManager
dm = DataManager()

# %% [markdown]
# Download all prices.

# %%
dm.process_sample_files()
# Out:
# 2026-01-21 10:44:06,117, data_manager.py, 53, INFO, Processing sample of tickers
# 2026-01-21 10:44:06,121, data_manager.py, 64, INFO, Getting file list from ../../05_src/data/prices_csv/
# 2026-01-21 10:44:06,159, data_manager.py, 66, INFO, Found 5884 files in ../../05_src/data/prices/
# 2026-01-21 10:44:06,159, data_manager.py, 74, INFO, Selecting sample of files
# 2026-01-21 10:44:06,159, data_manager.py, 80, INFO, Selected 30 files
# 2026-01-21 10:44:06,159, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\TBK.csv
# 2026-01-21 10:44:06,159, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\TBK.csv
# 2026-01-21 10:44:06,216, data_manager.py, 101, INFO, Saving data by year
# 2026-01-21 10:44:06,216, data_manager.py, 103, INFO, Processing ticker: TBK
# 2026-01-21 10:44:06,218, data_manager.py, 107, INFO, Processing year 2014 for ticker TBK.
# 2026-01-21 10:44:06,221, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/TBK\TBK_2014
# 2026-01-21 10:44:06,239, data_manager.py, 107, INFO, Processing year 2015 for ticker TBK.
# 2026-01-21 10:44:06,243, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/TBK\TBK_2015
# 2026-01-21 10:44:06,261, data_manager.py, 107, INFO, Processing year 2016 for ticker TBK.
# 2026-01-21 10:44:06,261, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/TBK\TBK_2016
# 2026-01-21 10:44:06,290, data_manager.py, 107, INFO, Processing year 2017 for ticker TBK.
# 2026-01-21 10:44:06,292, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/TBK\TBK_2017
# 2026-01-21 10:44:06,312, data_manager.py, 107, INFO, Processing year 2018 for ticker TBK.
# 2026-01-21 10:44:06,312, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/TBK\TBK_2018
# 2026-01-21 10:44:06,345, data_manager.py, 107, INFO, Processing year 2019 for ticker TBK.
# 2026-01-21 10:44:06,345, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/TBK\TBK_2019
# 2026-01-21 10:44:06,366, data_manager.py, 107, INFO, Processing year 2020 for ticker TBK.
# 2026-01-21 10:44:06,372, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/TBK\TBK_2020
# 2026-01-21 10:44:06,393, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\TBLTW.csv
# 2026-01-21 10:44:06,393, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\TBLTW.csv
# 2026-01-21 10:44:06,412, data_manager.py, 101, INFO, Saving data by year
# 2026-01-21 10:44:06,412, data_manager.py, 103, INFO, Processing ticker: TBLTW
# 2026-01-21 10:44:06,412, data_manager.py, 107, INFO, Processing year 2018 for ticker TBLTW.
# 2026-01-21 10:44:06,424, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/TBLTW\TBLTW_2018
# 2026-01-21 10:44:06,446, data_manager.py, 107, INFO, Processing year 2019 for ticker TBLTW.
# 2026-01-21 10:44:06,453, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/TBLTW\TBLTW_2019
# 2026-01-21 10:44:06,478, data_manager.py, 107, INFO, Processing year 2020 for ticker TBLTW.
# 2026-01-21 10:44:06,478, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/TBLTW\TBLTW_2020
# 2026-01-21 10:44:06,506, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\IMUX.csv
# 2026-01-21 10:44:06,507, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\IMUX.csv
# 2026-01-21 10:44:06,533, data_manager.py, 101, INFO, Saving data by year
# 2026-01-21 10:44:06,533, data_manager.py, 103, INFO, Processing ticker: IMUX
# 2026-01-21 10:44:06,541, data_manager.py, 107, INFO, Processing year 2014 for ticker IMUX.
# 2026-01-21 10:44:06,548, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/IMUX\IMUX_2014
# 2026-01-21 10:44:06,575, data_manager.py, 107, INFO, Processing year 2015 for ticker IMUX.
# 2026-01-21 10:44:06,579, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/IMUX\IMUX_2015
# 2026-01-21 10:44:06,601, data_manager.py, 107, INFO, Processing year 2016 for ticker IMUX.
# 2026-01-21 10:44:06,603, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/IMUX\IMUX_2016
# 2026-01-21 10:44:06,626, data_manager.py, 107, INFO, Processing year 2017 for ticker IMUX.
# 2026-01-21 10:44:06,632, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/IMUX\IMUX_2017
# 2026-01-21 10:44:06,671, data_manager.py, 107, INFO, Processing year 2018 for ticker IMUX.
# 2026-01-21 10:44:06,674, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/IMUX\IMUX_2018
# 2026-01-21 10:44:06,693, data_manager.py, 107, INFO, Processing year 2019 for ticker IMUX.
# 2026-01-21 10:44:06,693, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/IMUX\IMUX_2019
# 2026-01-21 10:44:06,716, data_manager.py, 107, INFO, Processing year 2020 for ticker IMUX.
# 2026-01-21 10:44:06,716, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/IMUX\IMUX_2020
# 2026-01-21 10:44:06,740, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\USLM.csv
# 2026-01-21 10:44:06,740, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\USLM.csv
# 2026-01-21 10:44:06,779, data_manager.py, 101, INFO, Saving data by year
# 2026-01-21 10:44:06,779, data_manager.py, 103, INFO, Processing ticker: USLM
# 2026-01-21 10:44:06,779, data_manager.py, 107, INFO, Processing year 1980 for ticker USLM.
# 2026-01-21 10:44:06,793, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USLM\USLM_1980
# 2026-01-21 10:44:06,813, data_manager.py, 107, INFO, Processing year 1981 for ticker USLM.
# 2026-01-21 10:44:06,813, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USLM\USLM_1981
# 2026-01-21 10:44:06,835, data_manager.py, 107, INFO, Processing year 1982 for ticker USLM.
# 2026-01-21 10:44:06,839, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USLM\USLM_1982
# 2026-01-21 10:44:06,866, data_manager.py, 107, INFO, Processing year 1983 for ticker USLM.
# 2026-01-21 10:44:06,866, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USLM\USLM_1983
# 2026-01-21 10:44:06,896, data_manager.py, 107, INFO, Processing year 1984 for ticker USLM.
# 2026-01-21 10:44:06,899, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USLM\USLM_1984
# 2026-01-21 10:44:06,921, data_manager.py, 107, INFO, Processing year 1985 for ticker USLM.
# 2026-01-21 10:44:06,926, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USLM\USLM_1985
# 2026-01-21 10:44:06,946, data_manager.py, 107, INFO, Processing year 1986 for ticker USLM.
# 2026-01-21 10:44:06,949, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USLM\USLM_1986
# 2026-01-21 10:44:06,972, data_manager.py, 107, INFO, Processing year 1987 for ticker USLM.
# 2026-01-21 10:44:06,977, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USLM\USLM_1987
# 2026-01-21 10:44:06,999, data_manager.py, 107, INFO, Processing year 1988 for ticker USLM.
# 2026-01-21 10:44:07,002, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USLM\USLM_1988
# 2026-01-21 10:44:07,029, data_manager.py, 107, INFO, Processing year 1989 for ticker USLM.
# 2026-01-21 10:44:07,034, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USLM\USLM_1989
# 2026-01-21 10:44:07,066, data_manager.py, 107, INFO, Processing year 1990 for ticker USLM.
# 2026-01-21 10:44:07,070, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USLM\USLM_1990
# 2026-01-21 10:44:07,097, data_manager.py, 107, INFO, Processing year 1991 for ticker USLM.
# 2026-01-21 10:44:07,101, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USLM\USLM_1991
# 2026-01-21 10:44:07,124, data_manager.py, 107, INFO, Processing year 1992 for ticker USLM.
# 2026-01-21 10:44:07,127, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USLM\USLM_1992
# 2026-01-21 10:44:07,147, data_manager.py, 107, INFO, Processing year 1993 for ticker USLM.
# 2026-01-21 10:44:07,150, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USLM\USLM_1993
# 2026-01-21 10:44:07,171, data_manager.py, 107, INFO, Processing year 1994 for ticker USLM.
# 2026-01-21 10:44:07,174, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USLM\USLM_1994
# 2026-01-21 10:44:07,193, data_manager.py, 107, INFO, Processing year 1995 for ticker USLM.
# 2026-01-21 10:44:07,196, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USLM\USLM_1995
# 2026-01-21 10:44:07,218, data_manager.py, 107, INFO, Processing year 1996 for ticker USLM.
# 2026-01-21 10:44:07,219, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USLM\USLM_1996
# 2026-01-21 10:44:07,262, data_manager.py, 107, INFO, Processing year 1997 for ticker USLM.
# 2026-01-21 10:44:07,268, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USLM\USLM_1997
# 2026-01-21 10:44:07,347, data_manager.py, 107, INFO, Processing year 1998 for ticker USLM.
# 2026-01-21 10:44:07,351, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USLM\USLM_1998
# 2026-01-21 10:44:07,394, data_manager.py, 107, INFO, Processing year 1999 for ticker USLM.
# 2026-01-21 10:44:07,397, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USLM\USLM_1999
# 2026-01-21 10:44:07,412, data_manager.py, 107, INFO, Processing year 2000 for ticker USLM.
# 2026-01-21 10:44:07,412, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USLM\USLM_2000
# 2026-01-21 10:44:07,443, data_manager.py, 107, INFO, Processing year 2001 for ticker USLM.
# 2026-01-21 10:44:07,447, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USLM\USLM_2001
# 2026-01-21 10:44:07,468, data_manager.py, 107, INFO, Processing year 2002 for ticker USLM.
# 2026-01-21 10:44:07,478, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USLM\USLM_2002
# 2026-01-21 10:44:07,496, data_manager.py, 107, INFO, Processing year 2003 for ticker USLM.
# 2026-01-21 10:44:07,504, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USLM\USLM_2003
# 2026-01-21 10:44:07,533, data_manager.py, 107, INFO, Processing year 2004 for ticker USLM.
# 2026-01-21 10:44:07,536, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USLM\USLM_2004
# 2026-01-21 10:44:07,566, data_manager.py, 107, INFO, Processing year 2005 for ticker USLM.
# 2026-01-21 10:44:07,569, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USLM\USLM_2005
# 2026-01-21 10:44:07,593, data_manager.py, 107, INFO, Processing year 2006 for ticker USLM.
# 2026-01-21 10:44:07,598, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USLM\USLM_2006
# 2026-01-21 10:44:07,614, data_manager.py, 107, INFO, Processing year 2007 for ticker USLM.
# 2026-01-21 10:44:07,614, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USLM\USLM_2007
# 2026-01-21 10:44:07,644, data_manager.py, 107, INFO, Processing year 2008 for ticker USLM.
# 2026-01-21 10:44:07,648, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USLM\USLM_2008
# 2026-01-21 10:44:07,657, data_manager.py, 107, INFO, Processing year 2009 for ticker USLM.
# 2026-01-21 10:44:07,657, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USLM\USLM_2009
# 2026-01-21 10:44:07,698, data_manager.py, 107, INFO, Processing year 2010 for ticker USLM.
# 2026-01-21 10:44:07,698, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USLM\USLM_2010
# 2026-01-21 10:44:07,728, data_manager.py, 107, INFO, Processing year 2011 for ticker USLM.
# 2026-01-21 10:44:07,731, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USLM\USLM_2011
# 2026-01-21 10:44:07,752, data_manager.py, 107, INFO, Processing year 2012 for ticker USLM.
# 2026-01-21 10:44:07,756, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USLM\USLM_2012
# 2026-01-21 10:44:07,777, data_manager.py, 107, INFO, Processing year 2013 for ticker USLM.
# 2026-01-21 10:44:07,779, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USLM\USLM_2013
# 2026-01-21 10:44:07,797, data_manager.py, 107, INFO, Processing year 2014 for ticker USLM.
# 2026-01-21 10:44:07,797, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USLM\USLM_2014
# 2026-01-21 10:44:07,830, data_manager.py, 107, INFO, Processing year 2015 for ticker USLM.
# 2026-01-21 10:44:07,830, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USLM\USLM_2015
# 2026-01-21 10:44:07,850, data_manager.py, 107, INFO, Processing year 2016 for ticker USLM.
# 2026-01-21 10:44:07,857, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USLM\USLM_2016
# 2026-01-21 10:44:07,877, data_manager.py, 107, INFO, Processing year 2017 for ticker USLM.
# 2026-01-21 10:44:07,877, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USLM\USLM_2017
# 2026-01-21 10:44:07,899, data_manager.py, 107, INFO, Processing year 2018 for ticker USLM.
# 2026-01-21 10:44:07,907, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USLM\USLM_2018
# 2026-01-21 10:44:07,927, data_manager.py, 107, INFO, Processing year 2019 for ticker USLM.
# 2026-01-21 10:44:07,934, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USLM\USLM_2019
# 2026-01-21 10:44:07,956, data_manager.py, 107, INFO, Processing year 2020 for ticker USLM.
# 2026-01-21 10:44:07,962, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USLM\USLM_2020
# 2026-01-21 10:44:08,017, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\TELA.csv
# 2026-01-21 10:44:08,018, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\TELA.csv
# 2026-01-21 10:44:08,050, data_manager.py, 101, INFO, Saving data by year
# 2026-01-21 10:44:08,052, data_manager.py, 103, INFO, Processing ticker: TELA
# 2026-01-21 10:44:08,055, data_manager.py, 107, INFO, Processing year 2019 for ticker TELA.
# 2026-01-21 10:44:08,065, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/TELA\TELA_2019
# 2026-01-21 10:44:08,098, data_manager.py, 107, INFO, Processing year 2020 for ticker TELA.
# 2026-01-21 10:44:08,101, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/TELA\TELA_2020
# 2026-01-21 10:44:08,131, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\BTAI.csv
# 2026-01-21 10:44:08,132, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\BTAI.csv
# 2026-01-21 10:44:08,155, data_manager.py, 101, INFO, Saving data by year
# 2026-01-21 10:44:08,158, data_manager.py, 103, INFO, Processing ticker: BTAI
# 2026-01-21 10:44:08,162, data_manager.py, 107, INFO, Processing year 2018 for ticker BTAI.
# 2026-01-21 10:44:08,165, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BTAI\BTAI_2018
# 2026-01-21 10:44:08,194, data_manager.py, 107, INFO, Processing year 2019 for ticker BTAI.
# 2026-01-21 10:44:08,198, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BTAI\BTAI_2019
# 2026-01-21 10:44:08,233, data_manager.py, 107, INFO, Processing year 2020 for ticker BTAI.
# 2026-01-21 10:44:08,239, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BTAI\BTAI_2020
# 2026-01-21 10:44:08,263, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\SASR.csv
# 2026-01-21 10:44:08,264, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\SASR.csv
# 2026-01-21 10:44:08,296, data_manager.py, 101, INFO, Saving data by year
# 2026-01-21 10:44:08,297, data_manager.py, 103, INFO, Processing ticker: SASR
# 2026-01-21 10:44:08,300, data_manager.py, 107, INFO, Processing year 1994 for ticker SASR.
# 2026-01-21 10:44:08,303, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SASR\SASR_1994
# 2026-01-21 10:44:08,326, data_manager.py, 107, INFO, Processing year 1995 for ticker SASR.
# 2026-01-21 10:44:08,329, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SASR\SASR_1995
# 2026-01-21 10:44:08,351, data_manager.py, 107, INFO, Processing year 1996 for ticker SASR.
# 2026-01-21 10:44:08,354, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SASR\SASR_1996
# 2026-01-21 10:44:08,377, data_manager.py, 107, INFO, Processing year 1997 for ticker SASR.
# 2026-01-21 10:44:08,381, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SASR\SASR_1997
# 2026-01-21 10:44:08,409, data_manager.py, 107, INFO, Processing year 1998 for ticker SASR.
# 2026-01-21 10:44:08,418, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SASR\SASR_1998
# 2026-01-21 10:44:08,453, data_manager.py, 107, INFO, Processing year 1999 for ticker SASR.
# 2026-01-21 10:44:08,458, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SASR\SASR_1999
# 2026-01-21 10:44:08,480, data_manager.py, 107, INFO, Processing year 2000 for ticker SASR.
# 2026-01-21 10:44:08,480, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SASR\SASR_2000
# 2026-01-21 10:44:08,513, data_manager.py, 107, INFO, Processing year 2001 for ticker SASR.
# 2026-01-21 10:44:08,517, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SASR\SASR_2001
# 2026-01-21 10:44:08,540, data_manager.py, 107, INFO, Processing year 2002 for ticker SASR.
# 2026-01-21 10:44:08,547, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SASR\SASR_2002
# 2026-01-21 10:44:08,557, data_manager.py, 107, INFO, Processing year 2003 for ticker SASR.
# 2026-01-21 10:44:08,557, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SASR\SASR_2003
# 2026-01-21 10:44:08,578, data_manager.py, 107, INFO, Processing year 2004 for ticker SASR.
# 2026-01-21 10:44:08,594, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SASR\SASR_2004
# 2026-01-21 10:44:08,615, data_manager.py, 107, INFO, Processing year 2005 for ticker SASR.
# 2026-01-21 10:44:08,618, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SASR\SASR_2005
# 2026-01-21 10:44:08,639, data_manager.py, 107, INFO, Processing year 2006 for ticker SASR.
# 2026-01-21 10:44:08,641, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SASR\SASR_2006
# 2026-01-21 10:44:08,663, data_manager.py, 107, INFO, Processing year 2007 for ticker SASR.
# 2026-01-21 10:44:08,663, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SASR\SASR_2007
# 2026-01-21 10:44:08,679, data_manager.py, 107, INFO, Processing year 2008 for ticker SASR.
# 2026-01-21 10:44:08,693, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SASR\SASR_2008
# 2026-01-21 10:44:08,717, data_manager.py, 107, INFO, Processing year 2009 for ticker SASR.
# 2026-01-21 10:44:08,721, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SASR\SASR_2009
# 2026-01-21 10:44:08,745, data_manager.py, 107, INFO, Processing year 2010 for ticker SASR.
# 2026-01-21 10:44:08,749, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SASR\SASR_2010
# 2026-01-21 10:44:08,767, data_manager.py, 107, INFO, Processing year 2011 for ticker SASR.
# 2026-01-21 10:44:08,778, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SASR\SASR_2011
# 2026-01-21 10:44:08,796, data_manager.py, 107, INFO, Processing year 2012 for ticker SASR.
# 2026-01-21 10:44:08,799, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SASR\SASR_2012
# 2026-01-21 10:44:08,816, data_manager.py, 107, INFO, Processing year 2013 for ticker SASR.
# 2026-01-21 10:44:08,827, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SASR\SASR_2013
# 2026-01-21 10:44:08,848, data_manager.py, 107, INFO, Processing year 2014 for ticker SASR.
# 2026-01-21 10:44:08,850, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SASR\SASR_2014
# 2026-01-21 10:44:08,870, data_manager.py, 107, INFO, Processing year 2015 for ticker SASR.
# 2026-01-21 10:44:08,873, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SASR\SASR_2015
# 2026-01-21 10:44:08,896, data_manager.py, 107, INFO, Processing year 2016 for ticker SASR.
# 2026-01-21 10:44:08,896, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SASR\SASR_2016
# 2026-01-21 10:44:08,921, data_manager.py, 107, INFO, Processing year 2017 for ticker SASR.
# 2026-01-21 10:44:08,928, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SASR\SASR_2017
# 2026-01-21 10:44:08,949, data_manager.py, 107, INFO, Processing year 2018 for ticker SASR.
# 2026-01-21 10:44:08,953, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SASR\SASR_2018
# 2026-01-21 10:44:08,980, data_manager.py, 107, INFO, Processing year 2019 for ticker SASR.
# 2026-01-21 10:44:08,984, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SASR\SASR_2019
# 2026-01-21 10:44:09,012, data_manager.py, 107, INFO, Processing year 2020 for ticker SASR.
# 2026-01-21 10:44:09,015, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SASR\SASR_2020
# 2026-01-21 10:44:09,040, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\NGHCZ.csv
# 2026-01-21 10:44:09,042, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\NGHCZ.csv
# 2026-01-21 10:44:09,067, data_manager.py, 101, INFO, Saving data by year
# 2026-01-21 10:44:09,068, data_manager.py, 103, INFO, Processing ticker: NGHCZ
# 2026-01-21 10:44:09,071, data_manager.py, 107, INFO, Processing year 2015 for ticker NGHCZ.
# 2026-01-21 10:44:09,075, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NGHCZ\NGHCZ_2015
# 2026-01-21 10:44:09,100, data_manager.py, 107, INFO, Processing year 2016 for ticker NGHCZ.
# 2026-01-21 10:44:09,103, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NGHCZ\NGHCZ_2016
# 2026-01-21 10:44:09,125, data_manager.py, 107, INFO, Processing year 2017 for ticker NGHCZ.
# 2026-01-21 10:44:09,129, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NGHCZ\NGHCZ_2017
# 2026-01-21 10:44:09,149, data_manager.py, 107, INFO, Processing year 2018 for ticker NGHCZ.
# 2026-01-21 10:44:09,152, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NGHCZ\NGHCZ_2018
# 2026-01-21 10:44:09,176, data_manager.py, 107, INFO, Processing year 2019 for ticker NGHCZ.
# 2026-01-21 10:44:09,179, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NGHCZ\NGHCZ_2019
# 2026-01-21 10:44:09,203, data_manager.py, 107, INFO, Processing year 2020 for ticker NGHCZ.
# 2026-01-21 10:44:09,206, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/NGHCZ\NGHCZ_2020
# 2026-01-21 10:44:09,230, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\USWS.csv
# 2026-01-21 10:44:09,231, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\USWS.csv
# 2026-01-21 10:44:09,253, data_manager.py, 101, INFO, Saving data by year
# 2026-01-21 10:44:09,255, data_manager.py, 103, INFO, Processing ticker: USWS
# 2026-01-21 10:44:09,257, data_manager.py, 107, INFO, Processing year 2018 for ticker USWS.
# 2026-01-21 10:44:09,260, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USWS\USWS_2018
# 2026-01-21 10:44:09,279, data_manager.py, 107, INFO, Processing year 2019 for ticker USWS.
# 2026-01-21 10:44:09,283, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USWS\USWS_2019
# 2026-01-21 10:44:09,315, data_manager.py, 107, INFO, Processing year 2020 for ticker USWS.
# 2026-01-21 10:44:09,319, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USWS\USWS_2020
# 2026-01-21 10:44:09,346, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\MRC.csv
# 2026-01-21 10:44:09,346, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\MRC.csv
# 2026-01-21 10:44:09,381, data_manager.py, 101, INFO, Saving data by year
# 2026-01-21 10:44:09,381, data_manager.py, 103, INFO, Processing ticker: MRC
# 2026-01-21 10:44:09,381, data_manager.py, 107, INFO, Processing year 2012 for ticker MRC.
# 2026-01-21 10:44:09,381, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/MRC\MRC_2012
# 2026-01-21 10:44:09,413, data_manager.py, 107, INFO, Processing year 2013 for ticker MRC.
# 2026-01-21 10:44:09,416, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/MRC\MRC_2013
# 2026-01-21 10:44:09,444, data_manager.py, 107, INFO, Processing year 2014 for ticker MRC.
# 2026-01-21 10:44:09,444, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/MRC\MRC_2014
# 2026-01-21 10:44:09,463, data_manager.py, 107, INFO, Processing year 2015 for ticker MRC.
# 2026-01-21 10:44:09,473, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/MRC\MRC_2015
# 2026-01-21 10:44:09,497, data_manager.py, 107, INFO, Processing year 2016 for ticker MRC.
# 2026-01-21 10:44:09,497, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/MRC\MRC_2016
# 2026-01-21 10:44:09,518, data_manager.py, 107, INFO, Processing year 2017 for ticker MRC.
# 2026-01-21 10:44:09,528, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/MRC\MRC_2017
# 2026-01-21 10:44:09,540, data_manager.py, 107, INFO, Processing year 2018 for ticker MRC.
# 2026-01-21 10:44:09,540, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/MRC\MRC_2018
# 2026-01-21 10:44:09,566, data_manager.py, 107, INFO, Processing year 2019 for ticker MRC.
# 2026-01-21 10:44:09,577, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/MRC\MRC_2019
# 2026-01-21 10:44:09,597, data_manager.py, 107, INFO, Processing year 2020 for ticker MRC.
# 2026-01-21 10:44:09,597, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/MRC\MRC_2020
# 2026-01-21 10:44:09,630, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\DMLP.csv
# 2026-01-21 10:44:09,630, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\DMLP.csv
# 2026-01-21 10:44:09,661, data_manager.py, 101, INFO, Saving data by year
# 2026-01-21 10:44:09,661, data_manager.py, 103, INFO, Processing ticker: DMLP
# 2026-01-21 10:44:09,661, data_manager.py, 107, INFO, Processing year 2003 for ticker DMLP.
# 2026-01-21 10:44:09,661, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DMLP\DMLP_2003
# 2026-01-21 10:44:09,697, data_manager.py, 107, INFO, Processing year 2004 for ticker DMLP.
# 2026-01-21 10:44:09,697, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DMLP\DMLP_2004
# 2026-01-21 10:44:09,723, data_manager.py, 107, INFO, Processing year 2005 for ticker DMLP.
# 2026-01-21 10:44:09,729, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DMLP\DMLP_2005
# 2026-01-21 10:44:09,746, data_manager.py, 107, INFO, Processing year 2006 for ticker DMLP.
# 2026-01-21 10:44:09,746, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DMLP\DMLP_2006
# 2026-01-21 10:44:09,781, data_manager.py, 107, INFO, Processing year 2007 for ticker DMLP.
# 2026-01-21 10:44:09,781, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DMLP\DMLP_2007
# 2026-01-21 10:44:09,808, data_manager.py, 107, INFO, Processing year 2008 for ticker DMLP.
# 2026-01-21 10:44:09,812, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DMLP\DMLP_2008
# 2026-01-21 10:44:09,823, data_manager.py, 107, INFO, Processing year 2009 for ticker DMLP.
# 2026-01-21 10:44:09,823, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DMLP\DMLP_2009
# 2026-01-21 10:44:09,865, data_manager.py, 107, INFO, Processing year 2010 for ticker DMLP.
# 2026-01-21 10:44:09,876, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DMLP\DMLP_2010
# 2026-01-21 10:44:09,899, data_manager.py, 107, INFO, Processing year 2011 for ticker DMLP.
# 2026-01-21 10:44:09,904, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DMLP\DMLP_2011
# 2026-01-21 10:44:09,932, data_manager.py, 107, INFO, Processing year 2012 for ticker DMLP.
# 2026-01-21 10:44:09,935, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DMLP\DMLP_2012
# 2026-01-21 10:44:09,957, data_manager.py, 107, INFO, Processing year 2013 for ticker DMLP.
# 2026-01-21 10:44:09,957, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DMLP\DMLP_2013
# 2026-01-21 10:44:10,000, data_manager.py, 107, INFO, Processing year 2014 for ticker DMLP.
# 2026-01-21 10:44:10,010, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DMLP\DMLP_2014
# 2026-01-21 10:44:10,040, data_manager.py, 107, INFO, Processing year 2015 for ticker DMLP.
# 2026-01-21 10:44:10,047, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DMLP\DMLP_2015
# 2026-01-21 10:44:10,077, data_manager.py, 107, INFO, Processing year 2016 for ticker DMLP.
# 2026-01-21 10:44:10,081, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DMLP\DMLP_2016
# 2026-01-21 10:44:10,111, data_manager.py, 107, INFO, Processing year 2017 for ticker DMLP.
# 2026-01-21 10:44:10,115, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DMLP\DMLP_2017
# 2026-01-21 10:44:10,146, data_manager.py, 107, INFO, Processing year 2018 for ticker DMLP.
# 2026-01-21 10:44:10,151, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DMLP\DMLP_2018
# 2026-01-21 10:44:10,182, data_manager.py, 107, INFO, Processing year 2019 for ticker DMLP.
# 2026-01-21 10:44:10,188, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DMLP\DMLP_2019
# 2026-01-21 10:44:10,232, data_manager.py, 107, INFO, Processing year 2020 for ticker DMLP.
# 2026-01-21 10:44:10,237, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DMLP\DMLP_2020
# 2026-01-21 10:44:10,267, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\STPP.csv
# 2026-01-21 10:44:10,268, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\STPP.csv
# 2026-01-21 10:44:10,312, data_manager.py, 101, INFO, Saving data by year
# 2026-01-21 10:44:10,314, data_manager.py, 103, INFO, Processing ticker: STPP
# 2026-01-21 10:44:10,318, data_manager.py, 107, INFO, Processing year 2010 for ticker STPP.
# 2026-01-21 10:44:10,322, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/STPP\STPP_2010
# 2026-01-21 10:44:10,353, data_manager.py, 107, INFO, Processing year 2011 for ticker STPP.
# 2026-01-21 10:44:10,360, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/STPP\STPP_2011
# 2026-01-21 10:44:10,391, data_manager.py, 107, INFO, Processing year 2012 for ticker STPP.
# 2026-01-21 10:44:10,395, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/STPP\STPP_2012
# 2026-01-21 10:44:10,426, data_manager.py, 107, INFO, Processing year 2013 for ticker STPP.
# 2026-01-21 10:44:10,431, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/STPP\STPP_2013
# 2026-01-21 10:44:10,464, data_manager.py, 107, INFO, Processing year 2014 for ticker STPP.
# 2026-01-21 10:44:10,470, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/STPP\STPP_2014
# 2026-01-21 10:44:10,517, data_manager.py, 107, INFO, Processing year 2015 for ticker STPP.
# 2026-01-21 10:44:10,517, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/STPP\STPP_2015
# 2026-01-21 10:44:10,564, data_manager.py, 107, INFO, Processing year 2016 for ticker STPP.
# 2026-01-21 10:44:10,564, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/STPP\STPP_2016
# 2026-01-21 10:44:10,599, data_manager.py, 107, INFO, Processing year 2017 for ticker STPP.
# 2026-01-21 10:44:10,607, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/STPP\STPP_2017
# 2026-01-21 10:44:10,643, data_manager.py, 107, INFO, Processing year 2018 for ticker STPP.
# 2026-01-21 10:44:10,647, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/STPP\STPP_2018
# 2026-01-21 10:44:10,682, data_manager.py, 107, INFO, Processing year 2019 for ticker STPP.
# 2026-01-21 10:44:10,683, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/STPP\STPP_2019
# 2026-01-21 10:44:10,726, data_manager.py, 107, INFO, Processing year 2020 for ticker STPP.
# 2026-01-21 10:44:10,731, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/STPP\STPP_2020
# 2026-01-21 10:44:10,762, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\BEN.csv
# 2026-01-21 10:44:10,762, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\BEN.csv
# 2026-01-21 10:44:10,823, data_manager.py, 101, INFO, Saving data by year
# 2026-01-21 10:44:10,823, data_manager.py, 103, INFO, Processing ticker: BEN
# 2026-01-21 10:44:10,823, data_manager.py, 107, INFO, Processing year 1983 for ticker BEN.
# 2026-01-21 10:44:10,823, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BEN\BEN_1983
# 2026-01-21 10:44:10,873, data_manager.py, 107, INFO, Processing year 1984 for ticker BEN.
# 2026-01-21 10:44:10,873, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BEN\BEN_1984
# 2026-01-21 10:44:10,913, data_manager.py, 107, INFO, Processing year 1985 for ticker BEN.
# 2026-01-21 10:44:10,918, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BEN\BEN_1985
# 2026-01-21 10:44:10,966, data_manager.py, 107, INFO, Processing year 1986 for ticker BEN.
# 2026-01-21 10:44:10,973, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BEN\BEN_1986
# 2026-01-21 10:44:11,007, data_manager.py, 107, INFO, Processing year 1987 for ticker BEN.
# 2026-01-21 10:44:11,010, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BEN\BEN_1987
# 2026-01-21 10:44:11,047, data_manager.py, 107, INFO, Processing year 1988 for ticker BEN.
# 2026-01-21 10:44:11,061, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BEN\BEN_1988
# 2026-01-21 10:44:11,102, data_manager.py, 107, INFO, Processing year 1989 for ticker BEN.
# 2026-01-21 10:44:11,107, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BEN\BEN_1989
# 2026-01-21 10:44:11,140, data_manager.py, 107, INFO, Processing year 1990 for ticker BEN.
# 2026-01-21 10:44:11,140, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BEN\BEN_1990
# 2026-01-21 10:44:11,179, data_manager.py, 107, INFO, Processing year 1991 for ticker BEN.
# 2026-01-21 10:44:11,186, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BEN\BEN_1991
# 2026-01-21 10:44:11,225, data_manager.py, 107, INFO, Processing year 1992 for ticker BEN.
# 2026-01-21 10:44:11,230, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BEN\BEN_1992
# 2026-01-21 10:44:11,265, data_manager.py, 107, INFO, Processing year 1993 for ticker BEN.
# 2026-01-21 10:44:11,270, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BEN\BEN_1993
# 2026-01-21 10:44:11,302, data_manager.py, 107, INFO, Processing year 1994 for ticker BEN.
# 2026-01-21 10:44:11,308, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BEN\BEN_1994
# 2026-01-21 10:44:11,340, data_manager.py, 107, INFO, Processing year 1995 for ticker BEN.
# 2026-01-21 10:44:11,346, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BEN\BEN_1995
# 2026-01-21 10:44:11,384, data_manager.py, 107, INFO, Processing year 1996 for ticker BEN.
# 2026-01-21 10:44:11,389, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BEN\BEN_1996
# 2026-01-21 10:44:11,422, data_manager.py, 107, INFO, Processing year 1997 for ticker BEN.
# 2026-01-21 10:44:11,429, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BEN\BEN_1997
# 2026-01-21 10:44:11,463, data_manager.py, 107, INFO, Processing year 1998 for ticker BEN.
# 2026-01-21 10:44:11,468, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BEN\BEN_1998
# 2026-01-21 10:44:11,503, data_manager.py, 107, INFO, Processing year 1999 for ticker BEN.
# 2026-01-21 10:44:11,510, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BEN\BEN_1999
# 2026-01-21 10:44:11,544, data_manager.py, 107, INFO, Processing year 2000 for ticker BEN.
# 2026-01-21 10:44:11,549, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BEN\BEN_2000
# 2026-01-21 10:44:11,598, data_manager.py, 107, INFO, Processing year 2001 for ticker BEN.
# 2026-01-21 10:44:11,631, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BEN\BEN_2001
# 2026-01-21 10:44:11,764, data_manager.py, 107, INFO, Processing year 2002 for ticker BEN.
# 2026-01-21 10:44:11,768, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BEN\BEN_2002
# 2026-01-21 10:44:11,837, data_manager.py, 107, INFO, Processing year 2003 for ticker BEN.
# 2026-01-21 10:44:11,846, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BEN\BEN_2003
# 2026-01-21 10:44:11,895, data_manager.py, 107, INFO, Processing year 2004 for ticker BEN.
# 2026-01-21 10:44:11,898, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BEN\BEN_2004
# 2026-01-21 10:44:11,949, data_manager.py, 107, INFO, Processing year 2005 for ticker BEN.
# 2026-01-21 10:44:11,952, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BEN\BEN_2005
# 2026-01-21 10:44:12,003, data_manager.py, 107, INFO, Processing year 2006 for ticker BEN.
# 2026-01-21 10:44:12,010, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BEN\BEN_2006
# 2026-01-21 10:44:12,046, data_manager.py, 107, INFO, Processing year 2007 for ticker BEN.
# 2026-01-21 10:44:12,058, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BEN\BEN_2007
# 2026-01-21 10:44:12,101, data_manager.py, 107, INFO, Processing year 2008 for ticker BEN.
# 2026-01-21 10:44:12,109, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BEN\BEN_2008
# 2026-01-21 10:44:12,147, data_manager.py, 107, INFO, Processing year 2009 for ticker BEN.
# 2026-01-21 10:44:12,161, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BEN\BEN_2009
# 2026-01-21 10:44:12,206, data_manager.py, 107, INFO, Processing year 2010 for ticker BEN.
# 2026-01-21 10:44:12,213, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BEN\BEN_2010
# 2026-01-21 10:44:12,252, data_manager.py, 107, INFO, Processing year 2011 for ticker BEN.
# 2026-01-21 10:44:12,258, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BEN\BEN_2011
# 2026-01-21 10:44:12,314, data_manager.py, 107, INFO, Processing year 2012 for ticker BEN.
# 2026-01-21 10:44:12,320, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BEN\BEN_2012
# 2026-01-21 10:44:12,360, data_manager.py, 107, INFO, Processing year 2013 for ticker BEN.
# 2026-01-21 10:44:12,364, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BEN\BEN_2013
# 2026-01-21 10:44:12,412, data_manager.py, 107, INFO, Processing year 2014 for ticker BEN.
# 2026-01-21 10:44:12,417, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BEN\BEN_2014
# 2026-01-21 10:44:12,453, data_manager.py, 107, INFO, Processing year 2015 for ticker BEN.
# 2026-01-21 10:44:12,464, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BEN\BEN_2015
# 2026-01-21 10:44:12,497, data_manager.py, 107, INFO, Processing year 2016 for ticker BEN.
# 2026-01-21 10:44:12,507, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BEN\BEN_2016
# 2026-01-21 10:44:12,547, data_manager.py, 107, INFO, Processing year 2017 for ticker BEN.
# 2026-01-21 10:44:12,552, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BEN\BEN_2017
# 2026-01-21 10:44:12,591, data_manager.py, 107, INFO, Processing year 2018 for ticker BEN.
# 2026-01-21 10:44:12,596, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BEN\BEN_2018
# 2026-01-21 10:44:12,631, data_manager.py, 107, INFO, Processing year 2019 for ticker BEN.
# 2026-01-21 10:44:12,636, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BEN\BEN_2019
# 2026-01-21 10:44:12,675, data_manager.py, 107, INFO, Processing year 2020 for ticker BEN.
# 2026-01-21 10:44:12,681, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BEN\BEN_2020
# 2026-01-21 10:44:12,715, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\CRNT.csv
# 2026-01-21 10:44:12,715, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\CRNT.csv
# 2026-01-21 10:44:12,770, data_manager.py, 101, INFO, Saving data by year
# 2026-01-21 10:44:12,772, data_manager.py, 103, INFO, Processing ticker: CRNT
# 2026-01-21 10:44:12,774, data_manager.py, 107, INFO, Processing year 2000 for ticker CRNT.
# 2026-01-21 10:44:12,774, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CRNT\CRNT_2000
# 2026-01-21 10:44:12,820, data_manager.py, 107, INFO, Processing year 2001 for ticker CRNT.
# 2026-01-21 10:44:12,823, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CRNT\CRNT_2001
# 2026-01-21 10:44:12,866, data_manager.py, 107, INFO, Processing year 2002 for ticker CRNT.
# 2026-01-21 10:44:12,873, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CRNT\CRNT_2002
# 2026-01-21 10:44:12,910, data_manager.py, 107, INFO, Processing year 2003 for ticker CRNT.
# 2026-01-21 10:44:12,916, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CRNT\CRNT_2003
# 2026-01-21 10:44:12,956, data_manager.py, 107, INFO, Processing year 2004 for ticker CRNT.
# 2026-01-21 10:44:12,963, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CRNT\CRNT_2004
# 2026-01-21 10:44:12,997, data_manager.py, 107, INFO, Processing year 2005 for ticker CRNT.
# 2026-01-21 10:44:12,997, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CRNT\CRNT_2005
# 2026-01-21 10:44:13,024, data_manager.py, 107, INFO, Processing year 2006 for ticker CRNT.
# 2026-01-21 10:44:13,053, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CRNT\CRNT_2006
# 2026-01-21 10:44:13,100, data_manager.py, 107, INFO, Processing year 2007 for ticker CRNT.
# 2026-01-21 10:44:13,100, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CRNT\CRNT_2007
# 2026-01-21 10:44:13,142, data_manager.py, 107, INFO, Processing year 2008 for ticker CRNT.
# 2026-01-21 10:44:13,142, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CRNT\CRNT_2008
# 2026-01-21 10:44:13,179, data_manager.py, 107, INFO, Processing year 2009 for ticker CRNT.
# 2026-01-21 10:44:13,179, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CRNT\CRNT_2009
# 2026-01-21 10:44:13,223, data_manager.py, 107, INFO, Processing year 2010 for ticker CRNT.
# 2026-01-21 10:44:13,229, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CRNT\CRNT_2010
# 2026-01-21 10:44:13,262, data_manager.py, 107, INFO, Processing year 2011 for ticker CRNT.
# 2026-01-21 10:44:13,266, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CRNT\CRNT_2011
# 2026-01-21 10:44:13,297, data_manager.py, 107, INFO, Processing year 2012 for ticker CRNT.
# 2026-01-21 10:44:13,306, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CRNT\CRNT_2012
# 2026-01-21 10:44:13,343, data_manager.py, 107, INFO, Processing year 2013 for ticker CRNT.
# 2026-01-21 10:44:13,349, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CRNT\CRNT_2013
# 2026-01-21 10:44:13,387, data_manager.py, 107, INFO, Processing year 2014 for ticker CRNT.
# 2026-01-21 10:44:13,394, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CRNT\CRNT_2014
# 2026-01-21 10:44:13,434, data_manager.py, 107, INFO, Processing year 2015 for ticker CRNT.
# 2026-01-21 10:44:13,438, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CRNT\CRNT_2015
# 2026-01-21 10:44:13,475, data_manager.py, 107, INFO, Processing year 2016 for ticker CRNT.
# 2026-01-21 10:44:13,480, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CRNT\CRNT_2016
# 2026-01-21 10:44:13,517, data_manager.py, 107, INFO, Processing year 2017 for ticker CRNT.
# 2026-01-21 10:44:13,525, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CRNT\CRNT_2017
# 2026-01-21 10:44:13,558, data_manager.py, 107, INFO, Processing year 2018 for ticker CRNT.
# 2026-01-21 10:44:13,565, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CRNT\CRNT_2018
# 2026-01-21 10:44:13,597, data_manager.py, 107, INFO, Processing year 2019 for ticker CRNT.
# 2026-01-21 10:44:13,613, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CRNT\CRNT_2019
# 2026-01-21 10:44:13,705, data_manager.py, 107, INFO, Processing year 2020 for ticker CRNT.
# 2026-01-21 10:44:13,708, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CRNT\CRNT_2020
# 2026-01-21 10:44:13,748, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\USFD.csv
# 2026-01-21 10:44:13,751, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\USFD.csv
# 2026-01-21 10:44:13,774, data_manager.py, 101, INFO, Saving data by year
# 2026-01-21 10:44:13,774, data_manager.py, 103, INFO, Processing ticker: USFD
# 2026-01-21 10:44:13,794, data_manager.py, 107, INFO, Processing year 2016 for ticker USFD.
# 2026-01-21 10:44:13,797, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USFD\USFD_2016
# 2026-01-21 10:44:13,834, data_manager.py, 107, INFO, Processing year 2017 for ticker USFD.
# 2026-01-21 10:44:13,841, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USFD\USFD_2017
# 2026-01-21 10:44:13,877, data_manager.py, 107, INFO, Processing year 2018 for ticker USFD.
# 2026-01-21 10:44:13,879, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USFD\USFD_2018
# 2026-01-21 10:44:13,919, data_manager.py, 107, INFO, Processing year 2019 for ticker USFD.
# 2026-01-21 10:44:13,925, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USFD\USFD_2019
# 2026-01-21 10:44:13,963, data_manager.py, 107, INFO, Processing year 2020 for ticker USFD.
# 2026-01-21 10:44:13,969, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/USFD\USFD_2020
# 2026-01-21 10:44:14,021, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\RPT.csv
# 2026-01-21 10:44:14,023, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\RPT.csv
# 2026-01-21 10:44:14,077, data_manager.py, 101, INFO, Saving data by year
# 2026-01-21 10:44:14,077, data_manager.py, 103, INFO, Processing ticker: RPT
# 2026-01-21 10:44:14,090, data_manager.py, 107, INFO, Processing year 1988 for ticker RPT.
# 2026-01-21 10:44:14,090, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/RPT\RPT_1988
# 2026-01-21 10:44:14,143, data_manager.py, 107, INFO, Processing year 1989 for ticker RPT.
# ...
# 2026-01-21 10:44:30,097, data_manager.py, 107, INFO, Processing year 1998 for ticker CM.
# 2026-01-21 10:44:30,102, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CM\CM_1998
# 2026-01-21 10:44:30,137, data_manager.py, 107, INFO, Processing year 1999 for ticker CM.
# 2026-01-21 10:44:30,145, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CM\CM_1999
# 2026-01-21 10:44:30,177, data_manager.py, 107, INFO, Processing year 2000 for ticker CM.
# 2026-01-21 10:44:30,181, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CM\CM_2000
# 2026-01-21 10:44:30,217, data_manager.py, 107, INFO, Processing year 2001 for ticker CM.
# 2026-01-21 10:44:30,221, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CM\CM_2001
# 2026-01-21 10:44:30,260, data_manager.py, 107, INFO, Processing year 2002 for ticker CM.
# 2026-01-21 10:44:30,268, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CM\CM_2002
# 2026-01-21 10:44:30,312, data_manager.py, 107, INFO, Processing year 2003 for ticker CM.
# 2026-01-21 10:44:30,317, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CM\CM_2003
# 2026-01-21 10:44:30,364, data_manager.py, 107, INFO, Processing year 2004 for ticker CM.
# 2026-01-21 10:44:30,374, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CM\CM_2004
# 2026-01-21 10:44:30,409, data_manager.py, 107, INFO, Processing year 2005 for ticker CM.
# 2026-01-21 10:44:30,413, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CM\CM_2005
# 2026-01-21 10:44:30,448, data_manager.py, 107, INFO, Processing year 2006 for ticker CM.
# 2026-01-21 10:44:30,462, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CM\CM_2006
# 2026-01-21 10:44:30,498, data_manager.py, 107, INFO, Processing year 2007 for ticker CM.
# 2026-01-21 10:44:30,504, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CM\CM_2007
# 2026-01-21 10:44:30,537, data_manager.py, 107, INFO, Processing year 2008 for ticker CM.
# 2026-01-21 10:44:30,543, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CM\CM_2008
# 2026-01-21 10:44:30,577, data_manager.py, 107, INFO, Processing year 2009 for ticker CM.
# 2026-01-21 10:44:30,582, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CM\CM_2009
# 2026-01-21 10:44:30,612, data_manager.py, 107, INFO, Processing year 2010 for ticker CM.
# 2026-01-21 10:44:30,629, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CM\CM_2010
# 2026-01-21 10:44:30,666, data_manager.py, 107, INFO, Processing year 2011 for ticker CM.
# 2026-01-21 10:44:30,671, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CM\CM_2011
# 2026-01-21 10:44:30,694, data_manager.py, 107, INFO, Processing year 2012 for ticker CM.
# 2026-01-21 10:44:30,708, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CM\CM_2012
# 2026-01-21 10:44:30,739, data_manager.py, 107, INFO, Processing year 2013 for ticker CM.
# 2026-01-21 10:44:30,745, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CM\CM_2013
# 2026-01-21 10:44:30,785, data_manager.py, 107, INFO, Processing year 2014 for ticker CM.
# 2026-01-21 10:44:30,789, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CM\CM_2014
# 2026-01-21 10:44:30,827, data_manager.py, 107, INFO, Processing year 2015 for ticker CM.
# 2026-01-21 10:44:30,830, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CM\CM_2015
# 2026-01-21 10:44:30,862, data_manager.py, 107, INFO, Processing year 2016 for ticker CM.
# 2026-01-21 10:44:30,863, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CM\CM_2016
# 2026-01-21 10:44:30,901, data_manager.py, 107, INFO, Processing year 2017 for ticker CM.
# 2026-01-21 10:44:30,907, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CM\CM_2017
# 2026-01-21 10:44:30,946, data_manager.py, 107, INFO, Processing year 2018 for ticker CM.
# 2026-01-21 10:44:30,952, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CM\CM_2018
# 2026-01-21 10:44:30,990, data_manager.py, 107, INFO, Processing year 2019 for ticker CM.
# 2026-01-21 10:44:30,996, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CM\CM_2019
# 2026-01-21 10:44:31,029, data_manager.py, 107, INFO, Processing year 2020 for ticker CM.
# 2026-01-21 10:44:31,034, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CM\CM_2020
# 2026-01-21 10:44:31,066, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\HEAR.csv
# 2026-01-21 10:44:31,066, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\HEAR.csv
# 2026-01-21 10:44:31,113, data_manager.py, 101, INFO, Saving data by year
# 2026-01-21 10:44:31,114, data_manager.py, 103, INFO, Processing ticker: HEAR
# 2026-01-21 10:44:31,117, data_manager.py, 107, INFO, Processing year 2010 for ticker HEAR.
# 2026-01-21 10:44:31,122, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HEAR\HEAR_2010
# 2026-01-21 10:44:31,144, data_manager.py, 107, INFO, Processing year 2011 for ticker HEAR.
# 2026-01-21 10:44:31,160, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HEAR\HEAR_2011
# 2026-01-21 10:44:31,192, data_manager.py, 107, INFO, Processing year 2012 for ticker HEAR.
# 2026-01-21 10:44:31,200, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HEAR\HEAR_2012
# 2026-01-21 10:44:31,233, data_manager.py, 107, INFO, Processing year 2013 for ticker HEAR.
# 2026-01-21 10:44:31,238, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HEAR\HEAR_2013
# 2026-01-21 10:44:31,272, data_manager.py, 107, INFO, Processing year 2014 for ticker HEAR.
# 2026-01-21 10:44:31,276, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HEAR\HEAR_2014
# 2026-01-21 10:44:31,305, data_manager.py, 107, INFO, Processing year 2015 for ticker HEAR.
# 2026-01-21 10:44:31,310, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HEAR\HEAR_2015
# 2026-01-21 10:44:31,342, data_manager.py, 107, INFO, Processing year 2016 for ticker HEAR.
# 2026-01-21 10:44:31,347, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HEAR\HEAR_2016
# 2026-01-21 10:44:31,376, data_manager.py, 107, INFO, Processing year 2017 for ticker HEAR.
# 2026-01-21 10:44:31,380, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HEAR\HEAR_2017
# 2026-01-21 10:44:31,411, data_manager.py, 107, INFO, Processing year 2018 for ticker HEAR.
# 2026-01-21 10:44:31,415, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HEAR\HEAR_2018
# 2026-01-21 10:44:31,449, data_manager.py, 107, INFO, Processing year 2019 for ticker HEAR.
# 2026-01-21 10:44:31,455, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HEAR\HEAR_2019
# 2026-01-21 10:44:31,491, data_manager.py, 107, INFO, Processing year 2020 for ticker HEAR.
# 2026-01-21 10:44:31,496, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/HEAR\HEAR_2020
# 2026-01-21 10:44:31,526, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\PGR.csv
# 2026-01-21 10:44:31,528, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv\stocks\PGR.csv
# 2026-01-21 10:44:31,582, data_manager.py, 101, INFO, Saving data by year
# 2026-01-21 10:44:31,584, data_manager.py, 103, INFO, Processing ticker: PGR
# 2026-01-21 10:44:31,594, data_manager.py, 107, INFO, Processing year 1980 for ticker PGR.
# 2026-01-21 10:44:31,599, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PGR\PGR_1980
# 2026-01-21 10:44:31,632, data_manager.py, 107, INFO, Processing year 1981 for ticker PGR.
# 2026-01-21 10:44:31,641, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PGR\PGR_1981
# 2026-01-21 10:44:31,703, data_manager.py, 107, INFO, Processing year 1982 for ticker PGR.
# 2026-01-21 10:44:31,712, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PGR\PGR_1982
# 2026-01-21 10:44:31,758, data_manager.py, 107, INFO, Processing year 1983 for ticker PGR.
# 2026-01-21 10:44:31,765, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PGR\PGR_1983
# 2026-01-21 10:44:31,810, data_manager.py, 107, INFO, Processing year 1984 for ticker PGR.
# 2026-01-21 10:44:31,816, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PGR\PGR_1984
# 2026-01-21 10:44:31,842, data_manager.py, 107, INFO, Processing year 1985 for ticker PGR.
# 2026-01-21 10:44:31,858, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PGR\PGR_1985
# 2026-01-21 10:44:31,906, data_manager.py, 107, INFO, Processing year 1986 for ticker PGR.
# 2026-01-21 10:44:31,913, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PGR\PGR_1986
# 2026-01-21 10:44:31,955, data_manager.py, 107, INFO, Processing year 1987 for ticker PGR.
# 2026-01-21 10:44:31,964, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PGR\PGR_1987
# 2026-01-21 10:44:32,017, data_manager.py, 107, INFO, Processing year 1988 for ticker PGR.
# 2026-01-21 10:44:32,026, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PGR\PGR_1988
# 2026-01-21 10:44:32,074, data_manager.py, 107, INFO, Processing year 1989 for ticker PGR.
# 2026-01-21 10:44:32,080, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PGR\PGR_1989
# 2026-01-21 10:44:32,119, data_manager.py, 107, INFO, Processing year 1990 for ticker PGR.
# 2026-01-21 10:44:32,127, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PGR\PGR_1990
# 2026-01-21 10:44:32,165, data_manager.py, 107, INFO, Processing year 1991 for ticker PGR.
# 2026-01-21 10:44:32,169, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PGR\PGR_1991
# 2026-01-21 10:44:32,209, data_manager.py, 107, INFO, Processing year 1992 for ticker PGR.
# 2026-01-21 10:44:32,215, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PGR\PGR_1992
# 2026-01-21 10:44:32,257, data_manager.py, 107, INFO, Processing year 1993 for ticker PGR.
# 2026-01-21 10:44:32,262, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PGR\PGR_1993
# 2026-01-21 10:44:32,302, data_manager.py, 107, INFO, Processing year 1994 for ticker PGR.
# 2026-01-21 10:44:32,308, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PGR\PGR_1994
# 2026-01-21 10:44:32,344, data_manager.py, 107, INFO, Processing year 1995 for ticker PGR.
# 2026-01-21 10:44:32,350, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PGR\PGR_1995
# 2026-01-21 10:44:32,400, data_manager.py, 107, INFO, Processing year 1996 for ticker PGR.
# 2026-01-21 10:44:32,409, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PGR\PGR_1996
# 2026-01-21 10:44:32,476, data_manager.py, 107, INFO, Processing year 1997 for ticker PGR.
# 2026-01-21 10:44:32,481, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PGR\PGR_1997
# 2026-01-21 10:44:32,542, data_manager.py, 107, INFO, Processing year 1998 for ticker PGR.
# 2026-01-21 10:44:32,551, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PGR\PGR_1998
# 2026-01-21 10:44:32,593, data_manager.py, 107, INFO, Processing year 1999 for ticker PGR.
# 2026-01-21 10:44:32,601, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PGR\PGR_1999
# 2026-01-21 10:44:32,644, data_manager.py, 107, INFO, Processing year 2000 for ticker PGR.
# 2026-01-21 10:44:32,644, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PGR\PGR_2000
# 2026-01-21 10:44:32,694, data_manager.py, 107, INFO, Processing year 2001 for ticker PGR.
# 2026-01-21 10:44:32,701, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PGR\PGR_2001
# 2026-01-21 10:44:32,743, data_manager.py, 107, INFO, Processing year 2002 for ticker PGR.
# 2026-01-21 10:44:32,751, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PGR\PGR_2002
# 2026-01-21 10:44:32,787, data_manager.py, 107, INFO, Processing year 2003 for ticker PGR.
# 2026-01-21 10:44:32,799, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PGR\PGR_2003
# 2026-01-21 10:44:32,845, data_manager.py, 107, INFO, Processing year 2004 for ticker PGR.
# 2026-01-21 10:44:32,848, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PGR\PGR_2004
# 2026-01-21 10:44:32,899, data_manager.py, 107, INFO, Processing year 2005 for ticker PGR.
# 2026-01-21 10:44:32,909, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PGR\PGR_2005
# 2026-01-21 10:44:32,996, data_manager.py, 107, INFO, Processing year 2006 for ticker PGR.
# 2026-01-21 10:44:33,010, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PGR\PGR_2006
# 2026-01-21 10:44:33,128, data_manager.py, 107, INFO, Processing year 2007 for ticker PGR.
# 2026-01-21 10:44:33,143, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PGR\PGR_2007
# 2026-01-21 10:44:33,232, data_manager.py, 107, INFO, Processing year 2008 for ticker PGR.
# 2026-01-21 10:44:33,249, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PGR\PGR_2008
# 2026-01-21 10:44:33,347, data_manager.py, 107, INFO, Processing year 2009 for ticker PGR.
# 2026-01-21 10:44:33,365, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PGR\PGR_2009
# 2026-01-21 10:44:33,445, data_manager.py, 107, INFO, Processing year 2010 for ticker PGR.
# 2026-01-21 10:44:33,453, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PGR\PGR_2010
# 2026-01-21 10:44:33,513, data_manager.py, 107, INFO, Processing year 2011 for ticker PGR.
# 2026-01-21 10:44:33,520, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PGR\PGR_2011
# 2026-01-21 10:44:33,584, data_manager.py, 107, INFO, Processing year 2012 for ticker PGR.
# 2026-01-21 10:44:33,595, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PGR\PGR_2012
# 2026-01-21 10:44:33,653, data_manager.py, 107, INFO, Processing year 2013 for ticker PGR.
# 2026-01-21 10:44:33,663, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PGR\PGR_2013
# 2026-01-21 10:44:33,712, data_manager.py, 107, INFO, Processing year 2014 for ticker PGR.
# 2026-01-21 10:44:33,719, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PGR\PGR_2014
# 2026-01-21 10:44:33,767, data_manager.py, 107, INFO, Processing year 2015 for ticker PGR.
# 2026-01-21 10:44:33,780, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PGR\PGR_2015
# 2026-01-21 10:44:33,837, data_manager.py, 107, INFO, Processing year 2016 for ticker PGR.
# 2026-01-21 10:44:33,846, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PGR\PGR_2016
# 2026-01-21 10:44:33,897, data_manager.py, 107, INFO, Processing year 2017 for ticker PGR.
# 2026-01-21 10:44:33,905, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PGR\PGR_2017
# 2026-01-21 10:44:33,986, data_manager.py, 107, INFO, Processing year 2018 for ticker PGR.
# 2026-01-21 10:44:33,999, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PGR\PGR_2018
# 2026-01-21 10:44:34,119, data_manager.py, 107, INFO, Processing year 2019 for ticker PGR.
# 2026-01-21 10:44:34,131, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PGR\PGR_2019
# 2026-01-21 10:44:34,196, data_manager.py, 107, INFO, Processing year 2020 for ticker PGR.
# 2026-01-21 10:44:34,203, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/PGR\PGR_2020

# %% [markdown]
# Finally, add features to the data set and save to a *feature store*.

# %%
dm.featurize()
# Out:
# 2026-01-21 10:44:39,797, data_manager.py, 134, INFO, Creating features data.
# 2026-01-21 10:44:39,798, data_manager.py, 144, INFO, Loading price data from ../../05_src/data/prices/
# 2026-01-21 10:45:13,680, data_manager.py, 153, INFO, Creating features
# 2026-01-21 10:45:13,686, data_manager.py, 174, INFO, DTYPES right before returns:
# Date           object
# Open           object
# High           object
# Low            object
# Close          object
# Adj Close      object
# Volume         object
# source         object
# Year           object
# Close_lag_1    object
# dtype: object
# 2026-01-21 10:45:13,712, data_manager.py, 190, INFO, Saving features to ../../05_src/data/features/stock_features
